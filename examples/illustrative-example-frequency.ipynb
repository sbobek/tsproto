# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn import tree
from graphviz import Source
from IPython.display import display
from IPython.display import SVG

# %% [markdown]
# ## Creating synthetic dataset
# We will create a synthetic dataset with two classes. The dataset will be hard to distinguish based on statistical features, but possible with proper prototypical parts extracted.
#
# We are making it even harder, as the prototypical parts are more or less the same. They are differing in terms of frequency.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(3*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X3 = np.concatenate((x1,x2))
Y3 = np.concatenate((y1,y2))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(2*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X4 = np.concatenate((x1,x2))
Y4 = np.concatenate((y1,y2))

# %% [markdown]
# ## Generating sample cases

# %%
x = X3
proto_sin_y = Y3
proto_inversed_sin_y = Y4

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,proto_sin_y)
axes[1].plot(x,proto_inversed_sin_y)

# %% [markdown]
# ## Generating noise and augmenting signals

# %%
noise_power = .2

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_sin_y = noise + proto_sin_y

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_inversed_sin_y = noise + proto_inversed_sin_y

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,noisy_proto_sin_y[0])
axes[1].plot(x,noisy_proto_inversed_sin_y[0])
for ax in axes:
    ax.set_ylim([-2, 2])

# %%
X=np.concatenate((noisy_proto_sin_y,noisy_proto_inversed_sin_y))
Xy=np.concatenate((np.ones(len(noisy_proto_sin_y))*0,
                   np.ones(len(noisy_proto_inversed_sin_y))*1))

trainX, testX, train_y,test_y = train_test_split(X,Xy)

# %% [markdown]
# ## Model
# We will build simple DNN model (not really needed in this case, but it serves the purpose of demonstration how to deal with more complex cases)

# %%
trainX.shape
# Out:
# (150, 200)

# %%
from keras.utils import to_categorical
trainXnn = trainX.reshape(150,1,200)
train_ynn = to_categorical(train_y)
num_classes = len(np.unique(Xy))

# %%
import keras
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    #add dropout
    input_layer = keras.layers.Dropout(0.5)(input_layer)
    conv1 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(input_layer)
    #conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv1)
    #conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv2)
    #conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)



model = make_model(input_shape=trainXnn.shape[1:])

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_crossentropy"],
)
history = model.fit(
    trainXnn,
    train_ynn,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 2s 229ms/step - loss: 0.6846 - categorical_crossentropy: 0.6846 - val_loss: 0.6619 - val_categorical_crossentropy: 0.6619 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 113ms/step - loss: 0.6455 - categorical_crossentropy: 0.6455 - val_loss: 0.5991 - val_categorical_crossentropy: 0.5991 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5692 - categorical_crossentropy: 0.5692 - val_loss: 0.4841 - val_categorical_crossentropy: 0.4841 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 1s 129ms/step - loss: 0.4381 - categorical_crossentropy: 0.4381 - val_loss: 0.3192 - val_categorical_crossentropy: 0.3192 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 108ms/step - loss: 0.2728 - categorical_crossentropy: 0.2728 - val_loss: 0.1573 - val_categorical_crossentropy: 0.1573 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 87ms/step - loss: 0.1227 - categorical_crossentropy: 0.1227 - val_loss: 0.0517 - val_categorical_crossentropy: 0.0517 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 130ms/step - loss: 0.0379 - categorical_crossentropy: 0.0379 - val_loss: 0.0122 - val_categorical_crossentropy: 0.0122 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 1s 156ms/step - loss: 0.0087 - categorical_crossentropy: 0.0087 - val_loss: 0.0028 - val_categorical_crossentropy: 0.0028 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0020 - categorical_crossentropy: 0.0020 - val_loss: 7.7350e-04 - val_categorical_crossentropy: 7.7350e-04 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 0s 102ms/step - loss: 5.5619e-04 - categorical_crossentropy: 5.5619e-04 - val_loss: 2.7931e-04 - val_categorical_crossentropy: 2.7931e-04 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2.1471e-04 - categorical_crossentropy: 2.1471e-04 - val_loss: 1.2993e-04 - val_categorical_crossentropy: 1.2993e-04 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 126ms/step - loss: 1.0405e-04 - categorical_crossentropy: 1.0405e-04 - val_loss: 7.4173e-05 - val_categorical_crossentropy: 7.4173e-05 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 0s 104ms/step - loss: 6.2197e-05 - categorical_crossentropy: 6.2197e-05 - val_loss: 4.9582e-05 - val_categorical_crossentropy: 4.9582e-05 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 115ms/step - loss: 4.2976e-05 - categorical_crossentropy: 4.2976e-05 - val_loss: 3.7224e-05 - val_categorical_crossentropy: 3.7224e-05 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 107ms/step - loss: 3.3095e-05 - categorical_crossentropy: 3.3095e-05 - val_loss: 3.0410e-05 - val_categorical_crossentropy: 3.0410e-05 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 90ms/step - loss: 2.7599e-05 - categorical_crossentropy: 2.7599e-05 - val_loss: 2.6424e-05 - val_categorical_crossentropy: 2.6424e-05 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 77ms/step - loss: 2.4289e-05 - categorical_crossentropy: 2.4289e-05 - val_loss: 2.3953e-05 - val_categorical_crossentropy: 2.3953e-05 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 130ms/step - loss: 2.2257e-05 - categorical_crossentropy: 2.2257e-05 - val_loss: 2.2324e-05 - val_categorical_crossentropy: 2.2324e-05 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 117ms/step - loss: 2.0904e-05 - categorical_crossentropy: 2.0904e-05 - val_loss: 2.1207e-05 - val_categorical_crossentropy: 2.1207e-05 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9969e-05 - categorical_crossentropy: 1.9969e-05 - val_loss: 2.0452e-05 - val_categorical_crossentropy: 2.0452e-05 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 110ms/step - loss: 1.9309e-05 - categorical_crossentropy: 1.9309e-05 - val_loss: 1.9876e-05 - val_categorical_crossentropy: 1.9876e-05 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 119ms/step - loss: 1.8833e-05 - categorical_crossentropy: 1.8833e-05 - val_loss: 1.9455e-05 - val_categorical_crossentropy: 1.9455e-05 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 114ms/step - loss: 1.8472e-05 - categorical_crossentropy: 1.8472e-05 - val_loss: 1.9129e-05 - val_categorical_crossentropy: 1.9129e-05 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 142ms/step - loss: 1.8186e-05 - categorical_crossentropy: 1.8186e-05 - val_loss: 1.8863e-05 - val_categorical_crossentropy: 1.8863e-05 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 1s 155ms/step - loss: 1.7953e-05 - categorical_crossentropy: 1.7953e-05 - val_loss: 1.8608e-05 - val_categorical_crossentropy: 1.8608e-05 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.7748e-05 - categorical_crossentropy: 1.7748e-05 - val_loss: 1.8402e-05 - val_categorical_crossentropy: 1.8402e-05 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 99ms/step - loss: 1.7582e-05 - categorical_crossentropy: 1.7582e-05 - val_loss: 1.8235e-05 - val_categorical_crossentropy: 1.8235e-05 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.7424e-05 - categorical_crossentropy: 1.7424e-05 - val_loss: 1.8040e-05 - val_categorical_crossentropy: 1.8040e-05 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.7265e-05 - categorical_crossentropy: 1.7265e-05 - val_loss: 1.7901e-05 - val_categorical_crossentropy: 1.7901e-05 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.7127e-05 - categorical_crossentropy: 1.7127e-05 - val_loss: 1.7734e-05 - val_categorical_crossentropy: 1.7734e-05 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.6998e-05 - categorical_crossentropy: 1.6998e-05 - val_loss: 1.7603e-05 - val_categorical_crossentropy: 1.7603e-05 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.6875e-05 - categorical_crossentropy: 1.6875e-05 - val_loss: 1.7476e-05 - val_categorical_crossentropy: 1.7476e-05 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.6757e-05 - categorical_crossentropy: 1.6757e-05 - val_loss: 1.7341e-05 - val_categorical_crossentropy: 1.7341e-05 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.6647e-05 - categorical_crossentropy: 1.6647e-05 - val_loss: 1.7210e-05 - val_categorical_crossentropy: 1.7210e-05 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.6525e-05 - categorical_crossentropy: 1.6525e-05 - val_loss: 1.7079e-05 - val_categorical_crossentropy: 1.7079e-05 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 1s 140ms/step - loss: 1.6415e-05 - categorical_crossentropy: 1.6415e-05 - val_loss: 1.6963e-05 - val_categorical_crossentropy: 1.6963e-05 - lr: 0.0010
# Epoch 37/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.6321e-05 - categorical_crossentropy: 1.6321e-05 - val_loss: 1.6892e-05 - val_categorical_crossentropy: 1.6892e-05 - lr: 5.0000e-04
# Epoch 38/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1.6261e-05 - categorical_crossentropy: 1.6261e-05 - val_loss: 1.6832e-05 - val_categorical_crossentropy: 1.6832e-05 - lr: 5.0000e-04
# Epoch 39/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.6214e-05 - categorical_crossentropy: 1.6214e-05 - val_loss: 1.6781e-05 - val_categorical_crossentropy: 1.6781e-05 - lr: 5.0000e-04
# Epoch 40/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.6154e-05 - categorical_crossentropy: 1.6154e-05 - val_loss: 1.6701e-05 - val_categorical_crossentropy: 1.6701e-05 - lr: 5.0000e-04
# Epoch 41/500
# 4/4 [==============================] - 0s 115ms/step - loss: 1.6102e-05 - categorical_crossentropy: 1.6102e-05 - val_loss: 1.6645e-05 - val_categorical_crossentropy: 1.6645e-05 - lr: 5.0000e-04
# Epoch 42/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.6043e-05 - categorical_crossentropy: 1.6043e-05 - val_loss: 1.6590e-05 - val_categorical_crossentropy: 1.6590e-05 - lr: 5.0000e-04
# Epoch 43/500
# 4/4 [==============================] - 0s 127ms/step - loss: 1.5990e-05 - categorical_crossentropy: 1.5990e-05 - val_loss: 1.6526e-05 - val_categorical_crossentropy: 1.6526e-05 - lr: 5.0000e-04
# Epoch 44/500
# 4/4 [==============================] - 0s 109ms/step - loss: 1.5932e-05 - categorical_crossentropy: 1.5932e-05 - val_loss: 1.6455e-05 - val_categorical_crossentropy: 1.6455e-05 - lr: 5.0000e-04
# Epoch 45/500
# 4/4 [==============================] - 0s 85ms/step - loss: 1.5877e-05 - categorical_crossentropy: 1.5877e-05 - val_loss: 1.6403e-05 - val_categorical_crossentropy: 1.6403e-05 - lr: 5.0000e-04
# Epoch 46/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.5810e-05 - categorical_crossentropy: 1.5810e-05 - val_loss: 1.6343e-05 - val_categorical_crossentropy: 1.6343e-05 - lr: 5.0000e-04
# Epoch 47/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.5763e-05 - categorical_crossentropy: 1.5763e-05 - val_loss: 1.6268e-05 - val_categorical_crossentropy: 1.6268e-05 - lr: 5.0000e-04
# Epoch 48/500
# 4/4 [==============================] - 0s 119ms/step - loss: 1.5707e-05 - categorical_crossentropy: 1.5707e-05 - val_loss: 1.6216e-05 - val_categorical_crossentropy: 1.6216e-05 - lr: 5.0000e-04
# Epoch 49/500
# 4/4 [==============================] - 1s 142ms/step - loss: 1.5652e-05 - categorical_crossentropy: 1.5652e-05 - val_loss: 1.6153e-05 - val_categorical_crossentropy: 1.6153e-05 - lr: 5.0000e-04
# Epoch 50/500
# 4/4 [==============================] - 0s 124ms/step - loss: 1.5591e-05 - categorical_crossentropy: 1.5591e-05 - val_loss: 1.6101e-05 - val_categorical_crossentropy: 1.6101e-05 - lr: 5.0000e-04
# Epoch 51/500
# 4/4 [==============================] - 0s 111ms/step - loss: 1.5538e-05 - categorical_crossentropy: 1.5538e-05 - val_loss: 1.6030e-05 - val_categorical_crossentropy: 1.6030e-05 - lr: 5.0000e-04
# Epoch 52/500
# 4/4 [==============================] - 0s 107ms/step - loss: 1.5481e-05 - categorical_crossentropy: 1.5481e-05 - val_loss: 1.5970e-05 - val_categorical_crossentropy: 1.5970e-05 - lr: 5.0000e-04
# Epoch 53/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.5421e-05 - categorical_crossentropy: 1.5421e-05 - val_loss: 1.5914e-05 - val_categorical_crossentropy: 1.5914e-05 - lr: 5.0000e-04
# Epoch 54/500
# 4/4 [==============================] - 0s 119ms/step - loss: 1.5367e-05 - categorical_crossentropy: 1.5367e-05 - val_loss: 1.5839e-05 - val_categorical_crossentropy: 1.5839e-05 - lr: 5.0000e-04
# Epoch 55/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.5309e-05 - categorical_crossentropy: 1.5309e-05 - val_loss: 1.5795e-05 - val_categorical_crossentropy: 1.5795e-05 - lr: 5.0000e-04
# Epoch 56/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.5250e-05 - categorical_crossentropy: 1.5250e-05 - val_loss: 1.5728e-05 - val_categorical_crossentropy: 1.5728e-05 - lr: 5.0000e-04
# Epoch 57/500
# 4/4 [==============================] - 0s 142ms/step - loss: 1.5211e-05 - categorical_crossentropy: 1.5211e-05 - val_loss: 1.5684e-05 - val_categorical_crossentropy: 1.5684e-05 - lr: 2.5000e-04
# Epoch 58/500
# 4/4 [==============================] - 0s 96ms/step - loss: 1.5172e-05 - categorical_crossentropy: 1.5172e-05 - val_loss: 1.5660e-05 - val_categorical_crossentropy: 1.5660e-05 - lr: 2.5000e-04
# Epoch 59/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.5147e-05 - categorical_crossentropy: 1.5147e-05 - val_loss: 1.5636e-05 - val_categorical_crossentropy: 1.5636e-05 - lr: 2.5000e-04
# Epoch 60/500
# 4/4 [==============================] - 0s 73ms/step - loss: 1.5121e-05 - categorical_crossentropy: 1.5121e-05 - val_loss: 1.5604e-05 - val_categorical_crossentropy: 1.5604e-05 - lr: 2.5000e-04
# Epoch 61/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.5093e-05 - categorical_crossentropy: 1.5093e-05 - val_loss: 1.5581e-05 - val_categorical_crossentropy: 1.5581e-05 - lr: 2.5000e-04
# Epoch 62/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.5064e-05 - categorical_crossentropy: 1.5064e-05 - val_loss: 1.5541e-05 - val_categorical_crossentropy: 1.5541e-05 - lr: 2.5000e-04
# Epoch 63/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.5032e-05 - categorical_crossentropy: 1.5032e-05 - val_loss: 1.5493e-05 - val_categorical_crossentropy: 1.5493e-05 - lr: 2.5000e-04
# Epoch 64/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.5002e-05 - categorical_crossentropy: 1.5002e-05 - val_loss: 1.5469e-05 - val_categorical_crossentropy: 1.5469e-05 - lr: 2.5000e-04
# Epoch 65/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.4977e-05 - categorical_crossentropy: 1.4977e-05 - val_loss: 1.5457e-05 - val_categorical_crossentropy: 1.5457e-05 - lr: 2.5000e-04
# Epoch 66/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.4944e-05 - categorical_crossentropy: 1.4944e-05 - val_loss: 1.5418e-05 - val_categorical_crossentropy: 1.5418e-05 - lr: 2.5000e-04
# Epoch 67/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.4915e-05 - categorical_crossentropy: 1.4915e-05 - val_loss: 1.5378e-05 - val_categorical_crossentropy: 1.5378e-05 - lr: 2.5000e-04
# Epoch 68/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.4888e-05 - categorical_crossentropy: 1.4888e-05 - val_loss: 1.5350e-05 - val_categorical_crossentropy: 1.5350e-05 - lr: 2.5000e-04
# Epoch 69/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.4856e-05 - categorical_crossentropy: 1.4856e-05 - val_loss: 1.5314e-05 - val_categorical_crossentropy: 1.5314e-05 - lr: 2.5000e-04
# Epoch 70/500
# 4/4 [==============================] - 0s 75ms/step - loss: 1.4827e-05 - categorical_crossentropy: 1.4827e-05 - val_loss: 1.5286e-05 - val_categorical_crossentropy: 1.5286e-05 - lr: 2.5000e-04
# Epoch 71/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.4797e-05 - categorical_crossentropy: 1.4797e-05 - val_loss: 1.5259e-05 - val_categorical_crossentropy: 1.5259e-05 - lr: 2.5000e-04
# Epoch 72/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.4769e-05 - categorical_crossentropy: 1.4769e-05 - val_loss: 1.5227e-05 - val_categorical_crossentropy: 1.5227e-05 - lr: 2.5000e-04
# Epoch 73/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.4735e-05 - categorical_crossentropy: 1.4735e-05 - val_loss: 1.5187e-05 - val_categorical_crossentropy: 1.5187e-05 - lr: 2.5000e-04
# Epoch 74/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.4707e-05 - categorical_crossentropy: 1.4707e-05 - val_loss: 1.5143e-05 - val_categorical_crossentropy: 1.5143e-05 - lr: 2.5000e-04
# Epoch 75/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.4677e-05 - categorical_crossentropy: 1.4677e-05 - val_loss: 1.5124e-05 - val_categorical_crossentropy: 1.5124e-05 - lr: 2.5000e-04
# Epoch 76/500
# 4/4 [==============================] - 0s 72ms/step - loss: 1.4646e-05 - categorical_crossentropy: 1.4646e-05 - val_loss: 1.5104e-05 - val_categorical_crossentropy: 1.5104e-05 - lr: 2.5000e-04
# Epoch 77/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.4619e-05 - categorical_crossentropy: 1.4619e-05 - val_loss: 1.5076e-05 - val_categorical_crossentropy: 1.5076e-05 - lr: 1.2500e-04
# Epoch 78/500
# 4/4 [==============================] - 0s 56ms/step - loss: 1.4609e-05 - categorical_crossentropy: 1.4609e-05 - val_loss: 1.5056e-05 - val_categorical_crossentropy: 1.5056e-05 - lr: 1.2500e-04
# Epoch 79/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.4591e-05 - categorical_crossentropy: 1.4591e-05 - val_loss: 1.5048e-05 - val_categorical_crossentropy: 1.5048e-05 - lr: 1.2500e-04
# Epoch 80/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.4577e-05 - categorical_crossentropy: 1.4577e-05 - val_loss: 1.5028e-05 - val_categorical_crossentropy: 1.5028e-05 - lr: 1.2500e-04
# Epoch 81/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.4558e-05 - categorical_crossentropy: 1.4558e-05 - val_loss: 1.5012e-05 - val_categorical_crossentropy: 1.5012e-05 - lr: 1.2500e-04
# Epoch 82/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.4543e-05 - categorical_crossentropy: 1.4543e-05 - val_loss: 1.5004e-05 - val_categorical_crossentropy: 1.5004e-05 - lr: 1.2500e-04
# Epoch 83/500
# 4/4 [==============================] - 0s 91ms/step - loss: 1.4532e-05 - categorical_crossentropy: 1.4532e-05 - val_loss: 1.4969e-05 - val_categorical_crossentropy: 1.4969e-05 - lr: 1.2500e-04
# Epoch 84/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.4514e-05 - categorical_crossentropy: 1.4514e-05 - val_loss: 1.4953e-05 - val_categorical_crossentropy: 1.4953e-05 - lr: 1.2500e-04
# Epoch 85/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1.4495e-05 - categorical_crossentropy: 1.4495e-05 - val_loss: 1.4949e-05 - val_categorical_crossentropy: 1.4949e-05 - lr: 1.2500e-04
# Epoch 86/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.4481e-05 - categorical_crossentropy: 1.4481e-05 - val_loss: 1.4925e-05 - val_categorical_crossentropy: 1.4925e-05 - lr: 1.2500e-04
# Epoch 87/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.4466e-05 - categorical_crossentropy: 1.4466e-05 - val_loss: 1.4909e-05 - val_categorical_crossentropy: 1.4909e-05 - lr: 1.2500e-04
# Epoch 88/500
# 4/4 [==============================] - 1s 158ms/step - loss: 1.4452e-05 - categorical_crossentropy: 1.4452e-05 - val_loss: 1.4901e-05 - val_categorical_crossentropy: 1.4901e-05 - lr: 1.2500e-04
# Epoch 89/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.4435e-05 - categorical_crossentropy: 1.4435e-05 - val_loss: 1.4877e-05 - val_categorical_crossentropy: 1.4877e-05 - lr: 1.2500e-04
# Epoch 90/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.4415e-05 - categorical_crossentropy: 1.4415e-05 - val_loss: 1.4857e-05 - val_categorical_crossentropy: 1.4857e-05 - lr: 1.2500e-04
# Epoch 91/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.4403e-05 - categorical_crossentropy: 1.4403e-05 - val_loss: 1.4837e-05 - val_categorical_crossentropy: 1.4837e-05 - lr: 1.2500e-04
# Epoch 92/500
# 4/4 [==============================] - 0s 64ms/step - loss: 1.4388e-05 - categorical_crossentropy: 1.4388e-05 - val_loss: 1.4822e-05 - val_categorical_crossentropy: 1.4822e-05 - lr: 1.2500e-04
# Epoch 93/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.4372e-05 - categorical_crossentropy: 1.4372e-05 - val_loss: 1.4818e-05 - val_categorical_crossentropy: 1.4818e-05 - lr: 1.2500e-04
# Epoch 94/500
# 4/4 [==============================] - 0s 75ms/step - loss: 1.4354e-05 - categorical_crossentropy: 1.4354e-05 - val_loss: 1.4802e-05 - val_categorical_crossentropy: 1.4802e-05 - lr: 1.2500e-04
# Epoch 95/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1.4333e-05 - categorical_crossentropy: 1.4333e-05 - val_loss: 1.4774e-05 - val_categorical_crossentropy: 1.4774e-05 - lr: 1.2500e-04
# Epoch 96/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.4316e-05 - categorical_crossentropy: 1.4316e-05 - val_loss: 1.4750e-05 - val_categorical_crossentropy: 1.4750e-05 - lr: 1.2500e-04
# Epoch 97/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.4302e-05 - categorical_crossentropy: 1.4302e-05 - val_loss: 1.4734e-05 - val_categorical_crossentropy: 1.4734e-05 - lr: 1.0000e-04
# Epoch 98/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.4292e-05 - categorical_crossentropy: 1.4292e-05 - val_loss: 1.4722e-05 - val_categorical_crossentropy: 1.4722e-05 - lr: 1.0000e-04
# Epoch 99/500
# 4/4 [==============================] - 0s 114ms/step - loss: 1.4278e-05 - categorical_crossentropy: 1.4278e-05 - val_loss: 1.4710e-05 - val_categorical_crossentropy: 1.4710e-05 - lr: 1.0000e-04
# Epoch 100/500
# 4/4 [==============================] - 0s 113ms/step - loss: 1.4267e-05 - categorical_crossentropy: 1.4267e-05 - val_loss: 1.4702e-05 - val_categorical_crossentropy: 1.4702e-05 - lr: 1.0000e-04
# Epoch 101/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1.4259e-05 - categorical_crossentropy: 1.4259e-05 - val_loss: 1.4686e-05 - val_categorical_crossentropy: 1.4686e-05 - lr: 1.0000e-04
# Epoch 102/500
# 4/4 [==============================] - 0s 116ms/step - loss: 1.4233e-05 - categorical_crossentropy: 1.4233e-05 - val_loss: 1.4675e-05 - val_categorical_crossentropy: 1.4675e-05 - lr: 1.0000e-04
# Epoch 103/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.4219e-05 - categorical_crossentropy: 1.4219e-05 - val_loss: 1.4655e-05 - val_categorical_crossentropy: 1.4655e-05 - lr: 1.0000e-04
# Epoch 104/500
# 4/4 [==============================] - 1s 147ms/step - loss: 1.4211e-05 - categorical_crossentropy: 1.4211e-05 - val_loss: 1.4635e-05 - val_categorical_crossentropy: 1.4635e-05 - lr: 1.0000e-04
# Epoch 105/500
# 4/4 [==============================] - 0s 59ms/step - loss: 1.4199e-05 - categorical_crossentropy: 1.4199e-05 - val_loss: 1.4635e-05 - val_categorical_crossentropy: 1.4635e-05 - lr: 1.0000e-04
# Epoch 106/500
# 4/4 [==============================] - 0s 118ms/step - loss: 1.4183e-05 - categorical_crossentropy: 1.4183e-05 - val_loss: 1.4611e-05 - val_categorical_crossentropy: 1.4611e-05 - lr: 1.0000e-04
# Epoch 107/500
# 4/4 [==============================] - 0s 59ms/step - loss: 1.4173e-05 - categorical_crossentropy: 1.4173e-05 - val_loss: 1.4595e-05 - val_categorical_crossentropy: 1.4595e-05 - lr: 1.0000e-04
# Epoch 108/500
# 4/4 [==============================] - 0s 98ms/step - loss: 1.4157e-05 - categorical_crossentropy: 1.4157e-05 - val_loss: 1.4591e-05 - val_categorical_crossentropy: 1.4591e-05 - lr: 1.0000e-04
# Epoch 109/500
# 4/4 [==============================] - 0s 122ms/step - loss: 1.4141e-05 - categorical_crossentropy: 1.4141e-05 - val_loss: 1.4571e-05 - val_categorical_crossentropy: 1.4571e-05 - lr: 1.0000e-04
# Epoch 110/500
# 4/4 [==============================] - 0s 123ms/step - loss: 1.4126e-05 - categorical_crossentropy: 1.4126e-05 - val_loss: 1.4555e-05 - val_categorical_crossentropy: 1.4555e-05 - lr: 1.0000e-04
# Epoch 111/500
# 4/4 [==============================] - 0s 126ms/step - loss: 1.4111e-05 - categorical_crossentropy: 1.4111e-05 - val_loss: 1.4535e-05 - val_categorical_crossentropy: 1.4535e-05 - lr: 1.0000e-04
# Epoch 112/500
# 4/4 [==============================] - 0s 99ms/step - loss: 1.4102e-05 - categorical_crossentropy: 1.4102e-05 - val_loss: 1.4520e-05 - val_categorical_crossentropy: 1.4520e-05 - lr: 1.0000e-04
# Epoch 113/500
# 4/4 [==============================] - 0s 111ms/step - loss: 1.4082e-05 - categorical_crossentropy: 1.4082e-05 - val_loss: 1.4508e-05 - val_categorical_crossentropy: 1.4508e-05 - lr: 1.0000e-04
# Epoch 114/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.4070e-05 - categorical_crossentropy: 1.4070e-05 - val_loss: 1.4488e-05 - val_categorical_crossentropy: 1.4488e-05 - lr: 1.0000e-04
# Epoch 115/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.4062e-05 - categorical_crossentropy: 1.4062e-05 - val_loss: 1.4476e-05 - val_categorical_crossentropy: 1.4476e-05 - lr: 1.0000e-04
# Epoch 116/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.4040e-05 - categorical_crossentropy: 1.4040e-05 - val_loss: 1.4460e-05 - val_categorical_crossentropy: 1.4460e-05 - lr: 1.0000e-04
# Epoch 117/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.4027e-05 - categorical_crossentropy: 1.4027e-05 - val_loss: 1.4448e-05 - val_categorical_crossentropy: 1.4448e-05 - lr: 1.0000e-04
# Epoch 118/500
# 4/4 [==============================] - 0s 115ms/step - loss: 1.4016e-05 - categorical_crossentropy: 1.4016e-05 - val_loss: 1.4440e-05 - val_categorical_crossentropy: 1.4440e-05 - lr: 1.0000e-04
# Epoch 119/500
# 4/4 [==============================] - 0s 133ms/step - loss: 1.4005e-05 - categorical_crossentropy: 1.4005e-05 - val_loss: 1.4420e-05 - val_categorical_crossentropy: 1.4420e-05 - lr: 1.0000e-04
# Epoch 120/500
# 4/4 [==============================] - 1s 152ms/step - loss: 1.3988e-05 - categorical_crossentropy: 1.3988e-05 - val_loss: 1.4400e-05 - val_categorical_crossentropy: 1.4400e-05 - lr: 1.0000e-04
# Epoch 121/500
# 4/4 [==============================] - 0s 134ms/step - loss: 1.3973e-05 - categorical_crossentropy: 1.3973e-05 - val_loss: 1.4392e-05 - val_categorical_crossentropy: 1.4392e-05 - lr: 1.0000e-04
# Epoch 122/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.3954e-05 - categorical_crossentropy: 1.3954e-05 - val_loss: 1.4381e-05 - val_categorical_crossentropy: 1.4381e-05 - lr: 1.0000e-04
# Epoch 123/500
# 4/4 [==============================] - 0s 119ms/step - loss: 1.3944e-05 - categorical_crossentropy: 1.3944e-05 - val_loss: 1.4365e-05 - val_categorical_crossentropy: 1.4365e-05 - lr: 1.0000e-04
# Epoch 124/500
# 4/4 [==============================] - 0s 133ms/step - loss: 1.3926e-05 - categorical_crossentropy: 1.3926e-05 - val_loss: 1.4349e-05 - val_categorical_crossentropy: 1.4349e-05 - lr: 1.0000e-04
# Epoch 125/500
# 4/4 [==============================] - 0s 131ms/step - loss: 1.3915e-05 - categorical_crossentropy: 1.3915e-05 - val_loss: 1.4321e-05 - val_categorical_crossentropy: 1.4321e-05 - lr: 1.0000e-04
# Epoch 126/500
# 4/4 [==============================] - 0s 128ms/step - loss: 1.3898e-05 - categorical_crossentropy: 1.3898e-05 - val_loss: 1.4297e-05 - val_categorical_crossentropy: 1.4297e-05 - lr: 1.0000e-04
# Epoch 127/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.3883e-05 - categorical_crossentropy: 1.3883e-05 - val_loss: 1.4293e-05 - val_categorical_crossentropy: 1.4293e-05 - lr: 1.0000e-04
# Epoch 128/500
# 4/4 [==============================] - 0s 144ms/step - loss: 1.3868e-05 - categorical_crossentropy: 1.3868e-05 - val_loss: 1.4281e-05 - val_categorical_crossentropy: 1.4281e-05 - lr: 1.0000e-04
# Epoch 129/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.3860e-05 - categorical_crossentropy: 1.3860e-05 - val_loss: 1.4265e-05 - val_categorical_crossentropy: 1.4265e-05 - lr: 1.0000e-04
# Epoch 130/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.3842e-05 - categorical_crossentropy: 1.3842e-05 - val_loss: 1.4261e-05 - val_categorical_crossentropy: 1.4261e-05 - lr: 1.0000e-04
# Epoch 131/500
# 4/4 [==============================] - 0s 57ms/step - loss: 1.3832e-05 - categorical_crossentropy: 1.3832e-05 - val_loss: 1.4237e-05 - val_categorical_crossentropy: 1.4237e-05 - lr: 1.0000e-04
# Epoch 132/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.3816e-05 - categorical_crossentropy: 1.3816e-05 - val_loss: 1.4222e-05 - val_categorical_crossentropy: 1.4222e-05 - lr: 1.0000e-04
# Epoch 133/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.3792e-05 - categorical_crossentropy: 1.3792e-05 - val_loss: 1.4202e-05 - val_categorical_crossentropy: 1.4202e-05 - lr: 1.0000e-04
# Epoch 134/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.3775e-05 - categorical_crossentropy: 1.3775e-05 - val_loss: 1.4186e-05 - val_categorical_crossentropy: 1.4186e-05 - lr: 1.0000e-04
# Epoch 135/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.3764e-05 - categorical_crossentropy: 1.3764e-05 - val_loss: 1.4174e-05 - val_categorical_crossentropy: 1.4174e-05 - lr: 1.0000e-04
# Epoch 136/500
# 4/4 [==============================] - 0s 50ms/step - loss: 1.3752e-05 - categorical_crossentropy: 1.3752e-05 - val_loss: 1.4166e-05 - val_categorical_crossentropy: 1.4166e-05 - lr: 1.0000e-04
# Epoch 137/500
# 4/4 [==============================] - 0s 70ms/step - loss: 1.3736e-05 - categorical_crossentropy: 1.3736e-05 - val_loss: 1.4142e-05 - val_categorical_crossentropy: 1.4142e-05 - lr: 1.0000e-04
# Epoch 138/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.3723e-05 - categorical_crossentropy: 1.3723e-05 - val_loss: 1.4126e-05 - val_categorical_crossentropy: 1.4126e-05 - lr: 1.0000e-04
# Epoch 139/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.3710e-05 - categorical_crossentropy: 1.3710e-05 - val_loss: 1.4102e-05 - val_categorical_crossentropy: 1.4102e-05 - lr: 1.0000e-04
# Epoch 140/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.3694e-05 - categorical_crossentropy: 1.3694e-05 - val_loss: 1.4090e-05 - val_categorical_crossentropy: 1.4090e-05 - lr: 1.0000e-04
# Epoch 141/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.3675e-05 - categorical_crossentropy: 1.3675e-05 - val_loss: 1.4082e-05 - val_categorical_crossentropy: 1.4082e-05 - lr: 1.0000e-04
# Epoch 142/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.3661e-05 - categorical_crossentropy: 1.3661e-05 - val_loss: 1.4071e-05 - val_categorical_crossentropy: 1.4071e-05 - lr: 1.0000e-04
# Epoch 143/500
# 4/4 [==============================] - 0s 49ms/step - loss: 1.3644e-05 - categorical_crossentropy: 1.3644e-05 - val_loss: 1.4043e-05 - val_categorical_crossentropy: 1.4043e-05 - lr: 1.0000e-04
# Epoch 144/500
# 4/4 [==============================] - 0s 47ms/step - loss: 1.3630e-05 - categorical_crossentropy: 1.3630e-05 - val_loss: 1.4027e-05 - val_categorical_crossentropy: 1.4027e-05 - lr: 1.0000e-04
# Epoch 145/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.3613e-05 - categorical_crossentropy: 1.3613e-05 - val_loss: 1.4003e-05 - val_categorical_crossentropy: 1.4003e-05 - lr: 1.0000e-04
# Epoch 146/500
# 4/4 [==============================] - 0s 71ms/step - loss: 1.3603e-05 - categorical_crossentropy: 1.3603e-05 - val_loss: 1.3991e-05 - val_categorical_crossentropy: 1.3991e-05 - lr: 1.0000e-04
# Epoch 147/500
# 4/4 [==============================] - 0s 75ms/step - loss: 1.3582e-05 - categorical_crossentropy: 1.3582e-05 - val_loss: 1.3987e-05 - val_categorical_crossentropy: 1.3987e-05 - lr: 1.0000e-04
# Epoch 148/500
# 4/4 [==============================] - 0s 66ms/step - loss: 1.3569e-05 - categorical_crossentropy: 1.3569e-05 - val_loss: 1.3983e-05 - val_categorical_crossentropy: 1.3983e-05 - lr: 1.0000e-04
# Epoch 149/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.3555e-05 - categorical_crossentropy: 1.3555e-05 - val_loss: 1.3943e-05 - val_categorical_crossentropy: 1.3943e-05 - lr: 1.0000e-04
# Epoch 150/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.3539e-05 - categorical_crossentropy: 1.3539e-05 - val_loss: 1.3939e-05 - val_categorical_crossentropy: 1.3939e-05 - lr: 1.0000e-04
# Epoch 151/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.3523e-05 - categorical_crossentropy: 1.3523e-05 - val_loss: 1.3928e-05 - val_categorical_crossentropy: 1.3928e-05 - lr: 1.0000e-04
# Epoch 152/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.3508e-05 - categorical_crossentropy: 1.3508e-05 - val_loss: 1.3900e-05 - val_categorical_crossentropy: 1.3900e-05 - lr: 1.0000e-04
# Epoch 153/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.3496e-05 - categorical_crossentropy: 1.3496e-05 - val_loss: 1.3884e-05 - val_categorical_crossentropy: 1.3884e-05 - lr: 1.0000e-04
# Epoch 154/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.3474e-05 - categorical_crossentropy: 1.3474e-05 - val_loss: 1.3864e-05 - val_categorical_crossentropy: 1.3864e-05 - lr: 1.0000e-04
# Epoch 155/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.3458e-05 - categorical_crossentropy: 1.3458e-05 - val_loss: 1.3840e-05 - val_categorical_crossentropy: 1.3840e-05 - lr: 1.0000e-04
# Epoch 156/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1.3442e-05 - categorical_crossentropy: 1.3442e-05 - val_loss: 1.3832e-05 - val_categorical_crossentropy: 1.3832e-05 - lr: 1.0000e-04
# Epoch 157/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.3431e-05 - categorical_crossentropy: 1.3431e-05 - val_loss: 1.3812e-05 - val_categorical_crossentropy: 1.3812e-05 - lr: 1.0000e-04
# Epoch 158/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.3416e-05 - categorical_crossentropy: 1.3416e-05 - val_loss: 1.3800e-05 - val_categorical_crossentropy: 1.3800e-05 - lr: 1.0000e-04
# Epoch 159/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.3406e-05 - categorical_crossentropy: 1.3406e-05 - val_loss: 1.3796e-05 - val_categorical_crossentropy: 1.3796e-05 - lr: 1.0000e-04
# Epoch 160/500
# 4/4 [==============================] - 0s 66ms/step - loss: 1.3385e-05 - categorical_crossentropy: 1.3385e-05 - val_loss: 1.3777e-05 - val_categorical_crossentropy: 1.3777e-05 - lr: 1.0000e-04
# Epoch 161/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.3360e-05 - categorical_crossentropy: 1.3360e-05 - val_loss: 1.3761e-05 - val_categorical_crossentropy: 1.3761e-05 - lr: 1.0000e-04
# Epoch 162/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.3348e-05 - categorical_crossentropy: 1.3348e-05 - val_loss: 1.3741e-05 - val_categorical_crossentropy: 1.3741e-05 - lr: 1.0000e-04
# Epoch 163/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.3337e-05 - categorical_crossentropy: 1.3337e-05 - val_loss: 1.3717e-05 - val_categorical_crossentropy: 1.3717e-05 - lr: 1.0000e-04
# Epoch 164/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.3319e-05 - categorical_crossentropy: 1.3319e-05 - val_loss: 1.3689e-05 - val_categorical_crossentropy: 1.3689e-05 - lr: 1.0000e-04
# Epoch 165/500
# 4/4 [==============================] - 0s 72ms/step - loss: 1.3307e-05 - categorical_crossentropy: 1.3307e-05 - val_loss: 1.3677e-05 - val_categorical_crossentropy: 1.3677e-05 - lr: 1.0000e-04
# Epoch 166/500
# 4/4 [==============================] - 0s 66ms/step - loss: 1.3291e-05 - categorical_crossentropy: 1.3291e-05 - val_loss: 1.3665e-05 - val_categorical_crossentropy: 1.3665e-05 - lr: 1.0000e-04
# Epoch 167/500
# 4/4 [==============================] - 0s 50ms/step - loss: 1.3269e-05 - categorical_crossentropy: 1.3269e-05 - val_loss: 1.3653e-05 - val_categorical_crossentropy: 1.3653e-05 - lr: 1.0000e-04
# Epoch 168/500
# 4/4 [==============================] - 0s 66ms/step - loss: 1.3258e-05 - categorical_crossentropy: 1.3258e-05 - val_loss: 1.3641e-05 - val_categorical_crossentropy: 1.3641e-05 - lr: 1.0000e-04
# Epoch 169/500
# 4/4 [==============================] - 0s 50ms/step - loss: 1.3242e-05 - categorical_crossentropy: 1.3242e-05 - val_loss: 1.3622e-05 - val_categorical_crossentropy: 1.3622e-05 - lr: 1.0000e-04
# Epoch 170/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.3223e-05 - categorical_crossentropy: 1.3223e-05 - val_loss: 1.3610e-05 - val_categorical_crossentropy: 1.3610e-05 - lr: 1.0000e-04
# Epoch 171/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.3205e-05 - categorical_crossentropy: 1.3205e-05 - val_loss: 1.3586e-05 - val_categorical_crossentropy: 1.3586e-05 - lr: 1.0000e-04
# Epoch 172/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.3194e-05 - categorical_crossentropy: 1.3194e-05 - val_loss: 1.3570e-05 - val_categorical_crossentropy: 1.3570e-05 - lr: 1.0000e-04
# Epoch 173/500
# 4/4 [==============================] - 0s 73ms/step - loss: 1.3175e-05 - categorical_crossentropy: 1.3175e-05 - val_loss: 1.3554e-05 - val_categorical_crossentropy: 1.3554e-05 - lr: 1.0000e-04
# Epoch 174/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.3162e-05 - categorical_crossentropy: 1.3162e-05 - val_loss: 1.3542e-05 - val_categorical_crossentropy: 1.3542e-05 - lr: 1.0000e-04
# Epoch 175/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.3145e-05 - categorical_crossentropy: 1.3145e-05 - val_loss: 1.3518e-05 - val_categorical_crossentropy: 1.3518e-05 - lr: 1.0000e-04
# Epoch 176/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.3129e-05 - categorical_crossentropy: 1.3129e-05 - val_loss: 1.3494e-05 - val_categorical_crossentropy: 1.3494e-05 - lr: 1.0000e-04
# Epoch 177/500
# 4/4 [==============================] - 0s 62ms/step - loss: 1.3118e-05 - categorical_crossentropy: 1.3118e-05 - val_loss: 1.3482e-05 - val_categorical_crossentropy: 1.3482e-05 - lr: 1.0000e-04
# Epoch 178/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.3092e-05 - categorical_crossentropy: 1.3092e-05 - val_loss: 1.3471e-05 - val_categorical_crossentropy: 1.3471e-05 - lr: 1.0000e-04
# Epoch 179/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.3081e-05 - categorical_crossentropy: 1.3081e-05 - val_loss: 1.3455e-05 - val_categorical_crossentropy: 1.3455e-05 - lr: 1.0000e-04
# Epoch 180/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.3062e-05 - categorical_crossentropy: 1.3062e-05 - val_loss: 1.3439e-05 - val_categorical_crossentropy: 1.3439e-05 - lr: 1.0000e-04
# Epoch 181/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.3042e-05 - categorical_crossentropy: 1.3042e-05 - val_loss: 1.3419e-05 - val_categorical_crossentropy: 1.3419e-05 - lr: 1.0000e-04
# Epoch 182/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.3029e-05 - categorical_crossentropy: 1.3029e-05 - val_loss: 1.3395e-05 - val_categorical_crossentropy: 1.3395e-05 - lr: 1.0000e-04
# Epoch 183/500
# 4/4 [==============================] - 0s 91ms/step - loss: 1.3018e-05 - categorical_crossentropy: 1.3018e-05 - val_loss: 1.3391e-05 - val_categorical_crossentropy: 1.3391e-05 - lr: 1.0000e-04
# Epoch 184/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.3005e-05 - categorical_crossentropy: 1.3005e-05 - val_loss: 1.3371e-05 - val_categorical_crossentropy: 1.3371e-05 - lr: 1.0000e-04
# Epoch 185/500
# 4/4 [==============================] - 0s 85ms/step - loss: 1.2989e-05 - categorical_crossentropy: 1.2989e-05 - val_loss: 1.3347e-05 - val_categorical_crossentropy: 1.3347e-05 - lr: 1.0000e-04
# Epoch 186/500
# 4/4 [==============================] - 0s 54ms/step - loss: 1.2966e-05 - categorical_crossentropy: 1.2966e-05 - val_loss: 1.3335e-05 - val_categorical_crossentropy: 1.3335e-05 - lr: 1.0000e-04
# Epoch 187/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.2948e-05 - categorical_crossentropy: 1.2948e-05 - val_loss: 1.3316e-05 - val_categorical_crossentropy: 1.3316e-05 - lr: 1.0000e-04
# Epoch 188/500
# 4/4 [==============================] - 0s 107ms/step - loss: 1.2934e-05 - categorical_crossentropy: 1.2934e-05 - val_loss: 1.3292e-05 - val_categorical_crossentropy: 1.3292e-05 - lr: 1.0000e-04
# Epoch 189/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.2916e-05 - categorical_crossentropy: 1.2916e-05 - val_loss: 1.3284e-05 - val_categorical_crossentropy: 1.3284e-05 - lr: 1.0000e-04
# Epoch 190/500
# 4/4 [==============================] - 0s 107ms/step - loss: 1.2905e-05 - categorical_crossentropy: 1.2905e-05 - val_loss: 1.3268e-05 - val_categorical_crossentropy: 1.3268e-05 - lr: 1.0000e-04
# Epoch 191/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.2887e-05 - categorical_crossentropy: 1.2887e-05 - val_loss: 1.3244e-05 - val_categorical_crossentropy: 1.3244e-05 - lr: 1.0000e-04
# Epoch 192/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.2870e-05 - categorical_crossentropy: 1.2870e-05 - val_loss: 1.3236e-05 - val_categorical_crossentropy: 1.3236e-05 - lr: 1.0000e-04
# Epoch 193/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.2853e-05 - categorical_crossentropy: 1.2853e-05 - val_loss: 1.3204e-05 - val_categorical_crossentropy: 1.3204e-05 - lr: 1.0000e-04
# Epoch 194/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.2838e-05 - categorical_crossentropy: 1.2838e-05 - val_loss: 1.3188e-05 - val_categorical_crossentropy: 1.3188e-05 - lr: 1.0000e-04
# Epoch 195/500
# 4/4 [==============================] - 0s 96ms/step - loss: 1.2824e-05 - categorical_crossentropy: 1.2824e-05 - val_loss: 1.3180e-05 - val_categorical_crossentropy: 1.3180e-05 - lr: 1.0000e-04
# Epoch 196/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.2808e-05 - categorical_crossentropy: 1.2808e-05 - val_loss: 1.3173e-05 - val_categorical_crossentropy: 1.3173e-05 - lr: 1.0000e-04
# Epoch 197/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.2789e-05 - categorical_crossentropy: 1.2789e-05 - val_loss: 1.3153e-05 - val_categorical_crossentropy: 1.3153e-05 - lr: 1.0000e-04
# Epoch 198/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.2769e-05 - categorical_crossentropy: 1.2769e-05 - val_loss: 1.3133e-05 - val_categorical_crossentropy: 1.3133e-05 - lr: 1.0000e-04
# Epoch 199/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.2754e-05 - categorical_crossentropy: 1.2754e-05 - val_loss: 1.3105e-05 - val_categorical_crossentropy: 1.3105e-05 - lr: 1.0000e-04
# Epoch 200/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.2738e-05 - categorical_crossentropy: 1.2738e-05 - val_loss: 1.3085e-05 - val_categorical_crossentropy: 1.3085e-05 - lr: 1.0000e-04
# Epoch 201/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.2724e-05 - categorical_crossentropy: 1.2724e-05 - val_loss: 1.3077e-05 - val_categorical_crossentropy: 1.3077e-05 - lr: 1.0000e-04
# Epoch 202/500
# 4/4 [==============================] - 0s 48ms/step - loss: 1.2709e-05 - categorical_crossentropy: 1.2709e-05 - val_loss: 1.3073e-05 - val_categorical_crossentropy: 1.3073e-05 - lr: 1.0000e-04
# Epoch 203/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.2688e-05 - categorical_crossentropy: 1.2688e-05 - val_loss: 1.3049e-05 - val_categorical_crossentropy: 1.3049e-05 - lr: 1.0000e-04
# Epoch 204/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.2671e-05 - categorical_crossentropy: 1.2671e-05 - val_loss: 1.3022e-05 - val_categorical_crossentropy: 1.3022e-05 - lr: 1.0000e-04
# Epoch 205/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.2654e-05 - categorical_crossentropy: 1.2654e-05 - val_loss: 1.3002e-05 - val_categorical_crossentropy: 1.3002e-05 - lr: 1.0000e-04
# Epoch 206/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.2635e-05 - categorical_crossentropy: 1.2635e-05 - val_loss: 1.2990e-05 - val_categorical_crossentropy: 1.2990e-05 - lr: 1.0000e-04
# Epoch 207/500
# 4/4 [==============================] - 0s 59ms/step - loss: 1.2625e-05 - categorical_crossentropy: 1.2625e-05 - val_loss: 1.2974e-05 - val_categorical_crossentropy: 1.2974e-05 - lr: 1.0000e-04
# Epoch 208/500
# 4/4 [==============================] - 0s 63ms/step - loss: 1.2605e-05 - categorical_crossentropy: 1.2605e-05 - val_loss: 1.2962e-05 - val_categorical_crossentropy: 1.2962e-05 - lr: 1.0000e-04
# Epoch 209/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.2593e-05 - categorical_crossentropy: 1.2593e-05 - val_loss: 1.2938e-05 - val_categorical_crossentropy: 1.2938e-05 - lr: 1.0000e-04
# Epoch 210/500
# 4/4 [==============================] - 0s 60ms/step - loss: 1.2573e-05 - categorical_crossentropy: 1.2573e-05 - val_loss: 1.2918e-05 - val_categorical_crossentropy: 1.2918e-05 - lr: 1.0000e-04
# Epoch 211/500
# 4/4 [==============================] - 0s 56ms/step - loss: 1.2557e-05 - categorical_crossentropy: 1.2557e-05 - val_loss: 1.2902e-05 - val_categorical_crossentropy: 1.2902e-05 - lr: 1.0000e-04
# Epoch 212/500
# 4/4 [==============================] - 0s 66ms/step - loss: 1.2540e-05 - categorical_crossentropy: 1.2540e-05 - val_loss: 1.2894e-05 - val_categorical_crossentropy: 1.2894e-05 - lr: 1.0000e-04
# Epoch 213/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.2526e-05 - categorical_crossentropy: 1.2526e-05 - val_loss: 1.2871e-05 - val_categorical_crossentropy: 1.2871e-05 - lr: 1.0000e-04
# Epoch 214/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.2508e-05 - categorical_crossentropy: 1.2508e-05 - val_loss: 1.2855e-05 - val_categorical_crossentropy: 1.2855e-05 - lr: 1.0000e-04
# Epoch 215/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1.2497e-05 - categorical_crossentropy: 1.2497e-05 - val_loss: 1.2823e-05 - val_categorical_crossentropy: 1.2823e-05 - lr: 1.0000e-04
# Epoch 216/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.2476e-05 - categorical_crossentropy: 1.2476e-05 - val_loss: 1.2803e-05 - val_categorical_crossentropy: 1.2803e-05 - lr: 1.0000e-04
# Epoch 217/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.2449e-05 - categorical_crossentropy: 1.2449e-05 - val_loss: 1.2795e-05 - val_categorical_crossentropy: 1.2795e-05 - lr: 1.0000e-04
# Epoch 218/500
# 4/4 [==============================] - 0s 55ms/step - loss: 1.2435e-05 - categorical_crossentropy: 1.2435e-05 - val_loss: 1.2787e-05 - val_categorical_crossentropy: 1.2787e-05 - lr: 1.0000e-04
# Epoch 219/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.2420e-05 - categorical_crossentropy: 1.2420e-05 - val_loss: 1.2775e-05 - val_categorical_crossentropy: 1.2775e-05 - lr: 1.0000e-04
# Epoch 220/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.2408e-05 - categorical_crossentropy: 1.2408e-05 - val_loss: 1.2763e-05 - val_categorical_crossentropy: 1.2763e-05 - lr: 1.0000e-04
# Epoch 221/500
# 4/4 [==============================] - 0s 73ms/step - loss: 1.2393e-05 - categorical_crossentropy: 1.2393e-05 - val_loss: 1.2731e-05 - val_categorical_crossentropy: 1.2731e-05 - lr: 1.0000e-04
# Epoch 222/500
# 4/4 [==============================] - 0s 54ms/step - loss: 1.2378e-05 - categorical_crossentropy: 1.2378e-05 - val_loss: 1.2708e-05 - val_categorical_crossentropy: 1.2708e-05 - lr: 1.0000e-04
# Epoch 223/500
# 4/4 [==============================] - 0s 91ms/step - loss: 1.2359e-05 - categorical_crossentropy: 1.2359e-05 - val_loss: 1.2688e-05 - val_categorical_crossentropy: 1.2688e-05 - lr: 1.0000e-04
# Epoch 224/500
# 4/4 [==============================] - 0s 119ms/step - loss: 1.2337e-05 - categorical_crossentropy: 1.2337e-05 - val_loss: 1.2676e-05 - val_categorical_crossentropy: 1.2676e-05 - lr: 1.0000e-04
# Epoch 225/500
# 4/4 [==============================] - 0s 119ms/step - loss: 1.2318e-05 - categorical_crossentropy: 1.2318e-05 - val_loss: 1.2660e-05 - val_categorical_crossentropy: 1.2660e-05 - lr: 1.0000e-04
# Epoch 226/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.2304e-05 - categorical_crossentropy: 1.2304e-05 - val_loss: 1.2640e-05 - val_categorical_crossentropy: 1.2640e-05 - lr: 1.0000e-04
# Epoch 227/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.2289e-05 - categorical_crossentropy: 1.2289e-05 - val_loss: 1.2632e-05 - val_categorical_crossentropy: 1.2632e-05 - lr: 1.0000e-04
# Epoch 228/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.2274e-05 - categorical_crossentropy: 1.2274e-05 - val_loss: 1.2612e-05 - val_categorical_crossentropy: 1.2612e-05 - lr: 1.0000e-04
# Epoch 229/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.2257e-05 - categorical_crossentropy: 1.2257e-05 - val_loss: 1.2596e-05 - val_categorical_crossentropy: 1.2596e-05 - lr: 1.0000e-04
# Epoch 230/500
# 4/4 [==============================] - 0s 72ms/step - loss: 1.2242e-05 - categorical_crossentropy: 1.2242e-05 - val_loss: 1.2584e-05 - val_categorical_crossentropy: 1.2584e-05 - lr: 1.0000e-04
# Epoch 231/500
# 4/4 [==============================] - 0s 62ms/step - loss: 1.2220e-05 - categorical_crossentropy: 1.2220e-05 - val_loss: 1.2557e-05 - val_categorical_crossentropy: 1.2557e-05 - lr: 1.0000e-04
# Epoch 232/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.2204e-05 - categorical_crossentropy: 1.2204e-05 - val_loss: 1.2537e-05 - val_categorical_crossentropy: 1.2537e-05 - lr: 1.0000e-04
# Epoch 233/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.2185e-05 - categorical_crossentropy: 1.2185e-05 - val_loss: 1.2513e-05 - val_categorical_crossentropy: 1.2513e-05 - lr: 1.0000e-04
# Epoch 234/500
# ...
# Epoch 424/500
# 4/4 [==============================] - 0s 91ms/step - loss: 9.0092e-06 - categorical_crossentropy: 9.0092e-06 - val_loss: 9.2387e-06 - val_categorical_crossentropy: 9.2387e-06 - lr: 1.0000e-04
# Epoch 425/500
# 4/4 [==============================] - 0s 55ms/step - loss: 8.9903e-06 - categorical_crossentropy: 8.9903e-06 - val_loss: 9.2387e-06 - val_categorical_crossentropy: 9.2387e-06 - lr: 1.0000e-04
# Epoch 426/500
# 4/4 [==============================] - 0s 82ms/step - loss: 8.9814e-06 - categorical_crossentropy: 8.9814e-06 - val_loss: 9.2228e-06 - val_categorical_crossentropy: 9.2228e-06 - lr: 1.0000e-04
# Epoch 427/500
# 4/4 [==============================] - 0s 97ms/step - loss: 8.9615e-06 - categorical_crossentropy: 8.9615e-06 - val_loss: 9.2029e-06 - val_categorical_crossentropy: 9.2029e-06 - lr: 1.0000e-04
# Epoch 428/500
# 4/4 [==============================] - 0s 87ms/step - loss: 8.9476e-06 - categorical_crossentropy: 8.9476e-06 - val_loss: 9.1870e-06 - val_categorical_crossentropy: 9.1870e-06 - lr: 1.0000e-04
# Epoch 429/500
# 4/4 [==============================] - 0s 86ms/step - loss: 8.9297e-06 - categorical_crossentropy: 8.9297e-06 - val_loss: 9.1672e-06 - val_categorical_crossentropy: 9.1672e-06 - lr: 1.0000e-04
# Epoch 430/500
# 4/4 [==============================] - 0s 91ms/step - loss: 8.9158e-06 - categorical_crossentropy: 8.9158e-06 - val_loss: 9.1393e-06 - val_categorical_crossentropy: 9.1393e-06 - lr: 1.0000e-04
# Epoch 431/500
# 4/4 [==============================] - 0s 87ms/step - loss: 8.8969e-06 - categorical_crossentropy: 8.8969e-06 - val_loss: 9.1234e-06 - val_categorical_crossentropy: 9.1234e-06 - lr: 1.0000e-04
# Epoch 432/500
# 4/4 [==============================] - 0s 91ms/step - loss: 8.8820e-06 - categorical_crossentropy: 8.8820e-06 - val_loss: 9.1155e-06 - val_categorical_crossentropy: 9.1155e-06 - lr: 1.0000e-04
# Epoch 433/500
# 4/4 [==============================] - 0s 84ms/step - loss: 8.8652e-06 - categorical_crossentropy: 8.8652e-06 - val_loss: 9.1036e-06 - val_categorical_crossentropy: 9.1036e-06 - lr: 1.0000e-04
# Epoch 434/500
# 4/4 [==============================] - 0s 106ms/step - loss: 8.8483e-06 - categorical_crossentropy: 8.8483e-06 - val_loss: 9.0917e-06 - val_categorical_crossentropy: 9.0917e-06 - lr: 1.0000e-04
# Epoch 435/500
# 4/4 [==============================] - 0s 99ms/step - loss: 8.8383e-06 - categorical_crossentropy: 8.8383e-06 - val_loss: 9.0877e-06 - val_categorical_crossentropy: 9.0877e-06 - lr: 1.0000e-04
# Epoch 436/500
# 4/4 [==============================] - 0s 86ms/step - loss: 8.8185e-06 - categorical_crossentropy: 8.8185e-06 - val_loss: 9.0599e-06 - val_categorical_crossentropy: 9.0599e-06 - lr: 1.0000e-04
# Epoch 437/500
# 4/4 [==============================] - 0s 97ms/step - loss: 8.8065e-06 - categorical_crossentropy: 8.8065e-06 - val_loss: 9.0400e-06 - val_categorical_crossentropy: 9.0400e-06 - lr: 1.0000e-04
# Epoch 438/500
# 4/4 [==============================] - 0s 82ms/step - loss: 8.7926e-06 - categorical_crossentropy: 8.7926e-06 - val_loss: 9.0082e-06 - val_categorical_crossentropy: 9.0082e-06 - lr: 1.0000e-04
# Epoch 439/500
# 4/4 [==============================] - 0s 83ms/step - loss: 8.7708e-06 - categorical_crossentropy: 8.7708e-06 - val_loss: 9.0003e-06 - val_categorical_crossentropy: 9.0003e-06 - lr: 1.0000e-04
# Epoch 440/500
# 4/4 [==============================] - 0s 96ms/step - loss: 8.7559e-06 - categorical_crossentropy: 8.7559e-06 - val_loss: 8.9804e-06 - val_categorical_crossentropy: 8.9804e-06 - lr: 1.0000e-04
# Epoch 441/500
# 4/4 [==============================] - 0s 74ms/step - loss: 8.7400e-06 - categorical_crossentropy: 8.7400e-06 - val_loss: 8.9764e-06 - val_categorical_crossentropy: 8.9764e-06 - lr: 1.0000e-04
# Epoch 442/500
# 4/4 [==============================] - 0s 89ms/step - loss: 8.7241e-06 - categorical_crossentropy: 8.7241e-06 - val_loss: 8.9645e-06 - val_categorical_crossentropy: 8.9645e-06 - lr: 1.0000e-04
# Epoch 443/500
# 4/4 [==============================] - 0s 94ms/step - loss: 8.7092e-06 - categorical_crossentropy: 8.7092e-06 - val_loss: 8.9486e-06 - val_categorical_crossentropy: 8.9486e-06 - lr: 1.0000e-04
# Epoch 444/500
# 4/4 [==============================] - 0s 101ms/step - loss: 8.6993e-06 - categorical_crossentropy: 8.6993e-06 - val_loss: 8.9327e-06 - val_categorical_crossentropy: 8.9327e-06 - lr: 1.0000e-04
# Epoch 445/500
# 4/4 [==============================] - 0s 93ms/step - loss: 8.6844e-06 - categorical_crossentropy: 8.6844e-06 - val_loss: 8.9128e-06 - val_categorical_crossentropy: 8.9128e-06 - lr: 1.0000e-04
# Epoch 446/500
# 4/4 [==============================] - 0s 107ms/step - loss: 8.6675e-06 - categorical_crossentropy: 8.6675e-06 - val_loss: 8.8930e-06 - val_categorical_crossentropy: 8.8930e-06 - lr: 1.0000e-04
# Epoch 447/500
# 4/4 [==============================] - 0s 75ms/step - loss: 8.6516e-06 - categorical_crossentropy: 8.6516e-06 - val_loss: 8.8731e-06 - val_categorical_crossentropy: 8.8731e-06 - lr: 1.0000e-04
# Epoch 448/500
# 4/4 [==============================] - 0s 88ms/step - loss: 8.6327e-06 - categorical_crossentropy: 8.6327e-06 - val_loss: 8.8612e-06 - val_categorical_crossentropy: 8.8612e-06 - lr: 1.0000e-04
# Epoch 449/500
# 4/4 [==============================] - 0s 79ms/step - loss: 8.6168e-06 - categorical_crossentropy: 8.6168e-06 - val_loss: 8.8453e-06 - val_categorical_crossentropy: 8.8453e-06 - lr: 1.0000e-04
# Epoch 450/500
# 4/4 [==============================] - 0s 67ms/step - loss: 8.5969e-06 - categorical_crossentropy: 8.5969e-06 - val_loss: 8.8294e-06 - val_categorical_crossentropy: 8.8294e-06 - lr: 1.0000e-04
# Epoch 451/500
# 4/4 [==============================] - 0s 83ms/step - loss: 8.5870e-06 - categorical_crossentropy: 8.5870e-06 - val_loss: 8.8214e-06 - val_categorical_crossentropy: 8.8214e-06 - lr: 1.0000e-04
# Epoch 452/500
# 4/4 [==============================] - 0s 86ms/step - loss: 8.5721e-06 - categorical_crossentropy: 8.5721e-06 - val_loss: 8.8095e-06 - val_categorical_crossentropy: 8.8095e-06 - lr: 1.0000e-04
# Epoch 453/500
# 4/4 [==============================] - 0s 71ms/step - loss: 8.5582e-06 - categorical_crossentropy: 8.5582e-06 - val_loss: 8.7857e-06 - val_categorical_crossentropy: 8.7857e-06 - lr: 1.0000e-04
# Epoch 454/500
# 4/4 [==============================] - 0s 60ms/step - loss: 8.5423e-06 - categorical_crossentropy: 8.5423e-06 - val_loss: 8.7658e-06 - val_categorical_crossentropy: 8.7658e-06 - lr: 1.0000e-04
# Epoch 455/500
# 4/4 [==============================] - 0s 80ms/step - loss: 8.5274e-06 - categorical_crossentropy: 8.5274e-06 - val_loss: 8.7499e-06 - val_categorical_crossentropy: 8.7499e-06 - lr: 1.0000e-04
# Epoch 456/500
# 4/4 [==============================] - 0s 83ms/step - loss: 8.5075e-06 - categorical_crossentropy: 8.5075e-06 - val_loss: 8.7301e-06 - val_categorical_crossentropy: 8.7301e-06 - lr: 1.0000e-04
# Epoch 457/500
# 4/4 [==============================] - 0s 90ms/step - loss: 8.4887e-06 - categorical_crossentropy: 8.4887e-06 - val_loss: 8.7221e-06 - val_categorical_crossentropy: 8.7221e-06 - lr: 1.0000e-04
# Epoch 458/500
# 4/4 [==============================] - 0s 73ms/step - loss: 8.4777e-06 - categorical_crossentropy: 8.4777e-06 - val_loss: 8.7102e-06 - val_categorical_crossentropy: 8.7102e-06 - lr: 1.0000e-04
# Epoch 459/500
# 4/4 [==============================] - 0s 89ms/step - loss: 8.4658e-06 - categorical_crossentropy: 8.4658e-06 - val_loss: 8.6903e-06 - val_categorical_crossentropy: 8.6903e-06 - lr: 1.0000e-04
# Epoch 460/500
# 4/4 [==============================] - 0s 81ms/step - loss: 8.4469e-06 - categorical_crossentropy: 8.4469e-06 - val_loss: 8.6824e-06 - val_categorical_crossentropy: 8.6824e-06 - lr: 1.0000e-04
# Epoch 461/500
# 4/4 [==============================] - 0s 61ms/step - loss: 8.4300e-06 - categorical_crossentropy: 8.4300e-06 - val_loss: 8.6585e-06 - val_categorical_crossentropy: 8.6585e-06 - lr: 1.0000e-04
# Epoch 462/500
# 4/4 [==============================] - 0s 81ms/step - loss: 8.4201e-06 - categorical_crossentropy: 8.4201e-06 - val_loss: 8.6347e-06 - val_categorical_crossentropy: 8.6347e-06 - lr: 1.0000e-04
# Epoch 463/500
# 4/4 [==============================] - 0s 97ms/step - loss: 8.4082e-06 - categorical_crossentropy: 8.4082e-06 - val_loss: 8.6228e-06 - val_categorical_crossentropy: 8.6228e-06 - lr: 1.0000e-04
# Epoch 464/500
# 4/4 [==============================] - 0s 89ms/step - loss: 8.3863e-06 - categorical_crossentropy: 8.3863e-06 - val_loss: 8.6069e-06 - val_categorical_crossentropy: 8.6069e-06 - lr: 1.0000e-04
# Epoch 465/500
# 4/4 [==============================] - 0s 75ms/step - loss: 8.3695e-06 - categorical_crossentropy: 8.3695e-06 - val_loss: 8.5950e-06 - val_categorical_crossentropy: 8.5950e-06 - lr: 1.0000e-04
# Epoch 466/500
# 4/4 [==============================] - 0s 81ms/step - loss: 8.3585e-06 - categorical_crossentropy: 8.3585e-06 - val_loss: 8.5870e-06 - val_categorical_crossentropy: 8.5870e-06 - lr: 1.0000e-04
# Epoch 467/500
# 4/4 [==============================] - 0s 92ms/step - loss: 8.3436e-06 - categorical_crossentropy: 8.3436e-06 - val_loss: 8.5751e-06 - val_categorical_crossentropy: 8.5751e-06 - lr: 1.0000e-04
# Epoch 468/500
# 4/4 [==============================] - 0s 84ms/step - loss: 8.3257e-06 - categorical_crossentropy: 8.3257e-06 - val_loss: 8.5592e-06 - val_categorical_crossentropy: 8.5592e-06 - lr: 1.0000e-04
# Epoch 469/500
# 4/4 [==============================] - 0s 88ms/step - loss: 8.3089e-06 - categorical_crossentropy: 8.3089e-06 - val_loss: 8.5274e-06 - val_categorical_crossentropy: 8.5274e-06 - lr: 1.0000e-04
# Epoch 470/500
# 4/4 [==============================] - 0s 91ms/step - loss: 8.2989e-06 - categorical_crossentropy: 8.2989e-06 - val_loss: 8.5075e-06 - val_categorical_crossentropy: 8.5075e-06 - lr: 1.0000e-04
# Epoch 471/500
# 4/4 [==============================] - 0s 89ms/step - loss: 8.2850e-06 - categorical_crossentropy: 8.2850e-06 - val_loss: 8.5036e-06 - val_categorical_crossentropy: 8.5036e-06 - lr: 1.0000e-04
# Epoch 472/500
# 4/4 [==============================] - 0s 80ms/step - loss: 8.2641e-06 - categorical_crossentropy: 8.2641e-06 - val_loss: 8.4916e-06 - val_categorical_crossentropy: 8.4916e-06 - lr: 1.0000e-04
# Epoch 473/500
# 4/4 [==============================] - 0s 86ms/step - loss: 8.2532e-06 - categorical_crossentropy: 8.2532e-06 - val_loss: 8.4757e-06 - val_categorical_crossentropy: 8.4757e-06 - lr: 1.0000e-04
# Epoch 474/500
# 4/4 [==============================] - 0s 103ms/step - loss: 8.2383e-06 - categorical_crossentropy: 8.2383e-06 - val_loss: 8.4638e-06 - val_categorical_crossentropy: 8.4638e-06 - lr: 1.0000e-04
# Epoch 475/500
# 4/4 [==============================] - 0s 73ms/step - loss: 8.2214e-06 - categorical_crossentropy: 8.2214e-06 - val_loss: 8.4400e-06 - val_categorical_crossentropy: 8.4400e-06 - lr: 1.0000e-04
# Epoch 476/500
# 4/4 [==============================] - 0s 85ms/step - loss: 8.2055e-06 - categorical_crossentropy: 8.2055e-06 - val_loss: 8.4281e-06 - val_categorical_crossentropy: 8.4281e-06 - lr: 1.0000e-04
# Epoch 477/500
# 4/4 [==============================] - 0s 66ms/step - loss: 8.1857e-06 - categorical_crossentropy: 8.1857e-06 - val_loss: 8.4161e-06 - val_categorical_crossentropy: 8.4161e-06 - lr: 1.0000e-04
# Epoch 478/500
# 4/4 [==============================] - 0s 78ms/step - loss: 8.1767e-06 - categorical_crossentropy: 8.1767e-06 - val_loss: 8.3963e-06 - val_categorical_crossentropy: 8.3963e-06 - lr: 1.0000e-04
# Epoch 479/500
# 4/4 [==============================] - 0s 117ms/step - loss: 8.1658e-06 - categorical_crossentropy: 8.1658e-06 - val_loss: 8.3764e-06 - val_categorical_crossentropy: 8.3764e-06 - lr: 1.0000e-04
# Epoch 480/500
# 4/4 [==============================] - 0s 91ms/step - loss: 8.1459e-06 - categorical_crossentropy: 8.1459e-06 - val_loss: 8.3645e-06 - val_categorical_crossentropy: 8.3645e-06 - lr: 1.0000e-04
# Epoch 481/500
# 4/4 [==============================] - 0s 67ms/step - loss: 8.1310e-06 - categorical_crossentropy: 8.1310e-06 - val_loss: 8.3605e-06 - val_categorical_crossentropy: 8.3605e-06 - lr: 1.0000e-04
# Epoch 482/500
# 4/4 [==============================] - 0s 72ms/step - loss: 8.1201e-06 - categorical_crossentropy: 8.1201e-06 - val_loss: 8.3287e-06 - val_categorical_crossentropy: 8.3287e-06 - lr: 1.0000e-04
# Epoch 483/500
# 4/4 [==============================] - 0s 83ms/step - loss: 8.1022e-06 - categorical_crossentropy: 8.1022e-06 - val_loss: 8.3208e-06 - val_categorical_crossentropy: 8.3208e-06 - lr: 1.0000e-04
# Epoch 484/500
# 4/4 [==============================] - 0s 104ms/step - loss: 8.0863e-06 - categorical_crossentropy: 8.0863e-06 - val_loss: 8.3009e-06 - val_categorical_crossentropy: 8.3009e-06 - lr: 1.0000e-04
# Epoch 485/500
# 4/4 [==============================] - 0s 84ms/step - loss: 8.0734e-06 - categorical_crossentropy: 8.0734e-06 - val_loss: 8.2969e-06 - val_categorical_crossentropy: 8.2969e-06 - lr: 1.0000e-04
# Epoch 486/500
# 4/4 [==============================] - 0s 96ms/step - loss: 8.0555e-06 - categorical_crossentropy: 8.0555e-06 - val_loss: 8.2691e-06 - val_categorical_crossentropy: 8.2691e-06 - lr: 1.0000e-04
# Epoch 487/500
# 4/4 [==============================] - 0s 92ms/step - loss: 8.0406e-06 - categorical_crossentropy: 8.0406e-06 - val_loss: 8.2572e-06 - val_categorical_crossentropy: 8.2572e-06 - lr: 1.0000e-04
# Epoch 488/500
# 4/4 [==============================] - 0s 81ms/step - loss: 8.0257e-06 - categorical_crossentropy: 8.0257e-06 - val_loss: 8.2453e-06 - val_categorical_crossentropy: 8.2453e-06 - lr: 1.0000e-04
# Epoch 489/500
# 4/4 [==============================] - 0s 96ms/step - loss: 8.0138e-06 - categorical_crossentropy: 8.0138e-06 - val_loss: 8.2254e-06 - val_categorical_crossentropy: 8.2254e-06 - lr: 1.0000e-04
# Epoch 490/500
# 4/4 [==============================] - 0s 112ms/step - loss: 7.9969e-06 - categorical_crossentropy: 7.9969e-06 - val_loss: 8.2175e-06 - val_categorical_crossentropy: 8.2175e-06 - lr: 1.0000e-04
# Epoch 491/500
# 4/4 [==============================] - 0s 90ms/step - loss: 7.9870e-06 - categorical_crossentropy: 7.9870e-06 - val_loss: 8.1896e-06 - val_categorical_crossentropy: 8.1896e-06 - lr: 1.0000e-04
# Epoch 492/500
# 4/4 [==============================] - 0s 68ms/step - loss: 7.9681e-06 - categorical_crossentropy: 7.9681e-06 - val_loss: 8.1896e-06 - val_categorical_crossentropy: 8.1896e-06 - lr: 1.0000e-04
# Epoch 493/500
# 4/4 [==============================] - 0s 113ms/step - loss: 7.9552e-06 - categorical_crossentropy: 7.9552e-06 - val_loss: 8.1737e-06 - val_categorical_crossentropy: 8.1737e-06 - lr: 1.0000e-04
# Epoch 494/500
# 4/4 [==============================] - 0s 76ms/step - loss: 7.9353e-06 - categorical_crossentropy: 7.9353e-06 - val_loss: 8.1539e-06 - val_categorical_crossentropy: 8.1539e-06 - lr: 1.0000e-04
# Epoch 495/500
# 4/4 [==============================] - 0s 102ms/step - loss: 7.9204e-06 - categorical_crossentropy: 7.9204e-06 - val_loss: 8.1300e-06 - val_categorical_crossentropy: 8.1300e-06 - lr: 1.0000e-04
# Epoch 496/500
# 4/4 [==============================] - 0s 79ms/step - loss: 7.9075e-06 - categorical_crossentropy: 7.9075e-06 - val_loss: 8.1181e-06 - val_categorical_crossentropy: 8.1181e-06 - lr: 1.0000e-04
# Epoch 497/500
# 4/4 [==============================] - 0s 82ms/step - loss: 7.8936e-06 - categorical_crossentropy: 7.8936e-06 - val_loss: 8.1102e-06 - val_categorical_crossentropy: 8.1102e-06 - lr: 1.0000e-04
# Epoch 498/500
# 4/4 [==============================] - 0s 111ms/step - loss: 7.8807e-06 - categorical_crossentropy: 7.8807e-06 - val_loss: 8.0903e-06 - val_categorical_crossentropy: 8.0903e-06 - lr: 1.0000e-04
# Epoch 499/500
# 4/4 [==============================] - 0s 108ms/step - loss: 7.8698e-06 - categorical_crossentropy: 7.8698e-06 - val_loss: 8.0824e-06 - val_categorical_crossentropy: 8.0824e-06 - lr: 1.0000e-04
# Epoch 500/500
# 4/4 [==============================] - 0s 113ms/step - loss: 7.8559e-06 - categorical_crossentropy: 7.8559e-06 - val_loss: 8.0744e-06 - val_categorical_crossentropy: 8.0744e-06 - lr: 1.0000e-04

# %%
class ModelWrapper():
    def __init__(self,model):
        self.model=model
    def predict_proba(self,X):
        if isinstance(X, pd.DataFrame):
            X=X.values
        Xnn=X.reshape(X.shape[0],1,X.shape[1])
        return self.model.predict(Xnn)
    def predict(self, X):
        return np.argmax(self.predict_proba(X),axis=1)
clf=ModelWrapper(model)

# %% [markdown]
# ## SHAP
# We calculate SHAP for datasets

# %%
fXtrain = trainX.reshape(150,1,200)

# %%
from tsproto.utils import getshap

shap_version='deep'
bg_size = 1000
stride=10
window_len=10
absshap = True
fXtrain,sv_tr = getshap(model=model, X=fXtrain, y=train_ynn,shap_version=shap_version,bg_size = bg_size, stride=stride, window_len=window_len, absshap = absshap, shuffle=False)
# Out:
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [markdown]
# ## Visualize SHAP
# In this section we can see that the network focused on correct parts of the time-series.
# In this toy example, it is sufficient to look at SHAP-visualizations to spot the difference, but in case of hundreds of dimensions and more complex problems, prototypes are more useful.

# %%
from  tsproto.plots import plot_smooth_colored_line
indexer = clf.predict(trainX)
shapclass = []
if absshap == False:
    for i in range(0,len(trainX)):
        best_index = indexer[i]
        shapclass.append([sv_tr[best_index][i,:]])
        
    shapclass=np.concatenate(shapclass)
else:
    shapclass  = sv_tr[:,0,:]

    fig, axes =plt.subplots(2,1,figsize=(12,6))

    for i in range(0,10):
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==0][i], color_values=shapclass[train_y==0][i], resolution=1000, ax=axes[0],add_cbar=(i==0))
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==1][i], color_values=shapclass[train_y==1][i], resolution=1000, ax=axes[1],add_cbar=(i==0))

for ax in axes:
    ax.set_ylim([-2, 2])
# Out:
# 5/5 [==============================] - 0s 4ms/step

# %% [markdown]
# ## Tsproto
# Now, lets try to apply TSProto to see if it is able to find the prototype and summarize them correctly to show what logical relation is between them and the model prediction

# %%
trainXproto = trainX.reshape((trainX.shape[0], trainX.shape[1],1))
shapclassXproto = shapclass.reshape((shapclass.shape[0], shapclass.shape[1],1))

# %%
from tsproto.models import *
im  = InterpretableModel()
pe = PrototypeEncoder(clf, n_clusters=4, min_size=50, method='dtw',
                              descriptors=['existance','duration','frequency'],
                      jump=1, pen=1,multiplier=1,n_jobs=-1,
                      verbose=1)
ohe_train, features, target_ohe,weights = pe.fit_transform(trainXproto,shapclassXproto)
acc,prec,rec,f1,iclf = im.fit_or_predict(ohe_train, features, target_ohe,intclf=None, verbose=0, max_depth=2, min_samples_leaf=0.05,
                       weights=None)
# Out:
# Dataset shape: (150, 200, 1)
# Calculating changepoints...
# Dim: 0
# 2
# 2
# 2
# For 0 c_clusters = 2
# Done in 1.1230347156524658.
# Clustering data
# (300, 114, 1)
# (300, 114, 1)
# Shape of data for clustering: (300, 114, 1)
# Clustering data
# X_bis shape: (300, 114, 1) for method=dtw
# Done in 6.852149248123169.
# OHE time series
# Len X=150 vs len of train = 150
# 5/5 [==============================] - 0s 6ms/step
# Done in 0.13513708114624023.

# %% [markdown]
# ## Visualize interpretable model
# We can easily see that the TSProto has found the sine wave at the beginning of the sample, marked it as prototype and correctly identified that its existence is not enough to treat the sample as a class 1 sample, additional frequency context has to be added in order to distinguish these two

# %%
from  tsproto.plots import *
ds_final = ohe_train.copy()
dot = export_decision_tree_with_embedded_histograms(decision_tree=iclf, 
                                              dataset=ds_final, 
                                              target_name='target', 
                                              feature_names=features, 
                                              filename='synthetic', 
                                              proto_encoder=pe, figsize=(6,3))

from IPython.display import SVG, Image
Image('synthetic.png')
# Out:
# [0 1]
# Shapes: (300, 114, 1) vs shap: (2, 114, 1) TODO: take IDS of a single sample that is plotted
# color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Decision Tree exported to synthetic with embedded histograms successfully.
