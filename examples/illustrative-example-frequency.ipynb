# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2024-03-27 14:27:16.058388: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn import tree
from graphviz import Source
from IPython.display import display
from IPython.display import SVG

# %% [markdown]
# ## Creating synthetic dataset
# We will create a synthetic dataset with two classes. The dataset will be hard to distinguish based on statistical features, but possible with proper prototypical parts extracted.
#
# We are making it even harder, as the prototypical parts are more or less the same. They are differing in terms of frequency.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(3*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X3 = np.concatenate((x1,x2))
Y3 = np.concatenate((y1,y2))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(2*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X4 = np.concatenate((x1,x2))
Y4 = np.concatenate((y1,y2))

# %% [markdown]
# ## Generating sample cases

# %%
x = X3
proto_sin_y = Y3
proto_inversed_sin_y = Y4

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,proto_sin_y)
axes[1].plot(x,proto_inversed_sin_y)

# %% [markdown]
# ## Generating noise and augmenting signals

# %%
noise_power = .2

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_sin_y = noise + proto_sin_y

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_inversed_sin_y = noise + proto_inversed_sin_y

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,noisy_proto_sin_y[0])
axes[1].plot(x,noisy_proto_inversed_sin_y[0])
for ax in axes:
    ax.set_ylim([-2, 2])

# %%
X=np.concatenate((noisy_proto_sin_y,noisy_proto_inversed_sin_y))
Xy=np.concatenate((np.ones(len(noisy_proto_sin_y))*0,
                   np.ones(len(noisy_proto_inversed_sin_y))*1))

trainX, testX, train_y,test_y = train_test_split(X,Xy)

# %% [markdown]
# ## Model
# We will build simple DNN model (not really needed in this case, but it serves the purpose of demonstration how to deal with more complex cases)

# %%
trainX.shape
# Out:
# (150, 200)

# %%
from keras.utils import to_categorical
trainXnn = trainX.reshape(150,1,200)
train_ynn = to_categorical(train_y)
num_classes = len(np.unique(Xy))

# %%
import keras
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    #add dropout
    input_layer = keras.layers.Dropout(0.5)(input_layer)
    conv1 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(input_layer)
    #conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv1)
    #conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv2)
    #conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)



model = make_model(input_shape=trainXnn.shape[1:])
# Out:
# 2024-03-27 14:27:20.333041: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_crossentropy"],
)
history = model.fit(
    trainXnn,
    train_ynn,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 2s 166ms/step - loss: 0.6845 - categorical_crossentropy: 0.6845 - val_loss: 0.6612 - val_categorical_crossentropy: 0.6612 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 91ms/step - loss: 0.6365 - categorical_crossentropy: 0.6365 - val_loss: 0.5877 - val_categorical_crossentropy: 0.5877 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 101ms/step - loss: 0.5352 - categorical_crossentropy: 0.5352 - val_loss: 0.4562 - val_categorical_crossentropy: 0.4562 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 0s 83ms/step - loss: 0.3793 - categorical_crossentropy: 0.3793 - val_loss: 0.2847 - val_categorical_crossentropy: 0.2847 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 83ms/step - loss: 0.2091 - categorical_crossentropy: 0.2091 - val_loss: 0.1325 - val_categorical_crossentropy: 0.1325 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0861 - categorical_crossentropy: 0.0861 - val_loss: 0.0408 - val_categorical_crossentropy: 0.0408 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0227 - categorical_crossentropy: 0.0227 - val_loss: 0.0088 - val_categorical_crossentropy: 0.0088 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0050 - categorical_crossentropy: 0.0050 - val_loss: 0.0019 - val_categorical_crossentropy: 0.0019 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0011 - categorical_crossentropy: 0.0011 - val_loss: 5.1108e-04 - val_categorical_crossentropy: 5.1108e-04 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 0s 65ms/step - loss: 3.5165e-04 - categorical_crossentropy: 3.5165e-04 - val_loss: 1.9922e-04 - val_categorical_crossentropy: 1.9922e-04 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 0s 58ms/step - loss: 1.5599e-04 - categorical_crossentropy: 1.5599e-04 - val_loss: 1.0332e-04 - val_categorical_crossentropy: 1.0332e-04 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 85ms/step - loss: 8.9907e-05 - categorical_crossentropy: 8.9907e-05 - val_loss: 6.5384e-05 - val_categorical_crossentropy: 6.5384e-05 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 0s 83ms/step - loss: 6.0808e-05 - categorical_crossentropy: 6.0808e-05 - val_loss: 4.7233e-05 - val_categorical_crossentropy: 4.7233e-05 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 81ms/step - loss: 4.5868e-05 - categorical_crossentropy: 4.5868e-05 - val_loss: 3.7308e-05 - val_categorical_crossentropy: 3.7308e-05 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 86ms/step - loss: 3.7362e-05 - categorical_crossentropy: 3.7362e-05 - val_loss: 3.1332e-05 - val_categorical_crossentropy: 3.1332e-05 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 88ms/step - loss: 3.1841e-05 - categorical_crossentropy: 3.1841e-05 - val_loss: 2.7509e-05 - val_categorical_crossentropy: 2.7509e-05 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 97ms/step - loss: 2.8280e-05 - categorical_crossentropy: 2.8280e-05 - val_loss: 2.4914e-05 - val_categorical_crossentropy: 2.4914e-05 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 88ms/step - loss: 2.5748e-05 - categorical_crossentropy: 2.5748e-05 - val_loss: 2.3083e-05 - val_categorical_crossentropy: 2.3083e-05 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 67ms/step - loss: 2.3969e-05 - categorical_crossentropy: 2.3969e-05 - val_loss: 2.1720e-05 - val_categorical_crossentropy: 2.1720e-05 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 68ms/step - loss: 2.2534e-05 - categorical_crossentropy: 2.2534e-05 - val_loss: 2.0691e-05 - val_categorical_crossentropy: 2.0691e-05 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 93ms/step - loss: 2.1432e-05 - categorical_crossentropy: 2.1432e-05 - val_loss: 1.9872e-05 - val_categorical_crossentropy: 1.9872e-05 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 62ms/step - loss: 2.0565e-05 - categorical_crossentropy: 2.0565e-05 - val_loss: 1.9220e-05 - val_categorical_crossentropy: 1.9220e-05 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.9816e-05 - categorical_crossentropy: 1.9816e-05 - val_loss: 1.8664e-05 - val_categorical_crossentropy: 1.8664e-05 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.9170e-05 - categorical_crossentropy: 1.9170e-05 - val_loss: 1.8187e-05 - val_categorical_crossentropy: 1.8187e-05 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.8661e-05 - categorical_crossentropy: 1.8661e-05 - val_loss: 1.7778e-05 - val_categorical_crossentropy: 1.7778e-05 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.8154e-05 - categorical_crossentropy: 1.8154e-05 - val_loss: 1.7396e-05 - val_categorical_crossentropy: 1.7396e-05 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 51ms/step - loss: 1.7708e-05 - categorical_crossentropy: 1.7708e-05 - val_loss: 1.7071e-05 - val_categorical_crossentropy: 1.7071e-05 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 75ms/step - loss: 1.7310e-05 - categorical_crossentropy: 1.7310e-05 - val_loss: 1.6769e-05 - val_categorical_crossentropy: 1.6769e-05 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.6953e-05 - categorical_crossentropy: 1.6953e-05 - val_loss: 1.6483e-05 - val_categorical_crossentropy: 1.6483e-05 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 68ms/step - loss: 1.6625e-05 - categorical_crossentropy: 1.6625e-05 - val_loss: 1.6212e-05 - val_categorical_crossentropy: 1.6212e-05 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.6280e-05 - categorical_crossentropy: 1.6280e-05 - val_loss: 1.5974e-05 - val_categorical_crossentropy: 1.5974e-05 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.6000e-05 - categorical_crossentropy: 1.6000e-05 - val_loss: 1.5751e-05 - val_categorical_crossentropy: 1.5751e-05 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.5760e-05 - categorical_crossentropy: 1.5760e-05 - val_loss: 1.5628e-05 - val_categorical_crossentropy: 1.5628e-05 - lr: 5.0000e-04
# Epoch 34/500
# 4/4 [==============================] - 0s 96ms/step - loss: 1.5626e-05 - categorical_crossentropy: 1.5626e-05 - val_loss: 1.5537e-05 - val_categorical_crossentropy: 1.5537e-05 - lr: 5.0000e-04
# Epoch 35/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.5507e-05 - categorical_crossentropy: 1.5507e-05 - val_loss: 1.5430e-05 - val_categorical_crossentropy: 1.5430e-05 - lr: 5.0000e-04
# Epoch 36/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.5381e-05 - categorical_crossentropy: 1.5381e-05 - val_loss: 1.5334e-05 - val_categorical_crossentropy: 1.5334e-05 - lr: 5.0000e-04
# Epoch 37/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.5259e-05 - categorical_crossentropy: 1.5259e-05 - val_loss: 1.5235e-05 - val_categorical_crossentropy: 1.5235e-05 - lr: 5.0000e-04
# Epoch 38/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.5130e-05 - categorical_crossentropy: 1.5130e-05 - val_loss: 1.5132e-05 - val_categorical_crossentropy: 1.5132e-05 - lr: 5.0000e-04
# Epoch 39/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.5023e-05 - categorical_crossentropy: 1.5023e-05 - val_loss: 1.5032e-05 - val_categorical_crossentropy: 1.5032e-05 - lr: 5.0000e-04
# Epoch 40/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.4909e-05 - categorical_crossentropy: 1.4909e-05 - val_loss: 1.4941e-05 - val_categorical_crossentropy: 1.4941e-05 - lr: 5.0000e-04
# Epoch 41/500
# 4/4 [==============================] - 0s 96ms/step - loss: 1.4793e-05 - categorical_crossentropy: 1.4793e-05 - val_loss: 1.4849e-05 - val_categorical_crossentropy: 1.4849e-05 - lr: 5.0000e-04
# Epoch 42/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.4670e-05 - categorical_crossentropy: 1.4670e-05 - val_loss: 1.4766e-05 - val_categorical_crossentropy: 1.4766e-05 - lr: 5.0000e-04
# Epoch 43/500
# 4/4 [==============================] - 0s 71ms/step - loss: 1.4566e-05 - categorical_crossentropy: 1.4566e-05 - val_loss: 1.4675e-05 - val_categorical_crossentropy: 1.4675e-05 - lr: 5.0000e-04
# Epoch 44/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.4453e-05 - categorical_crossentropy: 1.4453e-05 - val_loss: 1.4575e-05 - val_categorical_crossentropy: 1.4575e-05 - lr: 5.0000e-04
# Epoch 45/500
# 4/4 [==============================] - 0s 66ms/step - loss: 1.4353e-05 - categorical_crossentropy: 1.4353e-05 - val_loss: 1.4492e-05 - val_categorical_crossentropy: 1.4492e-05 - lr: 5.0000e-04
# Epoch 46/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.4246e-05 - categorical_crossentropy: 1.4246e-05 - val_loss: 1.4400e-05 - val_categorical_crossentropy: 1.4400e-05 - lr: 5.0000e-04
# Epoch 47/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.4137e-05 - categorical_crossentropy: 1.4137e-05 - val_loss: 1.4309e-05 - val_categorical_crossentropy: 1.4309e-05 - lr: 5.0000e-04
# Epoch 48/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.4039e-05 - categorical_crossentropy: 1.4039e-05 - val_loss: 1.4241e-05 - val_categorical_crossentropy: 1.4241e-05 - lr: 5.0000e-04
# Epoch 49/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.3937e-05 - categorical_crossentropy: 1.3937e-05 - val_loss: 1.4150e-05 - val_categorical_crossentropy: 1.4150e-05 - lr: 5.0000e-04
# Epoch 50/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.3835e-05 - categorical_crossentropy: 1.3835e-05 - val_loss: 1.4059e-05 - val_categorical_crossentropy: 1.4059e-05 - lr: 5.0000e-04
# Epoch 51/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.3738e-05 - categorical_crossentropy: 1.3738e-05 - val_loss: 1.3971e-05 - val_categorical_crossentropy: 1.3971e-05 - lr: 5.0000e-04
# Epoch 52/500
# 4/4 [==============================] - 0s 59ms/step - loss: 1.3643e-05 - categorical_crossentropy: 1.3643e-05 - val_loss: 1.3904e-05 - val_categorical_crossentropy: 1.3904e-05 - lr: 5.0000e-04
# Epoch 53/500
# 4/4 [==============================] - 0s 91ms/step - loss: 1.3567e-05 - categorical_crossentropy: 1.3567e-05 - val_loss: 1.3868e-05 - val_categorical_crossentropy: 1.3868e-05 - lr: 2.5000e-04
# Epoch 54/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.3521e-05 - categorical_crossentropy: 1.3521e-05 - val_loss: 1.3820e-05 - val_categorical_crossentropy: 1.3820e-05 - lr: 2.5000e-04
# Epoch 55/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.3473e-05 - categorical_crossentropy: 1.3473e-05 - val_loss: 1.3777e-05 - val_categorical_crossentropy: 1.3777e-05 - lr: 2.5000e-04
# Epoch 56/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.3427e-05 - categorical_crossentropy: 1.3427e-05 - val_loss: 1.3745e-05 - val_categorical_crossentropy: 1.3745e-05 - lr: 2.5000e-04
# Epoch 57/500
# 4/4 [==============================] - 0s 110ms/step - loss: 1.3382e-05 - categorical_crossentropy: 1.3382e-05 - val_loss: 1.3693e-05 - val_categorical_crossentropy: 1.3693e-05 - lr: 2.5000e-04
# Epoch 58/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.3331e-05 - categorical_crossentropy: 1.3331e-05 - val_loss: 1.3661e-05 - val_categorical_crossentropy: 1.3661e-05 - lr: 2.5000e-04
# Epoch 59/500
# 4/4 [==============================] - 0s 55ms/step - loss: 1.3291e-05 - categorical_crossentropy: 1.3291e-05 - val_loss: 1.3614e-05 - val_categorical_crossentropy: 1.3614e-05 - lr: 2.5000e-04
# Epoch 60/500
# 4/4 [==============================] - 0s 66ms/step - loss: 1.3243e-05 - categorical_crossentropy: 1.3243e-05 - val_loss: 1.3574e-05 - val_categorical_crossentropy: 1.3574e-05 - lr: 2.5000e-04
# Epoch 61/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.3195e-05 - categorical_crossentropy: 1.3195e-05 - val_loss: 1.3542e-05 - val_categorical_crossentropy: 1.3542e-05 - lr: 2.5000e-04
# Epoch 62/500
# 4/4 [==============================] - 0s 70ms/step - loss: 1.3151e-05 - categorical_crossentropy: 1.3151e-05 - val_loss: 1.3490e-05 - val_categorical_crossentropy: 1.3490e-05 - lr: 2.5000e-04
# Epoch 63/500
# 4/4 [==============================] - 0s 91ms/step - loss: 1.3097e-05 - categorical_crossentropy: 1.3097e-05 - val_loss: 1.3451e-05 - val_categorical_crossentropy: 1.3451e-05 - lr: 2.5000e-04
# Epoch 64/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.3054e-05 - categorical_crossentropy: 1.3054e-05 - val_loss: 1.3403e-05 - val_categorical_crossentropy: 1.3403e-05 - lr: 2.5000e-04
# Epoch 65/500
# 4/4 [==============================] - 0s 112ms/step - loss: 1.3015e-05 - categorical_crossentropy: 1.3015e-05 - val_loss: 1.3379e-05 - val_categorical_crossentropy: 1.3379e-05 - lr: 2.5000e-04
# Epoch 66/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.2965e-05 - categorical_crossentropy: 1.2965e-05 - val_loss: 1.3328e-05 - val_categorical_crossentropy: 1.3328e-05 - lr: 2.5000e-04
# Epoch 67/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.2924e-05 - categorical_crossentropy: 1.2924e-05 - val_loss: 1.3296e-05 - val_categorical_crossentropy: 1.3296e-05 - lr: 2.5000e-04
# Epoch 68/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.2875e-05 - categorical_crossentropy: 1.2875e-05 - val_loss: 1.3264e-05 - val_categorical_crossentropy: 1.3264e-05 - lr: 2.5000e-04
# Epoch 69/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.2835e-05 - categorical_crossentropy: 1.2835e-05 - val_loss: 1.3220e-05 - val_categorical_crossentropy: 1.3220e-05 - lr: 2.5000e-04
# Epoch 70/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.2784e-05 - categorical_crossentropy: 1.2784e-05 - val_loss: 1.3173e-05 - val_categorical_crossentropy: 1.3173e-05 - lr: 2.5000e-04
# Epoch 71/500
# 4/4 [==============================] - 0s 72ms/step - loss: 1.2733e-05 - categorical_crossentropy: 1.2733e-05 - val_loss: 1.3137e-05 - val_categorical_crossentropy: 1.3137e-05 - lr: 2.5000e-04
# Epoch 72/500
# 4/4 [==============================] - 0s 60ms/step - loss: 1.2698e-05 - categorical_crossentropy: 1.2698e-05 - val_loss: 1.3093e-05 - val_categorical_crossentropy: 1.3093e-05 - lr: 2.5000e-04
# Epoch 73/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.2654e-05 - categorical_crossentropy: 1.2654e-05 - val_loss: 1.3073e-05 - val_categorical_crossentropy: 1.3073e-05 - lr: 1.2500e-04
# Epoch 74/500
# 4/4 [==============================] - 0s 59ms/step - loss: 1.2634e-05 - categorical_crossentropy: 1.2634e-05 - val_loss: 1.3045e-05 - val_categorical_crossentropy: 1.3045e-05 - lr: 1.2500e-04
# Epoch 75/500
# 4/4 [==============================] - 0s 57ms/step - loss: 1.2617e-05 - categorical_crossentropy: 1.2617e-05 - val_loss: 1.3037e-05 - val_categorical_crossentropy: 1.3037e-05 - lr: 1.2500e-04
# Epoch 76/500
# 4/4 [==============================] - 0s 63ms/step - loss: 1.2585e-05 - categorical_crossentropy: 1.2585e-05 - val_loss: 1.3014e-05 - val_categorical_crossentropy: 1.3014e-05 - lr: 1.2500e-04
# Epoch 77/500
# 4/4 [==============================] - 0s 111ms/step - loss: 1.2571e-05 - categorical_crossentropy: 1.2571e-05 - val_loss: 1.2990e-05 - val_categorical_crossentropy: 1.2990e-05 - lr: 1.2500e-04
# Epoch 78/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.2552e-05 - categorical_crossentropy: 1.2552e-05 - val_loss: 1.2978e-05 - val_categorical_crossentropy: 1.2978e-05 - lr: 1.2500e-04
# Epoch 79/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.2523e-05 - categorical_crossentropy: 1.2523e-05 - val_loss: 1.2950e-05 - val_categorical_crossentropy: 1.2950e-05 - lr: 1.2500e-04
# Epoch 80/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.2503e-05 - categorical_crossentropy: 1.2503e-05 - val_loss: 1.2934e-05 - val_categorical_crossentropy: 1.2934e-05 - lr: 1.2500e-04
# Epoch 81/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.2478e-05 - categorical_crossentropy: 1.2478e-05 - val_loss: 1.2918e-05 - val_categorical_crossentropy: 1.2918e-05 - lr: 1.2500e-04
# Epoch 82/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.2457e-05 - categorical_crossentropy: 1.2457e-05 - val_loss: 1.2894e-05 - val_categorical_crossentropy: 1.2894e-05 - lr: 1.2500e-04
# Epoch 83/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1.2438e-05 - categorical_crossentropy: 1.2438e-05 - val_loss: 1.2878e-05 - val_categorical_crossentropy: 1.2878e-05 - lr: 1.2500e-04
# Epoch 84/500
# 4/4 [==============================] - 0s 117ms/step - loss: 1.2410e-05 - categorical_crossentropy: 1.2410e-05 - val_loss: 1.2855e-05 - val_categorical_crossentropy: 1.2855e-05 - lr: 1.2500e-04
# Epoch 85/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.2389e-05 - categorical_crossentropy: 1.2389e-05 - val_loss: 1.2823e-05 - val_categorical_crossentropy: 1.2823e-05 - lr: 1.2500e-04
# Epoch 86/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.2363e-05 - categorical_crossentropy: 1.2363e-05 - val_loss: 1.2815e-05 - val_categorical_crossentropy: 1.2815e-05 - lr: 1.2500e-04
# Epoch 87/500
# 4/4 [==============================] - 0s 64ms/step - loss: 1.2339e-05 - categorical_crossentropy: 1.2339e-05 - val_loss: 1.2783e-05 - val_categorical_crossentropy: 1.2783e-05 - lr: 1.2500e-04
# Epoch 88/500
# 4/4 [==============================] - 0s 56ms/step - loss: 1.2323e-05 - categorical_crossentropy: 1.2323e-05 - val_loss: 1.2767e-05 - val_categorical_crossentropy: 1.2767e-05 - lr: 1.2500e-04
# Epoch 89/500
# 4/4 [==============================] - 0s 57ms/step - loss: 1.2292e-05 - categorical_crossentropy: 1.2292e-05 - val_loss: 1.2755e-05 - val_categorical_crossentropy: 1.2755e-05 - lr: 1.2500e-04
# Epoch 90/500
# 4/4 [==============================] - 0s 60ms/step - loss: 1.2272e-05 - categorical_crossentropy: 1.2272e-05 - val_loss: 1.2735e-05 - val_categorical_crossentropy: 1.2735e-05 - lr: 1.2500e-04
# Epoch 91/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.2249e-05 - categorical_crossentropy: 1.2249e-05 - val_loss: 1.2700e-05 - val_categorical_crossentropy: 1.2700e-05 - lr: 1.2500e-04
# Epoch 92/500
# 4/4 [==============================] - 0s 117ms/step - loss: 1.2225e-05 - categorical_crossentropy: 1.2225e-05 - val_loss: 1.2688e-05 - val_categorical_crossentropy: 1.2688e-05 - lr: 1.2500e-04
# Epoch 93/500
# 4/4 [==============================] - 0s 96ms/step - loss: 1.2208e-05 - categorical_crossentropy: 1.2208e-05 - val_loss: 1.2672e-05 - val_categorical_crossentropy: 1.2672e-05 - lr: 1.0000e-04
# Epoch 94/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.2190e-05 - categorical_crossentropy: 1.2190e-05 - val_loss: 1.2640e-05 - val_categorical_crossentropy: 1.2640e-05 - lr: 1.0000e-04
# Epoch 95/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.2169e-05 - categorical_crossentropy: 1.2169e-05 - val_loss: 1.2636e-05 - val_categorical_crossentropy: 1.2636e-05 - lr: 1.0000e-04
# Epoch 96/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.2149e-05 - categorical_crossentropy: 1.2149e-05 - val_loss: 1.2624e-05 - val_categorical_crossentropy: 1.2624e-05 - lr: 1.0000e-04
# Epoch 97/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.2134e-05 - categorical_crossentropy: 1.2134e-05 - val_loss: 1.2608e-05 - val_categorical_crossentropy: 1.2608e-05 - lr: 1.0000e-04
# Epoch 98/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.2117e-05 - categorical_crossentropy: 1.2117e-05 - val_loss: 1.2584e-05 - val_categorical_crossentropy: 1.2584e-05 - lr: 1.0000e-04
# Epoch 99/500
# 4/4 [==============================] - 0s 66ms/step - loss: 1.2098e-05 - categorical_crossentropy: 1.2098e-05 - val_loss: 1.2569e-05 - val_categorical_crossentropy: 1.2569e-05 - lr: 1.0000e-04
# Epoch 100/500
# 4/4 [==============================] - 0s 72ms/step - loss: 1.2076e-05 - categorical_crossentropy: 1.2076e-05 - val_loss: 1.2557e-05 - val_categorical_crossentropy: 1.2557e-05 - lr: 1.0000e-04
# Epoch 101/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1.2061e-05 - categorical_crossentropy: 1.2061e-05 - val_loss: 1.2533e-05 - val_categorical_crossentropy: 1.2533e-05 - lr: 1.0000e-04
# Epoch 102/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.2039e-05 - categorical_crossentropy: 1.2039e-05 - val_loss: 1.2517e-05 - val_categorical_crossentropy: 1.2517e-05 - lr: 1.0000e-04
# Epoch 103/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.2020e-05 - categorical_crossentropy: 1.2020e-05 - val_loss: 1.2501e-05 - val_categorical_crossentropy: 1.2501e-05 - lr: 1.0000e-04
# Epoch 104/500
# 4/4 [==============================] - 0s 73ms/step - loss: 1.1998e-05 - categorical_crossentropy: 1.1998e-05 - val_loss: 1.2489e-05 - val_categorical_crossentropy: 1.2489e-05 - lr: 1.0000e-04
# Epoch 105/500
# 4/4 [==============================] - 0s 63ms/step - loss: 1.1980e-05 - categorical_crossentropy: 1.1980e-05 - val_loss: 1.2469e-05 - val_categorical_crossentropy: 1.2469e-05 - lr: 1.0000e-04
# Epoch 106/500
# 4/4 [==============================] - 0s 61ms/step - loss: 1.1964e-05 - categorical_crossentropy: 1.1964e-05 - val_loss: 1.2449e-05 - val_categorical_crossentropy: 1.2449e-05 - lr: 1.0000e-04
# Epoch 107/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.1946e-05 - categorical_crossentropy: 1.1946e-05 - val_loss: 1.2426e-05 - val_categorical_crossentropy: 1.2426e-05 - lr: 1.0000e-04
# Epoch 108/500
# 4/4 [==============================] - 0s 71ms/step - loss: 1.1922e-05 - categorical_crossentropy: 1.1922e-05 - val_loss: 1.2414e-05 - val_categorical_crossentropy: 1.2414e-05 - lr: 1.0000e-04
# Epoch 109/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.1904e-05 - categorical_crossentropy: 1.1904e-05 - val_loss: 1.2394e-05 - val_categorical_crossentropy: 1.2394e-05 - lr: 1.0000e-04
# Epoch 110/500
# 4/4 [==============================] - 0s 70ms/step - loss: 1.1891e-05 - categorical_crossentropy: 1.1891e-05 - val_loss: 1.2374e-05 - val_categorical_crossentropy: 1.2374e-05 - lr: 1.0000e-04
# Epoch 111/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.1873e-05 - categorical_crossentropy: 1.1873e-05 - val_loss: 1.2366e-05 - val_categorical_crossentropy: 1.2366e-05 - lr: 1.0000e-04
# Epoch 112/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.1850e-05 - categorical_crossentropy: 1.1850e-05 - val_loss: 1.2342e-05 - val_categorical_crossentropy: 1.2342e-05 - lr: 1.0000e-04
# Epoch 113/500
# 4/4 [==============================] - 0s 121ms/step - loss: 1.1831e-05 - categorical_crossentropy: 1.1831e-05 - val_loss: 1.2322e-05 - val_categorical_crossentropy: 1.2322e-05 - lr: 1.0000e-04
# Epoch 114/500
# 4/4 [==============================] - 0s 109ms/step - loss: 1.1816e-05 - categorical_crossentropy: 1.1816e-05 - val_loss: 1.2310e-05 - val_categorical_crossentropy: 1.2310e-05 - lr: 1.0000e-04
# Epoch 115/500
# 4/4 [==============================] - 0s 91ms/step - loss: 1.1797e-05 - categorical_crossentropy: 1.1797e-05 - val_loss: 1.2290e-05 - val_categorical_crossentropy: 1.2290e-05 - lr: 1.0000e-04
# Epoch 116/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.1773e-05 - categorical_crossentropy: 1.1773e-05 - val_loss: 1.2275e-05 - val_categorical_crossentropy: 1.2275e-05 - lr: 1.0000e-04
# Epoch 117/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.1752e-05 - categorical_crossentropy: 1.1752e-05 - val_loss: 1.2259e-05 - val_categorical_crossentropy: 1.2259e-05 - lr: 1.0000e-04
# Epoch 118/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.1736e-05 - categorical_crossentropy: 1.1736e-05 - val_loss: 1.2243e-05 - val_categorical_crossentropy: 1.2243e-05 - lr: 1.0000e-04
# Epoch 119/500
# 4/4 [==============================] - 0s 75ms/step - loss: 1.1716e-05 - categorical_crossentropy: 1.1716e-05 - val_loss: 1.2211e-05 - val_categorical_crossentropy: 1.2211e-05 - lr: 1.0000e-04
# Epoch 120/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.1695e-05 - categorical_crossentropy: 1.1695e-05 - val_loss: 1.2199e-05 - val_categorical_crossentropy: 1.2199e-05 - lr: 1.0000e-04
# Epoch 121/500
# 4/4 [==============================] - 0s 71ms/step - loss: 1.1679e-05 - categorical_crossentropy: 1.1679e-05 - val_loss: 1.2187e-05 - val_categorical_crossentropy: 1.2187e-05 - lr: 1.0000e-04
# Epoch 122/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.1662e-05 - categorical_crossentropy: 1.1662e-05 - val_loss: 1.2167e-05 - val_categorical_crossentropy: 1.2167e-05 - lr: 1.0000e-04
# Epoch 123/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.1641e-05 - categorical_crossentropy: 1.1641e-05 - val_loss: 1.2139e-05 - val_categorical_crossentropy: 1.2139e-05 - lr: 1.0000e-04
# Epoch 124/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.1620e-05 - categorical_crossentropy: 1.1620e-05 - val_loss: 1.2131e-05 - val_categorical_crossentropy: 1.2131e-05 - lr: 1.0000e-04
# Epoch 125/500
# 4/4 [==============================] - 0s 118ms/step - loss: 1.1600e-05 - categorical_crossentropy: 1.1600e-05 - val_loss: 1.2116e-05 - val_categorical_crossentropy: 1.2116e-05 - lr: 1.0000e-04
# Epoch 126/500
# 4/4 [==============================] - 0s 130ms/step - loss: 1.1583e-05 - categorical_crossentropy: 1.1583e-05 - val_loss: 1.2100e-05 - val_categorical_crossentropy: 1.2100e-05 - lr: 1.0000e-04
# Epoch 127/500
# 4/4 [==============================] - 0s 70ms/step - loss: 1.1562e-05 - categorical_crossentropy: 1.1562e-05 - val_loss: 1.2084e-05 - val_categorical_crossentropy: 1.2084e-05 - lr: 1.0000e-04
# Epoch 128/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.1542e-05 - categorical_crossentropy: 1.1542e-05 - val_loss: 1.2060e-05 - val_categorical_crossentropy: 1.2060e-05 - lr: 1.0000e-04
# Epoch 129/500
# 4/4 [==============================] - 0s 137ms/step - loss: 1.1524e-05 - categorical_crossentropy: 1.1524e-05 - val_loss: 1.2040e-05 - val_categorical_crossentropy: 1.2040e-05 - lr: 1.0000e-04
# Epoch 130/500
# 4/4 [==============================] - 1s 137ms/step - loss: 1.1507e-05 - categorical_crossentropy: 1.1507e-05 - val_loss: 1.2024e-05 - val_categorical_crossentropy: 1.2024e-05 - lr: 1.0000e-04
# Epoch 131/500
# 4/4 [==============================] - 0s 117ms/step - loss: 1.1485e-05 - categorical_crossentropy: 1.1485e-05 - val_loss: 1.2008e-05 - val_categorical_crossentropy: 1.2008e-05 - lr: 1.0000e-04
# Epoch 132/500
# 4/4 [==============================] - 0s 118ms/step - loss: 1.1467e-05 - categorical_crossentropy: 1.1467e-05 - val_loss: 1.1973e-05 - val_categorical_crossentropy: 1.1973e-05 - lr: 1.0000e-04
# Epoch 133/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.1447e-05 - categorical_crossentropy: 1.1447e-05 - val_loss: 1.1969e-05 - val_categorical_crossentropy: 1.1969e-05 - lr: 1.0000e-04
# Epoch 134/500
# 4/4 [==============================] - 0s 135ms/step - loss: 1.1430e-05 - categorical_crossentropy: 1.1430e-05 - val_loss: 1.1961e-05 - val_categorical_crossentropy: 1.1961e-05 - lr: 1.0000e-04
# Epoch 135/500
# 4/4 [==============================] - 1s 147ms/step - loss: 1.1413e-05 - categorical_crossentropy: 1.1413e-05 - val_loss: 1.1933e-05 - val_categorical_crossentropy: 1.1933e-05 - lr: 1.0000e-04
# Epoch 136/500
# 4/4 [==============================] - 0s 116ms/step - loss: 1.1392e-05 - categorical_crossentropy: 1.1392e-05 - val_loss: 1.1909e-05 - val_categorical_crossentropy: 1.1909e-05 - lr: 1.0000e-04
# Epoch 137/500
# 4/4 [==============================] - 0s 91ms/step - loss: 1.1370e-05 - categorical_crossentropy: 1.1370e-05 - val_loss: 1.1885e-05 - val_categorical_crossentropy: 1.1885e-05 - lr: 1.0000e-04
# Epoch 138/500
# 4/4 [==============================] - 0s 62ms/step - loss: 1.1349e-05 - categorical_crossentropy: 1.1349e-05 - val_loss: 1.1885e-05 - val_categorical_crossentropy: 1.1885e-05 - lr: 1.0000e-04
# Epoch 139/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.1334e-05 - categorical_crossentropy: 1.1334e-05 - val_loss: 1.1865e-05 - val_categorical_crossentropy: 1.1865e-05 - lr: 1.0000e-04
# Epoch 140/500
# 4/4 [==============================] - 0s 115ms/step - loss: 1.1313e-05 - categorical_crossentropy: 1.1313e-05 - val_loss: 1.1849e-05 - val_categorical_crossentropy: 1.1849e-05 - lr: 1.0000e-04
# Epoch 141/500
# 4/4 [==============================] - 0s 129ms/step - loss: 1.1298e-05 - categorical_crossentropy: 1.1298e-05 - val_loss: 1.1818e-05 - val_categorical_crossentropy: 1.1818e-05 - lr: 1.0000e-04
# Epoch 142/500
# 4/4 [==============================] - 0s 138ms/step - loss: 1.1275e-05 - categorical_crossentropy: 1.1275e-05 - val_loss: 1.1802e-05 - val_categorical_crossentropy: 1.1802e-05 - lr: 1.0000e-04
# Epoch 143/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1.1251e-05 - categorical_crossentropy: 1.1251e-05 - val_loss: 1.1782e-05 - val_categorical_crossentropy: 1.1782e-05 - lr: 1.0000e-04
# Epoch 144/500
# 4/4 [==============================] - 0s 119ms/step - loss: 1.1235e-05 - categorical_crossentropy: 1.1235e-05 - val_loss: 1.1770e-05 - val_categorical_crossentropy: 1.1770e-05 - lr: 1.0000e-04
# Epoch 145/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.1222e-05 - categorical_crossentropy: 1.1222e-05 - val_loss: 1.1758e-05 - val_categorical_crossentropy: 1.1758e-05 - lr: 1.0000e-04
# Epoch 146/500
# 4/4 [==============================] - 0s 119ms/step - loss: 1.1198e-05 - categorical_crossentropy: 1.1198e-05 - val_loss: 1.1738e-05 - val_categorical_crossentropy: 1.1738e-05 - lr: 1.0000e-04
# Epoch 147/500
# 4/4 [==============================] - 0s 122ms/step - loss: 1.1176e-05 - categorical_crossentropy: 1.1176e-05 - val_loss: 1.1702e-05 - val_categorical_crossentropy: 1.1702e-05 - lr: 1.0000e-04
# Epoch 148/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.1164e-05 - categorical_crossentropy: 1.1164e-05 - val_loss: 1.1694e-05 - val_categorical_crossentropy: 1.1694e-05 - lr: 1.0000e-04
# Epoch 149/500
# 4/4 [==============================] - 0s 124ms/step - loss: 1.1143e-05 - categorical_crossentropy: 1.1143e-05 - val_loss: 1.1678e-05 - val_categorical_crossentropy: 1.1678e-05 - lr: 1.0000e-04
# Epoch 150/500
# 4/4 [==============================] - 0s 119ms/step - loss: 1.1119e-05 - categorical_crossentropy: 1.1119e-05 - val_loss: 1.1667e-05 - val_categorical_crossentropy: 1.1667e-05 - lr: 1.0000e-04
# Epoch 151/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.1092e-05 - categorical_crossentropy: 1.1092e-05 - val_loss: 1.1643e-05 - val_categorical_crossentropy: 1.1643e-05 - lr: 1.0000e-04
# Epoch 152/500
# 4/4 [==============================] - 0s 122ms/step - loss: 1.1079e-05 - categorical_crossentropy: 1.1079e-05 - val_loss: 1.1627e-05 - val_categorical_crossentropy: 1.1627e-05 - lr: 1.0000e-04
# Epoch 153/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1.1065e-05 - categorical_crossentropy: 1.1065e-05 - val_loss: 1.1599e-05 - val_categorical_crossentropy: 1.1599e-05 - lr: 1.0000e-04
# Epoch 154/500
# 4/4 [==============================] - 1s 154ms/step - loss: 1.1042e-05 - categorical_crossentropy: 1.1042e-05 - val_loss: 1.1579e-05 - val_categorical_crossentropy: 1.1579e-05 - lr: 1.0000e-04
# Epoch 155/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1.1017e-05 - categorical_crossentropy: 1.1017e-05 - val_loss: 1.1567e-05 - val_categorical_crossentropy: 1.1567e-05 - lr: 1.0000e-04
# Epoch 156/500
# 4/4 [==============================] - 1s 139ms/step - loss: 1.1007e-05 - categorical_crossentropy: 1.1007e-05 - val_loss: 1.1547e-05 - val_categorical_crossentropy: 1.1547e-05 - lr: 1.0000e-04
# Epoch 157/500
# 4/4 [==============================] - 0s 142ms/step - loss: 1.0993e-05 - categorical_crossentropy: 1.0993e-05 - val_loss: 1.1531e-05 - val_categorical_crossentropy: 1.1531e-05 - lr: 1.0000e-04
# Epoch 158/500
# 4/4 [==============================] - 0s 127ms/step - loss: 1.0968e-05 - categorical_crossentropy: 1.0968e-05 - val_loss: 1.1512e-05 - val_categorical_crossentropy: 1.1512e-05 - lr: 1.0000e-04
# Epoch 159/500
# 4/4 [==============================] - 1s 152ms/step - loss: 1.0946e-05 - categorical_crossentropy: 1.0946e-05 - val_loss: 1.1488e-05 - val_categorical_crossentropy: 1.1488e-05 - lr: 1.0000e-04
# Epoch 160/500
# 4/4 [==============================] - 0s 126ms/step - loss: 1.0928e-05 - categorical_crossentropy: 1.0928e-05 - val_loss: 1.1480e-05 - val_categorical_crossentropy: 1.1480e-05 - lr: 1.0000e-04
# Epoch 161/500
# 4/4 [==============================] - 0s 111ms/step - loss: 1.0909e-05 - categorical_crossentropy: 1.0909e-05 - val_loss: 1.1468e-05 - val_categorical_crossentropy: 1.1468e-05 - lr: 1.0000e-04
# Epoch 162/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0888e-05 - categorical_crossentropy: 1.0888e-05 - val_loss: 1.1444e-05 - val_categorical_crossentropy: 1.1444e-05 - lr: 1.0000e-04
# Epoch 163/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.0868e-05 - categorical_crossentropy: 1.0868e-05 - val_loss: 1.1412e-05 - val_categorical_crossentropy: 1.1412e-05 - lr: 1.0000e-04
# Epoch 164/500
# 4/4 [==============================] - 0s 113ms/step - loss: 1.0849e-05 - categorical_crossentropy: 1.0849e-05 - val_loss: 1.1392e-05 - val_categorical_crossentropy: 1.1392e-05 - lr: 1.0000e-04
# Epoch 165/500
# 4/4 [==============================] - 0s 113ms/step - loss: 1.0829e-05 - categorical_crossentropy: 1.0829e-05 - val_loss: 1.1388e-05 - val_categorical_crossentropy: 1.1388e-05 - lr: 1.0000e-04
# Epoch 166/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.0813e-05 - categorical_crossentropy: 1.0813e-05 - val_loss: 1.1365e-05 - val_categorical_crossentropy: 1.1365e-05 - lr: 1.0000e-04
# Epoch 167/500
# 4/4 [==============================] - 0s 110ms/step - loss: 1.0795e-05 - categorical_crossentropy: 1.0795e-05 - val_loss: 1.1341e-05 - val_categorical_crossentropy: 1.1341e-05 - lr: 1.0000e-04
# Epoch 168/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.0775e-05 - categorical_crossentropy: 1.0775e-05 - val_loss: 1.1325e-05 - val_categorical_crossentropy: 1.1325e-05 - lr: 1.0000e-04
# Epoch 169/500
# 4/4 [==============================] - 0s 141ms/step - loss: 1.0752e-05 - categorical_crossentropy: 1.0752e-05 - val_loss: 1.1313e-05 - val_categorical_crossentropy: 1.1313e-05 - lr: 1.0000e-04
# Epoch 170/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.0735e-05 - categorical_crossentropy: 1.0735e-05 - val_loss: 1.1301e-05 - val_categorical_crossentropy: 1.1301e-05 - lr: 1.0000e-04
# Epoch 171/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.0717e-05 - categorical_crossentropy: 1.0717e-05 - val_loss: 1.1281e-05 - val_categorical_crossentropy: 1.1281e-05 - lr: 1.0000e-04
# Epoch 172/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.0701e-05 - categorical_crossentropy: 1.0701e-05 - val_loss: 1.1241e-05 - val_categorical_crossentropy: 1.1241e-05 - lr: 1.0000e-04
# Epoch 173/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.0675e-05 - categorical_crossentropy: 1.0675e-05 - val_loss: 1.1233e-05 - val_categorical_crossentropy: 1.1233e-05 - lr: 1.0000e-04
# Epoch 174/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0653e-05 - categorical_crossentropy: 1.0653e-05 - val_loss: 1.1218e-05 - val_categorical_crossentropy: 1.1218e-05 - lr: 1.0000e-04
# Epoch 175/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.0637e-05 - categorical_crossentropy: 1.0637e-05 - val_loss: 1.1206e-05 - val_categorical_crossentropy: 1.1206e-05 - lr: 1.0000e-04
# Epoch 176/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.0625e-05 - categorical_crossentropy: 1.0625e-05 - val_loss: 1.1178e-05 - val_categorical_crossentropy: 1.1178e-05 - lr: 1.0000e-04
# Epoch 177/500
# 4/4 [==============================] - 0s 69ms/step - loss: 1.0602e-05 - categorical_crossentropy: 1.0602e-05 - val_loss: 1.1154e-05 - val_categorical_crossentropy: 1.1154e-05 - lr: 1.0000e-04
# Epoch 178/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.0574e-05 - categorical_crossentropy: 1.0574e-05 - val_loss: 1.1150e-05 - val_categorical_crossentropy: 1.1150e-05 - lr: 1.0000e-04
# Epoch 179/500
# 4/4 [==============================] - 0s 107ms/step - loss: 1.0560e-05 - categorical_crossentropy: 1.0560e-05 - val_loss: 1.1138e-05 - val_categorical_crossentropy: 1.1138e-05 - lr: 1.0000e-04
# Epoch 180/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.0545e-05 - categorical_crossentropy: 1.0545e-05 - val_loss: 1.1114e-05 - val_categorical_crossentropy: 1.1114e-05 - lr: 1.0000e-04
# Epoch 181/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0529e-05 - categorical_crossentropy: 1.0529e-05 - val_loss: 1.1086e-05 - val_categorical_crossentropy: 1.1086e-05 - lr: 1.0000e-04
# Epoch 182/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.0507e-05 - categorical_crossentropy: 1.0507e-05 - val_loss: 1.1063e-05 - val_categorical_crossentropy: 1.1063e-05 - lr: 1.0000e-04
# Epoch 183/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.0484e-05 - categorical_crossentropy: 1.0484e-05 - val_loss: 1.1059e-05 - val_categorical_crossentropy: 1.1059e-05 - lr: 1.0000e-04
# Epoch 184/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.0466e-05 - categorical_crossentropy: 1.0466e-05 - val_loss: 1.1039e-05 - val_categorical_crossentropy: 1.1039e-05 - lr: 1.0000e-04
# Epoch 185/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0448e-05 - categorical_crossentropy: 1.0448e-05 - val_loss: 1.1007e-05 - val_categorical_crossentropy: 1.1007e-05 - lr: 1.0000e-04
# Epoch 186/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.0429e-05 - categorical_crossentropy: 1.0429e-05 - val_loss: 1.0995e-05 - val_categorical_crossentropy: 1.0995e-05 - lr: 1.0000e-04
# Epoch 187/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.0408e-05 - categorical_crossentropy: 1.0408e-05 - val_loss: 1.0979e-05 - val_categorical_crossentropy: 1.0979e-05 - lr: 1.0000e-04
# Epoch 188/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.0390e-05 - categorical_crossentropy: 1.0390e-05 - val_loss: 1.0967e-05 - val_categorical_crossentropy: 1.0967e-05 - lr: 1.0000e-04
# Epoch 189/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.0367e-05 - categorical_crossentropy: 1.0367e-05 - val_loss: 1.0943e-05 - val_categorical_crossentropy: 1.0943e-05 - lr: 1.0000e-04
# Epoch 190/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.0354e-05 - categorical_crossentropy: 1.0354e-05 - val_loss: 1.0927e-05 - val_categorical_crossentropy: 1.0927e-05 - lr: 1.0000e-04
# Epoch 191/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.0338e-05 - categorical_crossentropy: 1.0338e-05 - val_loss: 1.0900e-05 - val_categorical_crossentropy: 1.0900e-05 - lr: 1.0000e-04
# Epoch 192/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.0320e-05 - categorical_crossentropy: 1.0320e-05 - val_loss: 1.0892e-05 - val_categorical_crossentropy: 1.0892e-05 - lr: 1.0000e-04
# Epoch 193/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.0298e-05 - categorical_crossentropy: 1.0298e-05 - val_loss: 1.0856e-05 - val_categorical_crossentropy: 1.0856e-05 - lr: 1.0000e-04
# Epoch 194/500
# 4/4 [==============================] - 0s 66ms/step - loss: 1.0276e-05 - categorical_crossentropy: 1.0276e-05 - val_loss: 1.0852e-05 - val_categorical_crossentropy: 1.0852e-05 - lr: 1.0000e-04
# Epoch 195/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.0256e-05 - categorical_crossentropy: 1.0256e-05 - val_loss: 1.0840e-05 - val_categorical_crossentropy: 1.0840e-05 - lr: 1.0000e-04
# Epoch 196/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0235e-05 - categorical_crossentropy: 1.0235e-05 - val_loss: 1.0820e-05 - val_categorical_crossentropy: 1.0820e-05 - lr: 1.0000e-04
# Epoch 197/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.0220e-05 - categorical_crossentropy: 1.0220e-05 - val_loss: 1.0804e-05 - val_categorical_crossentropy: 1.0804e-05 - lr: 1.0000e-04
# Epoch 198/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.0202e-05 - categorical_crossentropy: 1.0202e-05 - val_loss: 1.0780e-05 - val_categorical_crossentropy: 1.0780e-05 - lr: 1.0000e-04
# Epoch 199/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.0185e-05 - categorical_crossentropy: 1.0185e-05 - val_loss: 1.0749e-05 - val_categorical_crossentropy: 1.0749e-05 - lr: 1.0000e-04
# Epoch 200/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.0166e-05 - categorical_crossentropy: 1.0166e-05 - val_loss: 1.0737e-05 - val_categorical_crossentropy: 1.0737e-05 - lr: 1.0000e-04
# Epoch 201/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.0150e-05 - categorical_crossentropy: 1.0150e-05 - val_loss: 1.0717e-05 - val_categorical_crossentropy: 1.0717e-05 - lr: 1.0000e-04
# Epoch 202/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.0128e-05 - categorical_crossentropy: 1.0128e-05 - val_loss: 1.0701e-05 - val_categorical_crossentropy: 1.0701e-05 - lr: 1.0000e-04
# Epoch 203/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.0106e-05 - categorical_crossentropy: 1.0106e-05 - val_loss: 1.0681e-05 - val_categorical_crossentropy: 1.0681e-05 - lr: 1.0000e-04
# Epoch 204/500
# 4/4 [==============================] - 0s 96ms/step - loss: 1.0086e-05 - categorical_crossentropy: 1.0086e-05 - val_loss: 1.0665e-05 - val_categorical_crossentropy: 1.0665e-05 - lr: 1.0000e-04
# Epoch 205/500
# 4/4 [==============================] - 0s 99ms/step - loss: 1.0072e-05 - categorical_crossentropy: 1.0072e-05 - val_loss: 1.0657e-05 - val_categorical_crossentropy: 1.0657e-05 - lr: 1.0000e-04
# Epoch 206/500
# 4/4 [==============================] - 0s 98ms/step - loss: 1.0056e-05 - categorical_crossentropy: 1.0056e-05 - val_loss: 1.0637e-05 - val_categorical_crossentropy: 1.0637e-05 - lr: 1.0000e-04
# Epoch 207/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.0032e-05 - categorical_crossentropy: 1.0032e-05 - val_loss: 1.0610e-05 - val_categorical_crossentropy: 1.0610e-05 - lr: 1.0000e-04
# Epoch 208/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.0016e-05 - categorical_crossentropy: 1.0016e-05 - val_loss: 1.0602e-05 - val_categorical_crossentropy: 1.0602e-05 - lr: 1.0000e-04
# Epoch 209/500
# 4/4 [==============================] - 0s 65ms/step - loss: 9.9976e-06 - categorical_crossentropy: 9.9976e-06 - val_loss: 1.0574e-05 - val_categorical_crossentropy: 1.0574e-05 - lr: 1.0000e-04
# Epoch 210/500
# 4/4 [==============================] - 0s 58ms/step - loss: 9.9778e-06 - categorical_crossentropy: 9.9778e-06 - val_loss: 1.0554e-05 - val_categorical_crossentropy: 1.0554e-05 - lr: 1.0000e-04
# Epoch 211/500
# 4/4 [==============================] - 0s 62ms/step - loss: 9.9639e-06 - categorical_crossentropy: 9.9639e-06 - val_loss: 1.0522e-05 - val_categorical_crossentropy: 1.0522e-05 - lr: 1.0000e-04
# Epoch 212/500
# 4/4 [==============================] - 0s 91ms/step - loss: 9.9380e-06 - categorical_crossentropy: 9.9380e-06 - val_loss: 1.0518e-05 - val_categorical_crossentropy: 1.0518e-05 - lr: 1.0000e-04
# Epoch 213/500
# 4/4 [==============================] - 0s 82ms/step - loss: 9.9211e-06 - categorical_crossentropy: 9.9211e-06 - val_loss: 1.0514e-05 - val_categorical_crossentropy: 1.0514e-05 - lr: 1.0000e-04
# Epoch 214/500
# 4/4 [==============================] - 0s 90ms/step - loss: 9.9013e-06 - categorical_crossentropy: 9.9013e-06 - val_loss: 1.0506e-05 - val_categorical_crossentropy: 1.0506e-05 - lr: 1.0000e-04
# Epoch 215/500
# 4/4 [==============================] - 0s 95ms/step - loss: 9.8854e-06 - categorical_crossentropy: 9.8854e-06 - val_loss: 1.0470e-05 - val_categorical_crossentropy: 1.0470e-05 - lr: 1.0000e-04
# Epoch 216/500
# 4/4 [==============================] - 0s 129ms/step - loss: 9.8745e-06 - categorical_crossentropy: 9.8745e-06 - val_loss: 1.0439e-05 - val_categorical_crossentropy: 1.0439e-05 - lr: 1.0000e-04
# Epoch 217/500
# 4/4 [==============================] - 0s 93ms/step - loss: 9.8476e-06 - categorical_crossentropy: 9.8476e-06 - val_loss: 1.0431e-05 - val_categorical_crossentropy: 1.0431e-05 - lr: 1.0000e-04
# Epoch 218/500
# 4/4 [==============================] - 0s 110ms/step - loss: 9.8288e-06 - categorical_crossentropy: 9.8288e-06 - val_loss: 1.0415e-05 - val_categorical_crossentropy: 1.0415e-05 - lr: 1.0000e-04
# Epoch 219/500
# 4/4 [==============================] - 0s 84ms/step - loss: 9.8099e-06 - categorical_crossentropy: 9.8099e-06 - val_loss: 1.0399e-05 - val_categorical_crossentropy: 1.0399e-05 - lr: 1.0000e-04
# Epoch 220/500
# 4/4 [==============================] - 0s 82ms/step - loss: 9.7970e-06 - categorical_crossentropy: 9.7970e-06 - val_loss: 1.0375e-05 - val_categorical_crossentropy: 1.0375e-05 - lr: 1.0000e-04
# Epoch 221/500
# 4/4 [==============================] - 0s 100ms/step - loss: 9.7781e-06 - categorical_crossentropy: 9.7781e-06 - val_loss: 1.0351e-05 - val_categorical_crossentropy: 1.0351e-05 - lr: 1.0000e-04
# Epoch 222/500
# 4/4 [==============================] - 0s 96ms/step - loss: 9.7523e-06 - categorical_crossentropy: 9.7523e-06 - val_loss: 1.0347e-05 - val_categorical_crossentropy: 1.0347e-05 - lr: 1.0000e-04
# Epoch 223/500
# 4/4 [==============================] - 0s 94ms/step - loss: 9.7324e-06 - categorical_crossentropy: 9.7324e-06 - val_loss: 1.0319e-05 - val_categorical_crossentropy: 1.0319e-05 - lr: 1.0000e-04
# Epoch 224/500
# 4/4 [==============================] - 0s 83ms/step - loss: 9.7215e-06 - categorical_crossentropy: 9.7215e-06 - val_loss: 1.0312e-05 - val_categorical_crossentropy: 1.0312e-05 - lr: 1.0000e-04
# Epoch 225/500
# 4/4 [==============================] - 0s 86ms/step - loss: 9.7006e-06 - categorical_crossentropy: 9.7006e-06 - val_loss: 1.0296e-05 - val_categorical_crossentropy: 1.0296e-05 - lr: 1.0000e-04
# Epoch 226/500
# 4/4 [==============================] - 0s 90ms/step - loss: 9.6887e-06 - categorical_crossentropy: 9.6887e-06 - val_loss: 1.0264e-05 - val_categorical_crossentropy: 1.0264e-05 - lr: 1.0000e-04
# Epoch 227/500
# 4/4 [==============================] - 0s 109ms/step - loss: 9.6688e-06 - categorical_crossentropy: 9.6688e-06 - val_loss: 1.0236e-05 - val_categorical_crossentropy: 1.0236e-05 - lr: 1.0000e-04
# Epoch 228/500
# 4/4 [==============================] - 0s 94ms/step - loss: 9.6420e-06 - categorical_crossentropy: 9.6420e-06 - val_loss: 1.0232e-05 - val_categorical_crossentropy: 1.0232e-05 - lr: 1.0000e-04
# Epoch 229/500
# 4/4 [==============================] - 0s 89ms/step - loss: 9.6231e-06 - categorical_crossentropy: 9.6231e-06 - val_loss: 1.0224e-05 - val_categorical_crossentropy: 1.0224e-05 - lr: 1.0000e-04
# Epoch 230/500
# 4/4 [==============================] - 0s 102ms/step - loss: 9.6062e-06 - categorical_crossentropy: 9.6062e-06 - val_loss: 1.0200e-05 - val_categorical_crossentropy: 1.0200e-05 - lr: 1.0000e-04
# Epoch 231/500
# 4/4 [==============================] - 0s 116ms/step - loss: 9.5973e-06 - categorical_crossentropy: 9.5973e-06 - val_loss: 1.0180e-05 - val_categorical_crossentropy: 1.0180e-05 - lr: 1.0000e-04
# Epoch 232/500
# 4/4 [==============================] - 0s 73ms/step - loss: 9.5834e-06 - categorical_crossentropy: 9.5834e-06 - val_loss: 1.0165e-05 - val_categorical_crossentropy: 1.0165e-05 - lr: 1.0000e-04
# Epoch 233/500
# 4/4 [==============================] - 0s 72ms/step - loss: 9.5635e-06 - categorical_crossentropy: 9.5635e-06 - val_loss: 1.0141e-05 - val_categorical_crossentropy: 1.0141e-05 - lr: 1.0000e-04
# Epoch 234/500
# ...
# Epoch 424/500
# 4/4 [==============================] - 0s 108ms/step - loss: 6.6648e-06 - categorical_crossentropy: 6.6648e-06 - val_loss: 7.2439e-06 - val_categorical_crossentropy: 7.2439e-06 - lr: 1.0000e-04
# Epoch 425/500
# 4/4 [==============================] - 0s 116ms/step - loss: 6.6499e-06 - categorical_crossentropy: 6.6499e-06 - val_loss: 7.2280e-06 - val_categorical_crossentropy: 7.2280e-06 - lr: 1.0000e-04
# Epoch 426/500
# 4/4 [==============================] - 0s 100ms/step - loss: 6.6350e-06 - categorical_crossentropy: 6.6350e-06 - val_loss: 7.2201e-06 - val_categorical_crossentropy: 7.2201e-06 - lr: 1.0000e-04
# Epoch 427/500
# 4/4 [==============================] - 0s 113ms/step - loss: 6.6240e-06 - categorical_crossentropy: 6.6240e-06 - val_loss: 7.2042e-06 - val_categorical_crossentropy: 7.2042e-06 - lr: 1.0000e-04
# Epoch 428/500
# 4/4 [==============================] - 0s 88ms/step - loss: 6.6181e-06 - categorical_crossentropy: 6.6181e-06 - val_loss: 7.2002e-06 - val_categorical_crossentropy: 7.2002e-06 - lr: 1.0000e-04
# Epoch 429/500
# 4/4 [==============================] - 0s 100ms/step - loss: 6.6081e-06 - categorical_crossentropy: 6.6081e-06 - val_loss: 7.1724e-06 - val_categorical_crossentropy: 7.1724e-06 - lr: 1.0000e-04
# Epoch 430/500
# 4/4 [==============================] - 0s 103ms/step - loss: 6.5972e-06 - categorical_crossentropy: 6.5972e-06 - val_loss: 7.1605e-06 - val_categorical_crossentropy: 7.1605e-06 - lr: 1.0000e-04
# Epoch 431/500
# 4/4 [==============================] - 0s 88ms/step - loss: 6.5744e-06 - categorical_crossentropy: 6.5744e-06 - val_loss: 7.1565e-06 - val_categorical_crossentropy: 7.1565e-06 - lr: 1.0000e-04
# Epoch 432/500
# 4/4 [==============================] - 0s 71ms/step - loss: 6.5615e-06 - categorical_crossentropy: 6.5615e-06 - val_loss: 7.1486e-06 - val_categorical_crossentropy: 7.1486e-06 - lr: 1.0000e-04
# Epoch 433/500
# 4/4 [==============================] - 0s 87ms/step - loss: 6.5515e-06 - categorical_crossentropy: 6.5515e-06 - val_loss: 7.1247e-06 - val_categorical_crossentropy: 7.1247e-06 - lr: 1.0000e-04
# Epoch 434/500
# 4/4 [==============================] - 0s 115ms/step - loss: 6.5406e-06 - categorical_crossentropy: 6.5406e-06 - val_loss: 7.1168e-06 - val_categorical_crossentropy: 7.1168e-06 - lr: 1.0000e-04
# Epoch 435/500
# 4/4 [==============================] - 0s 116ms/step - loss: 6.5257e-06 - categorical_crossentropy: 6.5257e-06 - val_loss: 7.1048e-06 - val_categorical_crossentropy: 7.1048e-06 - lr: 1.0000e-04
# Epoch 436/500
# 4/4 [==============================] - 0s 44ms/step - loss: 6.5098e-06 - categorical_crossentropy: 6.5098e-06 - val_loss: 7.1048e-06 - val_categorical_crossentropy: 7.1048e-06 - lr: 1.0000e-04
# Epoch 437/500
# 4/4 [==============================] - 0s 83ms/step - loss: 6.4989e-06 - categorical_crossentropy: 6.4989e-06 - val_loss: 7.0850e-06 - val_categorical_crossentropy: 7.0850e-06 - lr: 1.0000e-04
# Epoch 438/500
# 4/4 [==============================] - 0s 88ms/step - loss: 6.4909e-06 - categorical_crossentropy: 6.4909e-06 - val_loss: 7.0691e-06 - val_categorical_crossentropy: 7.0691e-06 - lr: 1.0000e-04
# Epoch 439/500
# 4/4 [==============================] - 0s 115ms/step - loss: 6.4830e-06 - categorical_crossentropy: 6.4830e-06 - val_loss: 7.0532e-06 - val_categorical_crossentropy: 7.0532e-06 - lr: 1.0000e-04
# Epoch 440/500
# 4/4 [==============================] - 0s 89ms/step - loss: 6.4701e-06 - categorical_crossentropy: 6.4701e-06 - val_loss: 7.0333e-06 - val_categorical_crossentropy: 7.0333e-06 - lr: 1.0000e-04
# Epoch 441/500
# 4/4 [==============================] - 0s 89ms/step - loss: 6.4571e-06 - categorical_crossentropy: 6.4571e-06 - val_loss: 7.0214e-06 - val_categorical_crossentropy: 7.0214e-06 - lr: 1.0000e-04
# Epoch 442/500
# 4/4 [==============================] - 0s 119ms/step - loss: 6.4442e-06 - categorical_crossentropy: 6.4442e-06 - val_loss: 7.0135e-06 - val_categorical_crossentropy: 7.0135e-06 - lr: 1.0000e-04
# Epoch 443/500
# 4/4 [==============================] - 0s 108ms/step - loss: 6.4313e-06 - categorical_crossentropy: 6.4313e-06 - val_loss: 6.9976e-06 - val_categorical_crossentropy: 6.9976e-06 - lr: 1.0000e-04
# Epoch 444/500
# 4/4 [==============================] - 0s 68ms/step - loss: 6.4204e-06 - categorical_crossentropy: 6.4204e-06 - val_loss: 6.9976e-06 - val_categorical_crossentropy: 6.9976e-06 - lr: 1.0000e-04
# Epoch 445/500
# 4/4 [==============================] - 0s 107ms/step - loss: 6.4035e-06 - categorical_crossentropy: 6.4035e-06 - val_loss: 6.9896e-06 - val_categorical_crossentropy: 6.9896e-06 - lr: 1.0000e-04
# Epoch 446/500
# 4/4 [==============================] - 0s 102ms/step - loss: 6.3886e-06 - categorical_crossentropy: 6.3886e-06 - val_loss: 6.9777e-06 - val_categorical_crossentropy: 6.9777e-06 - lr: 1.0000e-04
# Epoch 447/500
# 4/4 [==============================] - 0s 123ms/step - loss: 6.3797e-06 - categorical_crossentropy: 6.3797e-06 - val_loss: 6.9538e-06 - val_categorical_crossentropy: 6.9538e-06 - lr: 1.0000e-04
# Epoch 448/500
# 4/4 [==============================] - 0s 123ms/step - loss: 6.3737e-06 - categorical_crossentropy: 6.3737e-06 - val_loss: 6.9459e-06 - val_categorical_crossentropy: 6.9459e-06 - lr: 1.0000e-04
# Epoch 449/500
# 4/4 [==============================] - 0s 76ms/step - loss: 6.3648e-06 - categorical_crossentropy: 6.3648e-06 - val_loss: 6.9260e-06 - val_categorical_crossentropy: 6.9260e-06 - lr: 1.0000e-04
# Epoch 450/500
# 4/4 [==============================] - 0s 88ms/step - loss: 6.3518e-06 - categorical_crossentropy: 6.3518e-06 - val_loss: 6.9181e-06 - val_categorical_crossentropy: 6.9181e-06 - lr: 1.0000e-04
# Epoch 451/500
# 4/4 [==============================] - 0s 92ms/step - loss: 6.3369e-06 - categorical_crossentropy: 6.3369e-06 - val_loss: 6.8903e-06 - val_categorical_crossentropy: 6.8903e-06 - lr: 1.0000e-04
# Epoch 452/500
# 4/4 [==============================] - 0s 82ms/step - loss: 6.3230e-06 - categorical_crossentropy: 6.3230e-06 - val_loss: 6.8863e-06 - val_categorical_crossentropy: 6.8863e-06 - lr: 1.0000e-04
# Epoch 453/500
# 4/4 [==============================] - 0s 116ms/step - loss: 6.3161e-06 - categorical_crossentropy: 6.3161e-06 - val_loss: 6.8823e-06 - val_categorical_crossentropy: 6.8823e-06 - lr: 1.0000e-04
# Epoch 454/500
# 4/4 [==============================] - 0s 110ms/step - loss: 6.2982e-06 - categorical_crossentropy: 6.2982e-06 - val_loss: 6.8744e-06 - val_categorical_crossentropy: 6.8744e-06 - lr: 1.0000e-04
# Epoch 455/500
# 4/4 [==============================] - 0s 105ms/step - loss: 6.2873e-06 - categorical_crossentropy: 6.2873e-06 - val_loss: 6.8585e-06 - val_categorical_crossentropy: 6.8585e-06 - lr: 1.0000e-04
# Epoch 456/500
# 4/4 [==============================] - 0s 108ms/step - loss: 6.2724e-06 - categorical_crossentropy: 6.2724e-06 - val_loss: 6.8466e-06 - val_categorical_crossentropy: 6.8466e-06 - lr: 1.0000e-04
# Epoch 457/500
# 4/4 [==============================] - 0s 101ms/step - loss: 6.2634e-06 - categorical_crossentropy: 6.2634e-06 - val_loss: 6.8307e-06 - val_categorical_crossentropy: 6.8307e-06 - lr: 1.0000e-04
# Epoch 458/500
# 4/4 [==============================] - 0s 98ms/step - loss: 6.2495e-06 - categorical_crossentropy: 6.2495e-06 - val_loss: 6.8227e-06 - val_categorical_crossentropy: 6.8227e-06 - lr: 1.0000e-04
# Epoch 459/500
# 4/4 [==============================] - 0s 93ms/step - loss: 6.2386e-06 - categorical_crossentropy: 6.2386e-06 - val_loss: 6.7989e-06 - val_categorical_crossentropy: 6.7989e-06 - lr: 1.0000e-04
# Epoch 460/500
# 4/4 [==============================] - 0s 118ms/step - loss: 6.2277e-06 - categorical_crossentropy: 6.2277e-06 - val_loss: 6.7830e-06 - val_categorical_crossentropy: 6.7830e-06 - lr: 1.0000e-04
# Epoch 461/500
# 4/4 [==============================] - 0s 66ms/step - loss: 6.2177e-06 - categorical_crossentropy: 6.2177e-06 - val_loss: 6.7830e-06 - val_categorical_crossentropy: 6.7830e-06 - lr: 1.0000e-04
# Epoch 462/500
# 4/4 [==============================] - 0s 114ms/step - loss: 6.2068e-06 - categorical_crossentropy: 6.2068e-06 - val_loss: 6.7750e-06 - val_categorical_crossentropy: 6.7750e-06 - lr: 1.0000e-04
# Epoch 463/500
# 4/4 [==============================] - 0s 109ms/step - loss: 6.1929e-06 - categorical_crossentropy: 6.1929e-06 - val_loss: 6.7591e-06 - val_categorical_crossentropy: 6.7591e-06 - lr: 1.0000e-04
# Epoch 464/500
# 4/4 [==============================] - 0s 91ms/step - loss: 6.1810e-06 - categorical_crossentropy: 6.1810e-06 - val_loss: 6.7472e-06 - val_categorical_crossentropy: 6.7472e-06 - lr: 1.0000e-04
# Epoch 465/500
# 4/4 [==============================] - 0s 68ms/step - loss: 6.1701e-06 - categorical_crossentropy: 6.1701e-06 - val_loss: 6.7353e-06 - val_categorical_crossentropy: 6.7353e-06 - lr: 1.0000e-04
# Epoch 466/500
# 4/4 [==============================] - 0s 104ms/step - loss: 6.1611e-06 - categorical_crossentropy: 6.1611e-06 - val_loss: 6.7313e-06 - val_categorical_crossentropy: 6.7313e-06 - lr: 1.0000e-04
# Epoch 467/500
# 4/4 [==============================] - 0s 125ms/step - loss: 6.1442e-06 - categorical_crossentropy: 6.1442e-06 - val_loss: 6.7154e-06 - val_categorical_crossentropy: 6.7154e-06 - lr: 1.0000e-04
# Epoch 468/500
# 4/4 [==============================] - 0s 107ms/step - loss: 6.1373e-06 - categorical_crossentropy: 6.1373e-06 - val_loss: 6.6876e-06 - val_categorical_crossentropy: 6.6876e-06 - lr: 1.0000e-04
# Epoch 469/500
# 4/4 [==============================] - 0s 92ms/step - loss: 6.1224e-06 - categorical_crossentropy: 6.1224e-06 - val_loss: 6.6797e-06 - val_categorical_crossentropy: 6.6797e-06 - lr: 1.0000e-04
# Epoch 470/500
# 4/4 [==============================] - 0s 97ms/step - loss: 6.1134e-06 - categorical_crossentropy: 6.1134e-06 - val_loss: 6.6717e-06 - val_categorical_crossentropy: 6.6717e-06 - lr: 1.0000e-04
# Epoch 471/500
# 4/4 [==============================] - 0s 92ms/step - loss: 6.1025e-06 - categorical_crossentropy: 6.1025e-06 - val_loss: 6.6638e-06 - val_categorical_crossentropy: 6.6638e-06 - lr: 1.0000e-04
# Epoch 472/500
# 4/4 [==============================] - 0s 101ms/step - loss: 6.0876e-06 - categorical_crossentropy: 6.0876e-06 - val_loss: 6.6479e-06 - val_categorical_crossentropy: 6.6479e-06 - lr: 1.0000e-04
# Epoch 473/500
# 4/4 [==============================] - 0s 91ms/step - loss: 6.0737e-06 - categorical_crossentropy: 6.0737e-06 - val_loss: 6.6320e-06 - val_categorical_crossentropy: 6.6320e-06 - lr: 1.0000e-04
# Epoch 474/500
# 4/4 [==============================] - 0s 99ms/step - loss: 6.0618e-06 - categorical_crossentropy: 6.0618e-06 - val_loss: 6.6280e-06 - val_categorical_crossentropy: 6.6280e-06 - lr: 1.0000e-04
# Epoch 475/500
# 4/4 [==============================] - 0s 57ms/step - loss: 6.0538e-06 - categorical_crossentropy: 6.0538e-06 - val_loss: 6.6280e-06 - val_categorical_crossentropy: 6.6280e-06 - lr: 1.0000e-04
# Epoch 476/500
# 4/4 [==============================] - 0s 105ms/step - loss: 6.0449e-06 - categorical_crossentropy: 6.0449e-06 - val_loss: 6.6042e-06 - val_categorical_crossentropy: 6.6042e-06 - lr: 1.0000e-04
# Epoch 477/500
# 4/4 [==============================] - 0s 102ms/step - loss: 6.0349e-06 - categorical_crossentropy: 6.0349e-06 - val_loss: 6.5883e-06 - val_categorical_crossentropy: 6.5883e-06 - lr: 1.0000e-04
# Epoch 478/500
# 4/4 [==============================] - 0s 139ms/step - loss: 6.0230e-06 - categorical_crossentropy: 6.0230e-06 - val_loss: 6.5684e-06 - val_categorical_crossentropy: 6.5684e-06 - lr: 1.0000e-04
# Epoch 479/500
# 4/4 [==============================] - 0s 91ms/step - loss: 6.0091e-06 - categorical_crossentropy: 6.0091e-06 - val_loss: 6.5605e-06 - val_categorical_crossentropy: 6.5605e-06 - lr: 1.0000e-04
# Epoch 480/500
# 4/4 [==============================] - 0s 108ms/step - loss: 5.9922e-06 - categorical_crossentropy: 5.9922e-06 - val_loss: 6.5525e-06 - val_categorical_crossentropy: 6.5525e-06 - lr: 1.0000e-04
# Epoch 481/500
# 4/4 [==============================] - 0s 135ms/step - loss: 5.9833e-06 - categorical_crossentropy: 5.9833e-06 - val_loss: 6.5446e-06 - val_categorical_crossentropy: 6.5446e-06 - lr: 1.0000e-04
# Epoch 482/500
# 4/4 [==============================] - 0s 114ms/step - loss: 5.9704e-06 - categorical_crossentropy: 5.9704e-06 - val_loss: 6.5207e-06 - val_categorical_crossentropy: 6.5207e-06 - lr: 1.0000e-04
# Epoch 483/500
# 4/4 [==============================] - 0s 113ms/step - loss: 5.9595e-06 - categorical_crossentropy: 5.9595e-06 - val_loss: 6.5168e-06 - val_categorical_crossentropy: 6.5168e-06 - lr: 1.0000e-04
# Epoch 484/500
# 4/4 [==============================] - 0s 50ms/step - loss: 5.9485e-06 - categorical_crossentropy: 5.9485e-06 - val_loss: 6.5168e-06 - val_categorical_crossentropy: 6.5168e-06 - lr: 1.0000e-04
# Epoch 485/500
# 4/4 [==============================] - 0s 109ms/step - loss: 5.9406e-06 - categorical_crossentropy: 5.9406e-06 - val_loss: 6.4969e-06 - val_categorical_crossentropy: 6.4969e-06 - lr: 1.0000e-04
# Epoch 486/500
# 4/4 [==============================] - 0s 87ms/step - loss: 5.9326e-06 - categorical_crossentropy: 5.9326e-06 - val_loss: 6.4889e-06 - val_categorical_crossentropy: 6.4889e-06 - lr: 1.0000e-04
# Epoch 487/500
# 4/4 [==============================] - 0s 135ms/step - loss: 5.9207e-06 - categorical_crossentropy: 5.9207e-06 - val_loss: 6.4850e-06 - val_categorical_crossentropy: 6.4850e-06 - lr: 1.0000e-04
# Epoch 488/500
# 4/4 [==============================] - 0s 103ms/step - loss: 5.9078e-06 - categorical_crossentropy: 5.9078e-06 - val_loss: 6.4571e-06 - val_categorical_crossentropy: 6.4571e-06 - lr: 1.0000e-04
# Epoch 489/500
# 4/4 [==============================] - 0s 107ms/step - loss: 5.8959e-06 - categorical_crossentropy: 5.8959e-06 - val_loss: 6.4373e-06 - val_categorical_crossentropy: 6.4373e-06 - lr: 1.0000e-04
# Epoch 490/500
# 4/4 [==============================] - 0s 72ms/step - loss: 5.8810e-06 - categorical_crossentropy: 5.8810e-06 - val_loss: 6.4373e-06 - val_categorical_crossentropy: 6.4373e-06 - lr: 1.0000e-04
# Epoch 491/500
# 4/4 [==============================] - 0s 106ms/step - loss: 5.8700e-06 - categorical_crossentropy: 5.8700e-06 - val_loss: 6.4254e-06 - val_categorical_crossentropy: 6.4254e-06 - lr: 1.0000e-04
# Epoch 492/500
# 4/4 [==============================] - 0s 108ms/step - loss: 5.8581e-06 - categorical_crossentropy: 5.8581e-06 - val_loss: 6.4015e-06 - val_categorical_crossentropy: 6.4015e-06 - lr: 1.0000e-04
# Epoch 493/500
# 4/4 [==============================] - 0s 97ms/step - loss: 5.8482e-06 - categorical_crossentropy: 5.8482e-06 - val_loss: 6.3975e-06 - val_categorical_crossentropy: 6.3975e-06 - lr: 1.0000e-04
# Epoch 494/500
# 4/4 [==============================] - 0s 107ms/step - loss: 5.8343e-06 - categorical_crossentropy: 5.8343e-06 - val_loss: 6.3896e-06 - val_categorical_crossentropy: 6.3896e-06 - lr: 1.0000e-04
# Epoch 495/500
# 4/4 [==============================] - 0s 89ms/step - loss: 5.8263e-06 - categorical_crossentropy: 5.8263e-06 - val_loss: 6.3816e-06 - val_categorical_crossentropy: 6.3816e-06 - lr: 1.0000e-04
# Epoch 496/500
# 4/4 [==============================] - 0s 108ms/step - loss: 5.8194e-06 - categorical_crossentropy: 5.8194e-06 - val_loss: 6.3658e-06 - val_categorical_crossentropy: 6.3658e-06 - lr: 1.0000e-04
# Epoch 497/500
# 4/4 [==============================] - 0s 114ms/step - loss: 5.8075e-06 - categorical_crossentropy: 5.8075e-06 - val_loss: 6.3618e-06 - val_categorical_crossentropy: 6.3618e-06 - lr: 1.0000e-04
# Epoch 498/500
# 4/4 [==============================] - 0s 131ms/step - loss: 5.7945e-06 - categorical_crossentropy: 5.7945e-06 - val_loss: 6.3459e-06 - val_categorical_crossentropy: 6.3459e-06 - lr: 1.0000e-04
# Epoch 499/500
# 4/4 [==============================] - 0s 95ms/step - loss: 5.7836e-06 - categorical_crossentropy: 5.7836e-06 - val_loss: 6.3260e-06 - val_categorical_crossentropy: 6.3260e-06 - lr: 1.0000e-04
# Epoch 500/500
# 4/4 [==============================] - 0s 97ms/step - loss: 5.7717e-06 - categorical_crossentropy: 5.7717e-06 - val_loss: 6.3181e-06 - val_categorical_crossentropy: 6.3181e-06 - lr: 1.0000e-04

# %%
class ModelWrapper():
    def __init__(self,model):
        self.model=model
    def predict_proba(self,X):
        if isinstance(X, pd.DataFrame):
            X=X.values
        Xnn=X.reshape(X.shape[0],1,X.shape[1])
        return self.model.predict(Xnn)
    def predict(self, X):
        return np.argmax(self.predict_proba(X),axis=1)
clf=ModelWrapper(model)

# %% [markdown]
# ## SHAP
# We calculate SHAP for datasets

# %%
fXtrain = trainX.reshape(150,1,200)

# %%
from tsproto.utils import getshap

shap_version='deep'
bg_size = 1000
stride=10
window_len=10
absshap = True
fXtrain,sv_tr = getshap(model=model, X=fXtrain, y=train_ynn,shap_version=shap_version,bg_size = bg_size, stride=stride, window_len=window_len, absshap = absshap, shuffle=False)
# Out:
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [markdown]
# ## Visualize SHAP
# In this section we can see that the network focused on correct parts of the time-series.
# In this toy example, it is sufficient to look at SHAP-visualizations to spot the difference, but in case of hundreds of dimensions and more complex problems, prototypes are more useful.

# %%
from  tsproto.plots import plot_smooth_colored_line
indexer = clf.predict(trainX)
shapclass = []
if absshap == False:
    for i in range(0,len(trainX)):
        best_index = indexer[i]
        shapclass.append([sv_tr[best_index][i,:]])
        
    shapclass=np.concatenate(shapclass)
else:
    shapclass  = sv_tr[:,0,:]

    fig, axes =plt.subplots(2,1,figsize=(12,6))

    for i in range(0,10):
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==0][i], color_values=shapclass[train_y==0][i], resolution=1000, ax=axes[0],add_cbar=(i==0))
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==1][i], color_values=shapclass[train_y==1][i], resolution=1000, ax=axes[1],add_cbar=(i==0))

for ax in axes:
    ax.set_ylim([-2, 2])
# Out:
# 5/5 [==============================] - 0s 11ms/step

# %% [markdown]
# ## Tsproto
# Now, lets try to apply TSProto to see if it is able to find the prototype and summarize them correctly to show what logical relation is between them and the model prediction

# %%
trainXproto = trainX.reshape((trainX.shape[0], trainX.shape[1],1))
shapclassXproto = shapclass.reshape((shapclass.shape[0], shapclass.shape[1],1))

# %%
from tsproto.models import *
im  = InterpretableModel()
pe = PrototypeEncoder(clf, n_clusters=4, min_size=50, method='dtw',
                              descriptors=['existance','duration','frequency'],
                      jump=1, pen=1,multiplier=1,n_jobs=-1,
                      verbose=1)
ohe_train, features, target_ohe,weights = pe.fit_transform(trainXproto,shapclassXproto)
acc,prec,rec,f1,iclf = im.fit_or_predict(ohe_train, features, target_ohe,intclf=None, verbose=0, max_depth=2, min_samples_leaf=0.05,
                       weights=None)
# Out:
# Dataset shape: (150, 200, 1)
# Calculating changepoints...
# Dim: 0
# 2
# 2
# 2
# 2
# Before filtering no sigids: 150, uniqu 0
# Unique indexes: 150 vs max+1: 150
# After removing , no sigids: 150, uniqu 0
# Done in 1.1272180080413818.
# Clustering data
# (300, 114, 1)
# (300, 114, 1)
# Shape of data for clustering: (300, 114, 1)
# Clustering data
# X_bis shape: (300, 114, 1) for method=dtw
# Done in 6.864820957183838.
# OHE time series
# Shape weights: (150,)
# Len X=150 vs len of train = 150
# 5/5 [==============================] - 0s 8ms/step
# Done in 0.15124845504760742.

# %% [markdown]
# ## Visualize interpretable model
# We can easily see that the TSProto has found the sine wave at the beginning of the sample, marked it as prototype and correctly identified that its existence is not enough to treat the sample as a class 1 sample, additional frequency context has to be added in order to distinguish these two

# %%
from  tsproto.plots import *
ds_final = ohe_train.copy()
dot = export_decision_tree_with_embedded_histograms(decision_tree=iclf, 
                                              dataset=ds_final, 
                                              target_name='target', 
                                              feature_names=features, 
                                              filename='synthetic', 
                                              proto_encoder=pe, figsize=(6,3))

from IPython.display import SVG, Image
Image('synthetic.png')
# Out:
# [2 1]
# Shapes: (300, 114, 1) vs shap: (2, 114, 1) TODO: take IDS of a single sample that is plotted
# color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Decision Tree exported to synthetic with embedded histograms successfully.
