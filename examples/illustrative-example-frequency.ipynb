# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn import tree
from graphviz import Source
from IPython.display import display
from IPython.display import SVG

# %% [markdown]
# ## Creating synthetic dataset
# We will create a synthetic dataset with two classes. The dataset will be hard to distinguish based on statistical features, but possible with proper prototypical parts extracted.
#
# We are making it even harder, as the prototypical parts are more or less the same. They are differing in terms of frequency.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(3*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X3 = np.concatenate((x1,x2))
Y3 = np.concatenate((y1,y2))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(2*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X4 = np.concatenate((x1,x2))
Y4 = np.concatenate((y1,y2))

# %% [markdown]
# ## Generating sample cases

# %%
x = X3
proto_sin_y = Y3
proto_inversed_sin_y = Y4

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,proto_sin_y)
axes[1].plot(x,proto_inversed_sin_y)

# %% [markdown]
# ## Generating noise and augmenting signals

# %%
noise_power = .2

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_sin_y = noise + proto_sin_y

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_inversed_sin_y = noise + proto_inversed_sin_y

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,noisy_proto_sin_y[0])
axes[1].plot(x,noisy_proto_inversed_sin_y[0])
for ax in axes:
    ax.set_ylim([-2, 2])

# %%
X=np.concatenate((noisy_proto_sin_y,noisy_proto_inversed_sin_y))
Xy=np.concatenate((np.ones(len(noisy_proto_sin_y))*0,
                   np.ones(len(noisy_proto_inversed_sin_y))*1))

trainX, testX, train_y,test_y = train_test_split(X,Xy)

# %% [markdown]
# ## Model
# We will build simple DNN model (not really needed in this case, but it serves the purpose of demonstration how to deal with more complex cases)

# %%
trainX.shape
# Out:
# (150, 200)

# %%
from keras.utils import to_categorical
trainXnn = trainX.reshape(150,1,200)
train_ynn = to_categorical(train_y)
num_classes = len(np.unique(Xy))

# %%
import keras
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    #add dropout
    input_layer = keras.layers.Dropout(0.5)(input_layer)
    conv1 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(input_layer)
    #conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv1)
    #conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv2)
    #conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)



model = make_model(input_shape=trainXnn.shape[1:])

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_crossentropy"],
)
history = model.fit(
    trainXnn,
    train_ynn,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 1s 57ms/step - loss: 0.6410 - categorical_crossentropy: 0.6410 - val_loss: 0.5818 - val_categorical_crossentropy: 0.5818 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5429 - categorical_crossentropy: 0.5429 - val_loss: 0.4567 - val_categorical_crossentropy: 0.4567 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4137 - categorical_crossentropy: 0.4137 - val_loss: 0.3192 - val_categorical_crossentropy: 0.3192 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2856 - categorical_crossentropy: 0.2856 - val_loss: 0.2113 - val_categorical_crossentropy: 0.2113 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1843 - categorical_crossentropy: 0.1843 - val_loss: 0.1190 - val_categorical_crossentropy: 0.1190 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0915 - categorical_crossentropy: 0.0915 - val_loss: 0.0476 - val_categorical_crossentropy: 0.0476 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0339 - categorical_crossentropy: 0.0339 - val_loss: 0.0130 - val_categorical_crossentropy: 0.0130 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0090 - categorical_crossentropy: 0.0090 - val_loss: 0.0033 - val_categorical_crossentropy: 0.0033 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0023 - categorical_crossentropy: 0.0023 - val_loss: 0.0011 - val_categorical_crossentropy: 0.0011 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 0s 20ms/step - loss: 9.0902e-04 - categorical_crossentropy: 9.0902e-04 - val_loss: 6.1054e-04 - val_categorical_crossentropy: 6.1054e-04 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 0s 20ms/step - loss: 5.0594e-04 - categorical_crossentropy: 5.0594e-04 - val_loss: 4.0377e-04 - val_categorical_crossentropy: 4.0377e-04 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 24ms/step - loss: 3.4286e-04 - categorical_crossentropy: 3.4286e-04 - val_loss: 2.8653e-04 - val_categorical_crossentropy: 2.8653e-04 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4496e-04 - categorical_crossentropy: 2.4496e-04 - val_loss: 2.0938e-04 - val_categorical_crossentropy: 2.0938e-04 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.8270e-04 - categorical_crossentropy: 1.8270e-04 - val_loss: 1.5853e-04 - val_categorical_crossentropy: 1.5853e-04 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.3980e-04 - categorical_crossentropy: 1.3980e-04 - val_loss: 1.2683e-04 - val_categorical_crossentropy: 1.2683e-04 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.1424e-04 - categorical_crossentropy: 1.1424e-04 - val_loss: 1.0657e-04 - val_categorical_crossentropy: 1.0657e-04 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 19ms/step - loss: 9.7340e-05 - categorical_crossentropy: 9.7340e-05 - val_loss: 9.3448e-05 - val_categorical_crossentropy: 9.3448e-05 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 21ms/step - loss: 8.6259e-05 - categorical_crossentropy: 8.6259e-05 - val_loss: 8.4575e-05 - val_categorical_crossentropy: 8.4575e-05 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 24ms/step - loss: 7.9146e-05 - categorical_crossentropy: 7.9146e-05 - val_loss: 7.8131e-05 - val_categorical_crossentropy: 7.8131e-05 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 19ms/step - loss: 7.3641e-05 - categorical_crossentropy: 7.3641e-05 - val_loss: 7.3140e-05 - val_categorical_crossentropy: 7.3140e-05 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 18ms/step - loss: 6.9285e-05 - categorical_crossentropy: 6.9285e-05 - val_loss: 6.9040e-05 - val_categorical_crossentropy: 6.9040e-05 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 22ms/step - loss: 6.5581e-05 - categorical_crossentropy: 6.5581e-05 - val_loss: 6.5567e-05 - val_categorical_crossentropy: 6.5567e-05 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 19ms/step - loss: 6.2357e-05 - categorical_crossentropy: 6.2357e-05 - val_loss: 6.2464e-05 - val_categorical_crossentropy: 6.2464e-05 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 19ms/step - loss: 5.9463e-05 - categorical_crossentropy: 5.9463e-05 - val_loss: 5.9678e-05 - val_categorical_crossentropy: 5.9678e-05 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 0s 24ms/step - loss: 5.6831e-05 - categorical_crossentropy: 5.6831e-05 - val_loss: 5.7155e-05 - val_categorical_crossentropy: 5.7155e-05 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 22ms/step - loss: 5.4420e-05 - categorical_crossentropy: 5.4420e-05 - val_loss: 5.4847e-05 - val_categorical_crossentropy: 5.4847e-05 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 21ms/step - loss: 5.2250e-05 - categorical_crossentropy: 5.2250e-05 - val_loss: 5.2717e-05 - val_categorical_crossentropy: 5.2717e-05 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 17ms/step - loss: 5.0203e-05 - categorical_crossentropy: 5.0203e-05 - val_loss: 5.0754e-05 - val_categorical_crossentropy: 5.0754e-05 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 19ms/step - loss: 4.8342e-05 - categorical_crossentropy: 4.8342e-05 - val_loss: 4.8902e-05 - val_categorical_crossentropy: 4.8902e-05 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 20ms/step - loss: 4.6597e-05 - categorical_crossentropy: 4.6597e-05 - val_loss: 4.7198e-05 - val_categorical_crossentropy: 4.7198e-05 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 17ms/step - loss: 4.4975e-05 - categorical_crossentropy: 4.4975e-05 - val_loss: 4.5593e-05 - val_categorical_crossentropy: 4.5593e-05 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 17ms/step - loss: 4.3442e-05 - categorical_crossentropy: 4.3442e-05 - val_loss: 4.4083e-05 - val_categorical_crossentropy: 4.4083e-05 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 19ms/step - loss: 4.2023e-05 - categorical_crossentropy: 4.2023e-05 - val_loss: 4.2680e-05 - val_categorical_crossentropy: 4.2680e-05 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 0s 18ms/step - loss: 4.0681e-05 - categorical_crossentropy: 4.0681e-05 - val_loss: 4.1361e-05 - val_categorical_crossentropy: 4.1361e-05 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 0s 19ms/step - loss: 3.9429e-05 - categorical_crossentropy: 3.9429e-05 - val_loss: 4.0117e-05 - val_categorical_crossentropy: 4.0117e-05 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 0s 19ms/step - loss: 3.8273e-05 - categorical_crossentropy: 3.8273e-05 - val_loss: 3.8945e-05 - val_categorical_crossentropy: 3.8945e-05 - lr: 0.0010
# Epoch 37/500
# 4/4 [==============================] - 0s 19ms/step - loss: 3.7165e-05 - categorical_crossentropy: 3.7165e-05 - val_loss: 3.7868e-05 - val_categorical_crossentropy: 3.7868e-05 - lr: 0.0010
# Epoch 38/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.6160e-05 - categorical_crossentropy: 3.6160e-05 - val_loss: 3.6815e-05 - val_categorical_crossentropy: 3.6815e-05 - lr: 0.0010
# Epoch 39/500
# 4/4 [==============================] - 0s 21ms/step - loss: 3.5175e-05 - categorical_crossentropy: 3.5175e-05 - val_loss: 3.5854e-05 - val_categorical_crossentropy: 3.5854e-05 - lr: 0.0010
# Epoch 40/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.4273e-05 - categorical_crossentropy: 3.4273e-05 - val_loss: 3.4952e-05 - val_categorical_crossentropy: 3.4952e-05 - lr: 0.0010
# Epoch 41/500
# 4/4 [==============================] - 0s 20ms/step - loss: 3.3414e-05 - categorical_crossentropy: 3.3414e-05 - val_loss: 3.4101e-05 - val_categorical_crossentropy: 3.4101e-05 - lr: 0.0010
# Epoch 42/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2621e-05 - categorical_crossentropy: 3.2621e-05 - val_loss: 3.3303e-05 - val_categorical_crossentropy: 3.3303e-05 - lr: 0.0010
# Epoch 43/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1854e-05 - categorical_crossentropy: 3.1854e-05 - val_loss: 3.2552e-05 - val_categorical_crossentropy: 3.2552e-05 - lr: 0.0010
# Epoch 44/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1148e-05 - categorical_crossentropy: 3.1148e-05 - val_loss: 3.1824e-05 - val_categorical_crossentropy: 3.1824e-05 - lr: 0.0010
# Epoch 45/500
# 4/4 [==============================] - 0s 20ms/step - loss: 3.0475e-05 - categorical_crossentropy: 3.0475e-05 - val_loss: 3.1153e-05 - val_categorical_crossentropy: 3.1153e-05 - lr: 0.0010
# Epoch 46/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.9955e-05 - categorical_crossentropy: 2.9955e-05 - val_loss: 3.0839e-05 - val_categorical_crossentropy: 3.0839e-05 - lr: 5.0000e-04
# Epoch 47/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.9641e-05 - categorical_crossentropy: 2.9641e-05 - val_loss: 3.0505e-05 - val_categorical_crossentropy: 3.0505e-05 - lr: 5.0000e-04
# Epoch 48/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.9347e-05 - categorical_crossentropy: 2.9347e-05 - val_loss: 3.0199e-05 - val_categorical_crossentropy: 3.0199e-05 - lr: 5.0000e-04
# Epoch 49/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.9057e-05 - categorical_crossentropy: 2.9057e-05 - val_loss: 2.9917e-05 - val_categorical_crossentropy: 2.9917e-05 - lr: 5.0000e-04
# Epoch 50/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.8781e-05 - categorical_crossentropy: 2.8781e-05 - val_loss: 2.9619e-05 - val_categorical_crossentropy: 2.9619e-05 - lr: 5.0000e-04
# Epoch 51/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.8496e-05 - categorical_crossentropy: 2.8496e-05 - val_loss: 2.9337e-05 - val_categorical_crossentropy: 2.9337e-05 - lr: 5.0000e-04
# Epoch 52/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.8227e-05 - categorical_crossentropy: 2.8227e-05 - val_loss: 2.9063e-05 - val_categorical_crossentropy: 2.9063e-05 - lr: 5.0000e-04
# Epoch 53/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.7969e-05 - categorical_crossentropy: 2.7969e-05 - val_loss: 2.8801e-05 - val_categorical_crossentropy: 2.8801e-05 - lr: 5.0000e-04
# Epoch 54/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.7717e-05 - categorical_crossentropy: 2.7717e-05 - val_loss: 2.8542e-05 - val_categorical_crossentropy: 2.8542e-05 - lr: 5.0000e-04
# Epoch 55/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.7466e-05 - categorical_crossentropy: 2.7466e-05 - val_loss: 2.8268e-05 - val_categorical_crossentropy: 2.8268e-05 - lr: 5.0000e-04
# Epoch 56/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.7222e-05 - categorical_crossentropy: 2.7222e-05 - val_loss: 2.8030e-05 - val_categorical_crossentropy: 2.8030e-05 - lr: 5.0000e-04
# Epoch 57/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.6980e-05 - categorical_crossentropy: 2.6980e-05 - val_loss: 2.7779e-05 - val_categorical_crossentropy: 2.7779e-05 - lr: 5.0000e-04
# Epoch 58/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.6744e-05 - categorical_crossentropy: 2.6744e-05 - val_loss: 2.7525e-05 - val_categorical_crossentropy: 2.7525e-05 - lr: 5.0000e-04
# Epoch 59/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.6519e-05 - categorical_crossentropy: 2.6519e-05 - val_loss: 2.7279e-05 - val_categorical_crossentropy: 2.7279e-05 - lr: 5.0000e-04
# Epoch 60/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.6286e-05 - categorical_crossentropy: 2.6286e-05 - val_loss: 2.7052e-05 - val_categorical_crossentropy: 2.7052e-05 - lr: 5.0000e-04
# Epoch 61/500
# 4/4 [==============================] - 0s 15ms/step - loss: 2.6067e-05 - categorical_crossentropy: 2.6067e-05 - val_loss: 2.6818e-05 - val_categorical_crossentropy: 2.6818e-05 - lr: 5.0000e-04
# Epoch 62/500
# 4/4 [==============================] - 0s 15ms/step - loss: 2.5849e-05 - categorical_crossentropy: 2.5849e-05 - val_loss: 2.6587e-05 - val_categorical_crossentropy: 2.6587e-05 - lr: 5.0000e-04
# Epoch 63/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5635e-05 - categorical_crossentropy: 2.5635e-05 - val_loss: 2.6369e-05 - val_categorical_crossentropy: 2.6369e-05 - lr: 5.0000e-04
# Epoch 64/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5418e-05 - categorical_crossentropy: 2.5418e-05 - val_loss: 2.6162e-05 - val_categorical_crossentropy: 2.6162e-05 - lr: 5.0000e-04
# Epoch 65/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5215e-05 - categorical_crossentropy: 2.5215e-05 - val_loss: 2.5955e-05 - val_categorical_crossentropy: 2.5955e-05 - lr: 5.0000e-04
# Epoch 66/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.5045e-05 - categorical_crossentropy: 2.5045e-05 - val_loss: 2.5840e-05 - val_categorical_crossentropy: 2.5840e-05 - lr: 2.5000e-04
# Epoch 67/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4950e-05 - categorical_crossentropy: 2.4950e-05 - val_loss: 2.5729e-05 - val_categorical_crossentropy: 2.5729e-05 - lr: 2.5000e-04
# Epoch 68/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4850e-05 - categorical_crossentropy: 2.4850e-05 - val_loss: 2.5634e-05 - val_categorical_crossentropy: 2.5634e-05 - lr: 2.5000e-04
# Epoch 69/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.4752e-05 - categorical_crossentropy: 2.4752e-05 - val_loss: 2.5530e-05 - val_categorical_crossentropy: 2.5530e-05 - lr: 2.5000e-04
# Epoch 70/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.4648e-05 - categorical_crossentropy: 2.4648e-05 - val_loss: 2.5431e-05 - val_categorical_crossentropy: 2.5431e-05 - lr: 2.5000e-04
# Epoch 71/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4550e-05 - categorical_crossentropy: 2.4550e-05 - val_loss: 2.5336e-05 - val_categorical_crossentropy: 2.5336e-05 - lr: 2.5000e-04
# Epoch 72/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.4451e-05 - categorical_crossentropy: 2.4451e-05 - val_loss: 2.5216e-05 - val_categorical_crossentropy: 2.5216e-05 - lr: 2.5000e-04
# Epoch 73/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.4358e-05 - categorical_crossentropy: 2.4358e-05 - val_loss: 2.5129e-05 - val_categorical_crossentropy: 2.5129e-05 - lr: 2.5000e-04
# Epoch 74/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.4263e-05 - categorical_crossentropy: 2.4263e-05 - val_loss: 2.5018e-05 - val_categorical_crossentropy: 2.5018e-05 - lr: 2.5000e-04
# Epoch 75/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.4165e-05 - categorical_crossentropy: 2.4165e-05 - val_loss: 2.4914e-05 - val_categorical_crossentropy: 2.4914e-05 - lr: 2.5000e-04
# Epoch 76/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4077e-05 - categorical_crossentropy: 2.4077e-05 - val_loss: 2.4823e-05 - val_categorical_crossentropy: 2.4823e-05 - lr: 2.5000e-04
# Epoch 77/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.3978e-05 - categorical_crossentropy: 2.3978e-05 - val_loss: 2.4716e-05 - val_categorical_crossentropy: 2.4716e-05 - lr: 2.5000e-04
# Epoch 78/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3888e-05 - categorical_crossentropy: 2.3888e-05 - val_loss: 2.4620e-05 - val_categorical_crossentropy: 2.4620e-05 - lr: 2.5000e-04
# Epoch 79/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3794e-05 - categorical_crossentropy: 2.3794e-05 - val_loss: 2.4525e-05 - val_categorical_crossentropy: 2.4525e-05 - lr: 2.5000e-04
# Epoch 80/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3698e-05 - categorical_crossentropy: 2.3698e-05 - val_loss: 2.4422e-05 - val_categorical_crossentropy: 2.4422e-05 - lr: 2.5000e-04
# Epoch 81/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3604e-05 - categorical_crossentropy: 2.3604e-05 - val_loss: 2.4314e-05 - val_categorical_crossentropy: 2.4314e-05 - lr: 2.5000e-04
# Epoch 82/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3511e-05 - categorical_crossentropy: 2.3511e-05 - val_loss: 2.4223e-05 - val_categorical_crossentropy: 2.4223e-05 - lr: 2.5000e-04
# Epoch 83/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3418e-05 - categorical_crossentropy: 2.3418e-05 - val_loss: 2.4132e-05 - val_categorical_crossentropy: 2.4132e-05 - lr: 2.5000e-04
# Epoch 84/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3328e-05 - categorical_crossentropy: 2.3328e-05 - val_loss: 2.4032e-05 - val_categorical_crossentropy: 2.4032e-05 - lr: 2.5000e-04
# Epoch 85/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.3234e-05 - categorical_crossentropy: 2.3234e-05 - val_loss: 2.3945e-05 - val_categorical_crossentropy: 2.3945e-05 - lr: 2.5000e-04
# Epoch 86/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3165e-05 - categorical_crossentropy: 2.3165e-05 - val_loss: 2.3889e-05 - val_categorical_crossentropy: 2.3889e-05 - lr: 1.2500e-04
# Epoch 87/500
# 4/4 [==============================] - 0s 24ms/step - loss: 2.3115e-05 - categorical_crossentropy: 2.3115e-05 - val_loss: 2.3846e-05 - val_categorical_crossentropy: 2.3846e-05 - lr: 1.2500e-04
# Epoch 88/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.3069e-05 - categorical_crossentropy: 2.3069e-05 - val_loss: 2.3798e-05 - val_categorical_crossentropy: 2.3798e-05 - lr: 1.2500e-04
# Epoch 89/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3016e-05 - categorical_crossentropy: 2.3016e-05 - val_loss: 2.3754e-05 - val_categorical_crossentropy: 2.3754e-05 - lr: 1.2500e-04
# Epoch 90/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.2982e-05 - categorical_crossentropy: 2.2982e-05 - val_loss: 2.3698e-05 - val_categorical_crossentropy: 2.3698e-05 - lr: 1.2500e-04
# Epoch 91/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2931e-05 - categorical_crossentropy: 2.2931e-05 - val_loss: 2.3647e-05 - val_categorical_crossentropy: 2.3647e-05 - lr: 1.2500e-04
# Epoch 92/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2882e-05 - categorical_crossentropy: 2.2882e-05 - val_loss: 2.3607e-05 - val_categorical_crossentropy: 2.3607e-05 - lr: 1.2500e-04
# Epoch 93/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.2839e-05 - categorical_crossentropy: 2.2839e-05 - val_loss: 2.3551e-05 - val_categorical_crossentropy: 2.3551e-05 - lr: 1.2500e-04
# Epoch 94/500
# 4/4 [==============================] - 0s 24ms/step - loss: 2.2796e-05 - categorical_crossentropy: 2.2796e-05 - val_loss: 2.3512e-05 - val_categorical_crossentropy: 2.3512e-05 - lr: 1.2500e-04
# Epoch 95/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2746e-05 - categorical_crossentropy: 2.2746e-05 - val_loss: 2.3460e-05 - val_categorical_crossentropy: 2.3460e-05 - lr: 1.2500e-04
# Epoch 96/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2701e-05 - categorical_crossentropy: 2.2701e-05 - val_loss: 2.3408e-05 - val_categorical_crossentropy: 2.3408e-05 - lr: 1.2500e-04
# Epoch 97/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.2654e-05 - categorical_crossentropy: 2.2654e-05 - val_loss: 2.3361e-05 - val_categorical_crossentropy: 2.3361e-05 - lr: 1.2500e-04
# Epoch 98/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2612e-05 - categorical_crossentropy: 2.2612e-05 - val_loss: 2.3313e-05 - val_categorical_crossentropy: 2.3313e-05 - lr: 1.2500e-04
# Epoch 99/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2560e-05 - categorical_crossentropy: 2.2560e-05 - val_loss: 2.3257e-05 - val_categorical_crossentropy: 2.3257e-05 - lr: 1.2500e-04
# Epoch 100/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2517e-05 - categorical_crossentropy: 2.2517e-05 - val_loss: 2.3214e-05 - val_categorical_crossentropy: 2.3214e-05 - lr: 1.2500e-04
# Epoch 101/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2470e-05 - categorical_crossentropy: 2.2470e-05 - val_loss: 2.3158e-05 - val_categorical_crossentropy: 2.3158e-05 - lr: 1.2500e-04
# Epoch 102/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.2426e-05 - categorical_crossentropy: 2.2426e-05 - val_loss: 2.3122e-05 - val_categorical_crossentropy: 2.3122e-05 - lr: 1.2500e-04
# Epoch 103/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2380e-05 - categorical_crossentropy: 2.2380e-05 - val_loss: 2.3067e-05 - val_categorical_crossentropy: 2.3067e-05 - lr: 1.2500e-04
# Epoch 104/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.2331e-05 - categorical_crossentropy: 2.2331e-05 - val_loss: 2.3023e-05 - val_categorical_crossentropy: 2.3023e-05 - lr: 1.2500e-04
# Epoch 105/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.2288e-05 - categorical_crossentropy: 2.2288e-05 - val_loss: 2.2975e-05 - val_categorical_crossentropy: 2.2975e-05 - lr: 1.2500e-04
# Epoch 106/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.2240e-05 - categorical_crossentropy: 2.2240e-05 - val_loss: 2.2936e-05 - val_categorical_crossentropy: 2.2936e-05 - lr: 1.0000e-04
# Epoch 107/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.2209e-05 - categorical_crossentropy: 2.2209e-05 - val_loss: 2.2892e-05 - val_categorical_crossentropy: 2.2892e-05 - lr: 1.0000e-04
# Epoch 108/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2160e-05 - categorical_crossentropy: 2.2160e-05 - val_loss: 2.2856e-05 - val_categorical_crossentropy: 2.2856e-05 - lr: 1.0000e-04
# Epoch 109/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2135e-05 - categorical_crossentropy: 2.2135e-05 - val_loss: 2.2808e-05 - val_categorical_crossentropy: 2.2808e-05 - lr: 1.0000e-04
# Epoch 110/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.2104e-05 - categorical_crossentropy: 2.2104e-05 - val_loss: 2.2781e-05 - val_categorical_crossentropy: 2.2781e-05 - lr: 1.0000e-04
# Epoch 111/500
# 4/4 [==============================] - 0s 22ms/step - loss: 2.2048e-05 - categorical_crossentropy: 2.2048e-05 - val_loss: 2.2741e-05 - val_categorical_crossentropy: 2.2741e-05 - lr: 1.0000e-04
# Epoch 112/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2021e-05 - categorical_crossentropy: 2.2021e-05 - val_loss: 2.2693e-05 - val_categorical_crossentropy: 2.2693e-05 - lr: 1.0000e-04
# Epoch 113/500
# 4/4 [==============================] - 0s 24ms/step - loss: 2.1981e-05 - categorical_crossentropy: 2.1981e-05 - val_loss: 2.2661e-05 - val_categorical_crossentropy: 2.2661e-05 - lr: 1.0000e-04
# Epoch 114/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1945e-05 - categorical_crossentropy: 2.1945e-05 - val_loss: 2.2626e-05 - val_categorical_crossentropy: 2.2626e-05 - lr: 1.0000e-04
# Epoch 115/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1905e-05 - categorical_crossentropy: 2.1905e-05 - val_loss: 2.2582e-05 - val_categorical_crossentropy: 2.2582e-05 - lr: 1.0000e-04
# Epoch 116/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.1869e-05 - categorical_crossentropy: 2.1869e-05 - val_loss: 2.2542e-05 - val_categorical_crossentropy: 2.2542e-05 - lr: 1.0000e-04
# Epoch 117/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1835e-05 - categorical_crossentropy: 2.1835e-05 - val_loss: 2.2502e-05 - val_categorical_crossentropy: 2.2502e-05 - lr: 1.0000e-04
# Epoch 118/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1797e-05 - categorical_crossentropy: 2.1797e-05 - val_loss: 2.2467e-05 - val_categorical_crossentropy: 2.2467e-05 - lr: 1.0000e-04
# Epoch 119/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.1756e-05 - categorical_crossentropy: 2.1756e-05 - val_loss: 2.2423e-05 - val_categorical_crossentropy: 2.2423e-05 - lr: 1.0000e-04
# Epoch 120/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.1716e-05 - categorical_crossentropy: 2.1716e-05 - val_loss: 2.2387e-05 - val_categorical_crossentropy: 2.2387e-05 - lr: 1.0000e-04
# Epoch 121/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.1681e-05 - categorical_crossentropy: 2.1681e-05 - val_loss: 2.2340e-05 - val_categorical_crossentropy: 2.2340e-05 - lr: 1.0000e-04
# Epoch 122/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.1647e-05 - categorical_crossentropy: 2.1647e-05 - val_loss: 2.2308e-05 - val_categorical_crossentropy: 2.2308e-05 - lr: 1.0000e-04
# Epoch 123/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.1609e-05 - categorical_crossentropy: 2.1609e-05 - val_loss: 2.2272e-05 - val_categorical_crossentropy: 2.2272e-05 - lr: 1.0000e-04
# Epoch 124/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1565e-05 - categorical_crossentropy: 2.1565e-05 - val_loss: 2.2220e-05 - val_categorical_crossentropy: 2.2220e-05 - lr: 1.0000e-04
# Epoch 125/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1533e-05 - categorical_crossentropy: 2.1533e-05 - val_loss: 2.2173e-05 - val_categorical_crossentropy: 2.2173e-05 - lr: 1.0000e-04
# Epoch 126/500
# 4/4 [==============================] - 0s 22ms/step - loss: 2.1490e-05 - categorical_crossentropy: 2.1490e-05 - val_loss: 2.2145e-05 - val_categorical_crossentropy: 2.2145e-05 - lr: 1.0000e-04
# Epoch 127/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1454e-05 - categorical_crossentropy: 2.1454e-05 - val_loss: 2.2117e-05 - val_categorical_crossentropy: 2.2117e-05 - lr: 1.0000e-04
# Epoch 128/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.1417e-05 - categorical_crossentropy: 2.1417e-05 - val_loss: 2.2061e-05 - val_categorical_crossentropy: 2.2061e-05 - lr: 1.0000e-04
# Epoch 129/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1379e-05 - categorical_crossentropy: 2.1379e-05 - val_loss: 2.2030e-05 - val_categorical_crossentropy: 2.2030e-05 - lr: 1.0000e-04
# Epoch 130/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.1346e-05 - categorical_crossentropy: 2.1346e-05 - val_loss: 2.1998e-05 - val_categorical_crossentropy: 2.1998e-05 - lr: 1.0000e-04
# Epoch 131/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.1302e-05 - categorical_crossentropy: 2.1302e-05 - val_loss: 2.1942e-05 - val_categorical_crossentropy: 2.1942e-05 - lr: 1.0000e-04
# Epoch 132/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1265e-05 - categorical_crossentropy: 2.1265e-05 - val_loss: 2.1898e-05 - val_categorical_crossentropy: 2.1898e-05 - lr: 1.0000e-04
# Epoch 133/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1229e-05 - categorical_crossentropy: 2.1229e-05 - val_loss: 2.1871e-05 - val_categorical_crossentropy: 2.1871e-05 - lr: 1.0000e-04
# Epoch 134/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.1184e-05 - categorical_crossentropy: 2.1184e-05 - val_loss: 2.1827e-05 - val_categorical_crossentropy: 2.1827e-05 - lr: 1.0000e-04
# Epoch 135/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.1152e-05 - categorical_crossentropy: 2.1152e-05 - val_loss: 2.1795e-05 - val_categorical_crossentropy: 2.1795e-05 - lr: 1.0000e-04
# Epoch 136/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.1116e-05 - categorical_crossentropy: 2.1116e-05 - val_loss: 2.1740e-05 - val_categorical_crossentropy: 2.1740e-05 - lr: 1.0000e-04
# Epoch 137/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.1072e-05 - categorical_crossentropy: 2.1072e-05 - val_loss: 2.1708e-05 - val_categorical_crossentropy: 2.1708e-05 - lr: 1.0000e-04
# Epoch 138/500
# 4/4 [==============================] - 0s 22ms/step - loss: 2.1030e-05 - categorical_crossentropy: 2.1030e-05 - val_loss: 2.1676e-05 - val_categorical_crossentropy: 2.1676e-05 - lr: 1.0000e-04
# Epoch 139/500
# 4/4 [==============================] - 0s 22ms/step - loss: 2.0995e-05 - categorical_crossentropy: 2.0995e-05 - val_loss: 2.1616e-05 - val_categorical_crossentropy: 2.1616e-05 - lr: 1.0000e-04
# Epoch 140/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.0960e-05 - categorical_crossentropy: 2.0960e-05 - val_loss: 2.1593e-05 - val_categorical_crossentropy: 2.1593e-05 - lr: 1.0000e-04
# Epoch 141/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.0923e-05 - categorical_crossentropy: 2.0923e-05 - val_loss: 2.1545e-05 - val_categorical_crossentropy: 2.1545e-05 - lr: 1.0000e-04
# Epoch 142/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.0887e-05 - categorical_crossentropy: 2.0887e-05 - val_loss: 2.1521e-05 - val_categorical_crossentropy: 2.1521e-05 - lr: 1.0000e-04
# Epoch 143/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0845e-05 - categorical_crossentropy: 2.0845e-05 - val_loss: 2.1465e-05 - val_categorical_crossentropy: 2.1465e-05 - lr: 1.0000e-04
# Epoch 144/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0810e-05 - categorical_crossentropy: 2.0810e-05 - val_loss: 2.1422e-05 - val_categorical_crossentropy: 2.1422e-05 - lr: 1.0000e-04
# Epoch 145/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0772e-05 - categorical_crossentropy: 2.0772e-05 - val_loss: 2.1398e-05 - val_categorical_crossentropy: 2.1398e-05 - lr: 1.0000e-04
# Epoch 146/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.0724e-05 - categorical_crossentropy: 2.0724e-05 - val_loss: 2.1342e-05 - val_categorical_crossentropy: 2.1342e-05 - lr: 1.0000e-04
# Epoch 147/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.0699e-05 - categorical_crossentropy: 2.0699e-05 - val_loss: 2.1294e-05 - val_categorical_crossentropy: 2.1294e-05 - lr: 1.0000e-04
# Epoch 148/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.0657e-05 - categorical_crossentropy: 2.0657e-05 - val_loss: 2.1279e-05 - val_categorical_crossentropy: 2.1279e-05 - lr: 1.0000e-04
# Epoch 149/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.0605e-05 - categorical_crossentropy: 2.0605e-05 - val_loss: 2.1235e-05 - val_categorical_crossentropy: 2.1235e-05 - lr: 1.0000e-04
# Epoch 150/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.0582e-05 - categorical_crossentropy: 2.0582e-05 - val_loss: 2.1175e-05 - val_categorical_crossentropy: 2.1175e-05 - lr: 1.0000e-04
# Epoch 151/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.0539e-05 - categorical_crossentropy: 2.0539e-05 - val_loss: 2.1151e-05 - val_categorical_crossentropy: 2.1151e-05 - lr: 1.0000e-04
# Epoch 152/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.0499e-05 - categorical_crossentropy: 2.0499e-05 - val_loss: 2.1116e-05 - val_categorical_crossentropy: 2.1116e-05 - lr: 1.0000e-04
# Epoch 153/500
# 4/4 [==============================] - 0s 23ms/step - loss: 2.0461e-05 - categorical_crossentropy: 2.0461e-05 - val_loss: 2.1064e-05 - val_categorical_crossentropy: 2.1064e-05 - lr: 1.0000e-04
# Epoch 154/500
# 4/4 [==============================] - 0s 26ms/step - loss: 2.0422e-05 - categorical_crossentropy: 2.0422e-05 - val_loss: 2.1020e-05 - val_categorical_crossentropy: 2.1020e-05 - lr: 1.0000e-04
# Epoch 155/500
# 4/4 [==============================] - 0s 29ms/step - loss: 2.0392e-05 - categorical_crossentropy: 2.0392e-05 - val_loss: 2.0993e-05 - val_categorical_crossentropy: 2.0993e-05 - lr: 1.0000e-04
# Epoch 156/500
# 4/4 [==============================] - 0s 29ms/step - loss: 2.0350e-05 - categorical_crossentropy: 2.0350e-05 - val_loss: 2.0949e-05 - val_categorical_crossentropy: 2.0949e-05 - lr: 1.0000e-04
# Epoch 157/500
# 4/4 [==============================] - 0s 25ms/step - loss: 2.0304e-05 - categorical_crossentropy: 2.0304e-05 - val_loss: 2.0905e-05 - val_categorical_crossentropy: 2.0905e-05 - lr: 1.0000e-04
# Epoch 158/500
# 4/4 [==============================] - 0s 29ms/step - loss: 2.0274e-05 - categorical_crossentropy: 2.0274e-05 - val_loss: 2.0861e-05 - val_categorical_crossentropy: 2.0861e-05 - lr: 1.0000e-04
# Epoch 159/500
# 4/4 [==============================] - 0s 35ms/step - loss: 2.0238e-05 - categorical_crossentropy: 2.0238e-05 - val_loss: 2.0838e-05 - val_categorical_crossentropy: 2.0838e-05 - lr: 1.0000e-04
# Epoch 160/500
# 4/4 [==============================] - 0s 30ms/step - loss: 2.0193e-05 - categorical_crossentropy: 2.0193e-05 - val_loss: 2.0790e-05 - val_categorical_crossentropy: 2.0790e-05 - lr: 1.0000e-04
# Epoch 161/500
# 4/4 [==============================] - 0s 25ms/step - loss: 2.0159e-05 - categorical_crossentropy: 2.0159e-05 - val_loss: 2.0746e-05 - val_categorical_crossentropy: 2.0746e-05 - lr: 1.0000e-04
# Epoch 162/500
# 4/4 [==============================] - 0s 23ms/step - loss: 2.0123e-05 - categorical_crossentropy: 2.0123e-05 - val_loss: 2.0710e-05 - val_categorical_crossentropy: 2.0710e-05 - lr: 1.0000e-04
# Epoch 163/500
# 4/4 [==============================] - 0s 31ms/step - loss: 2.0081e-05 - categorical_crossentropy: 2.0081e-05 - val_loss: 2.0675e-05 - val_categorical_crossentropy: 2.0675e-05 - lr: 1.0000e-04
# Epoch 164/500
# 4/4 [==============================] - 0s 29ms/step - loss: 2.0043e-05 - categorical_crossentropy: 2.0043e-05 - val_loss: 2.0627e-05 - val_categorical_crossentropy: 2.0627e-05 - lr: 1.0000e-04
# Epoch 165/500
# 4/4 [==============================] - 0s 26ms/step - loss: 2.0002e-05 - categorical_crossentropy: 2.0002e-05 - val_loss: 2.0587e-05 - val_categorical_crossentropy: 2.0587e-05 - lr: 1.0000e-04
# Epoch 166/500
# 4/4 [==============================] - 0s 30ms/step - loss: 1.9969e-05 - categorical_crossentropy: 1.9969e-05 - val_loss: 2.0551e-05 - val_categorical_crossentropy: 2.0551e-05 - lr: 1.0000e-04
# Epoch 167/500
# 4/4 [==============================] - 0s 35ms/step - loss: 1.9933e-05 - categorical_crossentropy: 1.9933e-05 - val_loss: 2.0508e-05 - val_categorical_crossentropy: 2.0508e-05 - lr: 1.0000e-04
# Epoch 168/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.9890e-05 - categorical_crossentropy: 1.9890e-05 - val_loss: 2.0460e-05 - val_categorical_crossentropy: 2.0460e-05 - lr: 1.0000e-04
# Epoch 169/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.9851e-05 - categorical_crossentropy: 1.9851e-05 - val_loss: 2.0428e-05 - val_categorical_crossentropy: 2.0428e-05 - lr: 1.0000e-04
# Epoch 170/500
# 4/4 [==============================] - 0s 27ms/step - loss: 1.9816e-05 - categorical_crossentropy: 1.9816e-05 - val_loss: 2.0392e-05 - val_categorical_crossentropy: 2.0392e-05 - lr: 1.0000e-04
# Epoch 171/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.9768e-05 - categorical_crossentropy: 1.9768e-05 - val_loss: 2.0345e-05 - val_categorical_crossentropy: 2.0345e-05 - lr: 1.0000e-04
# Epoch 172/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.9734e-05 - categorical_crossentropy: 1.9734e-05 - val_loss: 2.0309e-05 - val_categorical_crossentropy: 2.0309e-05 - lr: 1.0000e-04
# Epoch 173/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.9703e-05 - categorical_crossentropy: 1.9703e-05 - val_loss: 2.0269e-05 - val_categorical_crossentropy: 2.0269e-05 - lr: 1.0000e-04
# Epoch 174/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.9669e-05 - categorical_crossentropy: 1.9669e-05 - val_loss: 2.0226e-05 - val_categorical_crossentropy: 2.0226e-05 - lr: 1.0000e-04
# Epoch 175/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.9624e-05 - categorical_crossentropy: 1.9624e-05 - val_loss: 2.0194e-05 - val_categorical_crossentropy: 2.0194e-05 - lr: 1.0000e-04
# Epoch 176/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.9584e-05 - categorical_crossentropy: 1.9584e-05 - val_loss: 2.0154e-05 - val_categorical_crossentropy: 2.0154e-05 - lr: 1.0000e-04
# Epoch 177/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.9554e-05 - categorical_crossentropy: 1.9554e-05 - val_loss: 2.0118e-05 - val_categorical_crossentropy: 2.0118e-05 - lr: 1.0000e-04
# Epoch 178/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.9512e-05 - categorical_crossentropy: 1.9512e-05 - val_loss: 2.0067e-05 - val_categorical_crossentropy: 2.0067e-05 - lr: 1.0000e-04
# Epoch 179/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.9473e-05 - categorical_crossentropy: 1.9473e-05 - val_loss: 2.0035e-05 - val_categorical_crossentropy: 2.0035e-05 - lr: 1.0000e-04
# Epoch 180/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.9436e-05 - categorical_crossentropy: 1.9436e-05 - val_loss: 1.9991e-05 - val_categorical_crossentropy: 1.9991e-05 - lr: 1.0000e-04
# Epoch 181/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.9397e-05 - categorical_crossentropy: 1.9397e-05 - val_loss: 1.9947e-05 - val_categorical_crossentropy: 1.9947e-05 - lr: 1.0000e-04
# Epoch 182/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.9362e-05 - categorical_crossentropy: 1.9362e-05 - val_loss: 1.9912e-05 - val_categorical_crossentropy: 1.9912e-05 - lr: 1.0000e-04
# Epoch 183/500
# 4/4 [==============================] - 0s 27ms/step - loss: 1.9320e-05 - categorical_crossentropy: 1.9320e-05 - val_loss: 1.9876e-05 - val_categorical_crossentropy: 1.9876e-05 - lr: 1.0000e-04
# Epoch 184/500
# 4/4 [==============================] - 0s 30ms/step - loss: 1.9289e-05 - categorical_crossentropy: 1.9289e-05 - val_loss: 1.9832e-05 - val_categorical_crossentropy: 1.9832e-05 - lr: 1.0000e-04
# Epoch 185/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.9242e-05 - categorical_crossentropy: 1.9242e-05 - val_loss: 1.9789e-05 - val_categorical_crossentropy: 1.9789e-05 - lr: 1.0000e-04
# Epoch 186/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.9210e-05 - categorical_crossentropy: 1.9210e-05 - val_loss: 1.9749e-05 - val_categorical_crossentropy: 1.9749e-05 - lr: 1.0000e-04
# Epoch 187/500
# 4/4 [==============================] - 0s 29ms/step - loss: 1.9173e-05 - categorical_crossentropy: 1.9173e-05 - val_loss: 1.9713e-05 - val_categorical_crossentropy: 1.9713e-05 - lr: 1.0000e-04
# Epoch 188/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.9133e-05 - categorical_crossentropy: 1.9133e-05 - val_loss: 1.9677e-05 - val_categorical_crossentropy: 1.9677e-05 - lr: 1.0000e-04
# Epoch 189/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.9094e-05 - categorical_crossentropy: 1.9094e-05 - val_loss: 1.9638e-05 - val_categorical_crossentropy: 1.9638e-05 - lr: 1.0000e-04
# Epoch 190/500
# 4/4 [==============================] - 0s 28ms/step - loss: 1.9059e-05 - categorical_crossentropy: 1.9059e-05 - val_loss: 1.9598e-05 - val_categorical_crossentropy: 1.9598e-05 - lr: 1.0000e-04
# Epoch 191/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.9020e-05 - categorical_crossentropy: 1.9020e-05 - val_loss: 1.9558e-05 - val_categorical_crossentropy: 1.9558e-05 - lr: 1.0000e-04
# Epoch 192/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.8985e-05 - categorical_crossentropy: 1.8985e-05 - val_loss: 1.9514e-05 - val_categorical_crossentropy: 1.9514e-05 - lr: 1.0000e-04
# Epoch 193/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.8944e-05 - categorical_crossentropy: 1.8944e-05 - val_loss: 1.9475e-05 - val_categorical_crossentropy: 1.9475e-05 - lr: 1.0000e-04
# Epoch 194/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.8913e-05 - categorical_crossentropy: 1.8913e-05 - val_loss: 1.9447e-05 - val_categorical_crossentropy: 1.9447e-05 - lr: 1.0000e-04
# Epoch 195/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.8867e-05 - categorical_crossentropy: 1.8867e-05 - val_loss: 1.9403e-05 - val_categorical_crossentropy: 1.9403e-05 - lr: 1.0000e-04
# Epoch 196/500
# 4/4 [==============================] - 0s 27ms/step - loss: 1.8833e-05 - categorical_crossentropy: 1.8833e-05 - val_loss: 1.9355e-05 - val_categorical_crossentropy: 1.9355e-05 - lr: 1.0000e-04
# Epoch 197/500
# 4/4 [==============================] - 0s 28ms/step - loss: 1.8796e-05 - categorical_crossentropy: 1.8796e-05 - val_loss: 1.9324e-05 - val_categorical_crossentropy: 1.9324e-05 - lr: 1.0000e-04
# Epoch 198/500
# 4/4 [==============================] - 0s 31ms/step - loss: 1.8761e-05 - categorical_crossentropy: 1.8761e-05 - val_loss: 1.9284e-05 - val_categorical_crossentropy: 1.9284e-05 - lr: 1.0000e-04
# Epoch 199/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.8721e-05 - categorical_crossentropy: 1.8721e-05 - val_loss: 1.9236e-05 - val_categorical_crossentropy: 1.9236e-05 - lr: 1.0000e-04
# Epoch 200/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.8685e-05 - categorical_crossentropy: 1.8685e-05 - val_loss: 1.9204e-05 - val_categorical_crossentropy: 1.9204e-05 - lr: 1.0000e-04
# Epoch 201/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.8646e-05 - categorical_crossentropy: 1.8646e-05 - val_loss: 1.9169e-05 - val_categorical_crossentropy: 1.9169e-05 - lr: 1.0000e-04
# Epoch 202/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.8611e-05 - categorical_crossentropy: 1.8611e-05 - val_loss: 1.9125e-05 - val_categorical_crossentropy: 1.9125e-05 - lr: 1.0000e-04
# Epoch 203/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.8574e-05 - categorical_crossentropy: 1.8574e-05 - val_loss: 1.9097e-05 - val_categorical_crossentropy: 1.9097e-05 - lr: 1.0000e-04
# Epoch 204/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.8534e-05 - categorical_crossentropy: 1.8534e-05 - val_loss: 1.9045e-05 - val_categorical_crossentropy: 1.9045e-05 - lr: 1.0000e-04
# Epoch 205/500
# 4/4 [==============================] - 0s 29ms/step - loss: 1.8504e-05 - categorical_crossentropy: 1.8504e-05 - val_loss: 1.9014e-05 - val_categorical_crossentropy: 1.9014e-05 - lr: 1.0000e-04
# Epoch 206/500
# 4/4 [==============================] - 0s 27ms/step - loss: 1.8463e-05 - categorical_crossentropy: 1.8463e-05 - val_loss: 1.8982e-05 - val_categorical_crossentropy: 1.8982e-05 - lr: 1.0000e-04
# Epoch 207/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.8425e-05 - categorical_crossentropy: 1.8425e-05 - val_loss: 1.8934e-05 - val_categorical_crossentropy: 1.8934e-05 - lr: 1.0000e-04
# Epoch 208/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.8391e-05 - categorical_crossentropy: 1.8391e-05 - val_loss: 1.8906e-05 - val_categorical_crossentropy: 1.8906e-05 - lr: 1.0000e-04
# Epoch 209/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.8347e-05 - categorical_crossentropy: 1.8347e-05 - val_loss: 1.8863e-05 - val_categorical_crossentropy: 1.8863e-05 - lr: 1.0000e-04
# Epoch 210/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.8314e-05 - categorical_crossentropy: 1.8314e-05 - val_loss: 1.8815e-05 - val_categorical_crossentropy: 1.8815e-05 - lr: 1.0000e-04
# Epoch 211/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.8281e-05 - categorical_crossentropy: 1.8281e-05 - val_loss: 1.8787e-05 - val_categorical_crossentropy: 1.8787e-05 - lr: 1.0000e-04
# Epoch 212/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.8244e-05 - categorical_crossentropy: 1.8244e-05 - val_loss: 1.8747e-05 - val_categorical_crossentropy: 1.8747e-05 - lr: 1.0000e-04
# Epoch 213/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.8208e-05 - categorical_crossentropy: 1.8208e-05 - val_loss: 1.8700e-05 - val_categorical_crossentropy: 1.8700e-05 - lr: 1.0000e-04
# Epoch 214/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.8170e-05 - categorical_crossentropy: 1.8170e-05 - val_loss: 1.8664e-05 - val_categorical_crossentropy: 1.8664e-05 - lr: 1.0000e-04
# Epoch 215/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.8133e-05 - categorical_crossentropy: 1.8133e-05 - val_loss: 1.8632e-05 - val_categorical_crossentropy: 1.8632e-05 - lr: 1.0000e-04
# Epoch 216/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.8089e-05 - categorical_crossentropy: 1.8089e-05 - val_loss: 1.8596e-05 - val_categorical_crossentropy: 1.8596e-05 - lr: 1.0000e-04
# Epoch 217/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.8054e-05 - categorical_crossentropy: 1.8054e-05 - val_loss: 1.8557e-05 - val_categorical_crossentropy: 1.8557e-05 - lr: 1.0000e-04
# Epoch 218/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.8019e-05 - categorical_crossentropy: 1.8019e-05 - val_loss: 1.8513e-05 - val_categorical_crossentropy: 1.8513e-05 - lr: 1.0000e-04
# Epoch 219/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.7987e-05 - categorical_crossentropy: 1.7987e-05 - val_loss: 1.8477e-05 - val_categorical_crossentropy: 1.8477e-05 - lr: 1.0000e-04
# Epoch 220/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.7944e-05 - categorical_crossentropy: 1.7944e-05 - val_loss: 1.8438e-05 - val_categorical_crossentropy: 1.8438e-05 - lr: 1.0000e-04
# Epoch 221/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.7908e-05 - categorical_crossentropy: 1.7908e-05 - val_loss: 1.8402e-05 - val_categorical_crossentropy: 1.8402e-05 - lr: 1.0000e-04
# Epoch 222/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.7877e-05 - categorical_crossentropy: 1.7877e-05 - val_loss: 1.8362e-05 - val_categorical_crossentropy: 1.8362e-05 - lr: 1.0000e-04
# Epoch 223/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.7839e-05 - categorical_crossentropy: 1.7839e-05 - val_loss: 1.8322e-05 - val_categorical_crossentropy: 1.8322e-05 - lr: 1.0000e-04
# Epoch 224/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.7800e-05 - categorical_crossentropy: 1.7800e-05 - val_loss: 1.8287e-05 - val_categorical_crossentropy: 1.8287e-05 - lr: 1.0000e-04
# Epoch 225/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.7767e-05 - categorical_crossentropy: 1.7767e-05 - val_loss: 1.8251e-05 - val_categorical_crossentropy: 1.8251e-05 - lr: 1.0000e-04
# Epoch 226/500
# 4/4 [==============================] - 0s 28ms/step - loss: 1.7733e-05 - categorical_crossentropy: 1.7733e-05 - val_loss: 1.8203e-05 - val_categorical_crossentropy: 1.8203e-05 - lr: 1.0000e-04
# Epoch 227/500
# 4/4 [==============================] - 0s 31ms/step - loss: 1.7690e-05 - categorical_crossentropy: 1.7690e-05 - val_loss: 1.8171e-05 - val_categorical_crossentropy: 1.8171e-05 - lr: 1.0000e-04
# Epoch 228/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.7657e-05 - categorical_crossentropy: 1.7657e-05 - val_loss: 1.8143e-05 - val_categorical_crossentropy: 1.8143e-05 - lr: 1.0000e-04
# Epoch 229/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.7622e-05 - categorical_crossentropy: 1.7622e-05 - val_loss: 1.8108e-05 - val_categorical_crossentropy: 1.8108e-05 - lr: 1.0000e-04
# Epoch 230/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.7584e-05 - categorical_crossentropy: 1.7584e-05 - val_loss: 1.8048e-05 - val_categorical_crossentropy: 1.8048e-05 - lr: 1.0000e-04
# Epoch 231/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.7543e-05 - categorical_crossentropy: 1.7543e-05 - val_loss: 1.8012e-05 - val_categorical_crossentropy: 1.8012e-05 - lr: 1.0000e-04
# Epoch 232/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.7515e-05 - categorical_crossentropy: 1.7515e-05 - val_loss: 1.7992e-05 - val_categorical_crossentropy: 1.7992e-05 - lr: 1.0000e-04
# Epoch 233/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.7480e-05 - categorical_crossentropy: 1.7480e-05 - val_loss: 1.7937e-05 - val_categorical_crossentropy: 1.7937e-05 - lr: 1.0000e-04
# Epoch 234/500
# ...
# Epoch 424/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.1476e-05 - categorical_crossentropy: 1.1476e-05 - val_loss: 1.1734e-05 - val_categorical_crossentropy: 1.1734e-05 - lr: 1.0000e-04
# Epoch 425/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.1452e-05 - categorical_crossentropy: 1.1452e-05 - val_loss: 1.1714e-05 - val_categorical_crossentropy: 1.1714e-05 - lr: 1.0000e-04
# Epoch 426/500
# 4/4 [==============================] - 0s 29ms/step - loss: 1.1426e-05 - categorical_crossentropy: 1.1426e-05 - val_loss: 1.1698e-05 - val_categorical_crossentropy: 1.1698e-05 - lr: 1.0000e-04
# Epoch 427/500
# 4/4 [==============================] - 0s 30ms/step - loss: 1.1393e-05 - categorical_crossentropy: 1.1393e-05 - val_loss: 1.1659e-05 - val_categorical_crossentropy: 1.1659e-05 - lr: 1.0000e-04
# Epoch 428/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.1376e-05 - categorical_crossentropy: 1.1376e-05 - val_loss: 1.1635e-05 - val_categorical_crossentropy: 1.1635e-05 - lr: 1.0000e-04
# Epoch 429/500
# 4/4 [==============================] - 0s 30ms/step - loss: 1.1352e-05 - categorical_crossentropy: 1.1352e-05 - val_loss: 1.1607e-05 - val_categorical_crossentropy: 1.1607e-05 - lr: 1.0000e-04
# Epoch 430/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.1322e-05 - categorical_crossentropy: 1.1322e-05 - val_loss: 1.1575e-05 - val_categorical_crossentropy: 1.1575e-05 - lr: 1.0000e-04
# Epoch 431/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.1295e-05 - categorical_crossentropy: 1.1295e-05 - val_loss: 1.1555e-05 - val_categorical_crossentropy: 1.1555e-05 - lr: 1.0000e-04
# Epoch 432/500
# 4/4 [==============================] - 0s 28ms/step - loss: 1.1266e-05 - categorical_crossentropy: 1.1266e-05 - val_loss: 1.1539e-05 - val_categorical_crossentropy: 1.1539e-05 - lr: 1.0000e-04
# Epoch 433/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.1240e-05 - categorical_crossentropy: 1.1240e-05 - val_loss: 1.1492e-05 - val_categorical_crossentropy: 1.1492e-05 - lr: 1.0000e-04
# Epoch 434/500
# 4/4 [==============================] - 0s 27ms/step - loss: 1.1212e-05 - categorical_crossentropy: 1.1212e-05 - val_loss: 1.1472e-05 - val_categorical_crossentropy: 1.1472e-05 - lr: 1.0000e-04
# Epoch 435/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.1191e-05 - categorical_crossentropy: 1.1191e-05 - val_loss: 1.1452e-05 - val_categorical_crossentropy: 1.1452e-05 - lr: 1.0000e-04
# Epoch 436/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.1168e-05 - categorical_crossentropy: 1.1168e-05 - val_loss: 1.1412e-05 - val_categorical_crossentropy: 1.1412e-05 - lr: 1.0000e-04
# Epoch 437/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.1140e-05 - categorical_crossentropy: 1.1140e-05 - val_loss: 1.1380e-05 - val_categorical_crossentropy: 1.1380e-05 - lr: 1.0000e-04
# Epoch 438/500
# 4/4 [==============================] - 0s 27ms/step - loss: 1.1110e-05 - categorical_crossentropy: 1.1110e-05 - val_loss: 1.1376e-05 - val_categorical_crossentropy: 1.1376e-05 - lr: 1.0000e-04
# Epoch 439/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.1087e-05 - categorical_crossentropy: 1.1087e-05 - val_loss: 1.1349e-05 - val_categorical_crossentropy: 1.1349e-05 - lr: 1.0000e-04
# Epoch 440/500
# 4/4 [==============================] - 0s 29ms/step - loss: 1.1059e-05 - categorical_crossentropy: 1.1059e-05 - val_loss: 1.1313e-05 - val_categorical_crossentropy: 1.1313e-05 - lr: 1.0000e-04
# Epoch 441/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.1035e-05 - categorical_crossentropy: 1.1035e-05 - val_loss: 1.1293e-05 - val_categorical_crossentropy: 1.1293e-05 - lr: 1.0000e-04
# Epoch 442/500
# 4/4 [==============================] - 0s 29ms/step - loss: 1.1008e-05 - categorical_crossentropy: 1.1008e-05 - val_loss: 1.1273e-05 - val_categorical_crossentropy: 1.1273e-05 - lr: 1.0000e-04
# Epoch 443/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.0986e-05 - categorical_crossentropy: 1.0986e-05 - val_loss: 1.1221e-05 - val_categorical_crossentropy: 1.1221e-05 - lr: 1.0000e-04
# Epoch 444/500
# 4/4 [==============================] - 0s 27ms/step - loss: 1.0961e-05 - categorical_crossentropy: 1.0961e-05 - val_loss: 1.1202e-05 - val_categorical_crossentropy: 1.1202e-05 - lr: 1.0000e-04
# Epoch 445/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.0929e-05 - categorical_crossentropy: 1.0929e-05 - val_loss: 1.1186e-05 - val_categorical_crossentropy: 1.1186e-05 - lr: 1.0000e-04
# Epoch 446/500
# 4/4 [==============================] - 0s 35ms/step - loss: 1.0905e-05 - categorical_crossentropy: 1.0905e-05 - val_loss: 1.1158e-05 - val_categorical_crossentropy: 1.1158e-05 - lr: 1.0000e-04
# Epoch 447/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0883e-05 - categorical_crossentropy: 1.0883e-05 - val_loss: 1.1134e-05 - val_categorical_crossentropy: 1.1134e-05 - lr: 1.0000e-04
# Epoch 448/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.0856e-05 - categorical_crossentropy: 1.0856e-05 - val_loss: 1.1110e-05 - val_categorical_crossentropy: 1.1110e-05 - lr: 1.0000e-04
# Epoch 449/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.0829e-05 - categorical_crossentropy: 1.0829e-05 - val_loss: 1.1078e-05 - val_categorical_crossentropy: 1.1078e-05 - lr: 1.0000e-04
# Epoch 450/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0809e-05 - categorical_crossentropy: 1.0809e-05 - val_loss: 1.1051e-05 - val_categorical_crossentropy: 1.1051e-05 - lr: 1.0000e-04
# Epoch 451/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0788e-05 - categorical_crossentropy: 1.0788e-05 - val_loss: 1.1031e-05 - val_categorical_crossentropy: 1.1031e-05 - lr: 1.0000e-04
# Epoch 452/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.0758e-05 - categorical_crossentropy: 1.0758e-05 - val_loss: 1.1003e-05 - val_categorical_crossentropy: 1.1003e-05 - lr: 1.0000e-04
# Epoch 453/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.0731e-05 - categorical_crossentropy: 1.0731e-05 - val_loss: 1.0975e-05 - val_categorical_crossentropy: 1.0975e-05 - lr: 1.0000e-04
# Epoch 454/500
# 4/4 [==============================] - 0s 29ms/step - loss: 1.0705e-05 - categorical_crossentropy: 1.0705e-05 - val_loss: 1.0955e-05 - val_categorical_crossentropy: 1.0955e-05 - lr: 1.0000e-04
# Epoch 455/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0677e-05 - categorical_crossentropy: 1.0677e-05 - val_loss: 1.0931e-05 - val_categorical_crossentropy: 1.0931e-05 - lr: 1.0000e-04
# Epoch 456/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.0652e-05 - categorical_crossentropy: 1.0652e-05 - val_loss: 1.0892e-05 - val_categorical_crossentropy: 1.0892e-05 - lr: 1.0000e-04
# Epoch 457/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.0634e-05 - categorical_crossentropy: 1.0634e-05 - val_loss: 1.0880e-05 - val_categorical_crossentropy: 1.0880e-05 - lr: 1.0000e-04
# Epoch 458/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.0609e-05 - categorical_crossentropy: 1.0609e-05 - val_loss: 1.0852e-05 - val_categorical_crossentropy: 1.0852e-05 - lr: 1.0000e-04
# Epoch 459/500
# 4/4 [==============================] - 0s 26ms/step - loss: 1.0585e-05 - categorical_crossentropy: 1.0585e-05 - val_loss: 1.0816e-05 - val_categorical_crossentropy: 1.0816e-05 - lr: 1.0000e-04
# Epoch 460/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0564e-05 - categorical_crossentropy: 1.0564e-05 - val_loss: 1.0792e-05 - val_categorical_crossentropy: 1.0792e-05 - lr: 1.0000e-04
# Epoch 461/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0533e-05 - categorical_crossentropy: 1.0533e-05 - val_loss: 1.0780e-05 - val_categorical_crossentropy: 1.0780e-05 - lr: 1.0000e-04
# Epoch 462/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0509e-05 - categorical_crossentropy: 1.0509e-05 - val_loss: 1.0753e-05 - val_categorical_crossentropy: 1.0753e-05 - lr: 1.0000e-04
# Epoch 463/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.0480e-05 - categorical_crossentropy: 1.0480e-05 - val_loss: 1.0721e-05 - val_categorical_crossentropy: 1.0721e-05 - lr: 1.0000e-04
# Epoch 464/500
# 4/4 [==============================] - 0s 29ms/step - loss: 1.0455e-05 - categorical_crossentropy: 1.0455e-05 - val_loss: 1.0705e-05 - val_categorical_crossentropy: 1.0705e-05 - lr: 1.0000e-04
# Epoch 465/500
# 4/4 [==============================] - 0s 27ms/step - loss: 1.0438e-05 - categorical_crossentropy: 1.0438e-05 - val_loss: 1.0677e-05 - val_categorical_crossentropy: 1.0677e-05 - lr: 1.0000e-04
# Epoch 466/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.0409e-05 - categorical_crossentropy: 1.0409e-05 - val_loss: 1.0637e-05 - val_categorical_crossentropy: 1.0637e-05 - lr: 1.0000e-04
# Epoch 467/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0390e-05 - categorical_crossentropy: 1.0390e-05 - val_loss: 1.0621e-05 - val_categorical_crossentropy: 1.0621e-05 - lr: 1.0000e-04
# Epoch 468/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.0372e-05 - categorical_crossentropy: 1.0372e-05 - val_loss: 1.0606e-05 - val_categorical_crossentropy: 1.0606e-05 - lr: 1.0000e-04
# Epoch 469/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0340e-05 - categorical_crossentropy: 1.0340e-05 - val_loss: 1.0570e-05 - val_categorical_crossentropy: 1.0570e-05 - lr: 1.0000e-04
# Epoch 470/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.0310e-05 - categorical_crossentropy: 1.0310e-05 - val_loss: 1.0546e-05 - val_categorical_crossentropy: 1.0546e-05 - lr: 1.0000e-04
# Epoch 471/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.0289e-05 - categorical_crossentropy: 1.0289e-05 - val_loss: 1.0542e-05 - val_categorical_crossentropy: 1.0542e-05 - lr: 1.0000e-04
# Epoch 472/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0268e-05 - categorical_crossentropy: 1.0268e-05 - val_loss: 1.0498e-05 - val_categorical_crossentropy: 1.0498e-05 - lr: 1.0000e-04
# Epoch 473/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.0233e-05 - categorical_crossentropy: 1.0233e-05 - val_loss: 1.0467e-05 - val_categorical_crossentropy: 1.0467e-05 - lr: 1.0000e-04
# Epoch 474/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.0211e-05 - categorical_crossentropy: 1.0211e-05 - val_loss: 1.0451e-05 - val_categorical_crossentropy: 1.0451e-05 - lr: 1.0000e-04
# Epoch 475/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0197e-05 - categorical_crossentropy: 1.0197e-05 - val_loss: 1.0423e-05 - val_categorical_crossentropy: 1.0423e-05 - lr: 1.0000e-04
# Epoch 476/500
# 4/4 [==============================] - 0s 24ms/step - loss: 1.0180e-05 - categorical_crossentropy: 1.0180e-05 - val_loss: 1.0395e-05 - val_categorical_crossentropy: 1.0395e-05 - lr: 1.0000e-04
# Epoch 477/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.0150e-05 - categorical_crossentropy: 1.0150e-05 - val_loss: 1.0371e-05 - val_categorical_crossentropy: 1.0371e-05 - lr: 1.0000e-04
# Epoch 478/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.0122e-05 - categorical_crossentropy: 1.0122e-05 - val_loss: 1.0359e-05 - val_categorical_crossentropy: 1.0359e-05 - lr: 1.0000e-04
# Epoch 479/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0103e-05 - categorical_crossentropy: 1.0103e-05 - val_loss: 1.0323e-05 - val_categorical_crossentropy: 1.0323e-05 - lr: 1.0000e-04
# Epoch 480/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0081e-05 - categorical_crossentropy: 1.0081e-05 - val_loss: 1.0300e-05 - val_categorical_crossentropy: 1.0300e-05 - lr: 1.0000e-04
# Epoch 481/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.0043e-05 - categorical_crossentropy: 1.0043e-05 - val_loss: 1.0280e-05 - val_categorical_crossentropy: 1.0280e-05 - lr: 1.0000e-04
# Epoch 482/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0027e-05 - categorical_crossentropy: 1.0027e-05 - val_loss: 1.0252e-05 - val_categorical_crossentropy: 1.0252e-05 - lr: 1.0000e-04
# Epoch 483/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0007e-05 - categorical_crossentropy: 1.0007e-05 - val_loss: 1.0228e-05 - val_categorical_crossentropy: 1.0228e-05 - lr: 1.0000e-04
# Epoch 484/500
# 4/4 [==============================] - 0s 19ms/step - loss: 9.9778e-06 - categorical_crossentropy: 9.9778e-06 - val_loss: 1.0204e-05 - val_categorical_crossentropy: 1.0204e-05 - lr: 1.0000e-04
# Epoch 485/500
# 4/4 [==============================] - 0s 19ms/step - loss: 9.9569e-06 - categorical_crossentropy: 9.9569e-06 - val_loss: 1.0184e-05 - val_categorical_crossentropy: 1.0184e-05 - lr: 1.0000e-04
# Epoch 486/500
# 4/4 [==============================] - 0s 20ms/step - loss: 9.9470e-06 - categorical_crossentropy: 9.9470e-06 - val_loss: 1.0161e-05 - val_categorical_crossentropy: 1.0161e-05 - lr: 1.0000e-04
# Epoch 487/500
# 4/4 [==============================] - 0s 22ms/step - loss: 9.9152e-06 - categorical_crossentropy: 9.9152e-06 - val_loss: 1.0141e-05 - val_categorical_crossentropy: 1.0141e-05 - lr: 1.0000e-04
# Epoch 488/500
# 4/4 [==============================] - 0s 20ms/step - loss: 9.8824e-06 - categorical_crossentropy: 9.8824e-06 - val_loss: 1.0113e-05 - val_categorical_crossentropy: 1.0113e-05 - lr: 1.0000e-04
# Epoch 489/500
# 4/4 [==============================] - 0s 24ms/step - loss: 9.8605e-06 - categorical_crossentropy: 9.8605e-06 - val_loss: 1.0081e-05 - val_categorical_crossentropy: 1.0081e-05 - lr: 1.0000e-04
# Epoch 490/500
# 4/4 [==============================] - 0s 26ms/step - loss: 9.8427e-06 - categorical_crossentropy: 9.8427e-06 - val_loss: 1.0069e-05 - val_categorical_crossentropy: 1.0069e-05 - lr: 1.0000e-04
# Epoch 491/500
# 4/4 [==============================] - 0s 21ms/step - loss: 9.8168e-06 - categorical_crossentropy: 9.8168e-06 - val_loss: 1.0041e-05 - val_categorical_crossentropy: 1.0041e-05 - lr: 1.0000e-04
# Epoch 492/500
# 4/4 [==============================] - 0s 22ms/step - loss: 9.7940e-06 - categorical_crossentropy: 9.7940e-06 - val_loss: 1.0017e-05 - val_categorical_crossentropy: 1.0017e-05 - lr: 1.0000e-04
# Epoch 493/500
# 4/4 [==============================] - 0s 20ms/step - loss: 9.7691e-06 - categorical_crossentropy: 9.7691e-06 - val_loss: 9.9936e-06 - val_categorical_crossentropy: 9.9936e-06 - lr: 1.0000e-04
# Epoch 494/500
# 4/4 [==============================] - 0s 19ms/step - loss: 9.7532e-06 - categorical_crossentropy: 9.7532e-06 - val_loss: 9.9619e-06 - val_categorical_crossentropy: 9.9619e-06 - lr: 1.0000e-04
# Epoch 495/500
# 4/4 [==============================] - 0s 22ms/step - loss: 9.7324e-06 - categorical_crossentropy: 9.7324e-06 - val_loss: 9.9460e-06 - val_categorical_crossentropy: 9.9460e-06 - lr: 1.0000e-04
# Epoch 496/500
# 4/4 [==============================] - 0s 21ms/step - loss: 9.7006e-06 - categorical_crossentropy: 9.7006e-06 - val_loss: 9.9181e-06 - val_categorical_crossentropy: 9.9181e-06 - lr: 1.0000e-04
# Epoch 497/500
# 4/4 [==============================] - 0s 20ms/step - loss: 9.6787e-06 - categorical_crossentropy: 9.6787e-06 - val_loss: 9.8943e-06 - val_categorical_crossentropy: 9.8943e-06 - lr: 1.0000e-04
# Epoch 498/500
# 4/4 [==============================] - 0s 23ms/step - loss: 9.6599e-06 - categorical_crossentropy: 9.6599e-06 - val_loss: 9.8784e-06 - val_categorical_crossentropy: 9.8784e-06 - lr: 1.0000e-04
# Epoch 499/500
# 4/4 [==============================] - 0s 21ms/step - loss: 9.6380e-06 - categorical_crossentropy: 9.6380e-06 - val_loss: 9.8625e-06 - val_categorical_crossentropy: 9.8625e-06 - lr: 1.0000e-04
# Epoch 500/500
# 4/4 [==============================] - 0s 22ms/step - loss: 9.6142e-06 - categorical_crossentropy: 9.6142e-06 - val_loss: 9.8307e-06 - val_categorical_crossentropy: 9.8307e-06 - lr: 1.0000e-04

# %%
class ModelWrapper():
    def __init__(self,model):
        self.model=model
    def predict_proba(self,X):
        if isinstance(X, pd.DataFrame):
            X=X.values
        Xnn=X.reshape(X.shape[0],1,X.shape[1])
        return self.model.predict(Xnn)
    def predict(self, X):
        return np.argmax(self.predict_proba(X),axis=1)
clf=ModelWrapper(model)

# %% [markdown]
# ## SHAP
# We calculate SHAP for datasets

# %%
fXtrain = trainX.reshape(150,1,200)

# %%
from tsproto.utils import getshap

shap_version='deep'
bg_size = 1000
stride=10
window_len=10
absshap = True
fXtrain,sv_tr = getshap(model=model, X=fXtrain, y=train_ynn,shap_version=shap_version,bg_size = bg_size, stride=stride, window_len=window_len, absshap = absshap, shuffle=False)
# Out:
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [markdown]
# ## Visualize SHAP
# In this section we can see that the network focused on correct parts of the time-series.
# In this toy example, it is sufficient to look at SHAP-visualizations to spot the difference, but in case of hundreds of dimensions and more complex problems, prototypes are more useful.

# %%
from  tsproto.plots import plot_smooth_colored_line
indexer = clf.predict(trainX)
shapclass = []
if absshap == False:
    for i in range(0,len(trainX)):
        best_index = indexer[i]
        shapclass.append([sv_tr[best_index][i,:]])
        
    shapclass=np.concatenate(shapclass)
else:
    shapclass  = sv_tr[:,0,:]

    fig, axes =plt.subplots(2,1,figsize=(12,6))

    for i in range(0,10):
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==0][i], color_values=shapclass[train_y==0][i], resolution=1000, ax=axes[0],add_cbar=(i==0))
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==1][i], color_values=shapclass[train_y==1][i], resolution=1000, ax=axes[1],add_cbar=(i==0))

for ax in axes:
    ax.set_ylim([-2, 2])
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Tsproto
# Now, lets try to apply TSProto to see if it is able to find the prototype and summarize them correctly to show what logical relation is between them and the model prediction

# %%
trainXproto = trainX.reshape((trainX.shape[0], trainX.shape[1],1))
shapclassXproto = shapclass.reshape((shapclass.shape[0], shapclass.shape[1],1))

# %%
from tsproto.models import *
im  = InterpretableModel()
pe = PrototypeEncoder(clf, n_clusters=2, min_size=50, method='rocket',
                              descriptors=['frequency','existance'],
                      jump=1, pen=1,multiplier=-1,n_jobs=-1,
                      verbose=1)
ohe_train, features, target_ohe,weights = pe.fit_transform(trainXproto,shapclassXproto)
acc,prec,rec,f1,iclf = im.fit_or_predict(ohe_train, features, target_ohe,intclf=None, verbose=0, max_depth=2, min_samples_leaf=0.05,
                       weights=None)
# Out:
# Dataset shape: (150, 200, 1)
# Calculating changepoints...
# 5/5 [==============================] - 0s 2ms/step
# WARNING: Changing the threshold, due to empty record
# Done in 1.4616234302520752.
# Clustering data
# Shape of data for clustering: (150, 86, 1)
# Clustering data
# Done in 12.977369785308838.
# OHE time series
# ['frequency', 'existance']
# Done in 0.1875295639038086.
# invalid value encountered in divide

# %% [markdown]
# ## Visualize interpretable model
# We can easily see that the TSProto has found the sine wave at the beginning of the sample, marked it as prototype and correctly identified that its existence is not enough to treat the sample as a class 1 sample, additional frequency context has to be added in order to distinguish these two

# %%
from  tsproto.plots import *
ds_final = ohe_train.copy()
dot = export_decision_tree_with_embedded_histograms(decision_tree=iclf, 
                                              dataset=ds_final, 
                                              target_name='target', 
                                              feature_names=features, 
                                              filename='synthetic', 
                                              proto_encoder=pe, figsize=(6,3))

from IPython.display import SVG, Image
Image('synthetic.png')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Decision Tree exported to synthetic with embedded histograms successfully.
