# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn import tree
from graphviz import Source
from IPython.display import display
from IPython.display import SVG

# %% [markdown]
# ## Creating synthetic dataset
# We will create a synthetic dataset with two classes. The dataset will be hard to distinguish based on statistical features, but possible with proper prototypical parts extracted.
#
# We are making it even harder, as the prototypical parts are more or less the same. They are differing in terms of frequency.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(3*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X3 = np.concatenate((x1,x2))
Y3 = np.concatenate((y1,y2))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(2*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X4 = np.concatenate((x1,x2))
Y4 = np.concatenate((y1,y2))

# %% [markdown]
# ## Generating sample cases

# %%
x = X3
proto_sin_y = Y3
proto_inversed_sin_y = Y4

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,proto_sin_y)
axes[1].plot(x,proto_inversed_sin_y)

# %% [markdown]
# ## Generating noise and augmenting signals

# %%
noise_power = .2

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_sin_y = noise + proto_sin_y

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_inversed_sin_y = noise + proto_inversed_sin_y

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,noisy_proto_sin_y[0])
axes[1].plot(x,noisy_proto_inversed_sin_y[0])
for ax in axes:
    ax.set_ylim([-2, 2])

# %%
X=np.concatenate((noisy_proto_sin_y,noisy_proto_inversed_sin_y))
Xy=np.concatenate((np.ones(len(noisy_proto_sin_y))*0,
                   np.ones(len(noisy_proto_inversed_sin_y))*1))

trainX, testX, train_y,test_y = train_test_split(X,Xy)

# %% [markdown]
# ## Model
# We will build simple DNN model (not really needed in this case, but it serves the purpose of demonstration how to deal with more complex cases)

# %%
trainX.shape
# Out:
# (150, 200)

# %%
from keras.utils import to_categorical
trainXnn = trainX.reshape(150,1,200)
train_ynn = to_categorical(train_y)
num_classes = len(np.unique(Xy))

# %%
import keras
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    #add dropout
    input_layer = keras.layers.Dropout(0.5)(input_layer)
    conv1 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(input_layer)
    #conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv1)
    #conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv2)
    #conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)



model = make_model(input_shape=trainXnn.shape[1:])

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_crossentropy"],
)
history = model.fit(
    trainXnn,
    train_ynn,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6814 - categorical_crossentropy: 0.6814 - val_loss: 0.6627 - val_categorical_crossentropy: 0.6627 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 95ms/step - loss: 0.6329 - categorical_crossentropy: 0.6329 - val_loss: 0.5914 - val_categorical_crossentropy: 0.5914 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 84ms/step - loss: 0.5369 - categorical_crossentropy: 0.5369 - val_loss: 0.4656 - val_categorical_crossentropy: 0.4656 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 0s 61ms/step - loss: 0.3840 - categorical_crossentropy: 0.3840 - val_loss: 0.2884 - val_categorical_crossentropy: 0.2884 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 81ms/step - loss: 0.2057 - categorical_crossentropy: 0.2057 - val_loss: 0.1222 - val_categorical_crossentropy: 0.1222 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0725 - categorical_crossentropy: 0.0725 - val_loss: 0.0322 - val_categorical_crossentropy: 0.0322 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 77ms/step - loss: 0.0178 - categorical_crossentropy: 0.0178 - val_loss: 0.0064 - val_categorical_crossentropy: 0.0064 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0033 - categorical_crossentropy: 0.0033 - val_loss: 0.0014 - val_categorical_crossentropy: 0.0014 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 0s 77ms/step - loss: 7.8858e-04 - categorical_crossentropy: 7.8858e-04 - val_loss: 3.8484e-04 - val_categorical_crossentropy: 3.8484e-04 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 0s 78ms/step - loss: 2.4441e-04 - categorical_crossentropy: 2.4441e-04 - val_loss: 1.4243e-04 - val_categorical_crossentropy: 1.4243e-04 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 0s 107ms/step - loss: 9.5470e-05 - categorical_crossentropy: 9.5470e-05 - val_loss: 6.7978e-05 - val_categorical_crossentropy: 6.7978e-05 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 66ms/step - loss: 5.0405e-05 - categorical_crossentropy: 5.0405e-05 - val_loss: 3.9771e-05 - val_categorical_crossentropy: 3.9771e-05 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 0s 69ms/step - loss: 3.0807e-05 - categorical_crossentropy: 3.0807e-05 - val_loss: 2.7167e-05 - val_categorical_crossentropy: 2.7167e-05 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 64ms/step - loss: 2.2169e-05 - categorical_crossentropy: 2.2169e-05 - val_loss: 2.0766e-05 - val_categorical_crossentropy: 2.0766e-05 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.7522e-05 - categorical_crossentropy: 1.7522e-05 - val_loss: 1.7234e-05 - val_categorical_crossentropy: 1.7234e-05 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.4904e-05 - categorical_crossentropy: 1.4904e-05 - val_loss: 1.5139e-05 - val_categorical_crossentropy: 1.5139e-05 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 59ms/step - loss: 1.3332e-05 - categorical_crossentropy: 1.3332e-05 - val_loss: 1.3852e-05 - val_categorical_crossentropy: 1.3852e-05 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.2336e-05 - categorical_crossentropy: 1.2336e-05 - val_loss: 1.3010e-05 - val_categorical_crossentropy: 1.3010e-05 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.1666e-05 - categorical_crossentropy: 1.1666e-05 - val_loss: 1.2457e-05 - val_categorical_crossentropy: 1.2457e-05 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.1237e-05 - categorical_crossentropy: 1.1237e-05 - val_loss: 1.2076e-05 - val_categorical_crossentropy: 1.2076e-05 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 99ms/step - loss: 1.0938e-05 - categorical_crossentropy: 1.0938e-05 - val_loss: 1.1814e-05 - val_categorical_crossentropy: 1.1814e-05 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 64ms/step - loss: 1.0731e-05 - categorical_crossentropy: 1.0731e-05 - val_loss: 1.1619e-05 - val_categorical_crossentropy: 1.1619e-05 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 115ms/step - loss: 1.0574e-05 - categorical_crossentropy: 1.0574e-05 - val_loss: 1.1472e-05 - val_categorical_crossentropy: 1.1472e-05 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.0462e-05 - categorical_crossentropy: 1.0462e-05 - val_loss: 1.1361e-05 - val_categorical_crossentropy: 1.1361e-05 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0365e-05 - categorical_crossentropy: 1.0365e-05 - val_loss: 1.1261e-05 - val_categorical_crossentropy: 1.1261e-05 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.0295e-05 - categorical_crossentropy: 1.0295e-05 - val_loss: 1.1194e-05 - val_categorical_crossentropy: 1.1194e-05 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.0219e-05 - categorical_crossentropy: 1.0219e-05 - val_loss: 1.1118e-05 - val_categorical_crossentropy: 1.1118e-05 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.0165e-05 - categorical_crossentropy: 1.0165e-05 - val_loss: 1.1074e-05 - val_categorical_crossentropy: 1.1074e-05 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.0114e-05 - categorical_crossentropy: 1.0114e-05 - val_loss: 1.0999e-05 - val_categorical_crossentropy: 1.0999e-05 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.0064e-05 - categorical_crossentropy: 1.0064e-05 - val_loss: 1.0939e-05 - val_categorical_crossentropy: 1.0939e-05 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 85ms/step - loss: 1.0015e-05 - categorical_crossentropy: 1.0015e-05 - val_loss: 1.0896e-05 - val_categorical_crossentropy: 1.0896e-05 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 80ms/step - loss: 9.9698e-06 - categorical_crossentropy: 9.9698e-06 - val_loss: 1.0848e-05 - val_categorical_crossentropy: 1.0848e-05 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 97ms/step - loss: 9.9321e-06 - categorical_crossentropy: 9.9321e-06 - val_loss: 1.0816e-05 - val_categorical_crossentropy: 1.0816e-05 - lr: 5.0000e-04
# Epoch 34/500
# 4/4 [==============================] - 0s 105ms/step - loss: 9.9142e-06 - categorical_crossentropy: 9.9142e-06 - val_loss: 1.0784e-05 - val_categorical_crossentropy: 1.0784e-05 - lr: 5.0000e-04
# Epoch 35/500
# 4/4 [==============================] - 0s 87ms/step - loss: 9.8794e-06 - categorical_crossentropy: 9.8794e-06 - val_loss: 1.0769e-05 - val_categorical_crossentropy: 1.0769e-05 - lr: 5.0000e-04
# Epoch 36/500
# 4/4 [==============================] - 0s 81ms/step - loss: 9.8566e-06 - categorical_crossentropy: 9.8566e-06 - val_loss: 1.0729e-05 - val_categorical_crossentropy: 1.0729e-05 - lr: 5.0000e-04
# Epoch 37/500
# 4/4 [==============================] - 0s 109ms/step - loss: 9.8437e-06 - categorical_crossentropy: 9.8437e-06 - val_loss: 1.0713e-05 - val_categorical_crossentropy: 1.0713e-05 - lr: 5.0000e-04
# Epoch 38/500
# 4/4 [==============================] - 0s 57ms/step - loss: 9.8129e-06 - categorical_crossentropy: 9.8129e-06 - val_loss: 1.0693e-05 - val_categorical_crossentropy: 1.0693e-05 - lr: 5.0000e-04
# Epoch 39/500
# 4/4 [==============================] - 0s 58ms/step - loss: 9.7940e-06 - categorical_crossentropy: 9.7940e-06 - val_loss: 1.0661e-05 - val_categorical_crossentropy: 1.0661e-05 - lr: 5.0000e-04
# Epoch 40/500
# 4/4 [==============================] - 0s 66ms/step - loss: 9.7691e-06 - categorical_crossentropy: 9.7691e-06 - val_loss: 1.0641e-05 - val_categorical_crossentropy: 1.0641e-05 - lr: 5.0000e-04
# Epoch 41/500
# 4/4 [==============================] - 0s 60ms/step - loss: 9.7503e-06 - categorical_crossentropy: 9.7503e-06 - val_loss: 1.0602e-05 - val_categorical_crossentropy: 1.0602e-05 - lr: 5.0000e-04
# 4/4 [==============================] - 0s 85ms/step - loss: 8.2542e-06 - categorical_crossentropy: 8.2542e-06 - val_loss: 8.9407e-06 - val_categorical_crossentropy: 8.9407e-06 - lr: 1.0000e-04
# Epoch 192/500
# 4/4 [==============================] - 0s 78ms/step - loss: 8.2463e-06 - categorical_crossentropy: 8.2463e-06 - val_loss: 8.9327e-06 - val_categorical_crossentropy: 8.9327e-06 - lr: 1.0000e-04
# Epoch 193/500
# 4/4 [==============================] - 0s 97ms/step - loss: 8.2363e-06 - categorical_crossentropy: 8.2363e-06 - val_loss: 8.9208e-06 - val_categorical_crossentropy: 8.9208e-06 - lr: 1.0000e-04
# Epoch 194/500
# 4/4 [==============================] - 0s 71ms/step - loss: 8.2284e-06 - categorical_crossentropy: 8.2284e-06 - val_loss: 8.9049e-06 - val_categorical_crossentropy: 8.9049e-06 - lr: 1.0000e-04
# Epoch 195/500
# 4/4 [==============================] - 0s 101ms/step - loss: 8.2234e-06 - categorical_crossentropy: 8.2234e-06 - val_loss: 8.8890e-06 - val_categorical_crossentropy: 8.8890e-06 - lr: 1.0000e-04
# Epoch 196/500
# 4/4 [==============================] - 0s 67ms/step - loss: 8.2155e-06 - categorical_crossentropy: 8.2155e-06 - val_loss: 8.8810e-06 - val_categorical_crossentropy: 8.8810e-06 - lr: 1.0000e-04
# Epoch 197/500
# 4/4 [==============================] - 0s 56ms/step - loss: 8.2105e-06 - categorical_crossentropy: 8.2105e-06 - val_loss: 8.8771e-06 - val_categorical_crossentropy: 8.8771e-06 - lr: 1.0000e-04
# Epoch 198/500
# 4/4 [==============================] - 0s 78ms/step - loss: 8.1976e-06 - categorical_crossentropy: 8.1976e-06 - val_loss: 8.8652e-06 - val_categorical_crossentropy: 8.8652e-06 - lr: 1.0000e-04
# Epoch 199/500
# 4/4 [==============================] - 0s 66ms/step - loss: 8.1877e-06 - categorical_crossentropy: 8.1877e-06 - val_loss: 8.8652e-06 - val_categorical_crossentropy: 8.8652e-06 - lr: 1.0000e-04
# Epoch 200/500
# 4/4 [==============================] - 0s 85ms/step - loss: 8.1837e-06 - categorical_crossentropy: 8.1837e-06 - val_loss: 8.8532e-06 - val_categorical_crossentropy: 8.8532e-06 - lr: 1.0000e-04
# Epoch 201/500
# 4/4 [==============================] - 0s 89ms/step - loss: 8.1708e-06 - categorical_crossentropy: 8.1708e-06 - val_loss: 8.8453e-06 - val_categorical_crossentropy: 8.8453e-06 - lr: 1.0000e-04
# Epoch 202/500
# 4/4 [==============================] - 0s 130ms/step - loss: 8.1618e-06 - categorical_crossentropy: 8.1618e-06 - val_loss: 8.8373e-06 - val_categorical_crossentropy: 8.8373e-06 - lr: 1.0000e-04
# Epoch 203/500
# 4/4 [==============================] - 0s 84ms/step - loss: 8.1519e-06 - categorical_crossentropy: 8.1519e-06 - val_loss: 8.8294e-06 - val_categorical_crossentropy: 8.8294e-06 - lr: 1.0000e-04
# Epoch 204/500
# 4/4 [==============================] - 0s 96ms/step - loss: 8.1430e-06 - categorical_crossentropy: 8.1430e-06 - val_loss: 8.8095e-06 - val_categorical_crossentropy: 8.8095e-06 - lr: 1.0000e-04
# Epoch 205/500
# 4/4 [==============================] - 0s 94ms/step - loss: 8.1320e-06 - categorical_crossentropy: 8.1320e-06 - val_loss: 8.7976e-06 - val_categorical_crossentropy: 8.7976e-06 - lr: 1.0000e-04
# Epoch 206/500
# 4/4 [==============================] - 0s 72ms/step - loss: 8.1241e-06 - categorical_crossentropy: 8.1241e-06 - val_loss: 8.7857e-06 - val_categorical_crossentropy: 8.7857e-06 - lr: 1.0000e-04
# Epoch 207/500
# 4/4 [==============================] - 0s 75ms/step - loss: 8.1122e-06 - categorical_crossentropy: 8.1122e-06 - val_loss: 8.7817e-06 - val_categorical_crossentropy: 8.7817e-06 - lr: 1.0000e-04
# Epoch 208/500
# 4/4 [==============================] - 0s 53ms/step - loss: 8.1002e-06 - categorical_crossentropy: 8.1002e-06 - val_loss: 8.7698e-06 - val_categorical_crossentropy: 8.7698e-06 - lr: 1.0000e-04
# Epoch 209/500
# 4/4 [==============================] - 0s 77ms/step - loss: 8.0943e-06 - categorical_crossentropy: 8.0943e-06 - val_loss: 8.7618e-06 - val_categorical_crossentropy: 8.7618e-06 - lr: 1.0000e-04
# Epoch 210/500
# 4/4 [==============================] - 0s 86ms/step - loss: 8.0863e-06 - categorical_crossentropy: 8.0863e-06 - val_loss: 8.7539e-06 - val_categorical_crossentropy: 8.7539e-06 - lr: 1.0000e-04
# Epoch 211/500
# 4/4 [==============================] - 0s 104ms/step - loss: 8.0764e-06 - categorical_crossentropy: 8.0764e-06 - val_loss: 8.7499e-06 - val_categorical_crossentropy: 8.7499e-06 - lr: 1.0000e-04
# Epoch 212/500
# 4/4 [==============================] - 0s 71ms/step - loss: 8.0655e-06 - categorical_crossentropy: 8.0655e-06 - val_loss: 8.7340e-06 - val_categorical_crossentropy: 8.7340e-06 - lr: 1.0000e-04
# Epoch 213/500
# 4/4 [==============================] - 0s 93ms/step - loss: 8.0575e-06 - categorical_crossentropy: 8.0575e-06 - val_loss: 8.7181e-06 - val_categorical_crossentropy: 8.7181e-06 - lr: 1.0000e-04
# Epoch 214/500
# 4/4 [==============================] - 0s 86ms/step - loss: 8.0516e-06 - categorical_crossentropy: 8.0516e-06 - val_loss: 8.7022e-06 - val_categorical_crossentropy: 8.7022e-06 - lr: 1.0000e-04
# Epoch 215/500
# 4/4 [==============================] - 0s 119ms/step - loss: 8.0446e-06 - categorical_crossentropy: 8.0446e-06 - val_loss: 8.6983e-06 - val_categorical_crossentropy: 8.6983e-06 - lr: 1.0000e-04
# Epoch 216/500
# 4/4 [==============================] - 0s 93ms/step - loss: 8.0386e-06 - categorical_crossentropy: 8.0386e-06 - val_loss: 8.6943e-06 - val_categorical_crossentropy: 8.6943e-06 - lr: 1.0000e-04
# Epoch 217/500
# 4/4 [==============================] - 0s 76ms/step - loss: 8.0277e-06 - categorical_crossentropy: 8.0277e-06 - val_loss: 8.6903e-06 - val_categorical_crossentropy: 8.6903e-06 - lr: 1.0000e-04
# Epoch 218/500
# 4/4 [==============================] - 0s 87ms/step - loss: 8.0188e-06 - categorical_crossentropy: 8.0188e-06 - val_loss: 8.6744e-06 - val_categorical_crossentropy: 8.6744e-06 - lr: 1.0000e-04
# Epoch 436/500
# 4/4 [==============================] - 0s 84ms/step - loss: 5.9982e-06 - categorical_crossentropy: 5.9982e-06 - val_loss: 6.4492e-06 - val_categorical_crossentropy: 6.4492e-06 - lr: 1.0000e-04
# Epoch 437/500
# 4/4 [==============================] - 0s 96ms/step - loss: 5.9873e-06 - categorical_crossentropy: 5.9873e-06 - val_loss: 6.4373e-06 - val_categorical_crossentropy: 6.4373e-06 - lr: 1.0000e-04
# Epoch 438/500
# 4/4 [==============================] - 0s 83ms/step - loss: 5.9823e-06 - categorical_crossentropy: 5.9823e-06 - val_loss: 6.4134e-06 - val_categorical_crossentropy: 6.4134e-06 - lr: 1.0000e-04
# Epoch 439/500
# 4/4 [==============================] - 0s 86ms/step - loss: 5.9714e-06 - categorical_crossentropy: 5.9714e-06 - val_loss: 6.4015e-06 - val_categorical_crossentropy: 6.4015e-06 - lr: 1.0000e-04
# Epoch 440/500
# 4/4 [==============================] - 0s 58ms/step - loss: 5.9604e-06 - categorical_crossentropy: 5.9604e-06 - val_loss: 6.4015e-06 - val_categorical_crossentropy: 6.4015e-06 - lr: 1.0000e-04
# Epoch 441/500
# 4/4 [==============================] - 0s 71ms/step - loss: 5.9515e-06 - categorical_crossentropy: 5.9515e-06 - val_loss: 6.3975e-06 - val_categorical_crossentropy: 6.3975e-06 - lr: 1.0000e-04
# Epoch 442/500
# 4/4 [==============================] - 0s 129ms/step - loss: 5.9406e-06 - categorical_crossentropy: 5.9406e-06 - val_loss: 6.3936e-06 - val_categorical_crossentropy: 6.3936e-06 - lr: 1.0000e-04
# Epoch 443/500
# 4/4 [==============================] - 0s 91ms/step - loss: 5.9366e-06 - categorical_crossentropy: 5.9366e-06 - val_loss: 6.3816e-06 - val_categorical_crossentropy: 6.3816e-06 - lr: 1.0000e-04
# Epoch 444/500
# 4/4 [==============================] - 0s 104ms/step - loss: 5.9237e-06 - categorical_crossentropy: 5.9237e-06 - val_loss: 6.3737e-06 - val_categorical_crossentropy: 6.3737e-06 - lr: 1.0000e-04
# Epoch 445/500
# 4/4 [==============================] - 0s 122ms/step - loss: 5.9147e-06 - categorical_crossentropy: 5.9147e-06 - val_loss: 6.3697e-06 - val_categorical_crossentropy: 6.3697e-06 - lr: 1.0000e-04
# Epoch 446/500
# 4/4 [==============================] - 0s 133ms/step - loss: 5.9038e-06 - categorical_crossentropy: 5.9038e-06 - val_loss: 6.3618e-06 - val_categorical_crossentropy: 6.3618e-06 - lr: 1.0000e-04
# Epoch 447/500
# 4/4 [==============================] - 0s 130ms/step - loss: 5.8929e-06 - categorical_crossentropy: 5.8929e-06 - val_loss: 6.3459e-06 - val_categorical_crossentropy: 6.3459e-06 - lr: 1.0000e-04
# Epoch 448/500
# 4/4 [==============================] - 0s 93ms/step - loss: 5.8859e-06 - categorical_crossentropy: 5.8859e-06 - val_loss: 6.3379e-06 - val_categorical_crossentropy: 6.3379e-06 - lr: 1.0000e-04
# Epoch 449/500
# Epoch 477/500
# 4/4 [==============================] - 0s 117ms/step - loss: 5.6346e-06 - categorical_crossentropy: 5.6346e-06 - val_loss: 6.0479e-06 - val_categorical_crossentropy: 6.0479e-06 - lr: 1.0000e-04
# Epoch 478/500
# 4/4 [==============================] - 0s 91ms/step - loss: 5.6267e-06 - categorical_crossentropy: 5.6267e-06 - val_loss: 6.0479e-06 - val_categorical_crossentropy: 6.0479e-06 - lr: 1.0000e-04
# Epoch 479/500
# 4/4 [==============================] - 0s 99ms/step - loss: 5.6137e-06 - categorical_crossentropy: 5.6137e-06 - val_loss: 6.0439e-06 - val_categorical_crossentropy: 6.0439e-06 - lr: 1.0000e-04
# Epoch 480/500
# 4/4 [==============================] - 0s 128ms/step - loss: 5.6048e-06 - categorical_crossentropy: 5.6048e-06 - val_loss: 6.0359e-06 - val_categorical_crossentropy: 6.0359e-06 - lr: 1.0000e-04
# Epoch 481/500
# 4/4 [==============================] - 0s 67ms/step - loss: 5.5939e-06 - categorical_crossentropy: 5.5939e-06 - val_loss: 6.0359e-06 - val_categorical_crossentropy: 6.0359e-06 - lr: 1.0000e-04
# Epoch 482/500
# 4/4 [==============================] - 0s 83ms/step - loss: 5.5859e-06 - categorical_crossentropy: 5.5859e-06 - val_loss: 6.0240e-06 - val_categorical_crossentropy: 6.0240e-06 - lr: 1.0000e-04
# Epoch 483/500
# 4/4 [==============================] - 0s 104ms/step - loss: 5.5800e-06 - categorical_crossentropy: 5.5800e-06 - val_loss: 6.0121e-06 - val_categorical_crossentropy: 6.0121e-06 - lr: 1.0000e-04
# Epoch 484/500
# 4/4 [==============================] - 1s 171ms/step - loss: 5.5750e-06 - categorical_crossentropy: 5.5750e-06 - val_loss: 6.0042e-06 - val_categorical_crossentropy: 6.0042e-06 - lr: 1.0000e-04
# Epoch 485/500
# 4/4 [==============================] - 0s 95ms/step - loss: 5.5690e-06 - categorical_crossentropy: 5.5690e-06 - val_loss: 5.9843e-06 - val_categorical_crossentropy: 5.9843e-06 - lr: 1.0000e-04
# Epoch 486/500
# 4/4 [==============================] - 0s 125ms/step - loss: 5.5611e-06 - categorical_crossentropy: 5.5611e-06 - val_loss: 5.9724e-06 - val_categorical_crossentropy: 5.9724e-06 - lr: 1.0000e-04
# Epoch 487/500
# 4/4 [==============================] - 0s 60ms/step - loss: 5.5522e-06 - categorical_crossentropy: 5.5522e-06 - val_loss: 5.9684e-06 - val_categorical_crossentropy: 5.9684e-06 - lr: 1.0000e-04
# Epoch 488/500
# 4/4 [==============================] - 0s 94ms/step - loss: 5.5382e-06 - categorical_crossentropy: 5.5382e-06 - val_loss: 5.9604e-06 - val_categorical_crossentropy: 5.9604e-06 - lr: 1.0000e-04
# Epoch 489/500
# 4/4 [==============================] - 0s 94ms/step - loss: 5.5313e-06 - categorical_crossentropy: 5.5313e-06 - val_loss: 5.9485e-06 - val_categorical_crossentropy: 5.9485e-06 - lr: 1.0000e-04
# Epoch 490/500
# 4/4 [==============================] - 0s 115ms/step - loss: 5.5224e-06 - categorical_crossentropy: 5.5224e-06 - val_loss: 5.9366e-06 - val_categorical_crossentropy: 5.9366e-06 - lr: 1.0000e-04
# Epoch 491/500
# 4/4 [==============================] - 0s 62ms/step - loss: 5.5104e-06 - categorical_crossentropy: 5.5104e-06 - val_loss: 5.9247e-06 - val_categorical_crossentropy: 5.9247e-06 - lr: 1.0000e-04
# Epoch 492/500
# 4/4 [==============================] - 0s 57ms/step - loss: 5.5005e-06 - categorical_crossentropy: 5.5005e-06 - val_loss: 5.9247e-06 - val_categorical_crossentropy: 5.9247e-06 - lr: 1.0000e-04
# Epoch 493/500
# 4/4 [==============================] - 0s 67ms/step - loss: 5.4945e-06 - categorical_crossentropy: 5.4945e-06 - val_loss: 5.9128e-06 - val_categorical_crossentropy: 5.9128e-06 - lr: 1.0000e-04
# Epoch 494/500
# 4/4 [==============================] - 0s 67ms/step - loss: 5.4856e-06 - categorical_crossentropy: 5.4856e-06 - val_loss: 5.8889e-06 - val_categorical_crossentropy: 5.8889e-06 - lr: 1.0000e-04
# Epoch 495/500
# 4/4 [==============================] - 0s 100ms/step - loss: 5.4777e-06 - categorical_crossentropy: 5.4777e-06 - val_loss: 5.8810e-06 - val_categorical_crossentropy: 5.8810e-06 - lr: 1.0000e-04
# Epoch 496/500
# 4/4 [==============================] - 0s 94ms/step - loss: 5.4677e-06 - categorical_crossentropy: 5.4677e-06 - val_loss: 5.8770e-06 - val_categorical_crossentropy: 5.8770e-06 - lr: 1.0000e-04
# Epoch 497/500
# 4/4 [==============================] - 0s 107ms/step - loss: 5.4568e-06 - categorical_crossentropy: 5.4568e-06 - val_loss: 5.8730e-06 - val_categorical_crossentropy: 5.8730e-06 - lr: 1.0000e-04
# Epoch 498/500
# 4/4 [==============================] - 0s 99ms/step - loss: 5.4518e-06 - categorical_crossentropy: 5.4518e-06 - val_loss: 5.8651e-06 - val_categorical_crossentropy: 5.8651e-06 - lr: 1.0000e-04
# Epoch 499/500
# 4/4 [==============================] - 0s 93ms/step - loss: 5.4449e-06 - categorical_crossentropy: 5.4449e-06 - val_loss: 5.8611e-06 - val_categorical_crossentropy: 5.8611e-06 - lr: 1.0000e-04
# Epoch 500/500
# 4/4 [==============================] - 0s 127ms/step - loss: 5.4359e-06 - categorical_crossentropy: 5.4359e-06 - val_loss: 5.8571e-06 - val_categorical_crossentropy: 5.8571e-06 - lr: 1.0000e-04

# %%
class ModelWrapper():
    def __init__(self,model):
        self.model=model
    def predict_proba(self,X):
        if isinstance(X, pd.DataFrame):
            X=X.values
        Xnn=X.reshape(X.shape[0],1,X.shape[1])
        return self.model.predict(Xnn)
    def predict(self, X):
        return np.argmax(self.predict_proba(X),axis=1)
clf=ModelWrapper(model)

# %% [markdown]
# ## SHAP
# We calculate SHAP for datasets

# %%
fXtrain = trainX.reshape(150,1,200)

# %%
from tsproto.utils import getshap

shap_version='deep'
bg_size = 1000
stride=10
window_len=10
absshap = True
sv_tr = getshap(model=model, X=fXtrain, y=train_ynn,shap_version='deep',bg_size = 1000, stride=10, window_len=10, absshap = True)
# Out:
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [markdown]
# ## Visualize SHAP
# In this section we can see that the network focused on correct parts of the time-series.
# In this toy example, it is sufficient to look at SHAP-visualizations to spot the difference, but in case of hundreds of dimensions and more complex problems, prototypes are more useful.

# %%
from  tsproto.plots import plot_smooth_colored_line
indexer = clf.predict(trainX)
shapclass = []
if absshap == False:
    for i in range(0,len(trainX)):
        best_index = indexer[i]
        shapclass.append([sv_tr[best_index][i,:]])
        
    shapclass=np.concatenate(shapclass)
else:
    shapclass  = sv_tr[:,0,:]

    fig, axes =plt.subplots(2,1,figsize=(12,6))

    for i in range(0,10):
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==0][i], color_values=shapclass[train_y==0][i], resolution=1000, ax=axes[0],add_cbar=(i==0))
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==1][i], color_values=shapclass[train_y==1][i], resolution=1000, ax=axes[1],add_cbar=(i==0))

for ax in axes:
    ax.set_ylim([-2, 2])
# Out:
# 5/5 [==============================] - 0s 16ms/step

# %% [markdown]
# ## Tsproto
# Now, lets try to apply TSProto to see if it is able to find the prototype and summarize them correctly to show what logical relation is between them and the model prediction

# %%
trainXproto = trainX.reshape((trainX.shape[0], trainX.shape[1],1))
shapclassXproto = shapclass.reshape((shapclass.shape[0], shapclass.shape[1],1))

# %%
from tsproto.models import *
im  = InterpretableModel()
pe = PrototypeEncoder(clf, n_clusters=4, min_size=50, method='dtw',
                              descriptors=['existance','duration','frequency'],
                      jump=1, pen=1,multiplier=1,n_jobs=-1,
                      verbose=1)
ohe_train, features, target_ohe,weights = pe.fit_transform(trainXproto,shapclassXproto)
acc,prec,rec,f1,iclf = im.fit_or_predict(ohe_train, features, target_ohe,intclf=None, verbose=0, max_depth=2, min_samples_leaf=0.05,
                       weights=None)
# Out:
# Dataset shape: (150, 200, 1)
# Calculating changepoints...
# Dim: 0
# 2
# 2
# 2
# For 0 c_clusters = 2
# Done in 1.4632508754730225.
# Clustering data
# (300, 114, 1)
# (300, 114, 1)
# Shape of data for clustering: (300, 114, 1)
# Clustering data
# X_bis shape: (300, 114, 1) for method=dtw
# Done in 4.739172458648682.
# OHE time series
# Len X=150 vs len of train = 150
# 5/5 [==============================] - 0s 21ms/step
# Done in 0.26000261306762695.

# %% [markdown]
# ## Visualize interpretable model
# We can easily see that the TSProto has found the sine wave at the beginning of the sample, marked it as prototype and correctly identified that its existence is not enough to treat the sample as a class 1 sample, additional frequency context has to be added in order to distinguish these two

# %%
from  tsproto.plots import *
ds_final = ohe_train.copy()
dot = export_decision_tree_with_embedded_histograms(decision_tree=iclf, 
                                              dataset=ds_final, 
                                              target_name='target', 
                                              feature_names=features, 
                                              filename='synthetic', 
                                              proto_encoder=pe, figsize=(6,3))

from IPython.display import SVG, Image
Image('synthetic.png')
# Out:
# [0 1]
# Shapes: (300, 114, 1) vs shap: (2, 114, 1) TODO: take IDS of a single sample that is plotted
# color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Decision Tree exported to synthetic with embedded histograms successfully.
