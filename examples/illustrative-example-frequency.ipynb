# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn import tree
from graphviz import Source
from IPython.display import display
from IPython.display import SVG

# %% [markdown]
# ## Creating synthetic dataset
# We will create a synthetic dataset with two classes. The dataset will be hard to distinguish based on statistical features, but possible with proper prototypical parts extracted.
#
# We are making it even harder, as the prototypical parts are more or less the same. They are differing in terms of frequency.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(3*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X3 = np.concatenate((x1,x2))
Y3 = np.concatenate((y1,y2))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(2*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X4 = np.concatenate((x1,x2))
Y4 = np.concatenate((y1,y2))

# %% [markdown]
# ## Generating sample cases

# %%
x = X3
proto_sin_y = Y3
proto_inversed_sin_y = Y4

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,proto_sin_y)
axes[1].plot(x,proto_inversed_sin_y)

# %% [markdown]
# ## Generating noise and augmenting signals

# %%
noise_power = .2

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_sin_y = noise + proto_sin_y

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_inversed_sin_y = noise + proto_inversed_sin_y

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,noisy_proto_sin_y[0])
axes[1].plot(x,noisy_proto_inversed_sin_y[0])
for ax in axes:
    ax.set_ylim([-2, 2])

# %%
X=np.concatenate((noisy_proto_sin_y,noisy_proto_inversed_sin_y))
Xy=np.concatenate((np.ones(len(noisy_proto_sin_y))*0,
                   np.ones(len(noisy_proto_inversed_sin_y))*1))

trainX, testX, train_y,test_y = train_test_split(X,Xy)

# %% [markdown]
# ## Model
# We will build simple DNN model (not really needed in this case, but it serves the purpose of demonstration how to deal with more complex cases)

# %%
trainX.shape
# Out:
# (150, 200)

# %%
from keras.utils import to_categorical
trainXnn = trainX.reshape(150,1,200)
train_ynn = to_categorical(train_y)
num_classes = len(np.unique(Xy))

# %%
import keras
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    #add dropout
    input_layer = keras.layers.Dropout(0.5)(input_layer)
    conv1 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(input_layer)
    #conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv1)
    #conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv2)
    #conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)



model = make_model(input_shape=trainXnn.shape[1:])

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_crossentropy"],
)
history = model.fit(
    trainXnn,
    train_ynn,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 1s 62ms/step - loss: 0.6829 - categorical_crossentropy: 0.6829 - val_loss: 0.6548 - val_categorical_crossentropy: 0.6548 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6418 - categorical_crossentropy: 0.6418 - val_loss: 0.5816 - val_categorical_crossentropy: 0.5816 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5626 - categorical_crossentropy: 0.5626 - val_loss: 0.4568 - val_categorical_crossentropy: 0.4568 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4378 - categorical_crossentropy: 0.4378 - val_loss: 0.2945 - val_categorical_crossentropy: 0.2945 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2838 - categorical_crossentropy: 0.2838 - val_loss: 0.1458 - val_categorical_crossentropy: 0.1458 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1453 - categorical_crossentropy: 0.1453 - val_loss: 0.0526 - val_categorical_crossentropy: 0.0526 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0531 - categorical_crossentropy: 0.0531 - val_loss: 0.0147 - val_categorical_crossentropy: 0.0147 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0158 - categorical_crossentropy: 0.0158 - val_loss: 0.0040 - val_categorical_crossentropy: 0.0040 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0040 - categorical_crossentropy: 0.0040 - val_loss: 0.0012 - val_categorical_crossentropy: 0.0012 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0013 - categorical_crossentropy: 0.0013 - val_loss: 4.8735e-04 - val_categorical_crossentropy: 4.8735e-04 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 0s 17ms/step - loss: 4.8081e-04 - categorical_crossentropy: 4.8081e-04 - val_loss: 2.4215e-04 - val_categorical_crossentropy: 2.4215e-04 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4482e-04 - categorical_crossentropy: 2.4482e-04 - val_loss: 1.4509e-04 - val_categorical_crossentropy: 1.4509e-04 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.4774e-04 - categorical_crossentropy: 1.4774e-04 - val_loss: 1.0030e-04 - val_categorical_crossentropy: 1.0030e-04 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0144e-04 - categorical_crossentropy: 1.0144e-04 - val_loss: 7.6851e-05 - val_categorical_crossentropy: 7.6851e-05 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 20ms/step - loss: 7.7896e-05 - categorical_crossentropy: 7.7896e-05 - val_loss: 6.3405e-05 - val_categorical_crossentropy: 6.3405e-05 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 23ms/step - loss: 6.4681e-05 - categorical_crossentropy: 6.4681e-05 - val_loss: 5.5149e-05 - val_categorical_crossentropy: 5.5149e-05 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 19ms/step - loss: 5.6568e-05 - categorical_crossentropy: 5.6568e-05 - val_loss: 4.9753e-05 - val_categorical_crossentropy: 4.9753e-05 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 20ms/step - loss: 5.1397e-05 - categorical_crossentropy: 5.1397e-05 - val_loss: 4.6069e-05 - val_categorical_crossentropy: 4.6069e-05 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 18ms/step - loss: 4.7842e-05 - categorical_crossentropy: 4.7842e-05 - val_loss: 4.3415e-05 - val_categorical_crossentropy: 4.3415e-05 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 20ms/step - loss: 4.5369e-05 - categorical_crossentropy: 4.5369e-05 - val_loss: 4.1412e-05 - val_categorical_crossentropy: 4.1412e-05 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 22ms/step - loss: 4.3554e-05 - categorical_crossentropy: 4.3554e-05 - val_loss: 3.9859e-05 - val_categorical_crossentropy: 3.9859e-05 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 18ms/step - loss: 4.2159e-05 - categorical_crossentropy: 4.2159e-05 - val_loss: 3.8571e-05 - val_categorical_crossentropy: 3.8571e-05 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 18ms/step - loss: 4.1056e-05 - categorical_crossentropy: 4.1056e-05 - val_loss: 3.7495e-05 - val_categorical_crossentropy: 3.7495e-05 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 18ms/step - loss: 4.0143e-05 - categorical_crossentropy: 4.0143e-05 - val_loss: 3.6589e-05 - val_categorical_crossentropy: 3.6589e-05 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.9369e-05 - categorical_crossentropy: 3.9369e-05 - val_loss: 3.5814e-05 - val_categorical_crossentropy: 3.5814e-05 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 19ms/step - loss: 3.8693e-05 - categorical_crossentropy: 3.8693e-05 - val_loss: 3.5091e-05 - val_categorical_crossentropy: 3.5091e-05 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.8092e-05 - categorical_crossentropy: 3.8092e-05 - val_loss: 3.4439e-05 - val_categorical_crossentropy: 3.4439e-05 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 23ms/step - loss: 3.7550e-05 - categorical_crossentropy: 3.7550e-05 - val_loss: 3.3811e-05 - val_categorical_crossentropy: 3.3811e-05 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 20ms/step - loss: 3.7020e-05 - categorical_crossentropy: 3.7020e-05 - val_loss: 3.3219e-05 - val_categorical_crossentropy: 3.3219e-05 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 20ms/step - loss: 3.6499e-05 - categorical_crossentropy: 3.6499e-05 - val_loss: 3.2667e-05 - val_categorical_crossentropy: 3.2667e-05 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.6022e-05 - categorical_crossentropy: 3.6022e-05 - val_loss: 3.2110e-05 - val_categorical_crossentropy: 3.2110e-05 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.5548e-05 - categorical_crossentropy: 3.5548e-05 - val_loss: 3.1574e-05 - val_categorical_crossentropy: 3.1574e-05 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.5073e-05 - categorical_crossentropy: 3.5073e-05 - val_loss: 3.1069e-05 - val_categorical_crossentropy: 3.1069e-05 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.4695e-05 - categorical_crossentropy: 3.4695e-05 - val_loss: 3.0815e-05 - val_categorical_crossentropy: 3.0815e-05 - lr: 5.0000e-04
# Epoch 35/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.4477e-05 - categorical_crossentropy: 3.4477e-05 - val_loss: 3.0561e-05 - val_categorical_crossentropy: 3.0561e-05 - lr: 5.0000e-04
# Epoch 36/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.4247e-05 - categorical_crossentropy: 3.4247e-05 - val_loss: 3.0330e-05 - val_categorical_crossentropy: 3.0330e-05 - lr: 5.0000e-04
# Epoch 37/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.4029e-05 - categorical_crossentropy: 3.4029e-05 - val_loss: 3.0076e-05 - val_categorical_crossentropy: 3.0076e-05 - lr: 5.0000e-04
# Epoch 38/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3803e-05 - categorical_crossentropy: 3.3803e-05 - val_loss: 2.9834e-05 - val_categorical_crossentropy: 2.9834e-05 - lr: 5.0000e-04
# Epoch 39/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3586e-05 - categorical_crossentropy: 3.3586e-05 - val_loss: 2.9607e-05 - val_categorical_crossentropy: 2.9607e-05 - lr: 5.0000e-04
# Epoch 40/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3365e-05 - categorical_crossentropy: 3.3365e-05 - val_loss: 2.9365e-05 - val_categorical_crossentropy: 2.9365e-05 - lr: 5.0000e-04
# Epoch 41/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3144e-05 - categorical_crossentropy: 3.3144e-05 - val_loss: 2.9126e-05 - val_categorical_crossentropy: 2.9126e-05 - lr: 5.0000e-04
# Epoch 42/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2924e-05 - categorical_crossentropy: 3.2924e-05 - val_loss: 2.8884e-05 - val_categorical_crossentropy: 2.8884e-05 - lr: 5.0000e-04
# Epoch 43/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2704e-05 - categorical_crossentropy: 3.2704e-05 - val_loss: 2.8650e-05 - val_categorical_crossentropy: 2.8650e-05 - lr: 5.0000e-04
# Epoch 44/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2485e-05 - categorical_crossentropy: 3.2485e-05 - val_loss: 2.8411e-05 - val_categorical_crossentropy: 2.8411e-05 - lr: 5.0000e-04
# Epoch 45/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2274e-05 - categorical_crossentropy: 3.2274e-05 - val_loss: 2.8189e-05 - val_categorical_crossentropy: 2.8189e-05 - lr: 5.0000e-04
# Epoch 46/500
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2054e-05 - categorical_crossentropy: 3.2054e-05 - val_loss: 2.7954e-05 - val_categorical_crossentropy: 2.7954e-05 - lr: 5.0000e-04
# Epoch 47/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1842e-05 - categorical_crossentropy: 3.1842e-05 - val_loss: 2.7728e-05 - val_categorical_crossentropy: 2.7728e-05 - lr: 5.0000e-04
# Epoch 48/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1627e-05 - categorical_crossentropy: 3.1627e-05 - val_loss: 2.7509e-05 - val_categorical_crossentropy: 2.7509e-05 - lr: 5.0000e-04
# Epoch 49/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1406e-05 - categorical_crossentropy: 3.1406e-05 - val_loss: 2.7275e-05 - val_categorical_crossentropy: 2.7275e-05 - lr: 5.0000e-04
# Epoch 50/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1196e-05 - categorical_crossentropy: 3.1196e-05 - val_loss: 2.7060e-05 - val_categorical_crossentropy: 2.7060e-05 - lr: 5.0000e-04
# Epoch 51/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.0980e-05 - categorical_crossentropy: 3.0980e-05 - val_loss: 2.6822e-05 - val_categorical_crossentropy: 2.6822e-05 - lr: 5.0000e-04
# Epoch 52/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.0769e-05 - categorical_crossentropy: 3.0769e-05 - val_loss: 2.6603e-05 - val_categorical_crossentropy: 2.6603e-05 - lr: 5.0000e-04
# Epoch 53/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.0556e-05 - categorical_crossentropy: 3.0556e-05 - val_loss: 2.6377e-05 - val_categorical_crossentropy: 2.6377e-05 - lr: 5.0000e-04
# Epoch 54/500
# 4/4 [==============================] - 0s 17ms/step - loss: 3.0385e-05 - categorical_crossentropy: 3.0385e-05 - val_loss: 2.6265e-05 - val_categorical_crossentropy: 2.6265e-05 - lr: 2.5000e-04
# Epoch 55/500
# 4/4 [==============================] - 0s 21ms/step - loss: 3.0277e-05 - categorical_crossentropy: 3.0277e-05 - val_loss: 2.6150e-05 - val_categorical_crossentropy: 2.6150e-05 - lr: 2.5000e-04
# Epoch 56/500
# 4/4 [==============================] - 0s 16ms/step - loss: 3.0170e-05 - categorical_crossentropy: 3.0170e-05 - val_loss: 2.6039e-05 - val_categorical_crossentropy: 2.6039e-05 - lr: 2.5000e-04
# Epoch 57/500
# 4/4 [==============================] - 0s 18ms/step - loss: 3.0061e-05 - categorical_crossentropy: 3.0061e-05 - val_loss: 2.5936e-05 - val_categorical_crossentropy: 2.5936e-05 - lr: 2.5000e-04
# Epoch 58/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.9955e-05 - categorical_crossentropy: 2.9955e-05 - val_loss: 2.5836e-05 - val_categorical_crossentropy: 2.5836e-05 - lr: 2.5000e-04
# Epoch 59/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.9854e-05 - categorical_crossentropy: 2.9854e-05 - val_loss: 2.5733e-05 - val_categorical_crossentropy: 2.5733e-05 - lr: 2.5000e-04
# Epoch 60/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.9743e-05 - categorical_crossentropy: 2.9743e-05 - val_loss: 2.5622e-05 - val_categorical_crossentropy: 2.5622e-05 - lr: 2.5000e-04
# Epoch 61/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.9636e-05 - categorical_crossentropy: 2.9636e-05 - val_loss: 2.5518e-05 - val_categorical_crossentropy: 2.5518e-05 - lr: 2.5000e-04
# Epoch 62/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.9532e-05 - categorical_crossentropy: 2.9532e-05 - val_loss: 2.5399e-05 - val_categorical_crossentropy: 2.5399e-05 - lr: 2.5000e-04
# Epoch 63/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.9421e-05 - categorical_crossentropy: 2.9421e-05 - val_loss: 2.5288e-05 - val_categorical_crossentropy: 2.5288e-05 - lr: 2.5000e-04
# Epoch 64/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.9315e-05 - categorical_crossentropy: 2.9315e-05 - val_loss: 2.5177e-05 - val_categorical_crossentropy: 2.5177e-05 - lr: 2.5000e-04
# Epoch 65/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.9209e-05 - categorical_crossentropy: 2.9209e-05 - val_loss: 2.5069e-05 - val_categorical_crossentropy: 2.5069e-05 - lr: 2.5000e-04
# Epoch 66/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.9101e-05 - categorical_crossentropy: 2.9101e-05 - val_loss: 2.4966e-05 - val_categorical_crossentropy: 2.4966e-05 - lr: 2.5000e-04
# Epoch 67/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.8992e-05 - categorical_crossentropy: 2.8992e-05 - val_loss: 2.4867e-05 - val_categorical_crossentropy: 2.4867e-05 - lr: 2.5000e-04
# Epoch 68/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.8885e-05 - categorical_crossentropy: 2.8885e-05 - val_loss: 2.4767e-05 - val_categorical_crossentropy: 2.4767e-05 - lr: 2.5000e-04
# Epoch 69/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.8777e-05 - categorical_crossentropy: 2.8777e-05 - val_loss: 2.4648e-05 - val_categorical_crossentropy: 2.4648e-05 - lr: 2.5000e-04
# Epoch 70/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.8674e-05 - categorical_crossentropy: 2.8674e-05 - val_loss: 2.4541e-05 - val_categorical_crossentropy: 2.4541e-05 - lr: 2.5000e-04
# Epoch 71/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.8558e-05 - categorical_crossentropy: 2.8558e-05 - val_loss: 2.4426e-05 - val_categorical_crossentropy: 2.4426e-05 - lr: 2.5000e-04
# Epoch 72/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.8455e-05 - categorical_crossentropy: 2.8455e-05 - val_loss: 2.4326e-05 - val_categorical_crossentropy: 2.4326e-05 - lr: 2.5000e-04
# Epoch 73/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.8345e-05 - categorical_crossentropy: 2.8345e-05 - val_loss: 2.4235e-05 - val_categorical_crossentropy: 2.4235e-05 - lr: 2.5000e-04
# Epoch 74/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.8257e-05 - categorical_crossentropy: 2.8257e-05 - val_loss: 2.4163e-05 - val_categorical_crossentropy: 2.4163e-05 - lr: 1.2500e-04
# Epoch 75/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.8200e-05 - categorical_crossentropy: 2.8200e-05 - val_loss: 2.4132e-05 - val_categorical_crossentropy: 2.4132e-05 - lr: 1.2500e-04
# Epoch 76/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.8153e-05 - categorical_crossentropy: 2.8153e-05 - val_loss: 2.4056e-05 - val_categorical_crossentropy: 2.4056e-05 - lr: 1.2500e-04
# Epoch 77/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.8097e-05 - categorical_crossentropy: 2.8097e-05 - val_loss: 2.4024e-05 - val_categorical_crossentropy: 2.4024e-05 - lr: 1.2500e-04
# Epoch 78/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.8045e-05 - categorical_crossentropy: 2.8045e-05 - val_loss: 2.3949e-05 - val_categorical_crossentropy: 2.3949e-05 - lr: 1.2500e-04
# Epoch 79/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7987e-05 - categorical_crossentropy: 2.7987e-05 - val_loss: 2.3909e-05 - val_categorical_crossentropy: 2.3909e-05 - lr: 1.2500e-04
# Epoch 80/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7931e-05 - categorical_crossentropy: 2.7931e-05 - val_loss: 2.3838e-05 - val_categorical_crossentropy: 2.3838e-05 - lr: 1.2500e-04
# Epoch 81/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7874e-05 - categorical_crossentropy: 2.7874e-05 - val_loss: 2.3802e-05 - val_categorical_crossentropy: 2.3802e-05 - lr: 1.2500e-04
# Epoch 82/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7824e-05 - categorical_crossentropy: 2.7824e-05 - val_loss: 2.3734e-05 - val_categorical_crossentropy: 2.3734e-05 - lr: 1.2500e-04
# Epoch 83/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7763e-05 - categorical_crossentropy: 2.7763e-05 - val_loss: 2.3691e-05 - val_categorical_crossentropy: 2.3691e-05 - lr: 1.2500e-04
# Epoch 84/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7710e-05 - categorical_crossentropy: 2.7710e-05 - val_loss: 2.3639e-05 - val_categorical_crossentropy: 2.3639e-05 - lr: 1.2500e-04
# Epoch 85/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.7652e-05 - categorical_crossentropy: 2.7652e-05 - val_loss: 2.3571e-05 - val_categorical_crossentropy: 2.3571e-05 - lr: 1.2500e-04
# Epoch 86/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.7601e-05 - categorical_crossentropy: 2.7601e-05 - val_loss: 2.3528e-05 - val_categorical_crossentropy: 2.3528e-05 - lr: 1.2500e-04
# Epoch 87/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7546e-05 - categorical_crossentropy: 2.7546e-05 - val_loss: 2.3456e-05 - val_categorical_crossentropy: 2.3456e-05 - lr: 1.2500e-04
# Epoch 88/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.7487e-05 - categorical_crossentropy: 2.7487e-05 - val_loss: 2.3412e-05 - val_categorical_crossentropy: 2.3412e-05 - lr: 1.2500e-04
# Epoch 89/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.7434e-05 - categorical_crossentropy: 2.7434e-05 - val_loss: 2.3365e-05 - val_categorical_crossentropy: 2.3365e-05 - lr: 1.2500e-04
# Epoch 90/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7375e-05 - categorical_crossentropy: 2.7375e-05 - val_loss: 2.3301e-05 - val_categorical_crossentropy: 2.3301e-05 - lr: 1.2500e-04
# Epoch 91/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7313e-05 - categorical_crossentropy: 2.7313e-05 - val_loss: 2.3246e-05 - val_categorical_crossentropy: 2.3246e-05 - lr: 1.2500e-04
# Epoch 92/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.7263e-05 - categorical_crossentropy: 2.7263e-05 - val_loss: 2.3190e-05 - val_categorical_crossentropy: 2.3190e-05 - lr: 1.2500e-04
# Epoch 93/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7197e-05 - categorical_crossentropy: 2.7197e-05 - val_loss: 2.3130e-05 - val_categorical_crossentropy: 2.3130e-05 - lr: 1.2500e-04
# Epoch 94/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.7154e-05 - categorical_crossentropy: 2.7154e-05 - val_loss: 2.3091e-05 - val_categorical_crossentropy: 2.3091e-05 - lr: 1.0000e-04
# Epoch 95/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7109e-05 - categorical_crossentropy: 2.7109e-05 - val_loss: 2.3047e-05 - val_categorical_crossentropy: 2.3047e-05 - lr: 1.0000e-04
# Epoch 96/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7059e-05 - categorical_crossentropy: 2.7059e-05 - val_loss: 2.2995e-05 - val_categorical_crossentropy: 2.2995e-05 - lr: 1.0000e-04
# Epoch 97/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.7015e-05 - categorical_crossentropy: 2.7015e-05 - val_loss: 2.2971e-05 - val_categorical_crossentropy: 2.2971e-05 - lr: 1.0000e-04
# Epoch 98/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6963e-05 - categorical_crossentropy: 2.6963e-05 - val_loss: 2.2912e-05 - val_categorical_crossentropy: 2.2912e-05 - lr: 1.0000e-04
# Epoch 99/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.6921e-05 - categorical_crossentropy: 2.6921e-05 - val_loss: 2.2868e-05 - val_categorical_crossentropy: 2.2868e-05 - lr: 1.0000e-04
# Epoch 100/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.6869e-05 - categorical_crossentropy: 2.6869e-05 - val_loss: 2.2816e-05 - val_categorical_crossentropy: 2.2816e-05 - lr: 1.0000e-04
# Epoch 101/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6820e-05 - categorical_crossentropy: 2.6820e-05 - val_loss: 2.2789e-05 - val_categorical_crossentropy: 2.2789e-05 - lr: 1.0000e-04
# Epoch 102/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6778e-05 - categorical_crossentropy: 2.6778e-05 - val_loss: 2.2729e-05 - val_categorical_crossentropy: 2.2729e-05 - lr: 1.0000e-04
# Epoch 103/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6734e-05 - categorical_crossentropy: 2.6734e-05 - val_loss: 2.2689e-05 - val_categorical_crossentropy: 2.2689e-05 - lr: 1.0000e-04
# Epoch 104/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6686e-05 - categorical_crossentropy: 2.6686e-05 - val_loss: 2.2638e-05 - val_categorical_crossentropy: 2.2638e-05 - lr: 1.0000e-04
# Epoch 105/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.6636e-05 - categorical_crossentropy: 2.6636e-05 - val_loss: 2.2606e-05 - val_categorical_crossentropy: 2.2606e-05 - lr: 1.0000e-04
# Epoch 106/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6592e-05 - categorical_crossentropy: 2.6592e-05 - val_loss: 2.2546e-05 - val_categorical_crossentropy: 2.2546e-05 - lr: 1.0000e-04
# Epoch 107/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.6544e-05 - categorical_crossentropy: 2.6544e-05 - val_loss: 2.2510e-05 - val_categorical_crossentropy: 2.2510e-05 - lr: 1.0000e-04
# Epoch 108/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6493e-05 - categorical_crossentropy: 2.6493e-05 - val_loss: 2.2463e-05 - val_categorical_crossentropy: 2.2463e-05 - lr: 1.0000e-04
# Epoch 109/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.6446e-05 - categorical_crossentropy: 2.6446e-05 - val_loss: 2.2411e-05 - val_categorical_crossentropy: 2.2411e-05 - lr: 1.0000e-04
# Epoch 110/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.6406e-05 - categorical_crossentropy: 2.6406e-05 - val_loss: 2.2371e-05 - val_categorical_crossentropy: 2.2371e-05 - lr: 1.0000e-04
# Epoch 111/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6355e-05 - categorical_crossentropy: 2.6355e-05 - val_loss: 2.2324e-05 - val_categorical_crossentropy: 2.2324e-05 - lr: 1.0000e-04
# Epoch 112/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.6310e-05 - categorical_crossentropy: 2.6310e-05 - val_loss: 2.2284e-05 - val_categorical_crossentropy: 2.2284e-05 - lr: 1.0000e-04
# Epoch 113/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.6253e-05 - categorical_crossentropy: 2.6253e-05 - val_loss: 2.2232e-05 - val_categorical_crossentropy: 2.2232e-05 - lr: 1.0000e-04
# Epoch 114/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.6214e-05 - categorical_crossentropy: 2.6214e-05 - val_loss: 2.2193e-05 - val_categorical_crossentropy: 2.2193e-05 - lr: 1.0000e-04
# Epoch 115/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6161e-05 - categorical_crossentropy: 2.6161e-05 - val_loss: 2.2145e-05 - val_categorical_crossentropy: 2.2145e-05 - lr: 1.0000e-04
# Epoch 116/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6113e-05 - categorical_crossentropy: 2.6113e-05 - val_loss: 2.2093e-05 - val_categorical_crossentropy: 2.2093e-05 - lr: 1.0000e-04
# Epoch 117/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6060e-05 - categorical_crossentropy: 2.6060e-05 - val_loss: 2.2049e-05 - val_categorical_crossentropy: 2.2049e-05 - lr: 1.0000e-04
# Epoch 118/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.6009e-05 - categorical_crossentropy: 2.6009e-05 - val_loss: 2.2010e-05 - val_categorical_crossentropy: 2.2010e-05 - lr: 1.0000e-04
# Epoch 119/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5965e-05 - categorical_crossentropy: 2.5965e-05 - val_loss: 2.1962e-05 - val_categorical_crossentropy: 2.1962e-05 - lr: 1.0000e-04
# Epoch 120/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5916e-05 - categorical_crossentropy: 2.5916e-05 - val_loss: 2.1914e-05 - val_categorical_crossentropy: 2.1914e-05 - lr: 1.0000e-04
# Epoch 121/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.5871e-05 - categorical_crossentropy: 2.5871e-05 - val_loss: 2.1863e-05 - val_categorical_crossentropy: 2.1863e-05 - lr: 1.0000e-04
# Epoch 122/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5819e-05 - categorical_crossentropy: 2.5819e-05 - val_loss: 2.1827e-05 - val_categorical_crossentropy: 2.1827e-05 - lr: 1.0000e-04
# Epoch 123/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5767e-05 - categorical_crossentropy: 2.5767e-05 - val_loss: 2.1759e-05 - val_categorical_crossentropy: 2.1759e-05 - lr: 1.0000e-04
# Epoch 124/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5728e-05 - categorical_crossentropy: 2.5728e-05 - val_loss: 2.1728e-05 - val_categorical_crossentropy: 2.1728e-05 - lr: 1.0000e-04
# Epoch 125/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5675e-05 - categorical_crossentropy: 2.5675e-05 - val_loss: 2.1684e-05 - val_categorical_crossentropy: 2.1684e-05 - lr: 1.0000e-04
# Epoch 126/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5620e-05 - categorical_crossentropy: 2.5620e-05 - val_loss: 2.1632e-05 - val_categorical_crossentropy: 2.1632e-05 - lr: 1.0000e-04
# Epoch 127/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5577e-05 - categorical_crossentropy: 2.5577e-05 - val_loss: 2.1589e-05 - val_categorical_crossentropy: 2.1589e-05 - lr: 1.0000e-04
# Epoch 128/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5527e-05 - categorical_crossentropy: 2.5527e-05 - val_loss: 2.1545e-05 - val_categorical_crossentropy: 2.1545e-05 - lr: 1.0000e-04
# Epoch 129/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5468e-05 - categorical_crossentropy: 2.5468e-05 - val_loss: 2.1497e-05 - val_categorical_crossentropy: 2.1497e-05 - lr: 1.0000e-04
# Epoch 130/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5427e-05 - categorical_crossentropy: 2.5427e-05 - val_loss: 2.1457e-05 - val_categorical_crossentropy: 2.1457e-05 - lr: 1.0000e-04
# Epoch 131/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5380e-05 - categorical_crossentropy: 2.5380e-05 - val_loss: 2.1406e-05 - val_categorical_crossentropy: 2.1406e-05 - lr: 1.0000e-04
# Epoch 132/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5328e-05 - categorical_crossentropy: 2.5328e-05 - val_loss: 2.1358e-05 - val_categorical_crossentropy: 2.1358e-05 - lr: 1.0000e-04
# Epoch 133/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5278e-05 - categorical_crossentropy: 2.5278e-05 - val_loss: 2.1314e-05 - val_categorical_crossentropy: 2.1314e-05 - lr: 1.0000e-04
# Epoch 134/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5223e-05 - categorical_crossentropy: 2.5223e-05 - val_loss: 2.1255e-05 - val_categorical_crossentropy: 2.1255e-05 - lr: 1.0000e-04
# Epoch 135/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5184e-05 - categorical_crossentropy: 2.5184e-05 - val_loss: 2.1223e-05 - val_categorical_crossentropy: 2.1223e-05 - lr: 1.0000e-04
# Epoch 136/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5129e-05 - categorical_crossentropy: 2.5129e-05 - val_loss: 2.1175e-05 - val_categorical_crossentropy: 2.1175e-05 - lr: 1.0000e-04
# Epoch 137/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5079e-05 - categorical_crossentropy: 2.5079e-05 - val_loss: 2.1128e-05 - val_categorical_crossentropy: 2.1128e-05 - lr: 1.0000e-04
# Epoch 138/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5036e-05 - categorical_crossentropy: 2.5036e-05 - val_loss: 2.1084e-05 - val_categorical_crossentropy: 2.1084e-05 - lr: 1.0000e-04
# Epoch 139/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4978e-05 - categorical_crossentropy: 2.4978e-05 - val_loss: 2.1032e-05 - val_categorical_crossentropy: 2.1032e-05 - lr: 1.0000e-04
# Epoch 140/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.4938e-05 - categorical_crossentropy: 2.4938e-05 - val_loss: 2.0985e-05 - val_categorical_crossentropy: 2.0985e-05 - lr: 1.0000e-04
# Epoch 141/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4878e-05 - categorical_crossentropy: 2.4878e-05 - val_loss: 2.0941e-05 - val_categorical_crossentropy: 2.0941e-05 - lr: 1.0000e-04
# Epoch 142/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4827e-05 - categorical_crossentropy: 2.4827e-05 - val_loss: 2.0893e-05 - val_categorical_crossentropy: 2.0893e-05 - lr: 1.0000e-04
# Epoch 143/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.4778e-05 - categorical_crossentropy: 2.4778e-05 - val_loss: 2.0842e-05 - val_categorical_crossentropy: 2.0842e-05 - lr: 1.0000e-04
# Epoch 144/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4728e-05 - categorical_crossentropy: 2.4728e-05 - val_loss: 2.0806e-05 - val_categorical_crossentropy: 2.0806e-05 - lr: 1.0000e-04
# Epoch 145/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4676e-05 - categorical_crossentropy: 2.4676e-05 - val_loss: 2.0750e-05 - val_categorical_crossentropy: 2.0750e-05 - lr: 1.0000e-04
# Epoch 146/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4631e-05 - categorical_crossentropy: 2.4631e-05 - val_loss: 2.0702e-05 - val_categorical_crossentropy: 2.0702e-05 - lr: 1.0000e-04
# Epoch 147/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4582e-05 - categorical_crossentropy: 2.4582e-05 - val_loss: 2.0667e-05 - val_categorical_crossentropy: 2.0667e-05 - lr: 1.0000e-04
# Epoch 148/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.4529e-05 - categorical_crossentropy: 2.4529e-05 - val_loss: 2.0611e-05 - val_categorical_crossentropy: 2.0611e-05 - lr: 1.0000e-04
# Epoch 149/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4474e-05 - categorical_crossentropy: 2.4474e-05 - val_loss: 2.0567e-05 - val_categorical_crossentropy: 2.0567e-05 - lr: 1.0000e-04
# Epoch 150/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4430e-05 - categorical_crossentropy: 2.4430e-05 - val_loss: 2.0532e-05 - val_categorical_crossentropy: 2.0532e-05 - lr: 1.0000e-04
# Epoch 151/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4377e-05 - categorical_crossentropy: 2.4377e-05 - val_loss: 2.0468e-05 - val_categorical_crossentropy: 2.0468e-05 - lr: 1.0000e-04
# Epoch 152/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4320e-05 - categorical_crossentropy: 2.4320e-05 - val_loss: 2.0428e-05 - val_categorical_crossentropy: 2.0428e-05 - lr: 1.0000e-04
# Epoch 153/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4276e-05 - categorical_crossentropy: 2.4276e-05 - val_loss: 2.0385e-05 - val_categorical_crossentropy: 2.0385e-05 - lr: 1.0000e-04
# Epoch 154/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4228e-05 - categorical_crossentropy: 2.4228e-05 - val_loss: 2.0333e-05 - val_categorical_crossentropy: 2.0333e-05 - lr: 1.0000e-04
# Epoch 155/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4175e-05 - categorical_crossentropy: 2.4175e-05 - val_loss: 2.0293e-05 - val_categorical_crossentropy: 2.0293e-05 - lr: 1.0000e-04
# Epoch 156/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4128e-05 - categorical_crossentropy: 2.4128e-05 - val_loss: 2.0245e-05 - val_categorical_crossentropy: 2.0245e-05 - lr: 1.0000e-04
# Epoch 157/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4076e-05 - categorical_crossentropy: 2.4076e-05 - val_loss: 2.0194e-05 - val_categorical_crossentropy: 2.0194e-05 - lr: 1.0000e-04
# Epoch 158/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4025e-05 - categorical_crossentropy: 2.4025e-05 - val_loss: 2.0154e-05 - val_categorical_crossentropy: 2.0154e-05 - lr: 1.0000e-04
# Epoch 159/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3980e-05 - categorical_crossentropy: 2.3980e-05 - val_loss: 2.0106e-05 - val_categorical_crossentropy: 2.0106e-05 - lr: 1.0000e-04
# Epoch 160/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3924e-05 - categorical_crossentropy: 2.3924e-05 - val_loss: 2.0055e-05 - val_categorical_crossentropy: 2.0055e-05 - lr: 1.0000e-04
# Epoch 161/500
# 4/4 [==============================] - 0s 16ms/step - loss: 2.3871e-05 - categorical_crossentropy: 2.3871e-05 - val_loss: 2.0027e-05 - val_categorical_crossentropy: 2.0027e-05 - lr: 1.0000e-04
# Epoch 162/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3822e-05 - categorical_crossentropy: 2.3822e-05 - val_loss: 1.9967e-05 - val_categorical_crossentropy: 1.9967e-05 - lr: 1.0000e-04
# Epoch 163/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3772e-05 - categorical_crossentropy: 2.3772e-05 - val_loss: 1.9920e-05 - val_categorical_crossentropy: 1.9920e-05 - lr: 1.0000e-04
# Epoch 164/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3720e-05 - categorical_crossentropy: 2.3720e-05 - val_loss: 1.9868e-05 - val_categorical_crossentropy: 1.9868e-05 - lr: 1.0000e-04
# Epoch 165/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3666e-05 - categorical_crossentropy: 2.3666e-05 - val_loss: 1.9840e-05 - val_categorical_crossentropy: 1.9840e-05 - lr: 1.0000e-04
# Epoch 166/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3615e-05 - categorical_crossentropy: 2.3615e-05 - val_loss: 1.9769e-05 - val_categorical_crossentropy: 1.9769e-05 - lr: 1.0000e-04
# Epoch 167/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3570e-05 - categorical_crossentropy: 2.3570e-05 - val_loss: 1.9737e-05 - val_categorical_crossentropy: 1.9737e-05 - lr: 1.0000e-04
# Epoch 168/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3519e-05 - categorical_crossentropy: 2.3519e-05 - val_loss: 1.9689e-05 - val_categorical_crossentropy: 1.9689e-05 - lr: 1.0000e-04
# Epoch 169/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.3472e-05 - categorical_crossentropy: 2.3472e-05 - val_loss: 1.9641e-05 - val_categorical_crossentropy: 1.9641e-05 - lr: 1.0000e-04
# Epoch 170/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.3418e-05 - categorical_crossentropy: 2.3418e-05 - val_loss: 1.9594e-05 - val_categorical_crossentropy: 1.9594e-05 - lr: 1.0000e-04
# Epoch 171/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3366e-05 - categorical_crossentropy: 2.3366e-05 - val_loss: 1.9554e-05 - val_categorical_crossentropy: 1.9554e-05 - lr: 1.0000e-04
# Epoch 172/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3321e-05 - categorical_crossentropy: 2.3321e-05 - val_loss: 1.9498e-05 - val_categorical_crossentropy: 1.9498e-05 - lr: 1.0000e-04
# Epoch 173/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3264e-05 - categorical_crossentropy: 2.3264e-05 - val_loss: 1.9451e-05 - val_categorical_crossentropy: 1.9451e-05 - lr: 1.0000e-04
# Epoch 174/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3213e-05 - categorical_crossentropy: 2.3213e-05 - val_loss: 1.9419e-05 - val_categorical_crossentropy: 1.9419e-05 - lr: 1.0000e-04
# Epoch 175/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3165e-05 - categorical_crossentropy: 2.3165e-05 - val_loss: 1.9375e-05 - val_categorical_crossentropy: 1.9375e-05 - lr: 1.0000e-04
# Epoch 176/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3116e-05 - categorical_crossentropy: 2.3116e-05 - val_loss: 1.9308e-05 - val_categorical_crossentropy: 1.9308e-05 - lr: 1.0000e-04
# Epoch 177/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.3065e-05 - categorical_crossentropy: 2.3065e-05 - val_loss: 1.9284e-05 - val_categorical_crossentropy: 1.9284e-05 - lr: 1.0000e-04
# Epoch 178/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.3011e-05 - categorical_crossentropy: 2.3011e-05 - val_loss: 1.9232e-05 - val_categorical_crossentropy: 1.9232e-05 - lr: 1.0000e-04
# Epoch 179/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2955e-05 - categorical_crossentropy: 2.2955e-05 - val_loss: 1.9181e-05 - val_categorical_crossentropy: 1.9181e-05 - lr: 1.0000e-04
# Epoch 180/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.2915e-05 - categorical_crossentropy: 2.2915e-05 - val_loss: 1.9137e-05 - val_categorical_crossentropy: 1.9137e-05 - lr: 1.0000e-04
# Epoch 181/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2859e-05 - categorical_crossentropy: 2.2859e-05 - val_loss: 1.9097e-05 - val_categorical_crossentropy: 1.9097e-05 - lr: 1.0000e-04
# Epoch 182/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.2807e-05 - categorical_crossentropy: 2.2807e-05 - val_loss: 1.9049e-05 - val_categorical_crossentropy: 1.9049e-05 - lr: 1.0000e-04
# Epoch 183/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.2753e-05 - categorical_crossentropy: 2.2753e-05 - val_loss: 1.9002e-05 - val_categorical_crossentropy: 1.9002e-05 - lr: 1.0000e-04
# Epoch 184/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2705e-05 - categorical_crossentropy: 2.2705e-05 - val_loss: 1.8954e-05 - val_categorical_crossentropy: 1.8954e-05 - lr: 1.0000e-04
# Epoch 185/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2662e-05 - categorical_crossentropy: 2.2662e-05 - val_loss: 1.8910e-05 - val_categorical_crossentropy: 1.8910e-05 - lr: 1.0000e-04
# Epoch 186/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2610e-05 - categorical_crossentropy: 2.2610e-05 - val_loss: 1.8863e-05 - val_categorical_crossentropy: 1.8863e-05 - lr: 1.0000e-04
# Epoch 187/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2553e-05 - categorical_crossentropy: 2.2553e-05 - val_loss: 1.8807e-05 - val_categorical_crossentropy: 1.8807e-05 - lr: 1.0000e-04
# Epoch 188/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2507e-05 - categorical_crossentropy: 2.2507e-05 - val_loss: 1.8775e-05 - val_categorical_crossentropy: 1.8775e-05 - lr: 1.0000e-04
# Epoch 189/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2456e-05 - categorical_crossentropy: 2.2456e-05 - val_loss: 1.8728e-05 - val_categorical_crossentropy: 1.8728e-05 - lr: 1.0000e-04
# Epoch 190/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2409e-05 - categorical_crossentropy: 2.2409e-05 - val_loss: 1.8680e-05 - val_categorical_crossentropy: 1.8680e-05 - lr: 1.0000e-04
# Epoch 191/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2353e-05 - categorical_crossentropy: 2.2353e-05 - val_loss: 1.8632e-05 - val_categorical_crossentropy: 1.8632e-05 - lr: 1.0000e-04
# Epoch 192/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2305e-05 - categorical_crossentropy: 2.2305e-05 - val_loss: 1.8592e-05 - val_categorical_crossentropy: 1.8592e-05 - lr: 1.0000e-04
# Epoch 193/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2253e-05 - categorical_crossentropy: 2.2253e-05 - val_loss: 1.8545e-05 - val_categorical_crossentropy: 1.8545e-05 - lr: 1.0000e-04
# Epoch 194/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2199e-05 - categorical_crossentropy: 2.2199e-05 - val_loss: 1.8497e-05 - val_categorical_crossentropy: 1.8497e-05 - lr: 1.0000e-04
# Epoch 195/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2152e-05 - categorical_crossentropy: 2.2152e-05 - val_loss: 1.8465e-05 - val_categorical_crossentropy: 1.8465e-05 - lr: 1.0000e-04
# Epoch 196/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2103e-05 - categorical_crossentropy: 2.2103e-05 - val_loss: 1.8414e-05 - val_categorical_crossentropy: 1.8414e-05 - lr: 1.0000e-04
# Epoch 197/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2053e-05 - categorical_crossentropy: 2.2053e-05 - val_loss: 1.8366e-05 - val_categorical_crossentropy: 1.8366e-05 - lr: 1.0000e-04
# Epoch 198/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2000e-05 - categorical_crossentropy: 2.2000e-05 - val_loss: 1.8318e-05 - val_categorical_crossentropy: 1.8318e-05 - lr: 1.0000e-04
# Epoch 199/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.1953e-05 - categorical_crossentropy: 2.1953e-05 - val_loss: 1.8279e-05 - val_categorical_crossentropy: 1.8279e-05 - lr: 1.0000e-04
# Epoch 200/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.1901e-05 - categorical_crossentropy: 2.1901e-05 - val_loss: 1.8219e-05 - val_categorical_crossentropy: 1.8219e-05 - lr: 1.0000e-04
# Epoch 201/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1847e-05 - categorical_crossentropy: 2.1847e-05 - val_loss: 1.8191e-05 - val_categorical_crossentropy: 1.8191e-05 - lr: 1.0000e-04
# Epoch 202/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1803e-05 - categorical_crossentropy: 2.1803e-05 - val_loss: 1.8136e-05 - val_categorical_crossentropy: 1.8136e-05 - lr: 1.0000e-04
# Epoch 203/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1749e-05 - categorical_crossentropy: 2.1749e-05 - val_loss: 1.8100e-05 - val_categorical_crossentropy: 1.8100e-05 - lr: 1.0000e-04
# Epoch 204/500
# 4/4 [==============================] - 0s 17ms/step - loss: 2.1699e-05 - categorical_crossentropy: 2.1699e-05 - val_loss: 1.8052e-05 - val_categorical_crossentropy: 1.8052e-05 - lr: 1.0000e-04
# Epoch 205/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.1650e-05 - categorical_crossentropy: 2.1650e-05 - val_loss: 1.8008e-05 - val_categorical_crossentropy: 1.8008e-05 - lr: 1.0000e-04
# Epoch 206/500
# 4/4 [==============================] - 0s 24ms/step - loss: 2.1598e-05 - categorical_crossentropy: 2.1598e-05 - val_loss: 1.7965e-05 - val_categorical_crossentropy: 1.7965e-05 - lr: 1.0000e-04
# Epoch 207/500
# 4/4 [==============================] - 0s 23ms/step - loss: 2.1550e-05 - categorical_crossentropy: 2.1550e-05 - val_loss: 1.7921e-05 - val_categorical_crossentropy: 1.7921e-05 - lr: 1.0000e-04
# Epoch 208/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.1491e-05 - categorical_crossentropy: 2.1491e-05 - val_loss: 1.7865e-05 - val_categorical_crossentropy: 1.7865e-05 - lr: 1.0000e-04
# Epoch 209/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.1452e-05 - categorical_crossentropy: 2.1452e-05 - val_loss: 1.7834e-05 - val_categorical_crossentropy: 1.7834e-05 - lr: 1.0000e-04
# Epoch 210/500
# 4/4 [==============================] - 0s 23ms/step - loss: 2.1395e-05 - categorical_crossentropy: 2.1395e-05 - val_loss: 1.7782e-05 - val_categorical_crossentropy: 1.7782e-05 - lr: 1.0000e-04
# Epoch 211/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.1352e-05 - categorical_crossentropy: 2.1352e-05 - val_loss: 1.7730e-05 - val_categorical_crossentropy: 1.7730e-05 - lr: 1.0000e-04
# Epoch 212/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1295e-05 - categorical_crossentropy: 2.1295e-05 - val_loss: 1.7698e-05 - val_categorical_crossentropy: 1.7698e-05 - lr: 1.0000e-04
# Epoch 213/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.1248e-05 - categorical_crossentropy: 2.1248e-05 - val_loss: 1.7659e-05 - val_categorical_crossentropy: 1.7659e-05 - lr: 1.0000e-04
# Epoch 214/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.1198e-05 - categorical_crossentropy: 2.1198e-05 - val_loss: 1.7587e-05 - val_categorical_crossentropy: 1.7587e-05 - lr: 1.0000e-04
# Epoch 215/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.1149e-05 - categorical_crossentropy: 2.1149e-05 - val_loss: 1.7555e-05 - val_categorical_crossentropy: 1.7555e-05 - lr: 1.0000e-04
# Epoch 216/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.1095e-05 - categorical_crossentropy: 2.1095e-05 - val_loss: 1.7532e-05 - val_categorical_crossentropy: 1.7532e-05 - lr: 1.0000e-04
# Epoch 217/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.1052e-05 - categorical_crossentropy: 2.1052e-05 - val_loss: 1.7460e-05 - val_categorical_crossentropy: 1.7460e-05 - lr: 1.0000e-04
# Epoch 218/500
# 4/4 [==============================] - 0s 22ms/step - loss: 2.0998e-05 - categorical_crossentropy: 2.0998e-05 - val_loss: 1.7432e-05 - val_categorical_crossentropy: 1.7432e-05 - lr: 1.0000e-04
# Epoch 219/500
# 4/4 [==============================] - 0s 22ms/step - loss: 2.0948e-05 - categorical_crossentropy: 2.0948e-05 - val_loss: 1.7388e-05 - val_categorical_crossentropy: 1.7388e-05 - lr: 1.0000e-04
# Epoch 220/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.0902e-05 - categorical_crossentropy: 2.0902e-05 - val_loss: 1.7341e-05 - val_categorical_crossentropy: 1.7341e-05 - lr: 1.0000e-04
# Epoch 221/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.0848e-05 - categorical_crossentropy: 2.0848e-05 - val_loss: 1.7293e-05 - val_categorical_crossentropy: 1.7293e-05 - lr: 1.0000e-04
# Epoch 222/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0794e-05 - categorical_crossentropy: 2.0794e-05 - val_loss: 1.7257e-05 - val_categorical_crossentropy: 1.7257e-05 - lr: 1.0000e-04
# Epoch 223/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0755e-05 - categorical_crossentropy: 2.0755e-05 - val_loss: 1.7214e-05 - val_categorical_crossentropy: 1.7214e-05 - lr: 1.0000e-04
# Epoch 224/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0699e-05 - categorical_crossentropy: 2.0699e-05 - val_loss: 1.7158e-05 - val_categorical_crossentropy: 1.7158e-05 - lr: 1.0000e-04
# Epoch 225/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0649e-05 - categorical_crossentropy: 2.0649e-05 - val_loss: 1.7126e-05 - val_categorical_crossentropy: 1.7126e-05 - lr: 1.0000e-04
# Epoch 226/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0601e-05 - categorical_crossentropy: 2.0601e-05 - val_loss: 1.7079e-05 - val_categorical_crossentropy: 1.7079e-05 - lr: 1.0000e-04
# Epoch 227/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.0558e-05 - categorical_crossentropy: 2.0558e-05 - val_loss: 1.7027e-05 - val_categorical_crossentropy: 1.7027e-05 - lr: 1.0000e-04
# Epoch 228/500
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0505e-05 - categorical_crossentropy: 2.0505e-05 - val_loss: 1.6995e-05 - val_categorical_crossentropy: 1.6995e-05 - lr: 1.0000e-04
# Epoch 229/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.0457e-05 - categorical_crossentropy: 2.0457e-05 - val_loss: 1.6955e-05 - val_categorical_crossentropy: 1.6955e-05 - lr: 1.0000e-04
# Epoch 230/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.0404e-05 - categorical_crossentropy: 2.0404e-05 - val_loss: 1.6908e-05 - val_categorical_crossentropy: 1.6908e-05 - lr: 1.0000e-04
# Epoch 231/500
# 4/4 [==============================] - 0s 21ms/step - loss: 2.0352e-05 - categorical_crossentropy: 2.0352e-05 - val_loss: 1.6864e-05 - val_categorical_crossentropy: 1.6864e-05 - lr: 1.0000e-04
# Epoch 232/500
# 4/4 [==============================] - 0s 20ms/step - loss: 2.0306e-05 - categorical_crossentropy: 2.0306e-05 - val_loss: 1.6828e-05 - val_categorical_crossentropy: 1.6828e-05 - lr: 1.0000e-04
# Epoch 233/500
# 4/4 [==============================] - 0s 19ms/step - loss: 2.0259e-05 - categorical_crossentropy: 2.0259e-05 - val_loss: 1.6788e-05 - val_categorical_crossentropy: 1.6788e-05 - lr: 1.0000e-04
# Epoch 234/500
# ...
# Epoch 424/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.2234e-05 - categorical_crossentropy: 1.2234e-05 - val_loss: 1.0041e-05 - val_categorical_crossentropy: 1.0041e-05 - lr: 1.0000e-04
# Epoch 425/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.2208e-05 - categorical_crossentropy: 1.2208e-05 - val_loss: 1.0021e-05 - val_categorical_crossentropy: 1.0021e-05 - lr: 1.0000e-04
# Epoch 426/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.2165e-05 - categorical_crossentropy: 1.2165e-05 - val_loss: 9.9976e-06 - val_categorical_crossentropy: 9.9976e-06 - lr: 1.0000e-04
# Epoch 427/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.2134e-05 - categorical_crossentropy: 1.2134e-05 - val_loss: 9.9539e-06 - val_categorical_crossentropy: 9.9539e-06 - lr: 1.0000e-04
# Epoch 428/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.2104e-05 - categorical_crossentropy: 1.2104e-05 - val_loss: 9.9301e-06 - val_categorical_crossentropy: 9.9301e-06 - lr: 1.0000e-04
# Epoch 429/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2067e-05 - categorical_crossentropy: 1.2067e-05 - val_loss: 9.9023e-06 - val_categorical_crossentropy: 9.9023e-06 - lr: 1.0000e-04
# Epoch 430/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.2038e-05 - categorical_crossentropy: 1.2038e-05 - val_loss: 9.8784e-06 - val_categorical_crossentropy: 9.8784e-06 - lr: 1.0000e-04
# Epoch 431/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1998e-05 - categorical_crossentropy: 1.1998e-05 - val_loss: 9.8705e-06 - val_categorical_crossentropy: 9.8705e-06 - lr: 1.0000e-04
# Epoch 432/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1969e-05 - categorical_crossentropy: 1.1969e-05 - val_loss: 9.8228e-06 - val_categorical_crossentropy: 9.8228e-06 - lr: 1.0000e-04
# Epoch 433/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1938e-05 - categorical_crossentropy: 1.1938e-05 - val_loss: 9.7950e-06 - val_categorical_crossentropy: 9.7950e-06 - lr: 1.0000e-04
# Epoch 434/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1899e-05 - categorical_crossentropy: 1.1899e-05 - val_loss: 9.7711e-06 - val_categorical_crossentropy: 9.7711e-06 - lr: 1.0000e-04
# Epoch 435/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1873e-05 - categorical_crossentropy: 1.1873e-05 - val_loss: 9.7393e-06 - val_categorical_crossentropy: 9.7393e-06 - lr: 1.0000e-04
# Epoch 436/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1833e-05 - categorical_crossentropy: 1.1833e-05 - val_loss: 9.7274e-06 - val_categorical_crossentropy: 9.7274e-06 - lr: 1.0000e-04
# Epoch 437/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1804e-05 - categorical_crossentropy: 1.1804e-05 - val_loss: 9.6877e-06 - val_categorical_crossentropy: 9.6877e-06 - lr: 1.0000e-04
# Epoch 438/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1772e-05 - categorical_crossentropy: 1.1772e-05 - val_loss: 9.6678e-06 - val_categorical_crossentropy: 9.6678e-06 - lr: 1.0000e-04
# Epoch 439/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1740e-05 - categorical_crossentropy: 1.1740e-05 - val_loss: 9.6400e-06 - val_categorical_crossentropy: 9.6400e-06 - lr: 1.0000e-04
# Epoch 440/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1701e-05 - categorical_crossentropy: 1.1701e-05 - val_loss: 9.6003e-06 - val_categorical_crossentropy: 9.6003e-06 - lr: 1.0000e-04
# Epoch 441/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1671e-05 - categorical_crossentropy: 1.1671e-05 - val_loss: 9.5844e-06 - val_categorical_crossentropy: 9.5844e-06 - lr: 1.0000e-04
# Epoch 442/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1639e-05 - categorical_crossentropy: 1.1639e-05 - val_loss: 9.5605e-06 - val_categorical_crossentropy: 9.5605e-06 - lr: 1.0000e-04
# Epoch 443/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1609e-05 - categorical_crossentropy: 1.1609e-05 - val_loss: 9.5248e-06 - val_categorical_crossentropy: 9.5248e-06 - lr: 1.0000e-04
# Epoch 444/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1574e-05 - categorical_crossentropy: 1.1574e-05 - val_loss: 9.5009e-06 - val_categorical_crossentropy: 9.5009e-06 - lr: 1.0000e-04
# Epoch 445/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1543e-05 - categorical_crossentropy: 1.1543e-05 - val_loss: 9.4850e-06 - val_categorical_crossentropy: 9.4850e-06 - lr: 1.0000e-04
# Epoch 446/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1514e-05 - categorical_crossentropy: 1.1514e-05 - val_loss: 9.4413e-06 - val_categorical_crossentropy: 9.4413e-06 - lr: 1.0000e-04
# Epoch 447/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1474e-05 - categorical_crossentropy: 1.1474e-05 - val_loss: 9.4254e-06 - val_categorical_crossentropy: 9.4254e-06 - lr: 1.0000e-04
# Epoch 448/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1449e-05 - categorical_crossentropy: 1.1449e-05 - val_loss: 9.4056e-06 - val_categorical_crossentropy: 9.4056e-06 - lr: 1.0000e-04
# Epoch 449/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1418e-05 - categorical_crossentropy: 1.1418e-05 - val_loss: 9.3738e-06 - val_categorical_crossentropy: 9.3738e-06 - lr: 1.0000e-04
# Epoch 450/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1382e-05 - categorical_crossentropy: 1.1382e-05 - val_loss: 9.3460e-06 - val_categorical_crossentropy: 9.3460e-06 - lr: 1.0000e-04
# Epoch 451/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1351e-05 - categorical_crossentropy: 1.1351e-05 - val_loss: 9.3261e-06 - val_categorical_crossentropy: 9.3261e-06 - lr: 1.0000e-04
# Epoch 452/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1322e-05 - categorical_crossentropy: 1.1322e-05 - val_loss: 9.2903e-06 - val_categorical_crossentropy: 9.2903e-06 - lr: 1.0000e-04
# Epoch 453/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1283e-05 - categorical_crossentropy: 1.1283e-05 - val_loss: 9.2665e-06 - val_categorical_crossentropy: 9.2665e-06 - lr: 1.0000e-04
# Epoch 454/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1261e-05 - categorical_crossentropy: 1.1261e-05 - val_loss: 9.2506e-06 - val_categorical_crossentropy: 9.2506e-06 - lr: 1.0000e-04
# Epoch 455/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1228e-05 - categorical_crossentropy: 1.1228e-05 - val_loss: 9.2188e-06 - val_categorical_crossentropy: 9.2188e-06 - lr: 1.0000e-04
# Epoch 456/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1192e-05 - categorical_crossentropy: 1.1192e-05 - val_loss: 9.1910e-06 - val_categorical_crossentropy: 9.1910e-06 - lr: 1.0000e-04
# Epoch 457/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1166e-05 - categorical_crossentropy: 1.1166e-05 - val_loss: 9.1711e-06 - val_categorical_crossentropy: 9.1711e-06 - lr: 1.0000e-04
# Epoch 458/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1129e-05 - categorical_crossentropy: 1.1129e-05 - val_loss: 9.1393e-06 - val_categorical_crossentropy: 9.1393e-06 - lr: 1.0000e-04
# Epoch 459/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1097e-05 - categorical_crossentropy: 1.1097e-05 - val_loss: 9.1195e-06 - val_categorical_crossentropy: 9.1195e-06 - lr: 1.0000e-04
# Epoch 460/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1075e-05 - categorical_crossentropy: 1.1075e-05 - val_loss: 9.0916e-06 - val_categorical_crossentropy: 9.0916e-06 - lr: 1.0000e-04
# Epoch 461/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.1037e-05 - categorical_crossentropy: 1.1037e-05 - val_loss: 9.0638e-06 - val_categorical_crossentropy: 9.0638e-06 - lr: 1.0000e-04
# Epoch 462/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.1006e-05 - categorical_crossentropy: 1.1006e-05 - val_loss: 9.0360e-06 - val_categorical_crossentropy: 9.0360e-06 - lr: 1.0000e-04
# Epoch 463/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.0977e-05 - categorical_crossentropy: 1.0977e-05 - val_loss: 9.0241e-06 - val_categorical_crossentropy: 9.0241e-06 - lr: 1.0000e-04
# Epoch 464/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0941e-05 - categorical_crossentropy: 1.0941e-05 - val_loss: 8.9883e-06 - val_categorical_crossentropy: 8.9883e-06 - lr: 1.0000e-04
# Epoch 465/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0918e-05 - categorical_crossentropy: 1.0918e-05 - val_loss: 8.9685e-06 - val_categorical_crossentropy: 8.9685e-06 - lr: 1.0000e-04
# Epoch 466/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0889e-05 - categorical_crossentropy: 1.0889e-05 - val_loss: 8.9446e-06 - val_categorical_crossentropy: 8.9446e-06 - lr: 1.0000e-04
# Epoch 467/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0855e-05 - categorical_crossentropy: 1.0855e-05 - val_loss: 8.9208e-06 - val_categorical_crossentropy: 8.9208e-06 - lr: 1.0000e-04
# Epoch 468/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0824e-05 - categorical_crossentropy: 1.0824e-05 - val_loss: 8.8890e-06 - val_categorical_crossentropy: 8.8890e-06 - lr: 1.0000e-04
# Epoch 469/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0794e-05 - categorical_crossentropy: 1.0794e-05 - val_loss: 8.8731e-06 - val_categorical_crossentropy: 8.8731e-06 - lr: 1.0000e-04
# Epoch 470/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0768e-05 - categorical_crossentropy: 1.0768e-05 - val_loss: 8.8453e-06 - val_categorical_crossentropy: 8.8453e-06 - lr: 1.0000e-04
# Epoch 471/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0732e-05 - categorical_crossentropy: 1.0732e-05 - val_loss: 8.8175e-06 - val_categorical_crossentropy: 8.8175e-06 - lr: 1.0000e-04
# Epoch 472/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0702e-05 - categorical_crossentropy: 1.0702e-05 - val_loss: 8.7857e-06 - val_categorical_crossentropy: 8.7857e-06 - lr: 1.0000e-04
# Epoch 473/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0674e-05 - categorical_crossentropy: 1.0674e-05 - val_loss: 8.7738e-06 - val_categorical_crossentropy: 8.7738e-06 - lr: 1.0000e-04
# Epoch 474/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0646e-05 - categorical_crossentropy: 1.0646e-05 - val_loss: 8.7420e-06 - val_categorical_crossentropy: 8.7420e-06 - lr: 1.0000e-04
# Epoch 475/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0615e-05 - categorical_crossentropy: 1.0615e-05 - val_loss: 8.7261e-06 - val_categorical_crossentropy: 8.7261e-06 - lr: 1.0000e-04
# Epoch 476/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0582e-05 - categorical_crossentropy: 1.0582e-05 - val_loss: 8.6983e-06 - val_categorical_crossentropy: 8.6983e-06 - lr: 1.0000e-04
# Epoch 477/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0554e-05 - categorical_crossentropy: 1.0554e-05 - val_loss: 8.6704e-06 - val_categorical_crossentropy: 8.6704e-06 - lr: 1.0000e-04
# Epoch 478/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0525e-05 - categorical_crossentropy: 1.0525e-05 - val_loss: 8.6506e-06 - val_categorical_crossentropy: 8.6506e-06 - lr: 1.0000e-04
# Epoch 479/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0498e-05 - categorical_crossentropy: 1.0498e-05 - val_loss: 8.6307e-06 - val_categorical_crossentropy: 8.6307e-06 - lr: 1.0000e-04
# Epoch 480/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0471e-05 - categorical_crossentropy: 1.0471e-05 - val_loss: 8.6029e-06 - val_categorical_crossentropy: 8.6029e-06 - lr: 1.0000e-04
# Epoch 481/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0438e-05 - categorical_crossentropy: 1.0438e-05 - val_loss: 8.5711e-06 - val_categorical_crossentropy: 8.5711e-06 - lr: 1.0000e-04
# Epoch 482/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0404e-05 - categorical_crossentropy: 1.0404e-05 - val_loss: 8.5473e-06 - val_categorical_crossentropy: 8.5473e-06 - lr: 1.0000e-04
# Epoch 483/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0380e-05 - categorical_crossentropy: 1.0380e-05 - val_loss: 8.5194e-06 - val_categorical_crossentropy: 8.5194e-06 - lr: 1.0000e-04
# Epoch 484/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0353e-05 - categorical_crossentropy: 1.0353e-05 - val_loss: 8.5075e-06 - val_categorical_crossentropy: 8.5075e-06 - lr: 1.0000e-04
# Epoch 485/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0322e-05 - categorical_crossentropy: 1.0322e-05 - val_loss: 8.4797e-06 - val_categorical_crossentropy: 8.4797e-06 - lr: 1.0000e-04
# Epoch 486/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0290e-05 - categorical_crossentropy: 1.0290e-05 - val_loss: 8.4598e-06 - val_categorical_crossentropy: 8.4598e-06 - lr: 1.0000e-04
# Epoch 487/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0258e-05 - categorical_crossentropy: 1.0258e-05 - val_loss: 8.4439e-06 - val_categorical_crossentropy: 8.4439e-06 - lr: 1.0000e-04
# Epoch 488/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0235e-05 - categorical_crossentropy: 1.0235e-05 - val_loss: 8.4161e-06 - val_categorical_crossentropy: 8.4161e-06 - lr: 1.0000e-04
# Epoch 489/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0202e-05 - categorical_crossentropy: 1.0202e-05 - val_loss: 8.3804e-06 - val_categorical_crossentropy: 8.3804e-06 - lr: 1.0000e-04
# Epoch 490/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0178e-05 - categorical_crossentropy: 1.0178e-05 - val_loss: 8.3645e-06 - val_categorical_crossentropy: 8.3645e-06 - lr: 1.0000e-04
# Epoch 491/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0152e-05 - categorical_crossentropy: 1.0152e-05 - val_loss: 8.3327e-06 - val_categorical_crossentropy: 8.3327e-06 - lr: 1.0000e-04
# Epoch 492/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0121e-05 - categorical_crossentropy: 1.0121e-05 - val_loss: 8.3128e-06 - val_categorical_crossentropy: 8.3128e-06 - lr: 1.0000e-04
# Epoch 493/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0085e-05 - categorical_crossentropy: 1.0085e-05 - val_loss: 8.3088e-06 - val_categorical_crossentropy: 8.3088e-06 - lr: 1.0000e-04
# Epoch 494/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0063e-05 - categorical_crossentropy: 1.0063e-05 - val_loss: 8.2810e-06 - val_categorical_crossentropy: 8.2810e-06 - lr: 1.0000e-04
# Epoch 495/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0036e-05 - categorical_crossentropy: 1.0036e-05 - val_loss: 8.2572e-06 - val_categorical_crossentropy: 8.2572e-06 - lr: 1.0000e-04
# Epoch 496/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0009e-05 - categorical_crossentropy: 1.0009e-05 - val_loss: 8.2254e-06 - val_categorical_crossentropy: 8.2254e-06 - lr: 1.0000e-04
# Epoch 497/500
# 4/4 [==============================] - 0s 17ms/step - loss: 9.9827e-06 - categorical_crossentropy: 9.9827e-06 - val_loss: 8.1896e-06 - val_categorical_crossentropy: 8.1896e-06 - lr: 1.0000e-04
# Epoch 498/500
# 4/4 [==============================] - 0s 19ms/step - loss: 9.9539e-06 - categorical_crossentropy: 9.9539e-06 - val_loss: 8.1737e-06 - val_categorical_crossentropy: 8.1737e-06 - lr: 1.0000e-04
# Epoch 499/500
# 4/4 [==============================] - 0s 19ms/step - loss: 9.9221e-06 - categorical_crossentropy: 9.9221e-06 - val_loss: 8.1618e-06 - val_categorical_crossentropy: 8.1618e-06 - lr: 1.0000e-04
# Epoch 500/500
# 4/4 [==============================] - 0s 16ms/step - loss: 9.8943e-06 - categorical_crossentropy: 9.8943e-06 - val_loss: 8.1340e-06 - val_categorical_crossentropy: 8.1340e-06 - lr: 1.0000e-04

# %%
class ModelWrapper():
    def __init__(self,model):
        self.model=model
    def predict_proba(self,X):
        if isinstance(X, pd.DataFrame):
            X=X.values
        Xnn=X.reshape(X.shape[0],1,X.shape[1])
        return self.model.predict(Xnn)
    def predict(self, X):
        return np.argmax(self.predict_proba(X),axis=1)
clf=ModelWrapper(model)

# %% [markdown]
# ## SHAP
# We calculate SHAP for datasets

# %%
fXtrain = trainX.reshape(150,1,200)

# %%
from tsproto.utils import getshap

shap_version='deep'
bg_size = 1000
stride=10
window_len=10
absshap = True
fXtrain,sv_tr = getshap(model=model, X=fXtrain, y=train_ynn,shap_version=shap_version,bg_size = bg_size, stride=stride, window_len=window_len, absshap = absshap, shuffle=False)
# Out:
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [markdown]
# ## Visualize SHAP
# In this section we can see that the network focused on correct parts of the time-series.
# In this toy example, it is sufficient to look at SHAP-visualizations to spot the difference, but in case of hundreds of dimensions and more complex problems, prototypes are more useful.

# %%
from  tsproto.plots import plot_smooth_colored_line
indexer = clf.predict(trainX)
shapclass = []
if absshap == False:
    for i in range(0,len(trainX)):
        best_index = indexer[i]
        shapclass.append([sv_tr[best_index][i,:]])
        
    shapclass=np.concatenate(shapclass)
else:
    shapclass  = sv_tr[:,0,:]

    fig, axes =plt.subplots(2,1,figsize=(12,6))

    for i in range(0,10):
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==0][i], color_values=shapclass[train_y==0][i], resolution=1000, ax=axes[0],add_cbar=(i==0))
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==1][i], color_values=shapclass[train_y==1][i], resolution=1000, ax=axes[1],add_cbar=(i==0))

for ax in axes:
    ax.set_ylim([-2, 2])
# Out:
# 5/5 [==============================] - 0s 1ms/step

# %%
## TEST breakpoints
import ruptures as rpt
pen=1
totalbpoints=[]
for i in range(0, trainX.shape[0]):
    algo = rpt.Pelt(model='l2', min_size=5, jump=1).fit(shapclass[i])

    try:
        breakpoints = algo.predict(pen=(0.25*trainX.shape[1])**(1-pen)*2*np.log(trainX.shape[1]))
        print(f'No bkps for pen: {(0.25*trainX.shape[1])**(1-pen)*2*np.log(trainX.shape[1])}: {len(breakpoints)}')
    except:
        # no change detected, means there are no breakpoints
        print('kk)')
        breakpoints = [0]
    totalbpoints.append(breakpoints)
# Out:
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1
# No bkps for pen: 10.596634733096073: 1

# %%
from tsproto.plots import plot_smooth_colored_line
import seaborn as sns

tbp = pd.DataFrame(totalbpoints)


fig, axes =plt.subplots(2,1,figsize=(12,6))
for i in range(0,1):
    bkp0 = x[tbp[train_y==0].iloc[i].dropna().astype(int)-1]
    bkp1 =x[tbp[train_y==1].iloc[i].dropna().astype(int)-1]
    plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==0][i], color_values=shapclass[train_y==0][i], resolution=1000, ax=axes[0],add_cbar=(i==0))
    
    for b in bkp0:
        axes[0].axvline(x=b, color='b', linestyle='--')
    
    plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==1][i], color_values=shapclass[train_y==1][i], resolution=1000, ax=axes[1],add_cbar=(i==0))
    for b in bkp1:
        axes[1].axvline(x=b, color='b', linestyle='--')

for ax in axes:
    ax.set_ylim([-2, 2])

axes[0].set_title('Sample time series from class 0')
axes[1].set_title('Sample time series from class 1')
plt.savefig('c1c2shap.svg', format='svg',bbox_inches='tight')

# %% [markdown]
# ## Tsproto
# Now, lets try to apply TSProto to see if it is able to find the prototype and summarize them correctly to show what logical relation is between them and the model prediction

# %%
trainXproto = trainX.reshape((trainX.shape[0], trainX.shape[1],1))
shapclassXproto = shapclass.reshape((shapclass.shape[0], shapclass.shape[1],1))

# %%
from tsproto.models import *
im  = InterpretableModel()
pe = PrototypeEncoder(clf, n_clusters=2, min_size=50, method='dtw',
                              descriptors=['frequency'],
                      jump=1, pen=1,multiplier=-1,n_jobs=-1,
                      verbose=1)
ohe_train, features, target_ohe,weights = pe.fit_transform(trainXproto,shapclassXproto)
acc,prec,rec,f1,iclf = im.fit_or_predict(ohe_train, features, target_ohe,intclf=None, verbose=0, max_depth=2, min_samples_leaf=0.05,
                       weights=None)
# Out:
# Dataset shape: (150, 200, 1)
# Calculating changepoints...
# 5/5 [==============================] - 0s 2ms/step
# WARNING: Changing the threshold, due to empty record
# Done in 1.4224035739898682.
# Clustering data
# Shape of data for clustering: (150, 86, 1)
# Clustering data
# Done in 1.2742383480072021.
# OHE time series
# ['frequency']
# Done in 0.1704859733581543.

# %% [markdown]
# ## Visualize interpretable model
# We can easily see that the TSProto has found the sine wave at the beginning of the sample, marked it as prototype and correctly identified that its existence is not enough to treat the sample as a class 1 sample, additional frequency context has to be added in order to distinguish these two

# %%
from  tsproto.plots import *
ds_final = ohe_train.copy()
dot = export_decision_tree_with_embedded_histograms(decision_tree=iclf, 
                                              dataset=ds_final, 
                                              target_name='target', 
                                              feature_names=features, 
                                              filename='synthetic', 
                                              focus_class=0,
                                              proto_encoder=pe, figsize=(6,3))

from IPython.display import SVG, Image
Image('synthetic.png')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# TC: 81 over ccshap: 81
# Number of clusters in opposite_class: [0] as opposed ot actual class [81]
# Found: [69]
# Decision Tree exported to synthetic with embedded histograms successfully.
