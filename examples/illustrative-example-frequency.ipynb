# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn import tree
from graphviz import Source
from IPython.display import display
from IPython.display import SVG

# %% [markdown]
# ## Creating synthetic dataset
# We will create a synthetic dataset with two classes. The dataset will be hard to distinguish based on statistical features, but possible with proper prototypical parts extracted.
#
# We are making it even harder, as the prototypical parts are more or less the same. They are differing in terms of frequency.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(3*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X3 = np.concatenate((x1,x2))
Y3 = np.concatenate((y1,y2))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(2*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X4 = np.concatenate((x1,x2))
Y4 = np.concatenate((y1,y2))

# %% [markdown]
# ## Generating sample cases

# %%
x = X3
proto_sin_y = Y3
proto_inversed_sin_y = Y4

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,proto_sin_y)
axes[1].plot(x,proto_inversed_sin_y)

# %% [markdown]
# ## Generating noise and augmenting signals

# %%
noise_power = .2

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_sin_y = noise + proto_sin_y

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_inversed_sin_y = noise + proto_inversed_sin_y

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,noisy_proto_sin_y[0])
axes[1].plot(x,noisy_proto_inversed_sin_y[0])
for ax in axes:
    ax.set_ylim([-2, 2])

# %%
X=np.concatenate((noisy_proto_sin_y,noisy_proto_inversed_sin_y))
Xy=np.concatenate((np.ones(len(noisy_proto_sin_y))*0,
                   np.ones(len(noisy_proto_inversed_sin_y))*1))

trainX, testX, train_y,test_y = train_test_split(X,Xy)

# %% [markdown]
# ## Model
# We will build simple DNN model (not really needed in this case, but it serves the purpose of demonstration how to deal with more complex cases)

# %%
trainX.shape
# Out:
# (150, 200)

# %%
from keras.utils import to_categorical
trainXnn = trainX.reshape(150,1,200)
train_ynn = to_categorical(train_y)
num_classes = len(np.unique(Xy))

# %%
import keras
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    #add dropout
    input_layer = keras.layers.Dropout(0.5)(input_layer)
    conv1 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(input_layer)
    #conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv1)
    #conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv2)
    #conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)



model = make_model(input_shape=trainXnn.shape[1:])

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_crossentropy"],
)
history = model.fit(
    trainXnn,
    train_ynn,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 1s 159ms/step - loss: 0.6771 - categorical_crossentropy: 0.6771 - val_loss: 0.6399 - val_categorical_crossentropy: 0.6399 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 82ms/step - loss: 0.6138 - categorical_crossentropy: 0.6138 - val_loss: 0.5394 - val_categorical_crossentropy: 0.5394 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 126ms/step - loss: 0.5014 - categorical_crossentropy: 0.5014 - val_loss: 0.3820 - val_categorical_crossentropy: 0.3820 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 0s 145ms/step - loss: 0.3389 - categorical_crossentropy: 0.3389 - val_loss: 0.2050 - val_categorical_crossentropy: 0.2050 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 92ms/step - loss: 0.1718 - categorical_crossentropy: 0.1718 - val_loss: 0.0780 - val_categorical_crossentropy: 0.0780 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 98ms/step - loss: 0.0631 - categorical_crossentropy: 0.0631 - val_loss: 0.0208 - val_categorical_crossentropy: 0.0208 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 100ms/step - loss: 0.0160 - categorical_crossentropy: 0.0160 - val_loss: 0.0044 - val_categorical_crossentropy: 0.0044 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0033 - categorical_crossentropy: 0.0033 - val_loss: 0.0011 - val_categorical_crossentropy: 0.0011 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 1s 185ms/step - loss: 8.0794e-04 - categorical_crossentropy: 8.0794e-04 - val_loss: 3.2995e-04 - val_categorical_crossentropy: 3.2995e-04 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 1s 140ms/step - loss: 2.6075e-04 - categorical_crossentropy: 2.6075e-04 - val_loss: 1.3882e-04 - val_categorical_crossentropy: 1.3882e-04 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 1s 138ms/step - loss: 1.1720e-04 - categorical_crossentropy: 1.1720e-04 - val_loss: 7.3974e-05 - val_categorical_crossentropy: 7.3974e-05 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 104ms/step - loss: 6.4259e-05 - categorical_crossentropy: 6.4259e-05 - val_loss: 4.7218e-05 - val_categorical_crossentropy: 4.7218e-05 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 1s 153ms/step - loss: 4.2465e-05 - categorical_crossentropy: 4.2465e-05 - val_loss: 3.4340e-05 - val_categorical_crossentropy: 3.4340e-05 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 105ms/step - loss: 3.1616e-05 - categorical_crossentropy: 3.1616e-05 - val_loss: 2.7414e-05 - val_categorical_crossentropy: 2.7414e-05 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 96ms/step - loss: 2.5683e-05 - categorical_crossentropy: 2.5683e-05 - val_loss: 2.3349e-05 - val_categorical_crossentropy: 2.3349e-05 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 138ms/step - loss: 2.2168e-05 - categorical_crossentropy: 2.2168e-05 - val_loss: 2.0830e-05 - val_categorical_crossentropy: 2.0830e-05 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 109ms/step - loss: 1.9965e-05 - categorical_crossentropy: 1.9965e-05 - val_loss: 1.9153e-05 - val_categorical_crossentropy: 1.9153e-05 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 111ms/step - loss: 1.8511e-05 - categorical_crossentropy: 1.8511e-05 - val_loss: 1.8020e-05 - val_categorical_crossentropy: 1.8020e-05 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 69ms/step - loss: 1.7503e-05 - categorical_crossentropy: 1.7503e-05 - val_loss: 1.7202e-05 - val_categorical_crossentropy: 1.7202e-05 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 50ms/step - loss: 1.6793e-05 - categorical_crossentropy: 1.6793e-05 - val_loss: 1.6602e-05 - val_categorical_crossentropy: 1.6602e-05 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 53ms/step - loss: 1.6278e-05 - categorical_crossentropy: 1.6278e-05 - val_loss: 1.6149e-05 - val_categorical_crossentropy: 1.6149e-05 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.5883e-05 - categorical_crossentropy: 1.5883e-05 - val_loss: 1.5779e-05 - val_categorical_crossentropy: 1.5779e-05 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 60ms/step - loss: 1.5570e-05 - categorical_crossentropy: 1.5570e-05 - val_loss: 1.5461e-05 - val_categorical_crossentropy: 1.5461e-05 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 66ms/step - loss: 1.5300e-05 - categorical_crossentropy: 1.5300e-05 - val_loss: 1.5195e-05 - val_categorical_crossentropy: 1.5195e-05 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 0s 68ms/step - loss: 1.5079e-05 - categorical_crossentropy: 1.5079e-05 - val_loss: 1.4965e-05 - val_categorical_crossentropy: 1.4965e-05 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 85ms/step - loss: 1.4873e-05 - categorical_crossentropy: 1.4873e-05 - val_loss: 1.4742e-05 - val_categorical_crossentropy: 1.4742e-05 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.4701e-05 - categorical_crossentropy: 1.4701e-05 - val_loss: 1.4543e-05 - val_categorical_crossentropy: 1.4543e-05 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.4524e-05 - categorical_crossentropy: 1.4524e-05 - val_loss: 1.4361e-05 - val_categorical_crossentropy: 1.4361e-05 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.4355e-05 - categorical_crossentropy: 1.4355e-05 - val_loss: 1.4182e-05 - val_categorical_crossentropy: 1.4182e-05 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 126ms/step - loss: 1.4207e-05 - categorical_crossentropy: 1.4207e-05 - val_loss: 1.4011e-05 - val_categorical_crossentropy: 1.4011e-05 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.4056e-05 - categorical_crossentropy: 1.4056e-05 - val_loss: 1.3836e-05 - val_categorical_crossentropy: 1.3836e-05 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.3922e-05 - categorical_crossentropy: 1.3922e-05 - val_loss: 1.3685e-05 - val_categorical_crossentropy: 1.3685e-05 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.3791e-05 - categorical_crossentropy: 1.3791e-05 - val_loss: 1.3522e-05 - val_categorical_crossentropy: 1.3522e-05 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 0s 85ms/step - loss: 1.3680e-05 - categorical_crossentropy: 1.3680e-05 - val_loss: 1.3439e-05 - val_categorical_crossentropy: 1.3439e-05 - lr: 5.0000e-04
# Epoch 35/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.3603e-05 - categorical_crossentropy: 1.3603e-05 - val_loss: 1.3363e-05 - val_categorical_crossentropy: 1.3363e-05 - lr: 5.0000e-04
# Epoch 36/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.3539e-05 - categorical_crossentropy: 1.3539e-05 - val_loss: 1.3296e-05 - val_categorical_crossentropy: 1.3296e-05 - lr: 5.0000e-04
# Epoch 37/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.3470e-05 - categorical_crossentropy: 1.3470e-05 - val_loss: 1.3220e-05 - val_categorical_crossentropy: 1.3220e-05 - lr: 5.0000e-04
# Epoch 38/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.3408e-05 - categorical_crossentropy: 1.3408e-05 - val_loss: 1.3153e-05 - val_categorical_crossentropy: 1.3153e-05 - lr: 5.0000e-04
# Epoch 39/500
# 4/4 [==============================] - 0s 50ms/step - loss: 1.3349e-05 - categorical_crossentropy: 1.3349e-05 - val_loss: 1.3077e-05 - val_categorical_crossentropy: 1.3077e-05 - lr: 5.0000e-04
# Epoch 40/500
# 4/4 [==============================] - 0s 85ms/step - loss: 1.3285e-05 - categorical_crossentropy: 1.3285e-05 - val_loss: 1.2998e-05 - val_categorical_crossentropy: 1.2998e-05 - lr: 5.0000e-04
# Epoch 41/500
# 4/4 [==============================] - 0s 73ms/step - loss: 1.3228e-05 - categorical_crossentropy: 1.3228e-05 - val_loss: 1.2922e-05 - val_categorical_crossentropy: 1.2922e-05 - lr: 5.0000e-04
# Epoch 42/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.3152e-05 - categorical_crossentropy: 1.3152e-05 - val_loss: 1.2851e-05 - val_categorical_crossentropy: 1.2851e-05 - lr: 5.0000e-04
# Epoch 43/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.3095e-05 - categorical_crossentropy: 1.3095e-05 - val_loss: 1.2783e-05 - val_categorical_crossentropy: 1.2783e-05 - lr: 5.0000e-04
# Epoch 44/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.3027e-05 - categorical_crossentropy: 1.3027e-05 - val_loss: 1.2716e-05 - val_categorical_crossentropy: 1.2716e-05 - lr: 5.0000e-04
# Epoch 45/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.2965e-05 - categorical_crossentropy: 1.2965e-05 - val_loss: 1.2644e-05 - val_categorical_crossentropy: 1.2644e-05 - lr: 5.0000e-04
# Epoch 46/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.2905e-05 - categorical_crossentropy: 1.2905e-05 - val_loss: 1.2569e-05 - val_categorical_crossentropy: 1.2569e-05 - lr: 5.0000e-04
# Epoch 47/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.2844e-05 - categorical_crossentropy: 1.2844e-05 - val_loss: 1.2493e-05 - val_categorical_crossentropy: 1.2493e-05 - lr: 5.0000e-04
# Epoch 48/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.2785e-05 - categorical_crossentropy: 1.2785e-05 - val_loss: 1.2422e-05 - val_categorical_crossentropy: 1.2422e-05 - lr: 5.0000e-04
# Epoch 49/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.2719e-05 - categorical_crossentropy: 1.2719e-05 - val_loss: 1.2362e-05 - val_categorical_crossentropy: 1.2362e-05 - lr: 5.0000e-04
# Epoch 50/500
# 4/4 [==============================] - 0s 99ms/step - loss: 1.2655e-05 - categorical_crossentropy: 1.2655e-05 - val_loss: 1.2294e-05 - val_categorical_crossentropy: 1.2294e-05 - lr: 5.0000e-04
# Epoch 51/500
# 4/4 [==============================] - 0s 109ms/step - loss: 1.2601e-05 - categorical_crossentropy: 1.2601e-05 - val_loss: 1.2235e-05 - val_categorical_crossentropy: 1.2235e-05 - lr: 5.0000e-04
# Epoch 52/500
# 4/4 [==============================] - 0s 110ms/step - loss: 1.2544e-05 - categorical_crossentropy: 1.2544e-05 - val_loss: 1.2163e-05 - val_categorical_crossentropy: 1.2163e-05 - lr: 5.0000e-04
# Epoch 53/500
# 4/4 [==============================] - 0s 99ms/step - loss: 1.2479e-05 - categorical_crossentropy: 1.2479e-05 - val_loss: 1.2084e-05 - val_categorical_crossentropy: 1.2084e-05 - lr: 5.0000e-04
# Epoch 54/500
# 4/4 [==============================] - 0s 132ms/step - loss: 1.2428e-05 - categorical_crossentropy: 1.2428e-05 - val_loss: 1.2060e-05 - val_categorical_crossentropy: 1.2060e-05 - lr: 2.5000e-04
# Epoch 55/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.2403e-05 - categorical_crossentropy: 1.2403e-05 - val_loss: 1.2032e-05 - val_categorical_crossentropy: 1.2032e-05 - lr: 2.5000e-04
# Epoch 56/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1.2371e-05 - categorical_crossentropy: 1.2371e-05 - val_loss: 1.2004e-05 - val_categorical_crossentropy: 1.2004e-05 - lr: 2.5000e-04
# Epoch 57/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.2341e-05 - categorical_crossentropy: 1.2341e-05 - val_loss: 1.1965e-05 - val_categorical_crossentropy: 1.1965e-05 - lr: 2.5000e-04
# Epoch 58/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.2312e-05 - categorical_crossentropy: 1.2312e-05 - val_loss: 1.1937e-05 - val_categorical_crossentropy: 1.1937e-05 - lr: 2.5000e-04
# Epoch 59/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.2279e-05 - categorical_crossentropy: 1.2279e-05 - val_loss: 1.1905e-05 - val_categorical_crossentropy: 1.1905e-05 - lr: 2.5000e-04
# Epoch 60/500
# 4/4 [==============================] - 0s 111ms/step - loss: 1.2254e-05 - categorical_crossentropy: 1.2254e-05 - val_loss: 1.1865e-05 - val_categorical_crossentropy: 1.1865e-05 - lr: 2.5000e-04
# Epoch 61/500
# 4/4 [==============================] - 0s 116ms/step - loss: 1.2219e-05 - categorical_crossentropy: 1.2219e-05 - val_loss: 1.1825e-05 - val_categorical_crossentropy: 1.1825e-05 - lr: 2.5000e-04
# Epoch 62/500
# 4/4 [==============================] - 0s 116ms/step - loss: 1.2195e-05 - categorical_crossentropy: 1.2195e-05 - val_loss: 1.1790e-05 - val_categorical_crossentropy: 1.1790e-05 - lr: 2.5000e-04
# Epoch 63/500
# 4/4 [==============================] - 0s 123ms/step - loss: 1.2160e-05 - categorical_crossentropy: 1.2160e-05 - val_loss: 1.1754e-05 - val_categorical_crossentropy: 1.1754e-05 - lr: 2.5000e-04
# Epoch 64/500
# 4/4 [==============================] - 0s 118ms/step - loss: 1.2133e-05 - categorical_crossentropy: 1.2133e-05 - val_loss: 1.1730e-05 - val_categorical_crossentropy: 1.1730e-05 - lr: 2.5000e-04
# Epoch 65/500
# 4/4 [==============================] - 0s 124ms/step - loss: 1.2102e-05 - categorical_crossentropy: 1.2102e-05 - val_loss: 1.1698e-05 - val_categorical_crossentropy: 1.1698e-05 - lr: 2.5000e-04
# Epoch 66/500
# 4/4 [==============================] - 0s 130ms/step - loss: 1.2075e-05 - categorical_crossentropy: 1.2075e-05 - val_loss: 1.1671e-05 - val_categorical_crossentropy: 1.1671e-05 - lr: 2.5000e-04
# Epoch 67/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.2040e-05 - categorical_crossentropy: 1.2040e-05 - val_loss: 1.1631e-05 - val_categorical_crossentropy: 1.1631e-05 - lr: 2.5000e-04
# Epoch 68/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.2010e-05 - categorical_crossentropy: 1.2010e-05 - val_loss: 1.1611e-05 - val_categorical_crossentropy: 1.1611e-05 - lr: 2.5000e-04
# Epoch 69/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.1974e-05 - categorical_crossentropy: 1.1974e-05 - val_loss: 1.1571e-05 - val_categorical_crossentropy: 1.1571e-05 - lr: 2.5000e-04
# Epoch 70/500
# 4/4 [==============================] - 0s 55ms/step - loss: 1.1948e-05 - categorical_crossentropy: 1.1948e-05 - val_loss: 1.1527e-05 - val_categorical_crossentropy: 1.1527e-05 - lr: 2.5000e-04
# Epoch 71/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.1919e-05 - categorical_crossentropy: 1.1919e-05 - val_loss: 1.1496e-05 - val_categorical_crossentropy: 1.1496e-05 - lr: 2.5000e-04
# Epoch 72/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.1886e-05 - categorical_crossentropy: 1.1886e-05 - val_loss: 1.1452e-05 - val_categorical_crossentropy: 1.1452e-05 - lr: 2.5000e-04
# Epoch 73/500
# 4/4 [==============================] - 0s 115ms/step - loss: 1.1863e-05 - categorical_crossentropy: 1.1863e-05 - val_loss: 1.1432e-05 - val_categorical_crossentropy: 1.1432e-05 - lr: 2.5000e-04
# Epoch 74/500
# 4/4 [==============================] - 0s 111ms/step - loss: 1.1834e-05 - categorical_crossentropy: 1.1834e-05 - val_loss: 1.1416e-05 - val_categorical_crossentropy: 1.1416e-05 - lr: 1.2500e-04
# Epoch 75/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1.1819e-05 - categorical_crossentropy: 1.1819e-05 - val_loss: 1.1404e-05 - val_categorical_crossentropy: 1.1404e-05 - lr: 1.2500e-04
# Epoch 76/500
# 4/4 [==============================] - 0s 70ms/step - loss: 1.1803e-05 - categorical_crossentropy: 1.1803e-05 - val_loss: 1.1384e-05 - val_categorical_crossentropy: 1.1384e-05 - lr: 1.2500e-04
# Epoch 77/500
# 4/4 [==============================] - 0s 98ms/step - loss: 1.1792e-05 - categorical_crossentropy: 1.1792e-05 - val_loss: 1.1369e-05 - val_categorical_crossentropy: 1.1369e-05 - lr: 1.2500e-04
# Epoch 78/500
# 4/4 [==============================] - 0s 116ms/step - loss: 1.1774e-05 - categorical_crossentropy: 1.1774e-05 - val_loss: 1.1349e-05 - val_categorical_crossentropy: 1.1349e-05 - lr: 1.2500e-04
# Epoch 79/500
# 4/4 [==============================] - 0s 107ms/step - loss: 1.1753e-05 - categorical_crossentropy: 1.1753e-05 - val_loss: 1.1337e-05 - val_categorical_crossentropy: 1.1337e-05 - lr: 1.2500e-04
# Epoch 80/500
# 4/4 [==============================] - 0s 75ms/step - loss: 1.1740e-05 - categorical_crossentropy: 1.1740e-05 - val_loss: 1.1321e-05 - val_categorical_crossentropy: 1.1321e-05 - lr: 1.2500e-04
# Epoch 81/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.1726e-05 - categorical_crossentropy: 1.1726e-05 - val_loss: 1.1305e-05 - val_categorical_crossentropy: 1.1305e-05 - lr: 1.2500e-04
# Epoch 82/500
# 4/4 [==============================] - 0s 127ms/step - loss: 1.1712e-05 - categorical_crossentropy: 1.1712e-05 - val_loss: 1.1289e-05 - val_categorical_crossentropy: 1.1289e-05 - lr: 1.2500e-04
# Epoch 83/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.1694e-05 - categorical_crossentropy: 1.1694e-05 - val_loss: 1.1257e-05 - val_categorical_crossentropy: 1.1257e-05 - lr: 1.2500e-04
# Epoch 84/500
# 4/4 [==============================] - 0s 140ms/step - loss: 1.1677e-05 - categorical_crossentropy: 1.1677e-05 - val_loss: 1.1241e-05 - val_categorical_crossentropy: 1.1241e-05 - lr: 1.2500e-04
# Epoch 85/500
# 4/4 [==============================] - 0s 109ms/step - loss: 1.1667e-05 - categorical_crossentropy: 1.1667e-05 - val_loss: 1.1222e-05 - val_categorical_crossentropy: 1.1222e-05 - lr: 1.2500e-04
# Epoch 86/500
# 4/4 [==============================] - 0s 57ms/step - loss: 1.1651e-05 - categorical_crossentropy: 1.1651e-05 - val_loss: 1.1202e-05 - val_categorical_crossentropy: 1.1202e-05 - lr: 1.2500e-04
# Epoch 87/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.1639e-05 - categorical_crossentropy: 1.1639e-05 - val_loss: 1.1194e-05 - val_categorical_crossentropy: 1.1194e-05 - lr: 1.2500e-04
# Epoch 88/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.1620e-05 - categorical_crossentropy: 1.1620e-05 - val_loss: 1.1178e-05 - val_categorical_crossentropy: 1.1178e-05 - lr: 1.2500e-04
# Epoch 89/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.1599e-05 - categorical_crossentropy: 1.1599e-05 - val_loss: 1.1158e-05 - val_categorical_crossentropy: 1.1158e-05 - lr: 1.2500e-04
# Epoch 90/500
# 4/4 [==============================] - 0s 99ms/step - loss: 1.1586e-05 - categorical_crossentropy: 1.1586e-05 - val_loss: 1.1146e-05 - val_categorical_crossentropy: 1.1146e-05 - lr: 1.2500e-04
# Epoch 91/500
# 4/4 [==============================] - 0s 65ms/step - loss: 1.1568e-05 - categorical_crossentropy: 1.1568e-05 - val_loss: 1.1126e-05 - val_categorical_crossentropy: 1.1126e-05 - lr: 1.2500e-04
# Epoch 92/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.1555e-05 - categorical_crossentropy: 1.1555e-05 - val_loss: 1.1118e-05 - val_categorical_crossentropy: 1.1118e-05 - lr: 1.2500e-04
# Epoch 93/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.1537e-05 - categorical_crossentropy: 1.1537e-05 - val_loss: 1.1094e-05 - val_categorical_crossentropy: 1.1094e-05 - lr: 1.2500e-04
# Epoch 94/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.1524e-05 - categorical_crossentropy: 1.1524e-05 - val_loss: 1.1082e-05 - val_categorical_crossentropy: 1.1082e-05 - lr: 1.0000e-04
# Epoch 95/500
# 4/4 [==============================] - 0s 98ms/step - loss: 1.1506e-05 - categorical_crossentropy: 1.1506e-05 - val_loss: 1.1071e-05 - val_categorical_crossentropy: 1.1071e-05 - lr: 1.0000e-04
# Epoch 96/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.1497e-05 - categorical_crossentropy: 1.1497e-05 - val_loss: 1.1055e-05 - val_categorical_crossentropy: 1.1055e-05 - lr: 1.0000e-04
# Epoch 97/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.1488e-05 - categorical_crossentropy: 1.1488e-05 - val_loss: 1.1043e-05 - val_categorical_crossentropy: 1.1043e-05 - lr: 1.0000e-04
# Epoch 98/500
# 4/4 [==============================] - 0s 132ms/step - loss: 1.1473e-05 - categorical_crossentropy: 1.1473e-05 - val_loss: 1.1027e-05 - val_categorical_crossentropy: 1.1027e-05 - lr: 1.0000e-04
# Epoch 99/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.1461e-05 - categorical_crossentropy: 1.1461e-05 - val_loss: 1.0991e-05 - val_categorical_crossentropy: 1.0991e-05 - lr: 1.0000e-04
# Epoch 100/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.1443e-05 - categorical_crossentropy: 1.1443e-05 - val_loss: 1.0987e-05 - val_categorical_crossentropy: 1.0987e-05 - lr: 1.0000e-04
# Epoch 101/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1.1428e-05 - categorical_crossentropy: 1.1428e-05 - val_loss: 1.0983e-05 - val_categorical_crossentropy: 1.0983e-05 - lr: 1.0000e-04
# Epoch 102/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.1418e-05 - categorical_crossentropy: 1.1418e-05 - val_loss: 1.0971e-05 - val_categorical_crossentropy: 1.0971e-05 - lr: 1.0000e-04
# Epoch 103/500
# 4/4 [==============================] - 0s 117ms/step - loss: 1.1403e-05 - categorical_crossentropy: 1.1403e-05 - val_loss: 1.0943e-05 - val_categorical_crossentropy: 1.0943e-05 - lr: 1.0000e-04
# Epoch 104/500
# 4/4 [==============================] - 1s 144ms/step - loss: 1.1393e-05 - categorical_crossentropy: 1.1393e-05 - val_loss: 1.0939e-05 - val_categorical_crossentropy: 1.0939e-05 - lr: 1.0000e-04
# Epoch 105/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.1376e-05 - categorical_crossentropy: 1.1376e-05 - val_loss: 1.0916e-05 - val_categorical_crossentropy: 1.0916e-05 - lr: 1.0000e-04
# Epoch 106/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.1365e-05 - categorical_crossentropy: 1.1365e-05 - val_loss: 1.0908e-05 - val_categorical_crossentropy: 1.0908e-05 - lr: 1.0000e-04
# Epoch 107/500
# 4/4 [==============================] - 0s 127ms/step - loss: 1.1354e-05 - categorical_crossentropy: 1.1354e-05 - val_loss: 1.0904e-05 - val_categorical_crossentropy: 1.0904e-05 - lr: 1.0000e-04
# Epoch 108/500
# 4/4 [==============================] - 0s 64ms/step - loss: 1.1342e-05 - categorical_crossentropy: 1.1342e-05 - val_loss: 1.0888e-05 - val_categorical_crossentropy: 1.0888e-05 - lr: 1.0000e-04
# Epoch 109/500
# 4/4 [==============================] - 0s 136ms/step - loss: 1.1328e-05 - categorical_crossentropy: 1.1328e-05 - val_loss: 1.0880e-05 - val_categorical_crossentropy: 1.0880e-05 - lr: 1.0000e-04
# Epoch 110/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.1316e-05 - categorical_crossentropy: 1.1316e-05 - val_loss: 1.0856e-05 - val_categorical_crossentropy: 1.0856e-05 - lr: 1.0000e-04
# Epoch 111/500
# 4/4 [==============================] - 0s 135ms/step - loss: 1.1301e-05 - categorical_crossentropy: 1.1301e-05 - val_loss: 1.0832e-05 - val_categorical_crossentropy: 1.0832e-05 - lr: 1.0000e-04
# Epoch 112/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.1288e-05 - categorical_crossentropy: 1.1288e-05 - val_loss: 1.0824e-05 - val_categorical_crossentropy: 1.0824e-05 - lr: 1.0000e-04
# Epoch 113/500
# 4/4 [==============================] - 0s 60ms/step - loss: 1.1278e-05 - categorical_crossentropy: 1.1278e-05 - val_loss: 1.0808e-05 - val_categorical_crossentropy: 1.0808e-05 - lr: 1.0000e-04
# Epoch 114/500
# 4/4 [==============================] - 0s 110ms/step - loss: 1.1263e-05 - categorical_crossentropy: 1.1263e-05 - val_loss: 1.0792e-05 - val_categorical_crossentropy: 1.0792e-05 - lr: 1.0000e-04
# Epoch 115/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.1247e-05 - categorical_crossentropy: 1.1247e-05 - val_loss: 1.0784e-05 - val_categorical_crossentropy: 1.0784e-05 - lr: 1.0000e-04
# Epoch 116/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.1232e-05 - categorical_crossentropy: 1.1232e-05 - val_loss: 1.0765e-05 - val_categorical_crossentropy: 1.0765e-05 - lr: 1.0000e-04
# Epoch 117/500
# 4/4 [==============================] - 0s 70ms/step - loss: 1.1212e-05 - categorical_crossentropy: 1.1212e-05 - val_loss: 1.0741e-05 - val_categorical_crossentropy: 1.0741e-05 - lr: 1.0000e-04
# Epoch 118/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.1199e-05 - categorical_crossentropy: 1.1199e-05 - val_loss: 1.0733e-05 - val_categorical_crossentropy: 1.0733e-05 - lr: 1.0000e-04
# Epoch 119/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.1191e-05 - categorical_crossentropy: 1.1191e-05 - val_loss: 1.0721e-05 - val_categorical_crossentropy: 1.0721e-05 - lr: 1.0000e-04
# Epoch 120/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1.1178e-05 - categorical_crossentropy: 1.1178e-05 - val_loss: 1.0713e-05 - val_categorical_crossentropy: 1.0713e-05 - lr: 1.0000e-04
# Epoch 121/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.1165e-05 - categorical_crossentropy: 1.1165e-05 - val_loss: 1.0701e-05 - val_categorical_crossentropy: 1.0701e-05 - lr: 1.0000e-04
# Epoch 122/500
# 4/4 [==============================] - 0s 98ms/step - loss: 1.1150e-05 - categorical_crossentropy: 1.1150e-05 - val_loss: 1.0681e-05 - val_categorical_crossentropy: 1.0681e-05 - lr: 1.0000e-04
# Epoch 123/500
# 4/4 [==============================] - 0s 73ms/step - loss: 1.1136e-05 - categorical_crossentropy: 1.1136e-05 - val_loss: 1.0657e-05 - val_categorical_crossentropy: 1.0657e-05 - lr: 1.0000e-04
# Epoch 124/500
# 4/4 [==============================] - 0s 114ms/step - loss: 1.1128e-05 - categorical_crossentropy: 1.1128e-05 - val_loss: 1.0653e-05 - val_categorical_crossentropy: 1.0653e-05 - lr: 1.0000e-04
# Epoch 125/500
# 4/4 [==============================] - 0s 75ms/step - loss: 1.1113e-05 - categorical_crossentropy: 1.1113e-05 - val_loss: 1.0641e-05 - val_categorical_crossentropy: 1.0641e-05 - lr: 1.0000e-04
# Epoch 126/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.1100e-05 - categorical_crossentropy: 1.1100e-05 - val_loss: 1.0618e-05 - val_categorical_crossentropy: 1.0618e-05 - lr: 1.0000e-04
# Epoch 127/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.1085e-05 - categorical_crossentropy: 1.1085e-05 - val_loss: 1.0602e-05 - val_categorical_crossentropy: 1.0602e-05 - lr: 1.0000e-04
# Epoch 128/500
# 4/4 [==============================] - 0s 87ms/step - loss: 1.1073e-05 - categorical_crossentropy: 1.1073e-05 - val_loss: 1.0578e-05 - val_categorical_crossentropy: 1.0578e-05 - lr: 1.0000e-04
# Epoch 129/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.1056e-05 - categorical_crossentropy: 1.1056e-05 - val_loss: 1.0570e-05 - val_categorical_crossentropy: 1.0570e-05 - lr: 1.0000e-04
# Epoch 130/500
# 4/4 [==============================] - 0s 112ms/step - loss: 1.1042e-05 - categorical_crossentropy: 1.1042e-05 - val_loss: 1.0558e-05 - val_categorical_crossentropy: 1.0558e-05 - lr: 1.0000e-04
# Epoch 131/500
# 4/4 [==============================] - 0s 50ms/step - loss: 1.1028e-05 - categorical_crossentropy: 1.1028e-05 - val_loss: 1.0558e-05 - val_categorical_crossentropy: 1.0558e-05 - lr: 1.0000e-04
# Epoch 132/500
# 4/4 [==============================] - 0s 85ms/step - loss: 1.1008e-05 - categorical_crossentropy: 1.1008e-05 - val_loss: 1.0526e-05 - val_categorical_crossentropy: 1.0526e-05 - lr: 1.0000e-04
# Epoch 133/500
# 4/4 [==============================] - 0s 60ms/step - loss: 1.0997e-05 - categorical_crossentropy: 1.0997e-05 - val_loss: 1.0522e-05 - val_categorical_crossentropy: 1.0522e-05 - lr: 1.0000e-04
# Epoch 134/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.0983e-05 - categorical_crossentropy: 1.0983e-05 - val_loss: 1.0498e-05 - val_categorical_crossentropy: 1.0498e-05 - lr: 1.0000e-04
# Epoch 135/500
# 4/4 [==============================] - 0s 67ms/step - loss: 1.0969e-05 - categorical_crossentropy: 1.0969e-05 - val_loss: 1.0486e-05 - val_categorical_crossentropy: 1.0486e-05 - lr: 1.0000e-04
# Epoch 136/500
# 4/4 [==============================] - 0s 135ms/step - loss: 1.0952e-05 - categorical_crossentropy: 1.0952e-05 - val_loss: 1.0482e-05 - val_categorical_crossentropy: 1.0482e-05 - lr: 1.0000e-04
# Epoch 137/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.0945e-05 - categorical_crossentropy: 1.0945e-05 - val_loss: 1.0459e-05 - val_categorical_crossentropy: 1.0459e-05 - lr: 1.0000e-04
# Epoch 138/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.0933e-05 - categorical_crossentropy: 1.0933e-05 - val_loss: 1.0451e-05 - val_categorical_crossentropy: 1.0451e-05 - lr: 1.0000e-04
# Epoch 139/500
# 4/4 [==============================] - 0s 99ms/step - loss: 1.0921e-05 - categorical_crossentropy: 1.0921e-05 - val_loss: 1.0427e-05 - val_categorical_crossentropy: 1.0427e-05 - lr: 1.0000e-04
# Epoch 140/500
# 4/4 [==============================] - 0s 114ms/step - loss: 1.0902e-05 - categorical_crossentropy: 1.0902e-05 - val_loss: 1.0411e-05 - val_categorical_crossentropy: 1.0411e-05 - lr: 1.0000e-04
# Epoch 141/500
# 4/4 [==============================] - 0s 136ms/step - loss: 1.0890e-05 - categorical_crossentropy: 1.0890e-05 - val_loss: 1.0391e-05 - val_categorical_crossentropy: 1.0391e-05 - lr: 1.0000e-04
# Epoch 142/500
# 4/4 [==============================] - 0s 117ms/step - loss: 1.0876e-05 - categorical_crossentropy: 1.0876e-05 - val_loss: 1.0375e-05 - val_categorical_crossentropy: 1.0375e-05 - lr: 1.0000e-04
# Epoch 143/500
# 4/4 [==============================] - 0s 121ms/step - loss: 1.0859e-05 - categorical_crossentropy: 1.0859e-05 - val_loss: 1.0371e-05 - val_categorical_crossentropy: 1.0371e-05 - lr: 1.0000e-04
# Epoch 144/500
# 4/4 [==============================] - 0s 96ms/step - loss: 1.0847e-05 - categorical_crossentropy: 1.0847e-05 - val_loss: 1.0363e-05 - val_categorical_crossentropy: 1.0363e-05 - lr: 1.0000e-04
# Epoch 145/500
# 4/4 [==============================] - 0s 124ms/step - loss: 1.0829e-05 - categorical_crossentropy: 1.0829e-05 - val_loss: 1.0343e-05 - val_categorical_crossentropy: 1.0343e-05 - lr: 1.0000e-04
# Epoch 146/500
# 4/4 [==============================] - 0s 99ms/step - loss: 1.0816e-05 - categorical_crossentropy: 1.0816e-05 - val_loss: 1.0331e-05 - val_categorical_crossentropy: 1.0331e-05 - lr: 1.0000e-04
# Epoch 147/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0802e-05 - categorical_crossentropy: 1.0802e-05 - val_loss: 1.0308e-05 - val_categorical_crossentropy: 1.0308e-05 - lr: 1.0000e-04
# Epoch 148/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.0785e-05 - categorical_crossentropy: 1.0785e-05 - val_loss: 1.0296e-05 - val_categorical_crossentropy: 1.0296e-05 - lr: 1.0000e-04
# Epoch 149/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.0775e-05 - categorical_crossentropy: 1.0775e-05 - val_loss: 1.0276e-05 - val_categorical_crossentropy: 1.0276e-05 - lr: 1.0000e-04
# Epoch 150/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.0759e-05 - categorical_crossentropy: 1.0759e-05 - val_loss: 1.0268e-05 - val_categorical_crossentropy: 1.0268e-05 - lr: 1.0000e-04
# Epoch 151/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.0749e-05 - categorical_crossentropy: 1.0749e-05 - val_loss: 1.0248e-05 - val_categorical_crossentropy: 1.0248e-05 - lr: 1.0000e-04
# Epoch 152/500
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0736e-05 - categorical_crossentropy: 1.0736e-05 - val_loss: 1.0232e-05 - val_categorical_crossentropy: 1.0232e-05 - lr: 1.0000e-04
# Epoch 153/500
# 4/4 [==============================] - 0s 75ms/step - loss: 1.0720e-05 - categorical_crossentropy: 1.0720e-05 - val_loss: 1.0212e-05 - val_categorical_crossentropy: 1.0212e-05 - lr: 1.0000e-04
# Epoch 154/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.0707e-05 - categorical_crossentropy: 1.0707e-05 - val_loss: 1.0204e-05 - val_categorical_crossentropy: 1.0204e-05 - lr: 1.0000e-04
# Epoch 155/500
# 4/4 [==============================] - 0s 96ms/step - loss: 1.0691e-05 - categorical_crossentropy: 1.0691e-05 - val_loss: 1.0192e-05 - val_categorical_crossentropy: 1.0192e-05 - lr: 1.0000e-04
# Epoch 156/500
# 4/4 [==============================] - 0s 110ms/step - loss: 1.0676e-05 - categorical_crossentropy: 1.0676e-05 - val_loss: 1.0184e-05 - val_categorical_crossentropy: 1.0184e-05 - lr: 1.0000e-04
# Epoch 157/500
# 4/4 [==============================] - 0s 71ms/step - loss: 1.0666e-05 - categorical_crossentropy: 1.0666e-05 - val_loss: 1.0157e-05 - val_categorical_crossentropy: 1.0157e-05 - lr: 1.0000e-04
# Epoch 158/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.0654e-05 - categorical_crossentropy: 1.0654e-05 - val_loss: 1.0141e-05 - val_categorical_crossentropy: 1.0141e-05 - lr: 1.0000e-04
# Epoch 159/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.0627e-05 - categorical_crossentropy: 1.0627e-05 - val_loss: 1.0129e-05 - val_categorical_crossentropy: 1.0129e-05 - lr: 1.0000e-04
# Epoch 160/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.0615e-05 - categorical_crossentropy: 1.0615e-05 - val_loss: 1.0109e-05 - val_categorical_crossentropy: 1.0109e-05 - lr: 1.0000e-04
# Epoch 161/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.0599e-05 - categorical_crossentropy: 1.0599e-05 - val_loss: 1.0097e-05 - val_categorical_crossentropy: 1.0097e-05 - lr: 1.0000e-04
# Epoch 162/500
# 4/4 [==============================] - 0s 153ms/step - loss: 1.0585e-05 - categorical_crossentropy: 1.0585e-05 - val_loss: 1.0089e-05 - val_categorical_crossentropy: 1.0089e-05 - lr: 1.0000e-04
# Epoch 163/500
# 4/4 [==============================] - 0s 125ms/step - loss: 1.0578e-05 - categorical_crossentropy: 1.0578e-05 - val_loss: 1.0065e-05 - val_categorical_crossentropy: 1.0065e-05 - lr: 1.0000e-04
# Epoch 164/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.0570e-05 - categorical_crossentropy: 1.0570e-05 - val_loss: 1.0053e-05 - val_categorical_crossentropy: 1.0053e-05 - lr: 1.0000e-04
# Epoch 165/500
# 4/4 [==============================] - 0s 135ms/step - loss: 1.0546e-05 - categorical_crossentropy: 1.0546e-05 - val_loss: 1.0041e-05 - val_categorical_crossentropy: 1.0041e-05 - lr: 1.0000e-04
# Epoch 166/500
# 4/4 [==============================] - 0s 130ms/step - loss: 1.0529e-05 - categorical_crossentropy: 1.0529e-05 - val_loss: 1.0021e-05 - val_categorical_crossentropy: 1.0021e-05 - lr: 1.0000e-04
# Epoch 167/500
# 4/4 [==============================] - 0s 68ms/step - loss: 1.0517e-05 - categorical_crossentropy: 1.0517e-05 - val_loss: 1.0010e-05 - val_categorical_crossentropy: 1.0010e-05 - lr: 1.0000e-04
# Epoch 168/500
# 4/4 [==============================] - 0s 53ms/step - loss: 1.0505e-05 - categorical_crossentropy: 1.0505e-05 - val_loss: 1.0006e-05 - val_categorical_crossentropy: 1.0006e-05 - lr: 1.0000e-04
# Epoch 169/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.0494e-05 - categorical_crossentropy: 1.0494e-05 - val_loss: 9.9817e-06 - val_categorical_crossentropy: 9.9817e-06 - lr: 1.0000e-04
# Epoch 170/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.0480e-05 - categorical_crossentropy: 1.0480e-05 - val_loss: 9.9658e-06 - val_categorical_crossentropy: 9.9658e-06 - lr: 1.0000e-04
# Epoch 171/500
# 4/4 [==============================] - 0s 107ms/step - loss: 1.0466e-05 - categorical_crossentropy: 1.0466e-05 - val_loss: 9.9460e-06 - val_categorical_crossentropy: 9.9460e-06 - lr: 1.0000e-04
# Epoch 172/500
# 4/4 [==============================] - 0s 85ms/step - loss: 1.0440e-05 - categorical_crossentropy: 1.0440e-05 - val_loss: 9.9221e-06 - val_categorical_crossentropy: 9.9221e-06 - lr: 1.0000e-04
# Epoch 173/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0427e-05 - categorical_crossentropy: 1.0427e-05 - val_loss: 9.9102e-06 - val_categorical_crossentropy: 9.9102e-06 - lr: 1.0000e-04
# Epoch 174/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.0417e-05 - categorical_crossentropy: 1.0417e-05 - val_loss: 9.8983e-06 - val_categorical_crossentropy: 9.8983e-06 - lr: 1.0000e-04
# Epoch 175/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.0404e-05 - categorical_crossentropy: 1.0404e-05 - val_loss: 9.8903e-06 - val_categorical_crossentropy: 9.8903e-06 - lr: 1.0000e-04
# Epoch 176/500
# 4/4 [==============================] - 0s 55ms/step - loss: 1.0393e-05 - categorical_crossentropy: 1.0393e-05 - val_loss: 9.8784e-06 - val_categorical_crossentropy: 9.8784e-06 - lr: 1.0000e-04
# Epoch 177/500
# 4/4 [==============================] - 0s 70ms/step - loss: 1.0378e-05 - categorical_crossentropy: 1.0378e-05 - val_loss: 9.8705e-06 - val_categorical_crossentropy: 9.8705e-06 - lr: 1.0000e-04
# Epoch 178/500
# 4/4 [==============================] - 0s 85ms/step - loss: 1.0363e-05 - categorical_crossentropy: 1.0363e-05 - val_loss: 9.8466e-06 - val_categorical_crossentropy: 9.8466e-06 - lr: 1.0000e-04
# Epoch 179/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.0342e-05 - categorical_crossentropy: 1.0342e-05 - val_loss: 9.8228e-06 - val_categorical_crossentropy: 9.8228e-06 - lr: 1.0000e-04
# Epoch 180/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.
# Epoch 193/500
# 4/4 [==============================] - 0s 109ms/step - loss: 1.0143e-05 - categorical_crossentropy: 1.0143e-05 - val_loss: 9.6003e-06 - val_categorical_crossentropy: 9.6003e-06 - lr: 1.0000e-04
# Epoch 194/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.0128e-05 - categorical_crossentropy: 1.0128e-05 - val_loss: 9.5963e-06 - val_categorical_crossentropy: 9.5963e-06 - lr: 1.0000e-04
# Epoch 195/500
# 4/4 [==============================] - 0s 61ms/step - loss: 1.0113e-05 - categorical_crossentropy: 1.0113e-05 - val_loss: 9.5804e-06 - val_categorical_crossentropy: 9.5804e-06 - lr: 1.0000e-04
# Epoch 196/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.0101e-05 - categorical_crossentropy: 1.0101e-05 - val_loss: 9.5605e-06 - val_categorical_crossentropy: 9.5605e-06 - lr: 1.0000e-04
# Epoch 197/500
# 4/4 [==============================] - 0s 58ms/step - loss: 1.0090e-05 - categorical_crossentropy: 1.0090e-05 - val_loss: 9.5605e-06 - val_categorical_crossentropy: 9.5605e-06 - lr: 1.0000e-04
# Epoch 198/500
# 4/4 [==============================] - 0s 53ms/step - loss: 1.0071e-05 - categorical_crossentropy: 1.0071e-05 - val_loss: 9.5566e-06 - val_categorical_crossentropy: 9.5566e-06 - lr: 1.0000e-04
# Epoch 199/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.0059e-05 - categorical_crossentropy: 1.0059e-05 - val_loss: 9.5367e-06 - val_categorical_crossentropy: 9.5367e-06 - lr: 1.0000e-04
# Epoch 200/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.0045e-05 - categorical_crossentropy: 1.0045e-05 - val_loss: 9.5208e-06 - val_categorical_crossentropy: 9.5208e-06 - lr: 1.0000e-04
# Epoch 201/500
# 4/4 [==============================] - 0s 111ms/step - loss: 1.0025e-05 - categorical_crossentropy: 1.0025e-05 - val_loss: 9.5009e-06 - val_categorical_crossentropy: 9.5009e-06 - lr: 1.0000e-04
# Epoch 202/500
# 4/4 [==============================] - 0s 127ms/step - loss: 1.0011e-05 - categorical_crossentropy: 1.0011e-05 - val_loss: 9.4771e-06 - val_categorical_crossentropy: 9.4771e-06 - lr: 1.0000e-04
# Epoch 203/500
# 4/4 [==============================] - 0s 102ms/step - loss: 9.9996e-06 - categorical_crossentropy: 9.9996e-06 - val_loss: 9.4572e-06 - val_categorical_crossentropy: 9.4572e-06 - lr: 1.0000e-04
# Epoch 204/500
# 4/4 [==============================] - 0s 103ms/step - loss: 9.9817e-06 - categorical_crossentropy: 9.9817e-06 - val_loss: 9.4532e-06 - val_categorical_crossentropy: 9.4532e-06 - lr: 1.0000e-04
# Epoch 205/500
# 4/4 [==============================] - 0s 96ms/step - loss: 9.9718e-06 - categorical_crossentropy: 9.9718e-06 - val_loss: 9.4453e-06 - val_categorical_crossentropy: 9.4453e-06 - lr: 1.0000e-04
# Epoch 206/500
# 4/4 [==============================] - 0s 82ms/step - loss: 9.9569e-06 - categorical_crossentropy: 9.9569e-06 - val_loss: 9.4215e-06 - val_categorical_crossentropy: 9.4215e-06 - lr: 1.0000e-04
# 4/4 [==============================] - 0s 108ms/step - loss: 6.5535e-06 - categorical_crossentropy: 6.5535e-06 - val_loss: 6.0916e-06 - val_categorical_crossentropy: 6.0916e-06 - lr: 1.0000e-04
# Epoch 465/500
# 4/4 [==============================] - 1s 136ms/step - loss: 6.5466e-06 - categorical_crossentropy: 6.5466e-06 - val_loss: 6.0717e-06 - val_categorical_crossentropy: 6.0717e-06 - lr: 1.0000e-04
# Epoch 466/500
# 4/4 [==============================] - 0s 131ms/step - loss: 6.5416e-06 - categorical_crossentropy: 6.5416e-06 - val_loss: 6.0638e-06 - val_categorical_crossentropy: 6.0638e-06 - lr: 1.0000e-04
# Epoch 467/500
# 4/4 [==============================] - 0s 93ms/step - loss: 6.5317e-06 - categorical_crossentropy: 6.5317e-06 - val_loss: 6.0479e-06 - val_categorical_crossentropy: 6.0479e-06 - lr: 1.0000e-04
# Epoch 468/500
# 4/4 [==============================] - 0s 127ms/step - loss: 6.5197e-06 - categorical_crossentropy: 6.5197e-06 - val_loss: 6.0399e-06 - val_categorical_crossentropy: 6.0399e-06 - lr: 1.0000e-04
# Epoch 469/500
# 4/4 [==============================] - 1s 119ms/step - loss: 6.5078e-06 - categorical_crossentropy: 6.5078e-06 - val_loss: 6.0280e-06 - val_categorical_crossentropy: 6.0280e-06 - lr: 1.0000e-04
# Epoch 470/500
# 4/4 [==============================] - 0s 92ms/step - loss: 6.4919e-06 - categorical_crossentropy: 6.4919e-06 - val_loss: 6.0200e-06 - val_categorical_crossentropy: 6.0200e-06 - lr: 1.0000e-04
# Epoch 471/500
# 4/4 [==============================] - 0s 128ms/step - loss: 6.4770e-06 - categorical_crossentropy: 6.4770e-06 - val_loss: 6.0121e-06 - val_categorical_crossentropy: 6.0121e-06 - lr: 1.0000e-04
# Epoch 472/500
# 4/4 [==============================] - 0s 111ms/step - loss: 6.4701e-06 - categorical_crossentropy: 6.4701e-06 - val_loss: 5.9962e-06 - val_categorical_crossentropy: 5.9962e-06 - lr: 1.0000e-04
# Epoch 473/500
# 4/4 [==============================] - 0s 115ms/step - loss: 6.4581e-06 - categorical_crossentropy: 6.4581e-06 - val_loss: 5.9843e-06 - val_categorical_crossentropy: 5.9843e-06 - lr: 1.0000e-04
# Epoch 474/500
# 4/4 [==============================] - 0s 86ms/step - loss: 6.4492e-06 - categorical_crossentropy: 6.4492e-06 - val_loss: 5.9684e-06 - val_categorical_crossentropy: 5.9684e-06 - lr: 1.0000e-04
# Epoch 475/500
# 4/4 [==============================] - 0s 73ms/step - loss: 6.4363e-06 - categorical_crossentropy: 6.4363e-06 - val_loss: 5.9644e-06 - val_categorical_crossentropy: 5.9644e-06 - lr: 1.0000e-04
# Epoch 476/500
# 4/4 [==============================] - 0s 71ms/step - loss: 6.4263e-06 - categorical_crossentropy: 6.4263e-06 - val_loss: 5.9525e-06 - val_categorical_crossentropy: 5.9525e-06 - lr: 1.0000e-04
# Epoch 477/500
# 4/4 [==============================] - 0s 96ms/step - loss: 6.4114e-06 - categorical_crossentropy: 6.4114e-06 - val_loss: 5.9406e-06 - val_categorical_crossentropy: 5.9406e-06 - lr: 1.0000e-04
# Epoch 478/500
# 4/4 [==============================] - 0s 114ms/step - loss: 6.3965e-06 - categorical_crossentropy: 6.3965e-06 - val_loss: 5.9366e-06 - val_categorical_crossentropy: 5.9366e-06 - lr: 1.0000e-04
# Epoch 479/500
# 4/4 [==============================] - 0s 103ms/step - loss: 6.3846e-06 - categorical_crossentropy: 6.3846e-06 - val_loss: 5.9287e-06 - val_categorical_crossentropy: 5.9287e-06 - lr: 1.0000e-04
# Epoch 480/500
# 4/4 [==============================] - 0s 66ms/step - loss: 6.3787e-06 - categorical_crossentropy: 6.3787e-06 - val_loss: 5.9128e-06 - val_categorical_crossentropy: 5.9128e-06 - lr: 1.0000e-04
# Epoch 481/500
# 4/4 [==============================] - 0s 71ms/step - loss: 6.3697e-06 - categorical_crossentropy: 6.3697e-06 - val_loss: 5.8969e-06 - val_categorical_crossentropy: 5.8969e-06 - lr: 1.0000e-04
# Epoch 482/500
# 4/4 [==============================] - 0s 66ms/step - loss: 6.3528e-06 - categorical_crossentropy: 6.3528e-06 - val_loss: 5.8810e-06 - val_categorical_crossentropy: 5.8810e-06 - lr: 1.0000e-04
# Epoch 483/500
# 4/4 [==============================] - 0s 75ms/step - loss: 6.3429e-06 - categorical_crossentropy: 6.3429e-06 - val_loss: 5.8730e-06 - val_categorical_crossentropy: 5.8730e-06 - lr: 1.0000e-04
# Epoch 484/500
# 4/4 [==============================] - 0s 51ms/step - loss: 6.3369e-06 - categorical_crossentropy: 6.3369e-06 - val_loss: 5.8730e-06 - val_categorical_crossentropy: 5.8730e-06 - lr: 1.0000e-04
# Epoch 485/500
# 4/4 [==============================] - 0s 67ms/step - loss: 6.3201e-06 - categorical_crossentropy: 6.3201e-06 - val_loss: 5.8532e-06 - val_categorical_crossentropy: 5.8532e-06 - lr: 1.0000e-04
# Epoch 486/500
# 4/4 [==============================] - 0s 50ms/step - loss: 6.3091e-06 - categorical_crossentropy: 6.3091e-06 - val_loss: 5.8412e-06 - val_categorical_crossentropy: 5.8412e-06 - lr: 1.0000e-04
# Epoch 487/500
# 4/4 [==============================] - 0s 92ms/step - loss: 6.2992e-06 - categorical_crossentropy: 6.2992e-06 - val_loss: 5.8293e-06 - val_categorical_crossentropy: 5.8293e-06 - lr: 1.0000e-04
# Epoch 488/500
# 4/4 [==============================] - 0s 99ms/step - loss: 6.2853e-06 - categorical_crossentropy: 6.2853e-06 - val_loss: 5.8214e-06 - val_categorical_crossentropy: 5.8214e-06 - lr: 1.0000e-04
# Epoch 489/500
# 4/4 [==============================] - 0s 70ms/step - loss: 6.2803e-06 - categorical_crossentropy: 6.2803e-06 - val_loss: 5.8134e-06 - val_categorical_crossentropy: 5.8134e-06 - lr: 1.0000e-04
# Epoch 490/500
# 4/4 [==============================] - 0s 72ms/step - loss: 6.2684e-06 - categorical_crossentropy: 6.2684e-06 - val_loss: 5.7975e-06 - val_categorical_crossentropy: 5.7975e-06 - lr: 1.0000e-04
# Epoch 491/500
# 4/4 [==============================] - 0s 66ms/step - loss: 6.2575e-06 - categorical_crossentropy: 6.2575e-06 - val_loss: 5.7896e-06 - val_categorical_crossentropy: 5.7896e-06 - lr: 1.0000e-04
# Epoch 492/500
# 4/4 [==============================] - 0s 55ms/step - loss: 6.2475e-06 - categorical_crossentropy: 6.2475e-06 - val_loss: 5.7896e-06 - val_categorical_crossentropy: 5.7896e-06 - lr: 1.0000e-04
# Epoch 493/500
# 4/4 [==============================] - 0s 112ms/step - loss: 6.2297e-06 - categorical_crossentropy: 6.2297e-06 - val_loss: 5.7777e-06 - val_categorical_crossentropy: 5.7777e-06 - lr: 1.0000e-04
# Epoch 494/500
# 4/4 [==============================] - 0s 103ms/step - loss: 6.2157e-06 - categorical_crossentropy: 6.2157e-06 - val_loss: 5.7697e-06 - val_categorical_crossentropy: 5.7697e-06 - lr: 1.0000e-04
# Epoch 495/500
# 4/4 [==============================] - 0s 87ms/step - loss: 6.2058e-06 - categorical_crossentropy: 6.2058e-06 - val_loss: 5.7459e-06 - val_categorical_crossentropy: 5.7459e-06 - lr: 1.0000e-04
# Epoch 496/500
# 4/4 [==============================] - 0s 75ms/step - loss: 6.1969e-06 - categorical_crossentropy: 6.1969e-06 - val_loss: 5.7379e-06 - val_categorical_crossentropy: 5.7379e-06 - lr: 1.0000e-04
# Epoch 497/500
# 4/4 [==============================] - 0s 82ms/step - loss: 6.1820e-06 - categorical_crossentropy: 6.1820e-06 - val_loss: 5.7300e-06 - val_categorical_crossentropy: 5.7300e-06 - lr: 1.0000e-04
# Epoch 498/500
# 4/4 [==============================] - 0s 99ms/step - loss: 6.1770e-06 - categorical_crossentropy: 6.1770e-06 - val_loss: 5.7141e-06 - val_categorical_crossentropy: 5.7141e-06 - lr: 1.0000e-04
# Epoch 499/500
# 4/4 [==============================] - 0s 58ms/step - loss: 6.1651e-06 - categorical_crossentropy: 6.1651e-06 - val_loss: 5.6982e-06 - val_categorical_crossentropy: 5.6982e-06 - lr: 1.0000e-04
# Epoch 500/500
# 4/4 [==============================] - 0s 102ms/step - loss: 6.1522e-06 - categorical_crossentropy: 6.1522e-06 - val_loss: 5.6942e-06 - val_categorical_crossentropy: 5.6942e-06 - lr: 1.0000e-04

# %%
class ModelWrapper():
    def __init__(self,model):
        self.model=model
    def predict_proba(self,X):
        if isinstance(X, pd.DataFrame):
            X=X.values
        Xnn=X.reshape(X.shape[0],1,X.shape[1])
        return self.model.predict(Xnn)
    def predict(self, X):
        return np.argmax(self.predict_proba(X),axis=1)
clf=ModelWrapper(model)

# %% [markdown]
# ## SHAP
# We calculate SHAP for datasets

# %%
fXtrain = trainX.reshape(150,1,200)

# %%
from tsproto.utils import getshap

shap_version='deep'
bg_size = 1000
stride=10
window_len=10
absshap = True
fXtrain,sv_tr = getshap(model=model, X=fXtrain, y=train_ynn,shap_version=shap_version,bg_size = bg_size, stride=stride, window_len=window_len, absshap = absshap, shuffle=False)
# Out:
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [markdown]
# ## Visualize SHAP
# In this section we can see that the network focused on correct parts of the time-series.
# In this toy example, it is sufficient to look at SHAP-visualizations to spot the difference, but in case of hundreds of dimensions and more complex problems, prototypes are more useful.

# %%
from  tsproto.plots import plot_smooth_colored_line
indexer = clf.predict(trainX)
shapclass = []
if absshap == False:
    for i in range(0,len(trainX)):
        best_index = indexer[i]
        shapclass.append([sv_tr[best_index][i,:]])
        
    shapclass=np.concatenate(shapclass)
else:
    shapclass  = sv_tr[:,0,:]

    fig, axes =plt.subplots(2,1,figsize=(12,6))

    for i in range(0,10):
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==0][i], color_values=shapclass[train_y==0][i], resolution=1000, ax=axes[0],add_cbar=(i==0))
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==1][i], color_values=shapclass[train_y==1][i], resolution=1000, ax=axes[1],add_cbar=(i==0))

for ax in axes:
    ax.set_ylim([-2, 2])
# Out:
# 5/5 [==============================] - 0s 15ms/step

# %% [markdown]
# ## Tsproto
# Now, lets try to apply TSProto to see if it is able to find the prototype and summarize them correctly to show what logical relation is between them and the model prediction

# %%
trainXproto = trainX.reshape((trainX.shape[0], trainX.shape[1],1))
shapclassXproto = shapclass.reshape((shapclass.shape[0], shapclass.shape[1],1))

# %%
from tsproto.models import *
im  = InterpretableModel()
pe = PrototypeEncoder(clf, n_clusters=4, min_size=50, method='dtw',
                              descriptors=['existance','duration','frequency'],
                      jump=1, pen=1,multiplier=1,n_jobs=-1,
                      verbose=1)
ohe_train, features, target_ohe,weights = pe.fit_transform(trainXproto,shapclassXproto)
acc,prec,rec,f1,iclf = im.fit_or_predict(ohe_train, features, target_ohe,intclf=None, verbose=0, max_depth=2, min_samples_leaf=0.05,
                       weights=None)
# Out:
# Dataset shape: (150, 200, 1)
# Calculating changepoints...
# Dim: 0
# 2
# 2
# 2
# 2
# Before filtering no sigids: 150, uniqu 0
# Unique indexes: 150 vs max+1: 150
# After removing , no sigids: 150, uniqu 0
# Done in 1.0482308864593506.
# Clustering data
# (238, 114, 1)
# (238, 114, 1)
# Shape of data for clustering: (238, 114, 1)
# Clustering data
# X_bis shape: (238, 114, 1) for method=dtw
# Done in 6.379816770553589.
# OHE time series
# Shape weights: (150,)
# Len X=150 vs len of train = 150
# 5/5 [==============================] - 0s 17ms/step
# Done in 0.18567752838134766.

# %% [markdown]
# ## Visualize interpretable model
# We can easily see that the TSProto has found the sine wave at the beginning of the sample, marked it as prototype and correctly identified that its existence is not enough to treat the sample as a class 1 sample, additional frequency context has to be added in order to distinguish these two

# %%
from  tsproto.plots import *
ds_final = ohe_train.copy()
dot = export_decision_tree_with_embedded_histograms(decision_tree=iclf, 
                                              dataset=ds_final, 
                                              target_name='target', 
                                              feature_names=features, 
                                              filename='synthetic', 
                                              proto_encoder=pe, figsize=(6,3))

from IPython.display import SVG, Image
Image('synthetic.png')
# Out:
# [2 0]
# Shapes: (238, 114, 1) vs shap: (2, 114, 1) TODO: take IDS of a single sample that is plotted
# color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Decision Tree exported to synthetic with embedded histograms successfully.
