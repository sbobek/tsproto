# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2024-05-09 16:12:59.466712: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn import tree
from graphviz import Source
from IPython.display import display
from IPython.display import SVG

# %% [markdown]
# ## Creating synthetic dataset
# We will create a synthetic dataset with two classes. The dataset will be hard to distinguish based on statistical features, but possible with proper prototypical parts extracted.
#
# We are making it even harder, as the prototypical parts are more or less the same. They are differing in terms of frequency.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(3*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X3 = np.concatenate((x1,x2))
Y3 = np.concatenate((y1,y2))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to π/2
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(2*np.pi, 4*np.pi, 100)

# Calculate y values for the sinusoidal function
y1 = np.sin(2*x1)
y2 = np.sin(x2)

# Plotting the sinusoidal function
plt.plot(x1, y1, label='sin(x)')
plt.plot(x2, y2, label='sin(x)')
plt.title('Sinusoidal Function from 0 to π/2')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.show()

# %%
X4 = np.concatenate((x1,x2))
Y4 = np.concatenate((y1,y2))

# %% [markdown]
# ## Generating sample cases

# %%
x = X3
proto_sin_y = Y3
proto_inversed_sin_y = Y4

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,proto_sin_y)
axes[1].plot(x,proto_inversed_sin_y)

# %% [markdown]
# ## Generating noise and augmenting signals

# %%
noise_power = .2

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_sin_y = noise + proto_sin_y

# %%
noise = (np.random.rand(100,len(x))-0.5)*noise_power
noisy_proto_inversed_sin_y = noise + proto_inversed_sin_y

# %%
fig, axes =plt.subplots(2,1,figsize=(12,6))
axes[0].plot(x,noisy_proto_sin_y[0])
axes[1].plot(x,noisy_proto_inversed_sin_y[0])
for ax in axes:
    ax.set_ylim([-2, 2])

# %%
X=np.concatenate((noisy_proto_sin_y,noisy_proto_inversed_sin_y))
Xy=np.concatenate((np.ones(len(noisy_proto_sin_y))*0,
                   np.ones(len(noisy_proto_inversed_sin_y))*1))

trainX, testX, train_y,test_y = train_test_split(X,Xy)

# %% [markdown]
# ## Model
# We will build simple DNN model (not really needed in this case, but it serves the purpose of demonstration how to deal with more complex cases)

# %%
trainX.shape
# Out:
# (150, 200)

# %%
from keras.utils import to_categorical
trainXnn = trainX.reshape(150,1,200)
train_ynn = to_categorical(train_y)
num_classes = len(np.unique(Xy))

# %%
import keras
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    #add dropout
    input_layer = keras.layers.Dropout(0.5)(input_layer)
    conv1 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(input_layer)
    #conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv1)
    #conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=20, padding="same")(conv2)
    #conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)



model = make_model(input_shape=trainXnn.shape[1:])
# Out:
# 2024-05-09 16:13:03.409695: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_crossentropy"],
)
history = model.fit(
    trainXnn,
    train_ynn,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 2s 202ms/step - loss: 0.6882 - categorical_crossentropy: 0.6882 - val_loss: 0.6686 - val_categorical_crossentropy: 0.6686 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 116ms/step - loss: 0.6560 - categorical_crossentropy: 0.6560 - val_loss: 0.6125 - val_categorical_crossentropy: 0.6125 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 97ms/step - loss: 0.5915 - categorical_crossentropy: 0.5915 - val_loss: 0.5127 - val_categorical_crossentropy: 0.5127 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4856 - categorical_crossentropy: 0.4856 - val_loss: 0.3739 - val_categorical_crossentropy: 0.3739 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 130ms/step - loss: 0.3474 - categorical_crossentropy: 0.3474 - val_loss: 0.2311 - val_categorical_crossentropy: 0.2311 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 81ms/step - loss: 0.2120 - categorical_crossentropy: 0.2120 - val_loss: 0.1198 - val_categorical_crossentropy: 0.1198 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 82ms/step - loss: 0.1056 - categorical_crossentropy: 0.1056 - val_loss: 0.0470 - val_categorical_crossentropy: 0.0470 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 0s 125ms/step - loss: 0.0378 - categorical_crossentropy: 0.0378 - val_loss: 0.0138 - val_categorical_crossentropy: 0.0138 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0109 - categorical_crossentropy: 0.0109 - val_loss: 0.0039 - val_categorical_crossentropy: 0.0039 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0030 - categorical_crossentropy: 0.0030 - val_loss: 0.0014 - val_categorical_crossentropy: 0.0014 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0011 - categorical_crossentropy: 0.0011 - val_loss: 6.4525e-04 - val_categorical_crossentropy: 6.4525e-04 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 102ms/step - loss: 5.4021e-04 - categorical_crossentropy: 5.4021e-04 - val_loss: 3.7533e-04 - val_categorical_crossentropy: 3.7533e-04 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 0s 100ms/step - loss: 3.1946e-04 - categorical_crossentropy: 3.1946e-04 - val_loss: 2.4900e-04 - val_categorical_crossentropy: 2.4900e-04 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 107ms/step - loss: 2.1668e-04 - categorical_crossentropy: 2.1668e-04 - val_loss: 1.8117e-04 - val_categorical_crossentropy: 1.8117e-04 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 107ms/step - loss: 1.6092e-04 - categorical_crossentropy: 1.6092e-04 - val_loss: 1.4126e-04 - val_categorical_crossentropy: 1.4126e-04 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.2817e-04 - categorical_crossentropy: 1.2817e-04 - val_loss: 1.1635e-04 - val_categorical_crossentropy: 1.1635e-04 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 109ms/step - loss: 1.0779e-04 - categorical_crossentropy: 1.0779e-04 - val_loss: 9.9952e-05 - val_categorical_crossentropy: 9.9952e-05 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 85ms/step - loss: 9.4171e-05 - categorical_crossentropy: 9.4171e-05 - val_loss: 8.8751e-05 - val_categorical_crossentropy: 8.8751e-05 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 58ms/step - loss: 8.4677e-05 - categorical_crossentropy: 8.4677e-05 - val_loss: 8.0824e-05 - val_categorical_crossentropy: 8.0824e-05 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 69ms/step - loss: 7.8028e-05 - categorical_crossentropy: 7.8028e-05 - val_loss: 7.4992e-05 - val_categorical_crossentropy: 7.4992e-05 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 80ms/step - loss: 7.3199e-05 - categorical_crossentropy: 7.3199e-05 - val_loss: 7.0470e-05 - val_categorical_crossentropy: 7.0470e-05 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 84ms/step - loss: 6.9327e-05 - categorical_crossentropy: 6.9327e-05 - val_loss: 6.6946e-05 - val_categorical_crossentropy: 6.6946e-05 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 75ms/step - loss: 6.6338e-05 - categorical_crossentropy: 6.6338e-05 - val_loss: 6.4025e-05 - val_categorical_crossentropy: 6.4025e-05 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 52ms/step - loss: 6.3761e-05 - categorical_crossentropy: 6.3761e-05 - val_loss: 6.1586e-05 - val_categorical_crossentropy: 6.1586e-05 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 0s 72ms/step - loss: 6.1606e-05 - categorical_crossentropy: 6.1606e-05 - val_loss: 5.9480e-05 - val_categorical_crossentropy: 5.9480e-05 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 107ms/step - loss: 5.9865e-05 - categorical_crossentropy: 5.9865e-05 - val_loss: 5.7576e-05 - val_categorical_crossentropy: 5.7576e-05 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 82ms/step - loss: 5.8125e-05 - categorical_crossentropy: 5.8125e-05 - val_loss: 5.5888e-05 - val_categorical_crossentropy: 5.5888e-05 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 86ms/step - loss: 5.6616e-05 - categorical_crossentropy: 5.6616e-05 - val_loss: 5.4326e-05 - val_categorical_crossentropy: 5.4326e-05 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 120ms/step - loss: 5.5179e-05 - categorical_crossentropy: 5.5179e-05 - val_loss: 5.2896e-05 - val_categorical_crossentropy: 5.2896e-05 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 94ms/step - loss: 5.3867e-05 - categorical_crossentropy: 5.3867e-05 - val_loss: 5.1553e-05 - val_categorical_crossentropy: 5.1553e-05 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 84ms/step - loss: 5.2604e-05 - categorical_crossentropy: 5.2604e-05 - val_loss: 5.0293e-05 - val_categorical_crossentropy: 5.0293e-05 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 88ms/step - loss: 5.1409e-05 - categorical_crossentropy: 5.1409e-05 - val_loss: 4.9093e-05 - val_categorical_crossentropy: 4.9093e-05 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 86ms/step - loss: 5.0288e-05 - categorical_crossentropy: 5.0288e-05 - val_loss: 4.7969e-05 - val_categorical_crossentropy: 4.7969e-05 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 0s 87ms/step - loss: 4.9195e-05 - categorical_crossentropy: 4.9195e-05 - val_loss: 4.6896e-05 - val_categorical_crossentropy: 4.6896e-05 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 0s 94ms/step - loss: 4.8163e-05 - categorical_crossentropy: 4.8163e-05 - val_loss: 4.5867e-05 - val_categorical_crossentropy: 4.5867e-05 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 0s 100ms/step - loss: 4.7336e-05 - categorical_crossentropy: 4.7336e-05 - val_loss: 4.5354e-05 - val_categorical_crossentropy: 4.5354e-05 - lr: 5.0000e-04
# Epoch 37/500
# 4/4 [==============================] - 0s 76ms/step - loss: 4.6847e-05 - categorical_crossentropy: 4.6847e-05 - val_loss: 4.4857e-05 - val_categorical_crossentropy: 4.4857e-05 - lr: 5.0000e-04
# Epoch 38/500
# 4/4 [==============================] - 0s 72ms/step - loss: 4.6383e-05 - categorical_crossentropy: 4.6383e-05 - val_loss: 4.4381e-05 - val_categorical_crossentropy: 4.4381e-05 - lr: 5.0000e-04
# Epoch 39/500
# 4/4 [==============================] - 0s 57ms/step - loss: 4.5912e-05 - categorical_crossentropy: 4.5912e-05 - val_loss: 4.3904e-05 - val_categorical_crossentropy: 4.3904e-05 - lr: 5.0000e-04
# Epoch 40/500
# 4/4 [==============================] - 0s 90ms/step - loss: 4.5446e-05 - categorical_crossentropy: 4.5446e-05 - val_loss: 4.3451e-05 - val_categorical_crossentropy: 4.3451e-05 - lr: 5.0000e-04
# Epoch 41/500
# 4/4 [==============================] - 0s 65ms/step - loss: 4.4996e-05 - categorical_crossentropy: 4.4996e-05 - val_loss: 4.2978e-05 - val_categorical_crossentropy: 4.2978e-05 - lr: 5.0000e-04
# Epoch 42/500
# 4/4 [==============================] - 0s 70ms/step - loss: 4.4552e-05 - categorical_crossentropy: 4.4552e-05 - val_loss: 4.2513e-05 - val_categorical_crossentropy: 4.2513e-05 - lr: 5.0000e-04
# Epoch 43/500
# 4/4 [==============================] - 0s 77ms/step - loss: 4.4112e-05 - categorical_crossentropy: 4.4112e-05 - val_loss: 4.2068e-05 - val_categorical_crossentropy: 4.2068e-05 - lr: 5.0000e-04
# Epoch 44/500
# 4/4 [==============================] - 0s 89ms/step - loss: 4.3664e-05 - categorical_crossentropy: 4.3664e-05 - val_loss: 4.1615e-05 - val_categorical_crossentropy: 4.1615e-05 - lr: 5.0000e-04
# Epoch 45/500
# 4/4 [==============================] - 0s 70ms/step - loss: 4.3240e-05 - categorical_crossentropy: 4.3240e-05 - val_loss: 4.1162e-05 - val_categorical_crossentropy: 4.1162e-05 - lr: 5.0000e-04
# Epoch 46/500
# 4/4 [==============================] - 0s 80ms/step - loss: 4.2807e-05 - categorical_crossentropy: 4.2807e-05 - val_loss: 4.0745e-05 - val_categorical_crossentropy: 4.0745e-05 - lr: 5.0000e-04
# Epoch 47/500
# 4/4 [==============================] - 0s 95ms/step - loss: 4.2395e-05 - categorical_crossentropy: 4.2395e-05 - val_loss: 4.0304e-05 - val_categorical_crossentropy: 4.0304e-05 - lr: 5.0000e-04
# Epoch 48/500
# 4/4 [==============================] - 0s 52ms/step - loss: 4.1966e-05 - categorical_crossentropy: 4.1966e-05 - val_loss: 3.9891e-05 - val_categorical_crossentropy: 3.9891e-05 - lr: 5.0000e-04
# Epoch 49/500
# 4/4 [==============================] - 0s 71ms/step - loss: 4.1567e-05 - categorical_crossentropy: 4.1567e-05 - val_loss: 3.9469e-05 - val_categorical_crossentropy: 3.9469e-05 - lr: 5.0000e-04
# Epoch 50/500
# 4/4 [==============================] - 0s 61ms/step - loss: 4.1146e-05 - categorical_crossentropy: 4.1146e-05 - val_loss: 3.9068e-05 - val_categorical_crossentropy: 3.9068e-05 - lr: 5.0000e-04
# Epoch 51/500
# 4/4 [==============================] - 0s 61ms/step - loss: 4.0766e-05 - categorical_crossentropy: 4.0766e-05 - val_loss: 3.8659e-05 - val_categorical_crossentropy: 3.8659e-05 - lr: 5.0000e-04
# Epoch 52/500
# 4/4 [==============================] - 0s 62ms/step - loss: 4.0364e-05 - categorical_crossentropy: 4.0364e-05 - val_loss: 3.8254e-05 - val_categorical_crossentropy: 3.8254e-05 - lr: 5.0000e-04
# Epoch 53/500
# 4/4 [==============================] - 0s 55ms/step - loss: 3.9975e-05 - categorical_crossentropy: 3.9975e-05 - val_loss: 3.7856e-05 - val_categorical_crossentropy: 3.7856e-05 - lr: 5.0000e-04
# Epoch 54/500
# 4/4 [==============================] - 0s 91ms/step - loss: 3.9597e-05 - categorical_crossentropy: 3.9597e-05 - val_loss: 3.7487e-05 - val_categorical_crossentropy: 3.7487e-05 - lr: 5.0000e-04
# Epoch 55/500
# 4/4 [==============================] - 0s 68ms/step - loss: 3.9223e-05 - categorical_crossentropy: 3.9223e-05 - val_loss: 3.7097e-05 - val_categorical_crossentropy: 3.7097e-05 - lr: 5.0000e-04
# Epoch 56/500
# 4/4 [==============================] - 0s 69ms/step - loss: 3.8849e-05 - categorical_crossentropy: 3.8849e-05 - val_loss: 3.6720e-05 - val_categorical_crossentropy: 3.6720e-05 - lr: 5.0000e-04
# Epoch 57/500
# 4/4 [==============================] - 0s 83ms/step - loss: 3.8482e-05 - categorical_crossentropy: 3.8482e-05 - val_loss: 3.6350e-05 - val_categorical_crossentropy: 3.6350e-05 - lr: 5.0000e-04
# Epoch 58/500
# 4/4 [==============================] - 0s 96ms/step - loss: 3.8119e-05 - categorical_crossentropy: 3.8119e-05 - val_loss: 3.5993e-05 - val_categorical_crossentropy: 3.5993e-05 - lr: 5.0000e-04
# Epoch 59/500
# 4/4 [==============================] - 0s 58ms/step - loss: 3.7760e-05 - categorical_crossentropy: 3.7760e-05 - val_loss: 3.5635e-05 - val_categorical_crossentropy: 3.5635e-05 - lr: 5.0000e-04
# Epoch 60/500
# 4/4 [==============================] - 0s 60ms/step - loss: 3.7419e-05 - categorical_crossentropy: 3.7419e-05 - val_loss: 3.5281e-05 - val_categorical_crossentropy: 3.5281e-05 - lr: 5.0000e-04
# Epoch 61/500
# 4/4 [==============================] - 0s 122ms/step - loss: 3.7073e-05 - categorical_crossentropy: 3.7073e-05 - val_loss: 3.4944e-05 - val_categorical_crossentropy: 3.4944e-05 - lr: 5.0000e-04
# Epoch 62/500
# 4/4 [==============================] - 0s 54ms/step - loss: 3.6735e-05 - categorical_crossentropy: 3.6735e-05 - val_loss: 3.4598e-05 - val_categorical_crossentropy: 3.4598e-05 - lr: 5.0000e-04
# Epoch 63/500
# 4/4 [==============================] - 0s 74ms/step - loss: 3.6398e-05 - categorical_crossentropy: 3.6398e-05 - val_loss: 3.4252e-05 - val_categorical_crossentropy: 3.4252e-05 - lr: 5.0000e-04
# Epoch 64/500
# 4/4 [==============================] - 0s 80ms/step - loss: 3.6079e-05 - categorical_crossentropy: 3.6079e-05 - val_loss: 3.3946e-05 - val_categorical_crossentropy: 3.3946e-05 - lr: 5.0000e-04
# Epoch 65/500
# 4/4 [==============================] - 0s 101ms/step - loss: 3.5749e-05 - categorical_crossentropy: 3.5749e-05 - val_loss: 3.3616e-05 - val_categorical_crossentropy: 3.3616e-05 - lr: 5.0000e-04
# Epoch 66/500
# 4/4 [==============================] - 0s 113ms/step - loss: 3.5488e-05 - categorical_crossentropy: 3.5488e-05 - val_loss: 3.3457e-05 - val_categorical_crossentropy: 3.3457e-05 - lr: 2.5000e-04
# Epoch 67/500
# 4/4 [==============================] - 0s 99ms/step - loss: 3.5330e-05 - categorical_crossentropy: 3.5330e-05 - val_loss: 3.3295e-05 - val_categorical_crossentropy: 3.3295e-05 - lr: 2.5000e-04
# Epoch 68/500
# 4/4 [==============================] - 0s 119ms/step - loss: 3.5175e-05 - categorical_crossentropy: 3.5175e-05 - val_loss: 3.3148e-05 - val_categorical_crossentropy: 3.3148e-05 - lr: 2.5000e-04
# Epoch 69/500
# 4/4 [==============================] - 0s 89ms/step - loss: 3.5019e-05 - categorical_crossentropy: 3.5019e-05 - val_loss: 3.2985e-05 - val_categorical_crossentropy: 3.2985e-05 - lr: 2.5000e-04
# Epoch 70/500
# 4/4 [==============================] - 0s 70ms/step - loss: 3.4863e-05 - categorical_crossentropy: 3.4863e-05 - val_loss: 3.2830e-05 - val_categorical_crossentropy: 3.2830e-05 - lr: 2.5000e-04
# Epoch 71/500
# 4/4 [==============================] - 0s 58ms/step - loss: 3.4701e-05 - categorical_crossentropy: 3.4701e-05 - val_loss: 3.2659e-05 - val_categorical_crossentropy: 3.2659e-05 - lr: 2.5000e-04
# Epoch 72/500
# 4/4 [==============================] - 0s 81ms/step - loss: 3.4554e-05 - categorical_crossentropy: 3.4554e-05 - val_loss: 3.2512e-05 - val_categorical_crossentropy: 3.2512e-05 - lr: 2.5000e-04
# Epoch 73/500
# 4/4 [==============================] - 0s 66ms/step - loss: 3.4400e-05 - categorical_crossentropy: 3.4400e-05 - val_loss: 3.2361e-05 - val_categorical_crossentropy: 3.2361e-05 - lr: 2.5000e-04
# Epoch 74/500
# 4/4 [==============================] - 0s 64ms/step - loss: 3.4240e-05 - categorical_crossentropy: 3.4240e-05 - val_loss: 3.2206e-05 - val_categorical_crossentropy: 3.2206e-05 - lr: 2.5000e-04
# Epoch 75/500
# 4/4 [==============================] - 0s 76ms/step - loss: 3.4091e-05 - categorical_crossentropy: 3.4091e-05 - val_loss: 3.2039e-05 - val_categorical_crossentropy: 3.2039e-05 - lr: 2.5000e-04
# Epoch 76/500
# 4/4 [==============================] - 0s 71ms/step - loss: 3.3939e-05 - categorical_crossentropy: 3.3939e-05 - val_loss: 3.1896e-05 - val_categorical_crossentropy: 3.1896e-05 - lr: 2.5000e-04
# Epoch 77/500
# 4/4 [==============================] - 0s 73ms/step - loss: 3.3794e-05 - categorical_crossentropy: 3.3794e-05 - val_loss: 3.1741e-05 - val_categorical_crossentropy: 3.1741e-05 - lr: 2.5000e-04
# Epoch 78/500
# 4/4 [==============================] - 0s 60ms/step - loss: 3.3643e-05 - categorical_crossentropy: 3.3643e-05 - val_loss: 3.1598e-05 - val_categorical_crossentropy: 3.1598e-05 - lr: 2.5000e-04
# Epoch 79/500
# 4/4 [==============================] - 0s 61ms/step - loss: 3.3491e-05 - categorical_crossentropy: 3.3491e-05 - val_loss: 3.1451e-05 - val_categorical_crossentropy: 3.1451e-05 - lr: 2.5000e-04
# Epoch 80/500
# 4/4 [==============================] - 0s 69ms/step - loss: 3.3345e-05 - categorical_crossentropy: 3.3345e-05 - val_loss: 3.1284e-05 - val_categorical_crossentropy: 3.1284e-05 - lr: 2.5000e-04
# Epoch 81/500
# 4/4 [==============================] - 0s 73ms/step - loss: 3.3188e-05 - categorical_crossentropy: 3.3188e-05 - val_loss: 3.1141e-05 - val_categorical_crossentropy: 3.1141e-05 - lr: 2.5000e-04
# Epoch 82/500
# 4/4 [==============================] - 0s 55ms/step - loss: 3.3054e-05 - categorical_crossentropy: 3.3054e-05 - val_loss: 3.0998e-05 - val_categorical_crossentropy: 3.0998e-05 - lr: 2.5000e-04
# Epoch 83/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.2896e-05 - categorical_crossentropy: 3.2896e-05 - val_loss: 3.0851e-05 - val_categorical_crossentropy: 3.0851e-05 - lr: 2.5000e-04
# Epoch 84/500
# 4/4 [==============================] - 0s 64ms/step - loss: 3.2758e-05 - categorical_crossentropy: 3.2758e-05 - val_loss: 3.0708e-05 - val_categorical_crossentropy: 3.0708e-05 - lr: 2.5000e-04
# Epoch 85/500
# 4/4 [==============================] - 0s 90ms/step - loss: 3.2612e-05 - categorical_crossentropy: 3.2612e-05 - val_loss: 3.0561e-05 - val_categorical_crossentropy: 3.0561e-05 - lr: 2.5000e-04
# Epoch 86/500
# 4/4 [==============================] - 0s 97ms/step - loss: 3.2497e-05 - categorical_crossentropy: 3.2497e-05 - val_loss: 3.0489e-05 - val_categorical_crossentropy: 3.0489e-05 - lr: 1.2500e-04
# Epoch 87/500
# 4/4 [==============================] - 0s 87ms/step - loss: 3.2420e-05 - categorical_crossentropy: 3.2420e-05 - val_loss: 3.0402e-05 - val_categorical_crossentropy: 3.0402e-05 - lr: 1.2500e-04
# Epoch 88/500
# 4/4 [==============================] - 0s 52ms/step - loss: 3.2349e-05 - categorical_crossentropy: 3.2349e-05 - val_loss: 3.0330e-05 - val_categorical_crossentropy: 3.0330e-05 - lr: 1.2500e-04
# Epoch 89/500
# 4/4 [==============================] - 0s 81ms/step - loss: 3.2271e-05 - categorical_crossentropy: 3.2271e-05 - val_loss: 3.0255e-05 - val_categorical_crossentropy: 3.0255e-05 - lr: 1.2500e-04
# Epoch 90/500
# 4/4 [==============================] - 0s 98ms/step - loss: 3.2202e-05 - categorical_crossentropy: 3.2202e-05 - val_loss: 3.0187e-05 - val_categorical_crossentropy: 3.0187e-05 - lr: 1.2500e-04
# Epoch 91/500
# 4/4 [==============================] - 0s 115ms/step - loss: 3.2134e-05 - categorical_crossentropy: 3.2134e-05 - val_loss: 3.0120e-05 - val_categorical_crossentropy: 3.0120e-05 - lr: 1.2500e-04
# Epoch 92/500
# 4/4 [==============================] - 0s 118ms/step - loss: 3.2066e-05 - categorical_crossentropy: 3.2066e-05 - val_loss: 3.0040e-05 - val_categorical_crossentropy: 3.0040e-05 - lr: 1.2500e-04
# Epoch 93/500
# 4/4 [==============================] - 0s 75ms/step - loss: 3.1993e-05 - categorical_crossentropy: 3.1993e-05 - val_loss: 2.9965e-05 - val_categorical_crossentropy: 2.9965e-05 - lr: 1.2500e-04
# Epoch 94/500
# 4/4 [==============================] - 0s 111ms/step - loss: 3.1918e-05 - categorical_crossentropy: 3.1918e-05 - val_loss: 2.9889e-05 - val_categorical_crossentropy: 2.9889e-05 - lr: 1.2500e-04
# Epoch 95/500
# 4/4 [==============================] - 0s 71ms/step - loss: 3.1851e-05 - categorical_crossentropy: 3.1851e-05 - val_loss: 2.9826e-05 - val_categorical_crossentropy: 2.9826e-05 - lr: 1.2500e-04
# Epoch 96/500
# 4/4 [==============================] - 0s 85ms/step - loss: 3.1768e-05 - categorical_crossentropy: 3.1768e-05 - val_loss: 2.9750e-05 - val_categorical_crossentropy: 2.9750e-05 - lr: 1.2500e-04
# Epoch 97/500
# 4/4 [==============================] - 0s 88ms/step - loss: 3.1701e-05 - categorical_crossentropy: 3.1701e-05 - val_loss: 2.9687e-05 - val_categorical_crossentropy: 2.9687e-05 - lr: 1.2500e-04
# Epoch 98/500
# 4/4 [==============================] - 0s 106ms/step - loss: 3.1628e-05 - categorical_crossentropy: 3.1628e-05 - val_loss: 2.9611e-05 - val_categorical_crossentropy: 2.9611e-05 - lr: 1.2500e-04
# Epoch 99/500
# 4/4 [==============================] - 0s 96ms/step - loss: 3.1572e-05 - categorical_crossentropy: 3.1572e-05 - val_loss: 2.9548e-05 - val_categorical_crossentropy: 2.9548e-05 - lr: 1.2500e-04
# Epoch 100/500
# 4/4 [==============================] - 0s 99ms/step - loss: 3.1479e-05 - categorical_crossentropy: 3.1479e-05 - val_loss: 2.9456e-05 - val_categorical_crossentropy: 2.9456e-05 - lr: 1.2500e-04
# Epoch 101/500
# 4/4 [==============================] - 0s 77ms/step - loss: 3.1414e-05 - categorical_crossentropy: 3.1414e-05 - val_loss: 2.9393e-05 - val_categorical_crossentropy: 2.9393e-05 - lr: 1.2500e-04
# Epoch 102/500
# 4/4 [==============================] - 0s 79ms/step - loss: 3.1343e-05 - categorical_crossentropy: 3.1343e-05 - val_loss: 2.9309e-05 - val_categorical_crossentropy: 2.9309e-05 - lr: 1.2500e-04
# Epoch 103/500
# 4/4 [==============================] - 0s 80ms/step - loss: 3.1270e-05 - categorical_crossentropy: 3.1270e-05 - val_loss: 2.9242e-05 - val_categorical_crossentropy: 2.9242e-05 - lr: 1.2500e-04
# Epoch 104/500
# 4/4 [==============================] - 0s 108ms/step - loss: 3.1199e-05 - categorical_crossentropy: 3.1199e-05 - val_loss: 2.9178e-05 - val_categorical_crossentropy: 2.9178e-05 - lr: 1.2500e-04
# Epoch 105/500
# 4/4 [==============================] - 0s 100ms/step - loss: 3.1133e-05 - categorical_crossentropy: 3.1133e-05 - val_loss: 2.9095e-05 - val_categorical_crossentropy: 2.9095e-05 - lr: 1.2500e-04
# Epoch 106/500
# 4/4 [==============================] - 0s 69ms/step - loss: 3.1055e-05 - categorical_crossentropy: 3.1055e-05 - val_loss: 2.9031e-05 - val_categorical_crossentropy: 2.9031e-05 - lr: 1.0000e-04
# Epoch 107/500
# 4/4 [==============================] - 0s 91ms/step - loss: 3.1005e-05 - categorical_crossentropy: 3.1005e-05 - val_loss: 2.8967e-05 - val_categorical_crossentropy: 2.8967e-05 - lr: 1.0000e-04
# Epoch 108/500
# 4/4 [==============================] - 0s 76ms/step - loss: 3.0945e-05 - categorical_crossentropy: 3.0945e-05 - val_loss: 2.8924e-05 - val_categorical_crossentropy: 2.8924e-05 - lr: 1.0000e-04
# Epoch 109/500
# 4/4 [==============================] - 0s 56ms/step - loss: 3.0891e-05 - categorical_crossentropy: 3.0891e-05 - val_loss: 2.8852e-05 - val_categorical_crossentropy: 2.8852e-05 - lr: 1.0000e-04
# Epoch 110/500
# 4/4 [==============================] - 0s 75ms/step - loss: 3.0832e-05 - categorical_crossentropy: 3.0832e-05 - val_loss: 2.8801e-05 - val_categorical_crossentropy: 2.8801e-05 - lr: 1.0000e-04
# Epoch 111/500
# 4/4 [==============================] - 0s 94ms/step - loss: 3.0771e-05 - categorical_crossentropy: 3.0771e-05 - val_loss: 2.8753e-05 - val_categorical_crossentropy: 2.8753e-05 - lr: 1.0000e-04
# Epoch 112/500
# 4/4 [==============================] - 0s 78ms/step - loss: 3.0716e-05 - categorical_crossentropy: 3.0716e-05 - val_loss: 2.8673e-05 - val_categorical_crossentropy: 2.8673e-05 - lr: 1.0000e-04
# Epoch 113/500
# 4/4 [==============================] - 0s 98ms/step - loss: 3.0655e-05 - categorical_crossentropy: 3.0655e-05 - val_loss: 2.8622e-05 - val_categorical_crossentropy: 2.8622e-05 - lr: 1.0000e-04
# Epoch 114/500
# 4/4 [==============================] - 0s 106ms/step - loss: 3.0600e-05 - categorical_crossentropy: 3.0600e-05 - val_loss: 2.8562e-05 - val_categorical_crossentropy: 2.8562e-05 - lr: 1.0000e-04
# Epoch 115/500
# 4/4 [==============================] - 0s 93ms/step - loss: 3.0538e-05 - categorical_crossentropy: 3.0538e-05 - val_loss: 2.8510e-05 - val_categorical_crossentropy: 2.8510e-05 - lr: 1.0000e-04
# Epoch 116/500
# 4/4 [==============================] - 0s 97ms/step - loss: 3.0481e-05 - categorical_crossentropy: 3.0481e-05 - val_loss: 2.8455e-05 - val_categorical_crossentropy: 2.8455e-05 - lr: 1.0000e-04
# Epoch 117/500
# 4/4 [==============================] - 0s 91ms/step - loss: 3.0424e-05 - categorical_crossentropy: 3.0424e-05 - val_loss: 2.8391e-05 - val_categorical_crossentropy: 2.8391e-05 - lr: 1.0000e-04
# Epoch 118/500
# 4/4 [==============================] - 0s 52ms/step - loss: 3.0364e-05 - categorical_crossentropy: 3.0364e-05 - val_loss: 2.8340e-05 - val_categorical_crossentropy: 2.8340e-05 - lr: 1.0000e-04
# Epoch 119/500
# 4/4 [==============================] - 0s 74ms/step - loss: 3.0306e-05 - categorical_crossentropy: 3.0306e-05 - val_loss: 2.8288e-05 - val_categorical_crossentropy: 2.8288e-05 - lr: 1.0000e-04
# Epoch 120/500
# 4/4 [==============================] - 0s 86ms/step - loss: 3.0244e-05 - categorical_crossentropy: 3.0244e-05 - val_loss: 2.8204e-05 - val_categorical_crossentropy: 2.8204e-05 - lr: 1.0000e-04
# Epoch 121/500
# 4/4 [==============================] - 0s 95ms/step - loss: 3.0192e-05 - categorical_crossentropy: 3.0192e-05 - val_loss: 2.8173e-05 - val_categorical_crossentropy: 2.8173e-05 - lr: 1.0000e-04
# Epoch 122/500
# 4/4 [==============================] - 0s 64ms/step - loss: 3.0132e-05 - categorical_crossentropy: 3.0132e-05 - val_loss: 2.8097e-05 - val_categorical_crossentropy: 2.8097e-05 - lr: 1.0000e-04
# Epoch 123/500
# 4/4 [==============================] - 0s 58ms/step - loss: 3.0073e-05 - categorical_crossentropy: 3.0073e-05 - val_loss: 2.8042e-05 - val_categorical_crossentropy: 2.8042e-05 - lr: 1.0000e-04
# Epoch 124/500
# 4/4 [==============================] - 0s 88ms/step - loss: 3.0019e-05 - categorical_crossentropy: 3.0019e-05 - val_loss: 2.7986e-05 - val_categorical_crossentropy: 2.7986e-05 - lr: 1.0000e-04
# Epoch 125/500
# 4/4 [==============================] - 0s 72ms/step - loss: 2.9958e-05 - categorical_crossentropy: 2.9958e-05 - val_loss: 2.7922e-05 - val_categorical_crossentropy: 2.7922e-05 - lr: 1.0000e-04
# Epoch 126/500
# 4/4 [==============================] - 0s 65ms/step - loss: 2.9898e-05 - categorical_crossentropy: 2.9898e-05 - val_loss: 2.7875e-05 - val_categorical_crossentropy: 2.7875e-05 - lr: 1.0000e-04
# Epoch 127/500
# 4/4 [==============================] - 0s 78ms/step - loss: 2.9839e-05 - categorical_crossentropy: 2.9839e-05 - val_loss: 2.7807e-05 - val_categorical_crossentropy: 2.7807e-05 - lr: 1.0000e-04
# Epoch 128/500
# 4/4 [==============================] - 0s 100ms/step - loss: 2.9783e-05 - categorical_crossentropy: 2.9783e-05 - val_loss: 2.7759e-05 - val_categorical_crossentropy: 2.7759e-05 - lr: 1.0000e-04
# Epoch 129/500
# 4/4 [==============================] - 0s 88ms/step - loss: 2.9722e-05 - categorical_crossentropy: 2.9722e-05 - val_loss: 2.7700e-05 - val_categorical_crossentropy: 2.7700e-05 - lr: 1.0000e-04
# Epoch 130/500
# 4/4 [==============================] - 0s 99ms/step - loss: 2.9670e-05 - categorical_crossentropy: 2.9670e-05 - val_loss: 2.7632e-05 - val_categorical_crossentropy: 2.7632e-05 - lr: 1.0000e-04
# Epoch 131/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2.9611e-05 - categorical_crossentropy: 2.9611e-05 - val_loss: 2.7573e-05 - val_categorical_crossentropy: 2.7573e-05 - lr: 1.0000e-04
# Epoch 132/500
# 4/4 [==============================] - 0s 87ms/step - loss: 2.9547e-05 - categorical_crossentropy: 2.9547e-05 - val_loss: 2.7525e-05 - val_categorical_crossentropy: 2.7525e-05 - lr: 1.0000e-04
# Epoch 133/500
# 4/4 [==============================] - 0s 70ms/step - loss: 2.9488e-05 - categorical_crossentropy: 2.9488e-05 - val_loss: 2.7450e-05 - val_categorical_crossentropy: 2.7450e-05 - lr: 1.0000e-04
# Epoch 134/500
# 4/4 [==============================] - 0s 78ms/step - loss: 2.9435e-05 - categorical_crossentropy: 2.9435e-05 - val_loss: 2.7406e-05 - val_categorical_crossentropy: 2.7406e-05 - lr: 1.0000e-04
# Epoch 135/500
# 4/4 [==============================] - 0s 75ms/step - loss: 2.9376e-05 - categorical_crossentropy: 2.9376e-05 - val_loss: 2.7346e-05 - val_categorical_crossentropy: 2.7346e-05 - lr: 1.0000e-04
# Epoch 136/500
# 4/4 [==============================] - 0s 88ms/step - loss: 2.9315e-05 - categorical_crossentropy: 2.9315e-05 - val_loss: 2.7287e-05 - val_categorical_crossentropy: 2.7287e-05 - lr: 1.0000e-04
# Epoch 137/500
# 4/4 [==============================] - 0s 96ms/step - loss: 2.9259e-05 - categorical_crossentropy: 2.9259e-05 - val_loss: 2.7231e-05 - val_categorical_crossentropy: 2.7231e-05 - lr: 1.0000e-04
# Epoch 138/500
# 4/4 [==============================] - 0s 75ms/step - loss: 2.9195e-05 - categorical_crossentropy: 2.9195e-05 - val_loss: 2.7163e-05 - val_categorical_crossentropy: 2.7163e-05 - lr: 1.0000e-04
# Epoch 139/500
# 4/4 [==============================] - 0s 100ms/step - loss: 2.9138e-05 - categorical_crossentropy: 2.9138e-05 - val_loss: 2.7112e-05 - val_categorical_crossentropy: 2.7112e-05 - lr: 1.0000e-04
# Epoch 140/500
# 4/4 [==============================] - 0s 93ms/step - loss: 2.9077e-05 - categorical_crossentropy: 2.9077e-05 - val_loss: 2.7052e-05 - val_categorical_crossentropy: 2.7052e-05 - lr: 1.0000e-04
# Epoch 141/500
# 4/4 [==============================] - 0s 55ms/step - loss: 2.9028e-05 - categorical_crossentropy: 2.9028e-05 - val_loss: 2.6985e-05 - val_categorical_crossentropy: 2.6985e-05 - lr: 1.0000e-04
# Epoch 142/500
# 4/4 [==============================] - 0s 84ms/step - loss: 2.8968e-05 - categorical_crossentropy: 2.8968e-05 - val_loss: 2.6949e-05 - val_categorical_crossentropy: 2.6949e-05 - lr: 1.0000e-04
# Epoch 143/500
# 4/4 [==============================] - 0s 109ms/step - loss: 2.8912e-05 - categorical_crossentropy: 2.8912e-05 - val_loss: 2.6873e-05 - val_categorical_crossentropy: 2.6873e-05 - lr: 1.0000e-04
# Epoch 144/500
# 4/4 [==============================] - 0s 73ms/step - loss: 2.8849e-05 - categorical_crossentropy: 2.8849e-05 - val_loss: 2.6834e-05 - val_categorical_crossentropy: 2.6834e-05 - lr: 1.0000e-04
# Epoch 145/500
# 4/4 [==============================] - 0s 92ms/step - loss: 2.8798e-05 - categorical_crossentropy: 2.8798e-05 - val_loss: 2.6758e-05 - val_categorical_crossentropy: 2.6758e-05 - lr: 1.0000e-04
# Epoch 146/500
# 4/4 [==============================] - 0s 89ms/step - loss: 2.8734e-05 - categorical_crossentropy: 2.8734e-05 - val_loss: 2.6714e-05 - val_categorical_crossentropy: 2.6714e-05 - lr: 1.0000e-04
# Epoch 147/500
# 4/4 [==============================] - 0s 124ms/step - loss: 2.8676e-05 - categorical_crossentropy: 2.8676e-05 - val_loss: 2.6643e-05 - val_categorical_crossentropy: 2.6643e-05 - lr: 1.0000e-04
# Epoch 148/500
# 4/4 [==============================] - 0s 60ms/step - loss: 2.8616e-05 - categorical_crossentropy: 2.8616e-05 - val_loss: 2.6595e-05 - val_categorical_crossentropy: 2.6595e-05 - lr: 1.0000e-04
# Epoch 149/500
# 4/4 [==============================] - 0s 61ms/step - loss: 2.8560e-05 - categorical_crossentropy: 2.8560e-05 - val_loss: 2.6528e-05 - val_categorical_crossentropy: 2.6528e-05 - lr: 1.0000e-04
# Epoch 150/500
# 4/4 [==============================] - 0s 85ms/step - loss: 2.8506e-05 - categorical_crossentropy: 2.8506e-05 - val_loss: 2.6484e-05 - val_categorical_crossentropy: 2.6484e-05 - lr: 1.0000e-04
# Epoch 151/500
# 4/4 [==============================] - 0s 88ms/step - loss: 2.8441e-05 - categorical_crossentropy: 2.8441e-05 - val_loss: 2.6408e-05 - val_categorical_crossentropy: 2.6408e-05 - lr: 1.0000e-04
# Epoch 152/500
# 4/4 [==============================] - 0s 86ms/step - loss: 2.8389e-05 - categorical_crossentropy: 2.8389e-05 - val_loss: 2.6361e-05 - val_categorical_crossentropy: 2.6361e-05 - lr: 1.0000e-04
# Epoch 153/500
# 4/4 [==============================] - 0s 64ms/step - loss: 2.8327e-05 - categorical_crossentropy: 2.8327e-05 - val_loss: 2.6313e-05 - val_categorical_crossentropy: 2.6313e-05 - lr: 1.0000e-04
# Epoch 154/500
# 4/4 [==============================] - 0s 88ms/step - loss: 2.8273e-05 - categorical_crossentropy: 2.8273e-05 - val_loss: 2.6242e-05 - val_categorical_crossentropy: 2.6242e-05 - lr: 1.0000e-04
# Epoch 155/500
# 4/4 [==============================] - 0s 59ms/step - loss: 2.8213e-05 - categorical_crossentropy: 2.8213e-05 - val_loss: 2.6198e-05 - val_categorical_crossentropy: 2.6198e-05 - lr: 1.0000e-04
# Epoch 156/500
# 4/4 [==============================] - 0s 66ms/step - loss: 2.8157e-05 - categorical_crossentropy: 2.8157e-05 - val_loss: 2.6122e-05 - val_categorical_crossentropy: 2.6122e-05 - lr: 1.0000e-04
# Epoch 157/500
# 4/4 [==============================] - 0s 81ms/step - loss: 2.8095e-05 - categorical_crossentropy: 2.8095e-05 - val_loss: 2.6071e-05 - val_categorical_crossentropy: 2.6071e-05 - lr: 1.0000e-04
# Epoch 158/500
# 4/4 [==============================] - 0s 53ms/step - loss: 2.8040e-05 - categorical_crossentropy: 2.8040e-05 - val_loss: 2.6019e-05 - val_categorical_crossentropy: 2.6019e-05 - lr: 1.0000e-04
# Epoch 159/500
# 4/4 [==============================] - 0s 60ms/step - loss: 2.7983e-05 - categorical_crossentropy: 2.7983e-05 - val_loss: 2.5948e-05 - val_categorical_crossentropy: 2.5948e-05 - lr: 1.0000e-04
# Epoch 160/500
# 4/4 [==============================] - 0s 80ms/step - loss: 2.7928e-05 - categorical_crossentropy: 2.7928e-05 - val_loss: 2.5904e-05 - val_categorical_crossentropy: 2.5904e-05 - lr: 1.0000e-04
# Epoch 161/500
# 4/4 [==============================] - 0s 111ms/step - loss: 2.7871e-05 - categorical_crossentropy: 2.7871e-05 - val_loss: 2.5844e-05 - val_categorical_crossentropy: 2.5844e-05 - lr: 1.0000e-04
# Epoch 162/500
# 4/4 [==============================] - 0s 118ms/step - loss: 2.7812e-05 - categorical_crossentropy: 2.7812e-05 - val_loss: 2.5797e-05 - val_categorical_crossentropy: 2.5797e-05 - lr: 1.0000e-04
# Epoch 163/500
# 4/4 [==============================] - 0s 131ms/step - loss: 2.7755e-05 - categorical_crossentropy: 2.7755e-05 - val_loss: 2.5729e-05 - val_categorical_crossentropy: 2.5729e-05 - lr: 1.0000e-04
# Epoch 164/500
# 4/4 [==============================] - 0s 133ms/step - loss: 2.7694e-05 - categorical_crossentropy: 2.7694e-05 - val_loss: 2.5681e-05 - val_categorical_crossentropy: 2.5681e-05 - lr: 1.0000e-04
# Epoch 165/500
# 4/4 [==============================] - 0s 114ms/step - loss: 2.7637e-05 - categorical_crossentropy: 2.7637e-05 - val_loss: 2.5618e-05 - val_categorical_crossentropy: 2.5618e-05 - lr: 1.0000e-04
# Epoch 166/500
# 4/4 [==============================] - 0s 84ms/step - loss: 2.7585e-05 - categorical_crossentropy: 2.7585e-05 - val_loss: 2.5570e-05 - val_categorical_crossentropy: 2.5570e-05 - lr: 1.0000e-04
# Epoch 167/500
# 4/4 [==============================] - 0s 98ms/step - loss: 2.7519e-05 - categorical_crossentropy: 2.7519e-05 - val_loss: 2.5514e-05 - val_categorical_crossentropy: 2.5514e-05 - lr: 1.0000e-04
# Epoch 168/500
# 4/4 [==============================] - 0s 68ms/step - loss: 2.7468e-05 - categorical_crossentropy: 2.7468e-05 - val_loss: 2.5447e-05 - val_categorical_crossentropy: 2.5447e-05 - lr: 1.0000e-04
# Epoch 169/500
# 4/4 [==============================] - 0s 122ms/step - loss: 2.7404e-05 - categorical_crossentropy: 2.7404e-05 - val_loss: 2.5399e-05 - val_categorical_crossentropy: 2.5399e-05 - lr: 1.0000e-04
# Epoch 170/500
# 4/4 [==============================] - 0s 92ms/step - loss: 2.7353e-05 - categorical_crossentropy: 2.7353e-05 - val_loss: 2.5336e-05 - val_categorical_crossentropy: 2.5336e-05 - lr: 1.0000e-04
# Epoch 171/500
# 4/4 [==============================] - 0s 117ms/step - loss: 2.7297e-05 - categorical_crossentropy: 2.7297e-05 - val_loss: 2.5288e-05 - val_categorical_crossentropy: 2.5288e-05 - lr: 1.0000e-04
# Epoch 172/500
# 4/4 [==============================] - 0s 93ms/step - loss: 2.7234e-05 - categorical_crossentropy: 2.7234e-05 - val_loss: 2.5224e-05 - val_categorical_crossentropy: 2.5224e-05 - lr: 1.0000e-04
# Epoch 173/500
# 4/4 [==============================] - 0s 89ms/step - loss: 2.7186e-05 - categorical_crossentropy: 2.7186e-05 - val_loss: 2.5169e-05 - val_categorical_crossentropy: 2.5169e-05 - lr: 1.0000e-04
# Epoch 174/500
# 4/4 [==============================] - 0s 94ms/step - loss: 2.7120e-05 - categorical_crossentropy: 2.7120e-05 - val_loss: 2.5109e-05 - val_categorical_crossentropy: 2.5109e-05 - lr: 1.0000e-04
# Epoch 175/500
# 4/4 [==============================] - 0s 101ms/step - loss: 2.7065e-05 - categorical_crossentropy: 2.7065e-05 - val_loss: 2.5046e-05 - val_categorical_crossentropy: 2.5046e-05 - lr: 1.0000e-04
# Epoch 176/500
# 4/4 [==============================] - 0s 114ms/step - loss: 2.7007e-05 - categorical_crossentropy: 2.7007e-05 - val_loss: 2.4998e-05 - val_categorical_crossentropy: 2.4998e-05 - lr: 1.0000e-04
# Epoch 177/500
# 4/4 [==============================] - 0s 95ms/step - loss: 2.6953e-05 - categorical_crossentropy: 2.6953e-05 - val_loss: 2.4938e-05 - val_categorical_crossentropy: 2.4938e-05 - lr: 1.0000e-04
# Epoch 178/500
# 4/4 [==============================] - 0s 102ms/step - loss: 2.6904e-05 - categorical_crossentropy: 2.6904e-05 - val_loss: 2.4887e-05 - val_categorical_crossentropy: 2.4887e-05 - lr: 1.0000e-04
# Epoch 179/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2.6840e-05 - categorical_crossentropy: 2.6840e-05 - val_loss: 2.4831e-05 - val_categorical_crossentropy: 2.4831e-05 - lr: 1.0000e-04
# Epoch 180/500
# 4/4 [==============================] - 0s 87ms/step - loss: 2.6787e-05 - categorical_crossentropy: 2.6787e-05 - val_loss: 2.4775e-05 - val_categorical_crossentropy: 2.4775e-05 - lr: 1.0000e-04
# Epoch 181/500
# 4/4 [==============================] - 0s 67ms/step - loss: 2.6726e-05 - categorical_crossentropy: 2.6726e-05 - val_loss: 2.4716e-05 - val_categorical_crossentropy: 2.4716e-05 - lr: 1.0000e-04
# Epoch 182/500
# 4/4 [==============================] - 0s 77ms/step - loss: 2.6676e-05 - categorical_crossentropy: 2.6676e-05 - val_loss: 2.4656e-05 - val_categorical_crossentropy: 2.4656e-05 - lr: 1.0000e-04
# Epoch 183/500
# 4/4 [==============================] - 0s 74ms/step - loss: 2.6614e-05 - categorical_crossentropy: 2.6614e-05 - val_loss: 2.4600e-05 - val_categorical_crossentropy: 2.4600e-05 - lr: 1.0000e-04
# Epoch 184/500
# 4/4 [==============================] - 0s 94ms/step - loss: 2.6564e-05 - categorical_crossentropy: 2.6564e-05 - val_loss: 2.4549e-05 - val_categorical_crossentropy: 2.4549e-05 - lr: 1.0000e-04
# Epoch 185/500
# 4/4 [==============================] - 0s 86ms/step - loss: 2.6506e-05 - categorical_crossentropy: 2.6506e-05 - val_loss: 2.4485e-05 - val_categorical_crossentropy: 2.4485e-05 - lr: 1.0000e-04
# Epoch 186/500
# 4/4 [==============================] - 0s 94ms/step - loss: 2.6443e-05 - categorical_crossentropy: 2.6443e-05 - val_loss: 2.4442e-05 - val_categorical_crossentropy: 2.4442e-05 - lr: 1.0000e-04
# Epoch 187/500
# 4/4 [==============================] - 0s 92ms/step - loss: 2.6389e-05 - categorical_crossentropy: 2.6389e-05 - val_loss: 2.4378e-05 - val_categorical_crossentropy: 2.4378e-05 - lr: 1.0000e-04
# Epoch 188/500
# 4/4 [==============================] - 0s 109ms/step - loss: 2.6334e-05 - categorical_crossentropy: 2.6334e-05 - val_loss: 2.4330e-05 - val_categorical_crossentropy: 2.4330e-05 - lr: 1.0000e-04
# Epoch 189/500
# 4/4 [==============================] - 0s 85ms/step - loss: 2.6281e-05 - categorical_crossentropy: 2.6281e-05 - val_loss: 2.4275e-05 - val_categorical_crossentropy: 2.4275e-05 - lr: 1.0000e-04
# Epoch 190/500
# 4/4 [==============================] - 0s 102ms/step - loss: 2.6222e-05 - categorical_crossentropy: 2.6222e-05 - val_loss: 2.4219e-05 - val_categorical_crossentropy: 2.4219e-05 - lr: 1.0000e-04
# Epoch 191/500
# 4/4 [==============================] - 0s 98ms/step - loss: 2.6171e-05 - categorical_crossentropy: 2.6171e-05 - val_loss: 2.4171e-05 - val_categorical_crossentropy: 2.4171e-05 - lr: 1.0000e-04
# Epoch 192/500
# 4/4 [==============================] - 0s 118ms/step - loss: 2.6102e-05 - categorical_crossentropy: 2.6102e-05 - val_loss: 2.4108e-05 - val_categorical_crossentropy: 2.4108e-05 - lr: 1.0000e-04
# Epoch 193/500
# 4/4 [==============================] - 0s 141ms/step - loss: 2.6056e-05 - categorical_crossentropy: 2.6056e-05 - val_loss: 2.4060e-05 - val_categorical_crossentropy: 2.4060e-05 - lr: 1.0000e-04
# Epoch 194/500
# 4/4 [==============================] - 0s 77ms/step - loss: 2.5996e-05 - categorical_crossentropy: 2.5996e-05 - val_loss: 2.3989e-05 - val_categorical_crossentropy: 2.3989e-05 - lr: 1.0000e-04
# Epoch 195/500
# 4/4 [==============================] - 0s 81ms/step - loss: 2.5941e-05 - categorical_crossentropy: 2.5941e-05 - val_loss: 2.3937e-05 - val_categorical_crossentropy: 2.3937e-05 - lr: 1.0000e-04
# Epoch 196/500
# 4/4 [==============================] - 0s 111ms/step - loss: 2.5887e-05 - categorical_crossentropy: 2.5887e-05 - val_loss: 2.3877e-05 - val_categorical_crossentropy: 2.3877e-05 - lr: 1.0000e-04
# Epoch 197/500
# 4/4 [==============================] - 1s 160ms/step - loss: 2.5829e-05 - categorical_crossentropy: 2.5829e-05 - val_loss: 2.3830e-05 - val_categorical_crossentropy: 2.3830e-05 - lr: 1.0000e-04
# Epoch 198/500
# 4/4 [==============================] - 0s 112ms/step - loss: 2.5777e-05 - categorical_crossentropy: 2.5777e-05 - val_loss: 2.3774e-05 - val_categorical_crossentropy: 2.3774e-05 - lr: 1.0000e-04
# Epoch 199/500
# 4/4 [==============================] - 0s 79ms/step - loss: 2.5713e-05 - categorical_crossentropy: 2.5713e-05 - val_loss: 2.3722e-05 - val_categorical_crossentropy: 2.3722e-05 - lr: 1.0000e-04
# Epoch 200/500
# 4/4 [==============================] - 0s 124ms/step - loss: 2.5665e-05 - categorical_crossentropy: 2.5665e-05 - val_loss: 2.3679e-05 - val_categorical_crossentropy: 2.3679e-05 - lr: 1.0000e-04
# Epoch 201/500
# 4/4 [==============================] - 0s 78ms/step - loss: 2.5606e-05 - categorical_crossentropy: 2.5606e-05 - val_loss: 2.3607e-05 - val_categorical_crossentropy: 2.3607e-05 - lr: 1.0000e-04
# Epoch 202/500
# 4/4 [==============================] - 0s 68ms/step - loss: 2.5551e-05 - categorical_crossentropy: 2.5551e-05 - val_loss: 2.3567e-05 - val_categorical_crossentropy: 2.3567e-05 - lr: 1.0000e-04
# Epoch 203/500
# 4/4 [==============================] - 0s 92ms/step - loss: 2.5496e-05 - categorical_crossentropy: 2.5496e-05 - val_loss: 2.3496e-05 - val_categorical_crossentropy: 2.3496e-05 - lr: 1.0000e-04
# Epoch 204/500
# 4/4 [==============================] - 0s 100ms/step - loss: 2.5446e-05 - categorical_crossentropy: 2.5446e-05 - val_loss: 2.3460e-05 - val_categorical_crossentropy: 2.3460e-05 - lr: 1.0000e-04
# Epoch 205/500
# 4/4 [==============================] - 0s 98ms/step - loss: 2.5383e-05 - categorical_crossentropy: 2.5383e-05 - val_loss: 2.3389e-05 - val_categorical_crossentropy: 2.3389e-05 - lr: 1.0000e-04
# Epoch 206/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2.5331e-05 - categorical_crossentropy: 2.5331e-05 - val_loss: 2.3349e-05 - val_categorical_crossentropy: 2.3349e-05 - lr: 1.0000e-04
# Epoch 207/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2.5270e-05 - categorical_crossentropy: 2.5270e-05 - val_loss: 2.3285e-05 - val_categorical_crossentropy: 2.3285e-05 - lr: 1.0000e-04
# Epoch 208/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2.5219e-05 - categorical_crossentropy: 2.5219e-05 - val_loss: 2.3242e-05 - val_categorical_crossentropy: 2.3242e-05 - lr: 1.0000e-04
# Epoch 209/500
# 4/4 [==============================] - 0s 76ms/step - loss: 2.5161e-05 - categorical_crossentropy: 2.5161e-05 - val_loss: 2.3178e-05 - val_categorical_crossentropy: 2.3178e-05 - lr: 1.0000e-04
# Epoch 210/500
# 4/4 [==============================] - 0s 61ms/step - loss: 2.5115e-05 - categorical_crossentropy: 2.5115e-05 - val_loss: 2.3130e-05 - val_categorical_crossentropy: 2.3130e-05 - lr: 1.0000e-04
# Epoch 211/500
# 4/4 [==============================] - 0s 61ms/step - loss: 2.5048e-05 - categorical_crossentropy: 2.5048e-05 - val_loss: 2.3071e-05 - val_categorical_crossentropy: 2.3071e-05 - lr: 1.0000e-04
# Epoch 212/500
# 4/4 [==============================] - 0s 81ms/step - loss: 2.4997e-05 - categorical_crossentropy: 2.4997e-05 - val_loss: 2.3027e-05 - val_categorical_crossentropy: 2.3027e-05 - lr: 1.0000e-04
# Epoch 213/500
# 4/4 [==============================] - 0s 73ms/step - loss: 2.4944e-05 - categorical_crossentropy: 2.4944e-05 - val_loss: 2.2971e-05 - val_categorical_crossentropy: 2.2971e-05 - lr: 1.0000e-04
# Epoch 214/500
# 4/4 [==============================] - 0s 101ms/step - loss: 2.4889e-05 - categorical_crossentropy: 2.4889e-05 - val_loss: 2.2928e-05 - val_categorical_crossentropy: 2.2928e-05 - lr: 1.0000e-04
# Epoch 215/500
# 4/4 [==============================] - 1s 141ms/step - loss: 2.4840e-05 - categorical_crossentropy: 2.4840e-05 - val_loss: 2.2856e-05 - val_categorical_crossentropy: 2.2856e-05 - lr: 1.0000e-04
# Epoch 216/500
# 4/4 [==============================] - 1s 171ms/step - loss: 2.4776e-05 - categorical_crossentropy: 2.4776e-05 - val_loss: 2.2808e-05 - val_categorical_crossentropy: 2.2808e-05 - lr: 1.0000e-04
# Epoch 217/500
# 4/4 [==============================] - 1s 149ms/step - loss: 2.4730e-05 - categorical_crossentropy: 2.4730e-05 - val_loss: 2.2741e-05 - val_categorical_crossentropy: 2.2741e-05 - lr: 1.0000e-04
# Epoch 218/500
# 4/4 [==============================] - 0s 132ms/step - loss: 2.4673e-05 - categorical_crossentropy: 2.4673e-05 - val_loss: 2.2701e-05 - val_categorical_crossentropy: 2.2701e-05 - lr: 1.0000e-04
# Epoch 219/500
# 4/4 [==============================] - 1s 150ms/step - loss: 2.4618e-05 - categorical_crossentropy: 2.4618e-05 - val_loss: 2.2649e-05 - val_categorical_crossentropy: 2.2649e-05 - lr: 1.0000e-04
# Epoch 220/500
# 4/4 [==============================] - 0s 132ms/step - loss: 2.4568e-05 - categorical_crossentropy: 2.4568e-05 - val_loss: 2.2598e-05 - val_categorical_crossentropy: 2.2598e-05 - lr: 1.0000e-04
# Epoch 221/500
# 4/4 [==============================] - 0s 100ms/step - loss: 2.4508e-05 - categorical_crossentropy: 2.4508e-05 - val_loss: 2.2546e-05 - val_categorical_crossentropy: 2.2546e-05 - lr: 1.0000e-04
# Epoch 222/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2.4459e-05 - categorical_crossentropy: 2.4459e-05 - val_loss: 2.2491e-05 - val_categorical_crossentropy: 2.2491e-05 - lr: 1.0000e-04
# Epoch 223/500
# 4/4 [==============================] - 0s 95ms/step - loss: 2.4405e-05 - categorical_crossentropy: 2.4405e-05 - val_loss: 2.2439e-05 - val_categorical_crossentropy: 2.2439e-05 - lr: 1.0000e-04
# Epoch 224/500
# 4/4 [==============================] - 0s 59ms/step - loss: 2.4346e-05 - categorical_crossentropy: 2.4346e-05 - val_loss: 2.2391e-05 - val_categorical_crossentropy: 2.2391e-05 - lr: 1.0000e-04
# Epoch 225/500
# 4/4 [==============================] - 0s 118ms/step - loss: 2.4300e-05 - categorical_crossentropy: 2.4300e-05 - val_loss: 2.2332e-05 - val_categorical_crossentropy: 2.2332e-05 - lr: 1.0000e-04
# Epoch 226/500
# 4/4 [==============================] - 0s 82ms/step - loss: 2.4234e-05 - categorical_crossentropy: 2.4234e-05 - val_loss: 2.2288e-05 - val_categorical_crossentropy: 2.2288e-05 - lr: 1.0000e-04
# Epoch 227/500
# 4/4 [==============================] - 0s 52ms/step - loss: 2.4184e-05 - categorical_crossentropy: 2.4184e-05 - val_loss: 2.2228e-05 - val_categorical_crossentropy: 2.2228e-05 - lr: 1.0000e-04
# Epoch 228/500
# 4/4 [==============================] - 0s 77ms/step - loss: 2.4138e-05 - categorical_crossentropy: 2.4138e-05 - val_loss: 2.2181e-05 - val_categorical_crossentropy: 2.2181e-05 - lr: 1.0000e-04
# Epoch 229/500
# 4/4 [==============================] - 0s 91ms/step - loss: 2.4080e-05 - categorical_crossentropy: 2.4080e-05 - val_loss: 2.2125e-05 - val_categorical_crossentropy: 2.2125e-05 - lr: 1.0000e-04
# Epoch 230/500
# 4/4 [==============================] - 1s 131ms/step - loss: 2.4031e-05 - categorical_crossentropy: 2.4031e-05 - val_loss: 2.2069e-05 - val_categorical_crossentropy: 2.2069e-05 - lr: 1.0000e-04
# Epoch 231/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2.3971e-05 - categorical_crossentropy: 2.3971e-05 - val_loss: 2.2026e-05 - val_categorical_crossentropy: 2.2026e-05 - lr: 1.0000e-04
# Epoch 232/500
# 4/4 [==============================] - 1s 145ms/step - loss: 2.3921e-05 - categorical_crossentropy: 2.3921e-05 - val_loss: 2.1970e-05 - val_categorical_crossentropy: 2.1970e-05 - lr: 1.0000e-04
# Epoch 233/500
# 4/4 [==============================] - 0s 99ms/step - loss: 2.3865e-05 - categorical_crossentropy: 2.3865e-05 - val_loss: 2.1934e-05 - val_categorical_crossentropy: 2.1934e-05 - lr: 1.0000e-04
# Epoch 234/500
# ...
# Epoch 424/500
# 4/4 [==============================] - 0s 127ms/step - loss: 1.5207e-05 - categorical_crossentropy: 1.5207e-05 - val_loss: 1.3749e-05 - val_categorical_crossentropy: 1.3749e-05 - lr: 1.0000e-04
# Epoch 425/500
# 4/4 [==============================] - 0s 84ms/step - loss: 1.5172e-05 - categorical_crossentropy: 1.5172e-05 - val_loss: 1.3725e-05 - val_categorical_crossentropy: 1.3725e-05 - lr: 1.0000e-04
# Epoch 426/500
# 4/4 [==============================] - 0s 74ms/step - loss: 1.5142e-05 - categorical_crossentropy: 1.5142e-05 - val_loss: 1.3685e-05 - val_categorical_crossentropy: 1.3685e-05 - lr: 1.0000e-04
# Epoch 427/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.5106e-05 - categorical_crossentropy: 1.5106e-05 - val_loss: 1.3649e-05 - val_categorical_crossentropy: 1.3649e-05 - lr: 1.0000e-04
# Epoch 428/500
# 4/4 [==============================] - 0s 125ms/step - loss: 1.5066e-05 - categorical_crossentropy: 1.5066e-05 - val_loss: 1.3614e-05 - val_categorical_crossentropy: 1.3614e-05 - lr: 1.0000e-04
# Epoch 429/500
# 4/4 [==============================] - 0s 83ms/step - loss: 1.5028e-05 - categorical_crossentropy: 1.5028e-05 - val_loss: 1.3582e-05 - val_categorical_crossentropy: 1.3582e-05 - lr: 1.0000e-04
# Epoch 430/500
# 4/4 [==============================] - 0s 124ms/step - loss: 1.4993e-05 - categorical_crossentropy: 1.4993e-05 - val_loss: 1.3550e-05 - val_categorical_crossentropy: 1.3550e-05 - lr: 1.0000e-04
# Epoch 431/500
# 4/4 [==============================] - 0s 81ms/step - loss: 1.4954e-05 - categorical_crossentropy: 1.4954e-05 - val_loss: 1.3514e-05 - val_categorical_crossentropy: 1.3514e-05 - lr: 1.0000e-04
# Epoch 432/500
# 4/4 [==============================] - 0s 96ms/step - loss: 1.4914e-05 - categorical_crossentropy: 1.4914e-05 - val_loss: 1.3478e-05 - val_categorical_crossentropy: 1.3478e-05 - lr: 1.0000e-04
# Epoch 433/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.4881e-05 - categorical_crossentropy: 1.4881e-05 - val_loss: 1.3435e-05 - val_categorical_crossentropy: 1.3435e-05 - lr: 1.0000e-04
# Epoch 434/500
# 4/4 [==============================] - 0s 91ms/step - loss: 1.4845e-05 - categorical_crossentropy: 1.4845e-05 - val_loss: 1.3419e-05 - val_categorical_crossentropy: 1.3419e-05 - lr: 1.0000e-04
# Epoch 435/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.4806e-05 - categorical_crossentropy: 1.4806e-05 - val_loss: 1.3371e-05 - val_categorical_crossentropy: 1.3371e-05 - lr: 1.0000e-04
# Epoch 436/500
# 4/4 [==============================] - 1s 159ms/step - loss: 1.4769e-05 - categorical_crossentropy: 1.4769e-05 - val_loss: 1.3343e-05 - val_categorical_crossentropy: 1.3343e-05 - lr: 1.0000e-04
# Epoch 437/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.4735e-05 - categorical_crossentropy: 1.4735e-05 - val_loss: 1.3320e-05 - val_categorical_crossentropy: 1.3320e-05 - lr: 1.0000e-04
# Epoch 438/500
# 4/4 [==============================] - 0s 110ms/step - loss: 1.4700e-05 - categorical_crossentropy: 1.4700e-05 - val_loss: 1.3276e-05 - val_categorical_crossentropy: 1.3276e-05 - lr: 1.0000e-04
# Epoch 439/500
# 4/4 [==============================] - 0s 147ms/step - loss: 1.4660e-05 - categorical_crossentropy: 1.4660e-05 - val_loss: 1.3252e-05 - val_categorical_crossentropy: 1.3252e-05 - lr: 1.0000e-04
# Epoch 440/500
# 4/4 [==============================] - 0s 115ms/step - loss: 1.4627e-05 - categorical_crossentropy: 1.4627e-05 - val_loss: 1.3216e-05 - val_categorical_crossentropy: 1.3216e-05 - lr: 1.0000e-04
# Epoch 441/500
# 4/4 [==============================] - 0s 91ms/step - loss: 1.4587e-05 - categorical_crossentropy: 1.4587e-05 - val_loss: 1.3165e-05 - val_categorical_crossentropy: 1.3165e-05 - lr: 1.0000e-04
# Epoch 442/500
# 4/4 [==============================] - 0s 121ms/step - loss: 1.4556e-05 - categorical_crossentropy: 1.4556e-05 - val_loss: 1.3161e-05 - val_categorical_crossentropy: 1.3161e-05 - lr: 1.0000e-04
# Epoch 443/500
# 4/4 [==============================] - 0s 135ms/step - loss: 1.4519e-05 - categorical_crossentropy: 1.4519e-05 - val_loss: 1.3109e-05 - val_categorical_crossentropy: 1.3109e-05 - lr: 1.0000e-04
# Epoch 444/500
# 4/4 [==============================] - 0s 116ms/step - loss: 1.4486e-05 - categorical_crossentropy: 1.4486e-05 - val_loss: 1.3073e-05 - val_categorical_crossentropy: 1.3073e-05 - lr: 1.0000e-04
# Epoch 445/500
# 4/4 [==============================] - 0s 75ms/step - loss: 1.4444e-05 - categorical_crossentropy: 1.4444e-05 - val_loss: 1.3053e-05 - val_categorical_crossentropy: 1.3053e-05 - lr: 1.0000e-04
# Epoch 446/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.4416e-05 - categorical_crossentropy: 1.4416e-05 - val_loss: 1.3002e-05 - val_categorical_crossentropy: 1.3002e-05 - lr: 1.0000e-04
# Epoch 447/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.4381e-05 - categorical_crossentropy: 1.4381e-05 - val_loss: 1.2990e-05 - val_categorical_crossentropy: 1.2990e-05 - lr: 1.0000e-04
# Epoch 448/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.4343e-05 - categorical_crossentropy: 1.4343e-05 - val_loss: 1.2946e-05 - val_categorical_crossentropy: 1.2946e-05 - lr: 1.0000e-04
# Epoch 449/500
# 4/4 [==============================] - 1s 141ms/step - loss: 1.4308e-05 - categorical_crossentropy: 1.4308e-05 - val_loss: 1.2918e-05 - val_categorical_crossentropy: 1.2918e-05 - lr: 1.0000e-04
# Epoch 450/500
# 4/4 [==============================] - 0s 109ms/step - loss: 1.4264e-05 - categorical_crossentropy: 1.4264e-05 - val_loss: 1.2894e-05 - val_categorical_crossentropy: 1.2894e-05 - lr: 1.0000e-04
# Epoch 451/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.4237e-05 - categorical_crossentropy: 1.4237e-05 - val_loss: 1.2839e-05 - val_categorical_crossentropy: 1.2839e-05 - lr: 1.0000e-04
# Epoch 452/500
# 4/4 [==============================] - 0s 98ms/step - loss: 1.4206e-05 - categorical_crossentropy: 1.4206e-05 - val_loss: 1.2819e-05 - val_categorical_crossentropy: 1.2819e-05 - lr: 1.0000e-04
# Epoch 453/500
# 4/4 [==============================] - 0s 78ms/step - loss: 1.4161e-05 - categorical_crossentropy: 1.4161e-05 - val_loss: 1.2791e-05 - val_categorical_crossentropy: 1.2791e-05 - lr: 1.0000e-04
# Epoch 454/500
# 4/4 [==============================] - 0s 62ms/step - loss: 1.4134e-05 - categorical_crossentropy: 1.4134e-05 - val_loss: 1.2755e-05 - val_categorical_crossentropy: 1.2755e-05 - lr: 1.0000e-04
# Epoch 455/500
# 4/4 [==============================] - 0s 125ms/step - loss: 1.4093e-05 - categorical_crossentropy: 1.4093e-05 - val_loss: 1.2731e-05 - val_categorical_crossentropy: 1.2731e-05 - lr: 1.0000e-04
# Epoch 456/500
# 4/4 [==============================] - 0s 94ms/step - loss: 1.4062e-05 - categorical_crossentropy: 1.4062e-05 - val_loss: 1.2696e-05 - val_categorical_crossentropy: 1.2696e-05 - lr: 1.0000e-04
# Epoch 457/500
# 4/4 [==============================] - 0s 125ms/step - loss: 1.4028e-05 - categorical_crossentropy: 1.4028e-05 - val_loss: 1.2656e-05 - val_categorical_crossentropy: 1.2656e-05 - lr: 1.0000e-04
# Epoch 458/500
# 4/4 [==============================] - 0s 131ms/step - loss: 1.3987e-05 - categorical_crossentropy: 1.3987e-05 - val_loss: 1.2632e-05 - val_categorical_crossentropy: 1.2632e-05 - lr: 1.0000e-04
# Epoch 459/500
# 4/4 [==============================] - 0s 128ms/step - loss: 1.3957e-05 - categorical_crossentropy: 1.3957e-05 - val_loss: 1.2588e-05 - val_categorical_crossentropy: 1.2588e-05 - lr: 1.0000e-04
# Epoch 460/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.3928e-05 - categorical_crossentropy: 1.3928e-05 - val_loss: 1.2573e-05 - val_categorical_crossentropy: 1.2573e-05 - lr: 1.0000e-04
# Epoch 461/500
# 4/4 [==============================] - 0s 123ms/step - loss: 1.3890e-05 - categorical_crossentropy: 1.3890e-05 - val_loss: 1.2537e-05 - val_categorical_crossentropy: 1.2537e-05 - lr: 1.0000e-04
# Epoch 462/500
# 4/4 [==============================] - 0s 119ms/step - loss: 1.3856e-05 - categorical_crossentropy: 1.3856e-05 - val_loss: 1.2497e-05 - val_categorical_crossentropy: 1.2497e-05 - lr: 1.0000e-04
# Epoch 463/500
# 4/4 [==============================] - 0s 75ms/step - loss: 1.3819e-05 - categorical_crossentropy: 1.3819e-05 - val_loss: 1.2465e-05 - val_categorical_crossentropy: 1.2465e-05 - lr: 1.0000e-04
# Epoch 464/500
# 4/4 [==============================] - 0s 132ms/step - loss: 1.3780e-05 - categorical_crossentropy: 1.3780e-05 - val_loss: 1.2441e-05 - val_categorical_crossentropy: 1.2441e-05 - lr: 1.0000e-04
# Epoch 465/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.3748e-05 - categorical_crossentropy: 1.3748e-05 - val_loss: 1.2410e-05 - val_categorical_crossentropy: 1.2410e-05 - lr: 1.0000e-04
# Epoch 466/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.3722e-05 - categorical_crossentropy: 1.3722e-05 - val_loss: 1.2398e-05 - val_categorical_crossentropy: 1.2398e-05 - lr: 1.0000e-04
# Epoch 467/500
# 4/4 [==============================] - 0s 92ms/step - loss: 1.3687e-05 - categorical_crossentropy: 1.3687e-05 - val_loss: 1.2342e-05 - val_categorical_crossentropy: 1.2342e-05 - lr: 1.0000e-04
# Epoch 468/500
# 4/4 [==============================] - 0s 76ms/step - loss: 1.3650e-05 - categorical_crossentropy: 1.3650e-05 - val_loss: 1.2302e-05 - val_categorical_crossentropy: 1.2302e-05 - lr: 1.0000e-04
# Epoch 469/500
# 4/4 [==============================] - 1s 136ms/step - loss: 1.3619e-05 - categorical_crossentropy: 1.3619e-05 - val_loss: 1.2278e-05 - val_categorical_crossentropy: 1.2278e-05 - lr: 1.0000e-04
# Epoch 470/500
# 4/4 [==============================] - 0s 127ms/step - loss: 1.3582e-05 - categorical_crossentropy: 1.3582e-05 - val_loss: 1.2247e-05 - val_categorical_crossentropy: 1.2247e-05 - lr: 1.0000e-04
# Epoch 471/500
# 4/4 [==============================] - 0s 95ms/step - loss: 1.3549e-05 - categorical_crossentropy: 1.3549e-05 - val_loss: 1.2235e-05 - val_categorical_crossentropy: 1.2235e-05 - lr: 1.0000e-04
# Epoch 472/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.3517e-05 - categorical_crossentropy: 1.3517e-05 - val_loss: 1.2207e-05 - val_categorical_crossentropy: 1.2207e-05 - lr: 1.0000e-04
# Epoch 473/500
# 4/4 [==============================] - 0s 117ms/step - loss: 1.3485e-05 - categorical_crossentropy: 1.3485e-05 - val_loss: 1.2151e-05 - val_categorical_crossentropy: 1.2151e-05 - lr: 1.0000e-04
# Epoch 474/500
# 4/4 [==============================] - 0s 111ms/step - loss: 1.3448e-05 - categorical_crossentropy: 1.3448e-05 - val_loss: 1.2123e-05 - val_categorical_crossentropy: 1.2123e-05 - lr: 1.0000e-04
# Epoch 475/500
# 4/4 [==============================] - 0s 121ms/step - loss: 1.3414e-05 - categorical_crossentropy: 1.3414e-05 - val_loss: 1.2088e-05 - val_categorical_crossentropy: 1.2088e-05 - lr: 1.0000e-04
# Epoch 476/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1.3378e-05 - categorical_crossentropy: 1.3378e-05 - val_loss: 1.2072e-05 - val_categorical_crossentropy: 1.2072e-05 - lr: 1.0000e-04
# Epoch 477/500
# 4/4 [==============================] - 1s 151ms/step - loss: 1.3348e-05 - categorical_crossentropy: 1.3348e-05 - val_loss: 1.2048e-05 - val_categorical_crossentropy: 1.2048e-05 - lr: 1.0000e-04
# Epoch 478/500
# 4/4 [==============================] - 0s 115ms/step - loss: 1.3323e-05 - categorical_crossentropy: 1.3323e-05 - val_loss: 1.2016e-05 - val_categorical_crossentropy: 1.2016e-05 - lr: 1.0000e-04
# Epoch 479/500
# 4/4 [==============================] - 0s 117ms/step - loss: 1.3285e-05 - categorical_crossentropy: 1.3285e-05 - val_loss: 1.1976e-05 - val_categorical_crossentropy: 1.1976e-05 - lr: 1.0000e-04
# Epoch 480/500
# 4/4 [==============================] - 0s 110ms/step - loss: 1.3246e-05 - categorical_crossentropy: 1.3246e-05 - val_loss: 1.1929e-05 - val_categorical_crossentropy: 1.1929e-05 - lr: 1.0000e-04
# Epoch 481/500
# 4/4 [==============================] - 0s 130ms/step - loss: 1.3216e-05 - categorical_crossentropy: 1.3216e-05 - val_loss: 1.1913e-05 - val_categorical_crossentropy: 1.1913e-05 - lr: 1.0000e-04
# Epoch 482/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.3183e-05 - categorical_crossentropy: 1.3183e-05 - val_loss: 1.1897e-05 - val_categorical_crossentropy: 1.1897e-05 - lr: 1.0000e-04
# Epoch 483/500
# 4/4 [==============================] - 0s 116ms/step - loss: 1.3151e-05 - categorical_crossentropy: 1.3151e-05 - val_loss: 1.1857e-05 - val_categorical_crossentropy: 1.1857e-05 - lr: 1.0000e-04
# Epoch 484/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.3128e-05 - categorical_crossentropy: 1.3128e-05 - val_loss: 1.1833e-05 - val_categorical_crossentropy: 1.1833e-05 - lr: 1.0000e-04
# Epoch 485/500
# 4/4 [==============================] - 0s 90ms/step - loss: 1.3089e-05 - categorical_crossentropy: 1.3089e-05 - val_loss: 1.1802e-05 - val_categorical_crossentropy: 1.1802e-05 - lr: 1.0000e-04
# Epoch 486/500
# 4/4 [==============================] - 0s 79ms/step - loss: 1.3050e-05 - categorical_crossentropy: 1.3050e-05 - val_loss: 1.1750e-05 - val_categorical_crossentropy: 1.1750e-05 - lr: 1.0000e-04
# Epoch 487/500
# 4/4 [==============================] - 0s 114ms/step - loss: 1.3023e-05 - categorical_crossentropy: 1.3023e-05 - val_loss: 1.1738e-05 - val_categorical_crossentropy: 1.1738e-05 - lr: 1.0000e-04
# Epoch 488/500
# 4/4 [==============================] - 0s 97ms/step - loss: 1.2982e-05 - categorical_crossentropy: 1.2982e-05 - val_loss: 1.1718e-05 - val_categorical_crossentropy: 1.1718e-05 - lr: 1.0000e-04
# Epoch 489/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.2954e-05 - categorical_crossentropy: 1.2954e-05 - val_loss: 1.1674e-05 - val_categorical_crossentropy: 1.1674e-05 - lr: 1.0000e-04
# Epoch 490/500
# 4/4 [==============================] - 0s 133ms/step - loss: 1.2928e-05 - categorical_crossentropy: 1.2928e-05 - val_loss: 1.1659e-05 - val_categorical_crossentropy: 1.1659e-05 - lr: 1.0000e-04
# Epoch 491/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.2889e-05 - categorical_crossentropy: 1.2889e-05 - val_loss: 1.1627e-05 - val_categorical_crossentropy: 1.1627e-05 - lr: 1.0000e-04
# Epoch 492/500
# 4/4 [==============================] - 0s 88ms/step - loss: 1.2864e-05 - categorical_crossentropy: 1.2864e-05 - val_loss: 1.1579e-05 - val_categorical_crossentropy: 1.1579e-05 - lr: 1.0000e-04
# Epoch 493/500
# 4/4 [==============================] - 0s 120ms/step - loss: 1.2827e-05 - categorical_crossentropy: 1.2827e-05 - val_loss: 1.1559e-05 - val_categorical_crossentropy: 1.1559e-05 - lr: 1.0000e-04
# Epoch 494/500
# 4/4 [==============================] - 0s 85ms/step - loss: 1.2790e-05 - categorical_crossentropy: 1.2790e-05 - val_loss: 1.1539e-05 - val_categorical_crossentropy: 1.1539e-05 - lr: 1.0000e-04
# Epoch 495/500
# 4/4 [==============================] - 0s 93ms/step - loss: 1.2767e-05 - categorical_crossentropy: 1.2767e-05 - val_loss: 1.1500e-05 - val_categorical_crossentropy: 1.1500e-05 - lr: 1.0000e-04
# Epoch 496/500
# 4/4 [==============================] - 0s 100ms/step - loss: 1.2735e-05 - categorical_crossentropy: 1.2735e-05 - val_loss: 1.1484e-05 - val_categorical_crossentropy: 1.1484e-05 - lr: 1.0000e-04
# Epoch 497/500
# 4/4 [==============================] - 0s 86ms/step - loss: 1.2709e-05 - categorical_crossentropy: 1.2709e-05 - val_loss: 1.1460e-05 - val_categorical_crossentropy: 1.1460e-05 - lr: 1.0000e-04
# Epoch 498/500
# 4/4 [==============================] - 0s 91ms/step - loss: 1.2672e-05 - categorical_crossentropy: 1.2672e-05 - val_loss: 1.1404e-05 - val_categorical_crossentropy: 1.1404e-05 - lr: 1.0000e-04
# Epoch 499/500
# 4/4 [==============================] - 0s 82ms/step - loss: 1.2632e-05 - categorical_crossentropy: 1.2632e-05 - val_loss: 1.1380e-05 - val_categorical_crossentropy: 1.1380e-05 - lr: 1.0000e-04
# Epoch 500/500
# 4/4 [==============================] - 0s 77ms/step - loss: 1.2605e-05 - categorical_crossentropy: 1.2605e-05 - val_loss: 1.1357e-05 - val_categorical_crossentropy: 1.1357e-05 - lr: 1.0000e-04

# %%
class ModelWrapper():
    def __init__(self,model):
        self.model=model
    def predict_proba(self,X):
        if isinstance(X, pd.DataFrame):
            X=X.values
        Xnn=X.reshape(X.shape[0],1,X.shape[1])
        return self.model.predict(Xnn)
    def predict(self, X):
        return np.argmax(self.predict_proba(X),axis=1)
clf=ModelWrapper(model)

# %% [markdown]
# ## SHAP
# We calculate SHAP for datasets

# %%
fXtrain = trainX.reshape(150,1,200)

# %%
from tsproto.utils import getshap

shap_version='deep'
bg_size = 1000
stride=10
window_len=10
absshap = True
fXtrain,sv_tr = getshap(model=model, X=fXtrain, y=train_ynn,shap_version=shap_version,bg_size = bg_size, stride=stride, window_len=window_len, absshap = absshap, shuffle=False)
# Out:
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [markdown]
# ## Visualize SHAP
# In this section we can see that the network focused on correct parts of the time-series.
# In this toy example, it is sufficient to look at SHAP-visualizations to spot the difference, but in case of hundreds of dimensions and more complex problems, prototypes are more useful.

# %%
from  tsproto.plots import plot_smooth_colored_line
indexer = clf.predict(trainX)
shapclass = []
if absshap == False:
    for i in range(0,len(trainX)):
        best_index = indexer[i]
        shapclass.append([sv_tr[best_index][i,:]])
        
    shapclass=np.concatenate(shapclass)
else:
    shapclass  = sv_tr[:,0,:]

    fig, axes =plt.subplots(2,1,figsize=(12,6))

    for i in range(0,10):
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==0][i], color_values=shapclass[train_y==0][i], resolution=1000, ax=axes[0],add_cbar=(i==0))
        plot_smooth_colored_line(x_values=x, y_values=trainX[train_y==1][i], color_values=shapclass[train_y==1][i], resolution=1000, ax=axes[1],add_cbar=(i==0))

for ax in axes:
    ax.set_ylim([-2, 2])
# Out:
# 5/5 [==============================] - 0s 19ms/step

# %% [markdown]
# ## Tsproto
# Now, lets try to apply TSProto to see if it is able to find the prototype and summarize them correctly to show what logical relation is between them and the model prediction

# %%
trainXproto = trainX.reshape((trainX.shape[0], trainX.shape[1],1))
shapclassXproto = shapclass.reshape((shapclass.shape[0], shapclass.shape[1],1))

# %%
from tsproto.models import *
im  = InterpretableModel()
pe = PrototypeEncoder(clf, n_clusters=4, min_size=50, method='dtw',
                              descriptors=['existance','duration','frequency'],
                      jump=1, changepoint_sensitivity=1,multiplier=1,n_jobs=-1,
                      verbose=1)
ohe_train, features, target_ohe,weights = pe.fit_transform(trainXproto,shapclassXproto)
acc,prec,rec,f1,iclf = im.fit_or_predict(ohe_train, features, target_ohe,intclf=None, verbose=0, max_depth=2, min_samples_leaf=0.05,
                       weights=None)
# Out:
# Dataset shape: (150, 200, 1)
# Calculating changepoints...
# Dim: 0
# 2
# 2
# 2
# 2
# Before filtering no sigids: 150, uniqu 0
# Unique indexes: 150 vs max+1: 150
# After removing , no sigids: 150, uniqu 0
# Done in 1.7377004623413086.
# Clustering data
# (226, 115, 1)
# (226, 115, 1)
# Shape of data for clustering: (226, 115, 1)
# Clustering data
# X_bis shape: (226, 115, 1) for method=dtw
# Done in 6.3563477993011475.
# OHE time series
# Shape weights: (150,)
# Len X=150 vs len of train = 150
# 5/5 [==============================] - 0s 16ms/step
# Done in 0.2020702362060547.

# %% [markdown]
# ## Visualize interpretable model
# We can easily see that the TSProto has found the sine wave at the beginning of the sample, marked it as prototype and correctly identified that its existence is not enough to treat the sample as a class 1 sample, additional frequency context has to be added in order to distinguish these two

# %%
from  tsproto.plots import *
ds_final = ohe_train.copy()
dot = export_decision_tree_with_embedded_histograms(decision_tree=iclf, 
                                              dataset=ds_final, 
                                              target_name='target', 
                                              feature_names=features, 
                                              filename='synthetic', 
                                              proto_encoder=pe, figsize=(6,3))

from IPython.display import SVG, Image
Image('synthetic.png')
# Out:
# [2 1]
# Shapes: (226, 115, 1) vs shap: (2, 115, 1) TODO: take IDS of a single sample that is plotted
# color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Decision Tree exported to synthetic with embedded histograms successfully.
